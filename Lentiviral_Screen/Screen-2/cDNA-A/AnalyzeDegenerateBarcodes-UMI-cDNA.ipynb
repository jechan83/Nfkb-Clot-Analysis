# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 5847

# %%
afile = pysam.AlignmentFile("./final.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %%
totalUMI = 0
for cellUMI in cellbyUMI:
    totalUMI += len(cellbyUMI[cellUMI])
print(totalUMI)
# Out:
# 3587567

# %%
print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))
# Out:
# In Whitelist UMI: 5847
# Out Whitelist UMI: 500553
# In Whitelist Reads: 248132225
# Out Whitelist Reads: 66332035

# %%
import pickle
with open('cellbyUMI.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 44

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 5847

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 5599

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] < threshold: 
                print("Not past threshold: %s" % str(newUMI))
            else:
                ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
#_ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')

plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (8.030753401166114, 1, 987, 1)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(count, bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 2082

# %%
len(whitelist)
# Out:
# 5847

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 3459

# %%
poorUMI
# Out:
# [[(1, ('TTAATTAG', 'GGAGGAAAGCGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGTGGTTGGGGAAA')),
#   (1, ('GGTAGGGA', 'CTAATAAGGCTTTTTGGAGAA')),
#   (1, ('GGTAGGGA', 'CCCTTAATGATTTTTCATTAA')),
#   (1, ('CTGAATCT', 'TCTTAAATTTCTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA'))],
#  [(1, ('GTACTTGC', 'TTTTAAACGGGATTTATTTAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TTCTTAATTTGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TGGTAAATGGATTTTTTGGAA')),
#   (1, ('CGTTCAAG', 'TTTGGAAGTTAATTAGTATAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'CGATGAATCCTATTGGCCGAA'))],
#  [(3, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('TTAATTAG', 'CATCCAAAACCTTTCCAACAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TGCAAAATGGTATTCGATTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGCGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('GGTAGGGA', 'GATTCAATGGTCTTGCTAAAA')),
#   (1, ('GGTAGGGA', 'AAATAAAATAAGTTCTTTAAA')),
#   (1, ('CTGAATCT', 'TAAAAAACATTTTTTATTCAA')),
#   (1, ('CTGAATCT', 'AAGACAAAACAATTAAAGAAA')),
#   (1, ('CGTTTCCT', 'AGATTAAGCGTCTTACAGTAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGTTCAAG', 'ATAATAAAACTATTAGCGGAA')),
#   (1, ('CGTTAGGG', 'CCTGAAACCAAGTTCAGGCAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA'))],
#  [(3, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA')),
#   (2, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (2, ('GGTAGGGA', 'GTAAGAACCTTTTTACATGAA')),
#   (2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (2, ('CCATTACT', 'ACCCCAACTGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATGATGTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGGGGGTTGCGGCAA')),
#   (1, ('TTAATTAG', 'AAGAAAACCCAATTAAGCAAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCACCCAA')),
#   (1, ('GTACTTGC', 'AGAATAAGTGTATTGCATTAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('GGTAGGGA', 'GAATGAAGACACTTTGTAAAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTTCAAAGGATTTTGTTTCAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CTGAATCT', 'TAAAAAACATTTTTTATTCAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTGGAAATCGTTTTTGTTCAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA'))],
#  [(1, ('TTAATTAG', 'TTTTAAATTTTTTTCTGTCAA')),
#   (1, ('GTACTTGC', 'TACAAAAGTTCATTCATCTAA')),
#   (1, ('GGTAGGGA', 'TGATTAATGTGGTTCGCTGAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGAATAAAATAATTTAGGAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'))],
#  [(1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGGGATTGGTGGAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGTTAGGG', 'ACTGAAACGTTTTTTTTCGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA'))],
#  [(2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('TTAATTAG', 'TGTTTAATGATTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('GTACTTGC', 'AGAATAAGTGTATTGCATTAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('CTGAATCT', 'ACACCAACACCATTAAACAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATGGTGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGGGTAAGGGGGTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGAGAATGAGGTTTGTGTAA'))],
#  [(1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CTGAATCT', 'TCTTAAATTTCTTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GGACCAATAATGTTAAGTTAA')),
#   (1, ('TTAATTAG', 'AACAAAAGAAATTTACAAAAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGTTAGGG', 'CTGTTAATTGAATTAACGAAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA'))],
#  [(1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('ACAGAGCC', 'TCTATAATTTGGTTGTTGGAA'))],
#  [(3, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('TTAATTAG', 'TGAGCAAGGGGGTTGGGACAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('GCCTACGT', 'AAAAAAAATAAATTAAAAAAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA'))],
#  [(1, ('TGTCTAGT', 'TCTTTAACGTTATTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'TGTACAAGAGTATTAAAAAAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'CCATAAAAAATATTTCTGAAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GTCCCAAGGTTTTTCCGTCAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'ACAGAAACGAGATTGGAATAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('GGTAGGGA', 'CTTAAAAGATCGTTATGCTAA')),
#   (1, ('GCCTACGT', 'GTAAAAATAAAATTAACAGAA')),
#   (1, ('CTGAATCT', 'TTATAAAGATCTTTGTATTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCCAATTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'TTTTGAACTTCTTTCACTAAA')),
#   (1, ('ACAGAGCC', 'TCTATAATTTGGTTGTTGGAA'))],
#  [(2, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('TTAATTAG', 'GGCGAAAAAGTGTTCTAATAA')),
#   (1, ('TGTCTAGT', 'ACAGAAACGAGATTGGAATAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('GGTAGGGA', 'ACTTCAAGGTTATTTAACGAA')),
#   (1, ('CGTTAGGG', 'GGATCAAGCGGGTTTGCTTAA')),
#   (1, ('CGTTAGGG', 'AAATGAACTGATTTAGATAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTGTAA')),
#   (1, ('CGGGAATG', 'TCACTAATTAGTTTTTCTTAA'))],
#  [(1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('CCATTACT', 'TGGAGAATGAGGTTTGTGTAA')),
#   (1, ('ACAGAGCC', 'TCTATAATTTGGTTGTTGGAA'))],
#  [(2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('TTAATTAG', 'TTGGTAATGATTTTACATGAA')),
#   (1, ('TTAATTAG', 'TGCAAAATGGTATTCGATTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAAAGAACAACATTCAGTCAA')),
#   (1, ('CGTTAGGG', 'ACTGAAACGTTTTTTTTCGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTATTTTAA'))],
#  [(1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('GGTAGGGA', 'GATTCAATGGTCTTGCTAAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'CGGCCAACCCCATTCTTACAA'))],
#  [(3, ('ACAGAGCC', 'ATAGAAAATCCCTTTCTCGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAACTGGGTTAGTATAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA'))],
#  [(2, ('ACACGTGA', 'TTTTTAATTTTTTTAGTCCAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CTGAATCT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACACCAACACCATTAAACAAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGTTCAAG', 'TTTGGAAGTTAATTAGTATAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('ACACGTGA', 'TGTTGAAATGTGTTTGGGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATATTTTTTTTGCAA')),
#   (1, ('GGTAGGGA', 'GGGATAAGTGTTTTTCCGCAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GGTAGGGA', 'AAATAAAATAAGTTCTTTAAA')),
#   (1, ('CTGAATCT', 'TCTTAAATTTCTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TCGTAAAGCTTTTTAGGGGAA')),
#   (1, ('ACACGTGA', 'CTCTAAAACCGTTTCGTCGAA'))],
#  [(3, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TCGCAAAAATTTTTCTCTCAA')),
#   (1, ('TTAATTAG', 'GGGGAAAGGAGATTGATGTAA')),
#   (1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('TTAATTAG', 'CATCCAAAACCTTTCCAACAA')),
#   (1, ('GTACTTGC', 'TACAAAAGTTCATTCATCTAA')),
#   (1, ('GGTAGGGA', 'AGAGGAACCGTATTTTAGTAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTATAAATCTTGTTAGTTGAA')),
#   (1, ('ACAGAGCC', 'GTGATAACCTTTTTGGGTAAA'))],
#  [(1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAGGGTGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'CATCCAAAACCTTTCCAACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGGGAATG', 'TCACTAATTAGTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTAGTCCAA'))],
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('CTGAATCT', 'AAAAGAACAACATTCAGTCAA'))],
#  [(8, ('ACAGAGCC', 'GTAATAATTCTATTTATATAA')),
#   (5, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TGTGAAATTAGTTTTAGATAA')),
#   (1, ('TTAATTAG', 'TCGCAAAAATTTTTCTCTCAA')),
#   (1, ('TTAATTAG', 'ACATCAACATAATTAAGCCAA')),
#   (1, ('GGTAGGGA', 'GCATGAATTGTATTCCTGCAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCTCTTCAACCAA')),
#   (1, ('CGTTAGGG', 'ACTGAAACGTTTTTTTTCGAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('ACAGAGCC', 'GTGATAACCTTTTTGGGTAAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'))],
#  [(2, ('ACAGAGCC', 'TGTAGAATCTAGTTGTTCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGTGGTTGGCGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA'))],
#  [(2, ('TTAATTAG', 'TACCTAATACTTTTCCAACAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA')),
#   (2, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('GTACTTGC', 'TACAAAAGTTCATTCATCTAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAATCCGTTCGGTCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTGAA')),
#   (1, ('CCATTACT', 'TGGAGAATGAGGTTTGTGTAA')),
#   (1, ('ACAGAGCC', 'CATTCAATGCCTTTTATCGAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TTGTAAAAATTGTTGTGAAAA')),
#   (1, ('GGTAGGGA', 'GGGAAAATTGAGTTTATTTAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGTGTTTGGCGGAA')),
#   (1, ('GCCTACGT', 'AAAAAAAATAAATTAAAAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GTTTAAAGGTTATTTTCTGAA')),
#   (1, ('ACACGTGA', 'CTCTAAAACCGTTTCGTCGAA'))],
#  [(1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TTCCGAAACTTTTTGTTTTAA'))],
#  [(1, ('TTAATTAG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TGAGGAAGGATGTTGGGATAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('CTGAATCT', 'ACACCAACACCATTAAACAAA')),
#   (1, ('CGTTAGGG', 'AGAACAAAGACCTTGTTGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'AAAAGAATACAATTCTCGTAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('CTGAATCT', 'TCGTAAAGCTTTTTAGGGGAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CCATTACT', 'CTCCGAACTATCTTTCTCCAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGCGAAAAAGTGTTCTAATAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA'))],
#  [(1, ('TTAATTAG', 'TGTTTAATGATTTTATTTTAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGGGAATG', 'GTTGTAAGTGGGTTGGTGGAA')),
#   (1, ('CGGGAATG', 'GAGGGAAGGTGGTTGGACCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'AAAAGAATACAATTCTCGTAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'GGAGTAAATCGATTGGTGGAA'))],
#  [(1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA'))],
#  [(3, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCTCCCAA')),
#   (1, ('TTAATTAG', 'TTCTTAATTTGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TGAGAAAAAAAATTATAAGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GAAGGAAGGGGGTTGGAAGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'ATCAAAACCCCATTCAGCAAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACACGTGA', 'CGGCCAACCCCATTCTTACAA'))],
#  [(1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA'))],
#  [(3, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GTTTGAACACACTTTTATGAA')),
#   (1, ('ACACGTGA', 'CTCTAAAACCGTTTCGTCGAA'))],
#  [(3, ('CGGGAATG', 'GGAATAAAATAATTTAGGAAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (2, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAATTTGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'GGGGAAAGGAGATTGATGTAA')),
#   (1, ('TTAATTAG', 'GAATAAATCATATTCTAAAAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'CATGAAACTCTATTTATCGAA')),
#   (1, ('GCCTACGT', 'AAAAAAATAAAATTAAAAAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCGAA')),
#   (1, ('CGTTCAAG', 'TTTCTAATTCAATTAAATAAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAATCCGTTCGGTCAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CGTTAGGG', 'AAATGAACTGATTTAGATAAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TAGTTAACGTTGTTGAAATAA')),
#   (1, ('CCATTACT', 'CCCATAATCCATTTCCCGAAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'CCATAAAAAATATTTCTGAAA')),
#   (1, ('ACACGTGA', 'TAAGAAAACGCATTGGGGGAA')),
#   (1, ('ACACGTGA', 'CACTTAACCTTCTTCTTGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('GGTAGGGA', 'GATTCAATGGTCTTGCTAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA'))],
#  [(2, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TTGTGAATGTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'AAATCAAATAAATTAAAGAAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTTTTTTAA'))],
#  [(1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('GGTAGGGA', 'GGAAGAAGGTGATTGTCCAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'TTTTGAACTTCTTTCACTAAA')),
#   (1, ('ACAGAGCC', 'CCATAAAAAATATTTCTGAAA'))],
#  [(1, ('CTGAATCT', 'TCGTAAAGCTTTTTAGGGGAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA'))],
#  [(3, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (2, ('GGTAGGGA', 'TCTAAAATTTGCTTTCTTAAA')),
#   (1, ('TTAATTAG', 'GGCGAAAAAGTGTTCTAATAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TGGTGAACTTTGTTAATGCAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGTGGTTGGGGAAA')),
#   (1, ('TCTGGGGC', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TACATAATCTATTTTGTGCAA')),
#   (1, ('GCCTACGT', 'TGGTTAATGTCGTTTTGTTAA')),
#   (1, ('GCCTACGT', 'TGGGGAATGTGGTTTTGGTAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('CCATTACT', 'CCCCCAATCACCTTTTACGAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'AGAGAAACGTAGTTCGAGAAA')),
#   (1, ('ACAGAGCC', 'AGTAGAATATCATTCTCTAAA')),
#   (1, ('ACACGTGA', 'TAAGAAAACGCATTGGGGGAA'))],
#  [(1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TATCAAAGGGCGTTGACGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTGAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(2, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTAGATGAA')),
#   (1, ('TTAATTAG', 'AAAAGAATACAATTCTCGTAA')),
#   (1, ('GTACTTGC', 'TTTTAAACGGGATTTATTTAA'))],
#  [(1, ('TTAATTAG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'GAATGAAGACACTTTGTAAAA')),
#   (1, ('GGTAGGGA', 'ACCTTAATACAGTTCCGGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CTGAATCT', 'TCTTAAATTTCTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'GGAATAAAATAATTTAGGAAA')),
#   (1, ('ACAGAGCC', 'CCATAAAAAATATTTCTGAAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'AGAAGAAGTTGATTCTCGTAA'))],
#  [(3, ('TTAATTAG', 'TTTGGAATGATGTTTTTTTAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTCTTAATTTGTTTCTTTGAA')),
#   (1, ('GGTAGGGA', 'CTAATAAGGCTTTTTGGAGAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('ACACGTGA', 'GGGGTAATTTTTTTGTTACAA'))],
#  [(1, ('TTAATTAG', 'TTGGTAATGATTTTACATGAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('ACACGTGA', 'GGAGTAAATCGATTGGTGGAA'))],
#  [(2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('GTACTTGC', 'GATTGAATTACTTTGTCCAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGTGGTTGGCGGAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA'))],
#  [(1, ('TCTGGGGC', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GCCAATCG', 'CTATGAATCATCTTGCATGAA')),
#   (1, ('CGTTTCCT', 'AGATTAAGCGTCTTACAGTAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('GGTAGGGA', 'CCCTTAATGATTTTTCATTAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCGCAA')),
#   (1, ('ACACGTGA', 'CAGCCAAACTAGTTATAATAA'))],
#  [(2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('TTAATTAG', 'TTATCAATAATTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'GGGTAAAGTAGGTTATAGGAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('GGTAGGGA', 'CTAATAAGGCTTTTTGGAGAA')),
#   (1, ('GGTAGGGA', 'CATGGAAGGTCGTTAGGAGAA')),
#   (1, ('CGGGAATG', 'TCACTAATTAGTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCCAATTCCCCCAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(2, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'CCACCAACGCAATTACACCAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('CTGAATCT', 'TTCTTAACTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('CAGTGCAT', 'AATCCAAAAGCATTAATACAA'))],
#  [(1, ('TTAATTAG', 'TTTGGAATGATGTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA'))],
#  [(3, ('CGTTAGGG', 'CTGTTAATTGAATTAACGAAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('TTAATTAG', 'ACATCAACATAATTAAGCCAA')),
#   (1, ('GGTAGGGA', 'CTTGGAAATAGATTCTTCTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCGAA')),
#   (1, ('CGTTTCCT', 'AGATTAAGCGTCTTACAGTAA')),
#   (1, ('CGTTAGGG', 'CGTAGAATGATATTAAAACAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'CCTTGAAATATATTCACGAAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA')),
#   (1, ('TTAATTAG', 'TTATCAATAATTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'TGTTTAATGATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'CTCAAAATACCATTCTATCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGGGATTGGTGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACACGTGA', 'CACTTAACCTTCTTCTTGAAA'))],
#  [(1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('ACACGTGA', 'CGGCCAACCCCATTCTTACAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAATTTGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GATGGAATTTTGTTTAATTAA')),
#   (1, ('GGTAGGGA', 'TGGCGAACGAGATTGGAGGAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGTGGTTGGCGGAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCTCTTCAACCAA')),
#   (1, ('CGTTCAAG', 'ATAATAAAACTATTAGCGGAA')),
#   (1, ('CGTTAGGG', 'ACTGAAACGTTTTTTTTCGAA')),
#   (1, ('CGGGAATG', 'TATCAAAGGGCGTTGACGGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'ATCAAAACCCCATTCAGCAAA')),
#   (1, ('CCATTACT', 'CCCCTAAGCTCCTTCCGCAAA')),
#   (1, ('ACACGTGA', 'AGAGAAAGCGCATTGAAAGAA'))],
#  [(2, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (2, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TGTTTAATGATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGCGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGTGGTTGGGGAAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('GGTAGGGA', 'CATGAAACTCTATTTATCGAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGAGGGAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCGAA')),
#   (1, ('CTGAATCT', 'AAATCAAATAAATTAAAGAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACAGAGCC', 'CCATAAAAAATATTTCTGAAA')),
#   (1, ('ACACGTGA', 'CGGCCAACCCCATTCTTACAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'CATCCAAAACCTTTCCAACAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('CGTTCAAG', 'TTTCTAATTCAATTAAATAAA')),
#   (1, ('CGGGAATG', 'CCCGCAACCCCCTTTGCCCAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('ACACGTGA', 'TGTTGAAATGTGTTTGGGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA'))],
#  [(3, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (2, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'CCCGCAAACCCCTTTCACTAA')),
#   (1, ('TGTCTAGT', 'CCACCAACGCAATTACACCAA')),
#   (1, ('GTACTTGC', 'TTTTAAACGGGATTTATTTAA')),
#   (1, ('GTACTTGC', 'TACAAAAGTTCATTCATCTAA')),
#   (1, ('GTACTTGC', 'GATTGAATTACTTTGTCCAAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('GCCTACGT', 'AACAGAATTAATTTTAAAAAA')),
#   (1, ('CTGAATCT', 'TTATAAAGATCTTTGTATTAA')),
#   (1, ('CTGAATCT', 'ACCAAAAAACAATTCTCTCAA')),
#   (1, ('CTGAATCT', 'AAATCAAATAAATTAAAGAAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGTTAGGG', 'TATCTAAGAAATTTTTTGGAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'AAAAAAAAGAGATTGGATAAA')),
#   (1, ('ACACGTGA', 'TGTTGAAATGTGTTTGGGTAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGGGGGTTGCGGCAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GGTAGGGA', 'ACCTTAATACAGTTCCGGTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'AGACAAAAGGAATTAAGAAAA'))],
#  [(3, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('TTAATTAG', 'TGAGAAAAAAAATTATAAGAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGATGTTATAGTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTTTTAATGTTGTTTTCTGAA')),
#   (1, ('CTGAATCT', 'GTATGAAGTTGCTTTTTGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCTCTTCAACCAA')),
#   (1, ('CGTTCAAG', 'TTTCTAATGTAGTTCCGTCAA')),
#   (1, ('CGGGAATG', 'TGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'TCACTAATTAGTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACTGCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'AGGTTAATGAGGTTATGTTAA')),
#   (1, ('ACACGTGA', 'GGGTTAAAGGGTTTGTTTGAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('GGTAGGGA', 'ACTTCAAGGTTATTTAACGAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCTCTTCAACCAA')),
#   (1, ('CTGAATCT', 'ACCAAAAAACAATTCTCTCAA'))],
#  [(2, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (2, ('CGGGAATG', 'CCCCCAAGCCCCTTCTCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTTTTTCAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('CTGAATCT', 'TCGTAAAGCTTTTTAGGGGAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCTCCAACGTCCTTCCCCTAA')),
#   (1, ('CAGTGCAT', 'AATCCAAAAGCATTAATACAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACACGTGA', 'GGGGTAATTTTTTTGTTACAA'))],
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTATCAATAATTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'TGAGCAAGGGGGTTGGGACAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAATCCGTTCGGTCAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTATCGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTTCAAAGGATTTTGTTTCAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA'))],
#  [(2, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (2, ('TGTCTAGT', 'TTTGTAATTTTTTTTTTTTAA')),
#   (2, ('GTACTTGC', 'TTATAAATAGGCTTTTATGAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATGATGTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TTAATTAG', 'GGCGAAAAAGTGTTCTAATAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGATGTTAGGAGAA')),
#   (1, ('TTAATTAG', 'ACATCAACATAATTAAGCCAA')),
#   (1, ('TGTCTAGT', 'TCTTTAACGTTATTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('GGTAGGGA', 'CATTCAATCGCCTTCGAATAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('GCCTACGT', 'AAAAAAAATAAATTAAAAAAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCGCCTTCCCGCAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCTCTTCAACCAA')),
#   (1, ('CTGAATCT', 'AAAGTAACAAAATTAAAAAAA')),
#   (1, ('CGTTTCCT', 'TCCAAAACCACCTTAAGCAAA')),
#   (1, ('CGTTCAAG', 'CATTGAACCTTATTGTACAAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'CCCGCAACCCCCTTTGCCCAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'TTCCGAAACTTTTTGTTTTAA')),
#   (1, ('ACAGAGCC', 'TGTAGAATCTAGTTGTTCTAA')),
#   (1, ('ACAGAGCC', 'AAAAAAAATCAATTCTTCTAA')),
#   (1, ('ACACGTGA', 'GGATGAAGGCTGTTGGTAGAA')),
#   (1, ('ACACGTGA', 'CGATGAATCCTATTGGCCGAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCGCCTTCGCATAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGTTCAAG', 'TTTCTAATGTAGTTCCGTCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA'))],
#  [(1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTTTTTTAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTTTTTCTGTCAA')),
#   (1, ('TTAATTAG', 'TTTGTAATTATTTTTTTATAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCGAA')),
#   (1, ('CCATTACT', 'AGGGAAAAGAGGTTCAATGAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTCAATTTTATTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('GCCAATCG', 'GTGAAAATAGTTTTTTCCTAA')),
#   (1, ('CTGAATCT', 'TTTTAAATGTTTTTGTATTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'GGAATAAAATAATTTAGGAAA')),
#   (1, ('CGGGAATG', 'AACAAAAACGCCTTCGTAAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTAGTCCAA'))],
#  [(3, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('TTAATTAG', 'GGCGAAAAAGTGTTCTAATAA')),
#   (2, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (2, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAATTTGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TTATAAATATTTTTCTCATAA')),
#   (1, ('TTAATTAG', 'TGTTTAATGATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'TACAAAAGTTCATTCATCTAA')),
#   (1, ('GTACTTGC', 'AACGCAATACATTTAGATAAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('CGTTAGGG', 'ACTGAAACGTTTTTTTTCGAA')),
#   (1, ('CGTTAGGG', 'AAATGAACTGATTTAGATAAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'TTGTGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACTCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'AGCAAAATACGCTTTTAAAAA')),
#   (1, ('ACACGTGA', 'GGAAAAAATGAGTTAGGGGAA'))],
#  {('GGTAGGGA', 'CTTAAAAGATCGTTATGCTAA'): 1},
#  [(2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGATGTTGTAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGGGATTGGTGGAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CGTTTCCT', 'TCCAAAACCGCCTTAAGCAAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'TTCCGAAACTTTTTGTTTTAA')),
#   (1, ('ACAGAGCC', 'TCTATAATTTGGTTGTTGGAA'))],
#  [(1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'AGGGAAAAGAGGTTCAATGAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTTTTGCAA')),
#   (1, ('TTAATTAG', 'TTGGTAATGATTTTACATGAA')),
#   (1, ('TTAATTAG', 'TGAGCAAGGGGGTTGGGACAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGATGTTGTAAGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'TACAAAAGTTCATTCATCTAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('CTGAATCT', 'TTCCTAATCCCTTTTCTTCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'))],
#  [(1, ('CTGAATCT', 'TCTTAAATTTCTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'))],
#  [(3, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (2, ('ACACGTGA', 'GGGGTAATTTTTTTGTTACAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'TGAGCAAGGGGGTTGGGACAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGATGTTGTAAGAA')),
#   (1, ('TTAATTAG', 'GGACCAATAATGTTAAGTTAA')),
#   (1, ('TTAATTAG', 'ACATCAACATAATTAAGCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'AACGCAATACATTTAGATAAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGTTAGGG', 'AAATGAACTGATTTAGATAAA')),
#   (1, ('CGGGAATG', 'TCTTTAATTTTTTTTTTTGAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACACGTGA', 'TGTTGAAATGTGTTTGGGTAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA'))],
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACTATGTTGTAAGAA')),
#   (1, ('GTACTTGC', 'ATTTGAACTGTTTTGTTAGAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'GTGGGAATGGGTTTGGTGGAA'))],
#  [(2, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGATGTTGTAAGAA')),
#   (1, ('TTAATTAG', 'GATGGAATTTTGTTTAATTAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'CCACCAACGCAATTACACCAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTGAA')),
#   (1, ('CGGGAATG', 'TTGGAAATCGTTTTTGTTCAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'))],
#  [(3, ('TTAATTAG', 'TTTTAAATTTTTTTATTTTAA')),
#   (1, ('CTGAATCT', 'TAAAAAACATTTTTTATTCAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('TTAATTAG', 'AAAAGAATACAATTCTCGTAA')),
#   (1, ('GTACTTGC', 'TTTTAAACGGGATTTATTTAA')),
#   (1, ('CTGAATCT', 'TTCTTAACTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CAGTGCAT', 'AATCCAAAAGCATTAATACAA'))],
#  {('ACACGTGA', 'GGGGTAATTTTTTTGTTACAA'): 3},
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA')),
#   (1, ('TTAATTAG', 'TGAGGAAGGATGTTGGGATAA')),
#   (1, ('TTAATTAG', 'GGTGAAATTATTTTATATGAA')),
#   (1, ('GGTAGGGA', 'TGTACAAGAGTATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'GGGAAAATTGAGTTTATTTAA')),
#   (1, ('GGTAGGGA', 'CCCTTAATGATTTTTCATTAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('CTGAATCT', 'TTATAAAGATCTTTGTATTAA')),
#   (1, ('CTGAATCT', 'TGAAAAAAAAAATTAATATAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCGCAACCCCCTTTGCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TGGAGAATGAGGTTTGTGTAA')),
#   (1, ('CCATTACT', 'CGGCCAAGCACATTTTGGTAA')),
#   (1, ('ACAGAGCC', 'GTGATAAGTTGCTTCGTAGAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'TCTTTAACGTTATTTGTTTAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAATCCGTTCGGTCAA')),
#   (1, ('ACACGTGA', 'TGTTGAAATGTGTTTGGGTAA'))],
#  [(4, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('GGTAGGGA', 'GTAAGAACCTTTTTACATGAA'))],
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (2, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('TTAATTAG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATGATGTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTCCAAACATTATTCCCTCAA')),
#   (1, ('TTAATTAG', 'TGTTTAATGATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'AAAAGAATACAATTCTCGTAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GCCAATCG', 'GATGAAACCTTGTTCTAATAA')),
#   (1, ('CTGAATCT', 'TTTTTAAACTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CGTTTCCT', 'AGATTAAGCGTCTTACAGTAA')),
#   (1, ('CGTTAGGG', 'CTGTTAATTGAATTAACGAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'TCTATAATTTGGTTGTTGGAA')),
#   (1, ('ACAGAGCC', 'TATATAAATTCTTTCATAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTAGTCCAA'))],
#  [(1, ('TTAATTAG', 'TTATTAATTATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TGAGCAAGGGGGTTGGGACAA')),
#   (1, ('GGTAGGGA', 'ATTTAAAGCCTCTTTTTGTAA')),
#   (1, ('CTGAATCT', 'AAAAGAACAACATTCAGTCAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGATACTTTGTAGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACTGCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'AAGCAAACCACCTTACCGCAA'))],
#  [(2, ('ACACGTGA', 'TAAGAAAACGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TATCAAAGTTACTTACATAAA')),
#   (1, ('CGTTTCCT', 'TCTATAACTCGTTTTTTTAAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CAGTGCAT', 'AATCCAAAAGCATTAATACAA'))],
#  [(1, ('TTAATTAG', 'TTTGTAATTTTGTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGTTTGTGTGAA')),
#   (1, ('CTGAATCT', 'TTCTTAACTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA'))],
#  [(1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('TTAATTAG', 'GTCCCAAGGTTTTTCCGTCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GATTCAATGGTCTTGCTAAAA')),
#   (1, ('CTGAATCT', 'TCTTAAATTTCTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAATCCGTTCGGTCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'TGGTGAACTTTGTTAATGCAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'ACAGAAACGAGATTGGAATAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('ACAGAGCC', 'ATAGAAAATCCCTTTCTCGAA')),
#   (1, ('ACAGAGCC', 'AGCAAAATACGCTTTTAAAAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TCCCAAATCCCATTCCCTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TCTTTAATTTTTTTTTTTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA'))],
#  [(2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TGAGAAAAAAAATTATAAGAA')),
#   (1, ('TTAATTAG', 'TCCCAAATCCCATTCCCTCAA')),
#   (1, ('TTAATTAG', 'AAAAGAATACAATTCTCGTAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGAGGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'ATCAAAACCCCATTCAGCAAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('CCATTACT', 'CGGCCAAGCACATTTTGGTAA')),
#   (1, ('ACACGTGA', 'CGGCCAACCCCATTCTTACAA'))],
#  [(1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGATGTTATAGTAA')),
#   (1, ('TTAATTAG', 'GACACAAGGCAGTTGAAATAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'CCGCCAACCTCCTTCCTCTAA')),
#   (1, ('GGTAGGGA', 'TACATAATCTATTTTGTGCAA')),
#   (1, ('GCCTACGT', 'GGGGAAATTTAGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTTCAAAGGATTTTGTTTCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TCACTAATTAGTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCCACAACCCCCTTTGCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CATAGTCA', 'TATTTAATTTTATTTAGACAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTTTTTTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('GGTAGGGA', 'TGGCGAACGAGATTGGAGGAA')),
#   (1, ('CTGAATCT', 'TAAAAAACATTTTTTATTCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TATCAAAGGGCGTTGACGGAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('TTAATTAG', 'TCCCAAATCCCATTCCCTCAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'ACCTTAATACAGTTCCGGTAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CGTTCAAG', 'TTTCTAATGTAGTTCCGTCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'AGCAAAATACGCTTTTAAAAA'))],
#  [(1, ('TTAATTAG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATGATGTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TGATAAACTTCCTTAGTGTAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGTTAGGG', 'TATCTAAGAAATTTTTTGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAATTTGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGGAGGAA')),
#   (1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCAATTCACAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'CCACCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'GATTCAATGGTCTTGCTAAAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'GGTAGAATGGATTTGTAAAAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'))],
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TGTGAAATTAGTTTTAGATAA')),
#   (1, ('TTAATTAG', 'TACCTAATACTTTTCCAACAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'TTGTAAAAATTGTTGTGAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGTGGTTGGCGGAA')),
#   (1, ('CTGAATCT', 'TTTGAAACTTTTTTTTTTCAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCGAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGGGAATG', 'TCACTAATTAGTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('TTAATTAG', 'TGGTAAATGGATTTTTTGGAA')),
#   (1, ('TTAATTAG', 'GGCGAAAAAGTGTTCTAATAA')),
#   (1, ('TCTGGGGC', 'TTTTTAATTTTTTTTTTTTAA')),
# ...
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTATTTTAA'))],
#  [(1, ('TTAATTAG', 'ACCACAAAAACATTCCACCAA')),
#   (1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CTGAATCT', 'TCGTAAAGCTTTTTAGGGGAA')),
#   (1, ('CGTTTCCT', 'TAGATAAGTGCATTGGTTAAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGAATAAAATAATTTAGGAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'GATGGAAAACACTTCGTTAAA'))],
#  [(2, ('TGTCTAGT', 'GGGCGAAGGTGGTTGGGGAAA')),
#   (1, ('TTAATTAG', 'TTTGTAATTTTGTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGATGTTATAGTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGTTTGTGTGAA')),
#   (1, ('CTGAATCT', 'TTTTTAATCTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACACCAACACCATTAAACAAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA')),
#   (1, ('CCATTACT', 'TAGTTAACGTTGTTGAAATAA')),
#   (1, ('CATAGTCA', 'AAACTAAATAAATTAGGAAAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTTTTTTAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA'))],
#  [(2, ('TTAATTAG', 'CATCCAAAACCTTTCCAACAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'TGAGAAAAAAAATTATAAGAA')),
#   (1, ('TTAATTAG', 'GAATAAATCATATTCTAAAAA')),
#   (1, ('TTAATTAG', 'AAAAGAATACAATTCTCGTAA')),
#   (1, ('GTACTTGC', 'GATTGAATTACTTTGTCCAAA')),
#   (1, ('GGTAGGGA', 'TCTAAAATTTGCTTTCTTAAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CGTTTCCT', 'TATTTAACTATATTTATACAA')),
#   (1, ('CGTTCAAG', 'CGTTAAATTCGGTTTCGCGAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('ACAGAGCC', 'AAAAAAAATCAATTCTTCTAA'))],
#  [(2, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATGTTATAATAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TTAATTAG', 'GACACAAGGCAGTTGAAATAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('CTGAATCT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCATAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA')),
#   (1, ('ACAGAGCC', 'ATAGAAAATCCCTTTCTCGAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'CTCTAAAACCGTTTCGTCGAA'))],
#  [(2, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('GGTAGGGA', 'AAATAAAATAAGTTCTTTAAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CAAAGAAACAGATTACCAAAA'))],
#  [(2, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTGTAA')),
#   (1, ('GGTAGGGA', 'TTGTAAAAATTGTTGTGAAAA')),
#   (1, ('GGTAGGGA', 'TATCAAAGTTACTTACATAAA')),
#   (1, ('CTGAATCT', 'TTTTTAATCTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'AACAAAAACGCCTTCGTAAAA')),
#   (1, ('CATAGTCA', 'GGGGGAAGGGCCTTGGGAAAA'))],
#  {('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'): 1},
#  [(1, ('TTAATTAG', 'TGAGCAAGGGGGTTGGGACAA')),
#   (1, ('GGTAGGGA', 'TGTACAAGAGTATTAAAAAAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA'))],
#  [(3, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (3, ('CGGGAATG', 'CCCCCAACTGCCTTCCCCCAA')),
#   (3, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('GGTAGGGA', 'ACTTCAAGGTTATTTAACGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGAGGGAA')),
#   (1, ('CTGAATCT', 'TTTGAAACTTTTTTTTTTCAA')),
#   (1, ('CTGAATCT', 'TTTCAAAGGATTTTGTTTCAA')),
#   (1, ('CTGAATCT', 'TTATAAAGATCTTTGTATTAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAATCCGTTCGGTCAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAAGCCCCTTCTCCCAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA')),
#   (1, ('ACACGTGA', 'TGTTGAAATGTGTTTGGGTAA'))],
#  [(3, ('GTACTTGC', 'AACGCAATACATTTAGATAAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TGTTGAAATGTGTTTGGGTAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('TTAATTAG', 'GGCGAAAAAGTGTTCTAATAA')),
#   (1, ('CTGAATCT', 'TAAAAAACATTTTTTATTCAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('TGTCTAGT', 'CCACCAACGCAATTACACCAA')),
#   (1, ('CGTTCAAG', 'TTTCTAATGTAGTTCCGTCAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('TTAATTAG', 'AAAAAAAATCACTTCACAAAA')),
#   (1, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CGATGAATCCTATTGGCCGAA'))],
#  {('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'): 1},
#  [(1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('TCTGGGGC', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'ATATAAAACAGATTAATACAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (2, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('TTAATTAG', 'TGTTTAATGATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TGTTAAAAGCGTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TCCCAAATCCCATTCCCTCAA')),
#   (1, ('TCTGGGGC', 'AACGGAAAGAAGTTAACAGAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA')),
#   (1, ('ACAGAGCC', 'GTTTAAAGGTTATTTTCTGAA')),
#   (1, ('ACACGTGA', 'GGGGTAATTTTTTTGTTACAA'))],
#  [(1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('ACACGTGA', 'CGATGAATCCTATTGGCCGAA'))],
#  {('TTAATTAG', 'TTTTTAATATTTTTTTTGCAA'): 1},
#  [(1, ('TTAATTAG', 'TTATAAATATTTTTCTCATAA')),
#   (1, ('TTAATTAG', 'TGAGGAATAAGGTTATATGAA')),
#   (1, ('TTAATTAG', 'AAGAAAACCCAATTAAGCAAA')),
#   (1, ('GGTAGGGA', 'TGATTAATGTGGTTCGCTGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTCCCAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACAGAGCC', 'AAAGCAAATTTCTTTAAAGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTTTTTCTGTCAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCTCTTCAACCAA')),
#   (1, ('CTGAATCT', 'AAAAGAACAACATTCAGTCAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('TTAATTAG', 'GAAGCAAGGGAGTTGAAACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGGGATTGGTGGAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('CGTTTCCT', 'AGATTAAGCGTCTTACAGTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GGGGTAATTTTTTTGTTACAA'))],
#  [(2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TTTTAAAAATTTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'TGAGGAAGGATGTTGGGATAA')),
#   (1, ('CGTTAGGG', 'TATCTAAGAAATTTTTTGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA'))],
#  [(3, ('CTGAATCT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTATCAATAATTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('GGTAGGGA', 'TTGTAAAAATTGTTGTGAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCGCAACCCCCTTTGCCCAA'))],
#  {('TTAATTAG', 'TCCCAAATCCCATTCCCTCAA'): 1},
#  [(1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('CTGAATCT', 'TTTTTAATCTTTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA')),
#   (1, ('ACAGAGCC', 'ATAGAAAATCCCTTTCTCGAA')),
#   (1, ('ACACGTGA', 'GGGGTAATTTTTTTGTTACAA'))],
#  [(1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACACGTGA', 'CAGCCAAACTAGTTATAATAA'))],
#  [(1, ('GGTAGGGA', 'ATTCTAATGTATTTTGGATAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('CGTTTCCT', 'GAGTAAAAGAGATTAGGCTAA')),
#   (1, ('CGGGAATG', 'AAGAAAAAAGGGTTAAGAAAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'AACAAAAACGCCTTCGTAAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTCTTAAATTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTGGAATGATGTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'CTCAAAATACCATTCTATCAA')),
#   (1, ('GGTAGGGA', 'GAATGAAGACACTTTGTAAAA')),
#   (1, ('GGTAGGGA', 'AGTAGAATGAGATTGTGACAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCCAATTCCCCCAA')),
#   (1, ('CCATTACT', 'ATAAAAAAGTACTTATAAAAA')),
#   (1, ('ACAGAGCC', 'AAAAAAAATCAATTCTTCTAA'))],
#  [(3, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATGTTATAATAA')),
#   (1, ('TTAATTAG', 'CTCAAAATACCATTCTATCAA')),
#   (1, ('TGTCTAGT', 'GGGTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGGGATTGGTGGAA')),
#   (1, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('CTGAATCT', 'TTATAAAGATCTTTGTATTAA')),
#   (1, ('CTGAATCT', 'ACACCAACACCATTAAACAAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGGGAATG', 'GGTTGAAGGGTGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA'))],
#  {('CCATTACT', 'TGGTTAATTAGGTTGTGGAAA'): 1},
#  [(2, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA'))],
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TGGGAAATGAGTTTATGATAA')),
#   (1, ('GTACTTGC', 'TTTTAAACGGGATTTATTTAA')),
#   (1, ('GGTAGGGA', 'GGGAAAATTGAGTTTATTTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTGTTATAA')),
#   (1, ('CTGAATCT', 'ACCAAAAAACAATTCTCTCAA')),
#   (1, ('CGGGAATG', 'GGGGTAATGGGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'CCATAAAAAATATTTCTGAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGAGGAA')),
#   (1, ('GGTAGGGA', 'ACTTCAAGGTTATTTAACGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'TACAAAAGTTCATTCATCTAA')),
#   (1, ('GGTAGGGA', 'TGATTAATGTGGTTCGCTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'AGTAGAATATCATTCTCTAAA'))],
#  [(1, ('TTAATTAG', 'TGGTAAATGGATTTTTTGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTGAA')),
#   (1, ('CAGTGCAT', 'AATCCAAAAGCATTAATACAA')),
#   (1, ('ACAGAGCC', 'CATTCAATGCCTTTTATCGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  {('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA'): 1},
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TCGTTAATTTTTTTTTATTAA')),
#   (1, ('GTACTTGC', 'AGAATAAGTGTATTGCATTAA')),
#   (1, ('GGTAGGGA', 'CATTCAATCGCCTTCGAATAA')),
#   (1, ('CTGAATCT', 'TTTTAAATGTTTTTGTATTAA')),
#   (1, ('CGTTCAAG', 'CATTGAACCTTATTGTACAAA')),
#   (1, ('CAGTGCAT', 'CCAATAATCCATTTTCCGGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTATAAATATTTTTCTCATAA')),
#   (1, ('GGTAGGGA', 'TGTACAAGAGTATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'CATTCAATCGCCTTCGAATAA')),
#   (1, ('CTGAATCT', 'TACCAAACCTCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCCCAATCACCTTTTACGAA')),
#   (1, ('CCATTACT', 'AAAAAAAAGAAGTTAAAGTAA')),
#   (1, ('ACAGAGCC', 'CATTCAATGCCTTTTATCGAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCGCAA'))],
#  [(2, ('GGTAGGGA', 'GACCAAATTACGTTCCGCAAA')),
#   (1, ('TGTCTAGT', 'CCACCAACGCAATTACACCAA')),
#   (1, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA'))],
#  [(1, ('TTAATTAG', 'TACCTAATACTTTTCCAACAA')),
#   (1, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (1, ('CGTTAGGG', 'AAATGAACTGATTTAGATAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'AAGTTAATTTTGTTTGTGAAA')),
#   (1, ('ACAGAGCC', 'GACTCAAATAGTTTATTATAA')),
#   (1, ('ACAGAGCC', 'CCATAAAAAATATTTCTGAAA'))],
#  [(3, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA')),
#   (2, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (2, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (2, ('CGGGAATG', 'CCCCCAACGCCCTTCCCCCAA')),
#   (2, ('CCATTACT', 'ACCCCAACCGTCTTCCTCCAA')),
#   (1, ('TTAATTAG', 'TGAGCAAGGGGGTTGGGACAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTAGAAGAA')),
#   (1, ('GTACTTGC', 'TTTTAAACGGGATTTATTTAA')),
#   (1, ('GGTAGGGA', 'ATACAAACAGGTTTGCACGAA')),
#   (1, ('GCCTACGT', 'TTCCGAAGGGGGTTGTCGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TCCAAAACCGCCTTAAGCAAA')),
#   (1, ('CGTTTCCT', 'AGATTAAGCGTCTTACAGTAA')),
#   (1, ('CGTTCAAG', 'TTTCTAATGTAGTTCCGTCAA')),
#   (1, ('CGTTCAAG', 'ATAATAAAACTATTAGCGGAA')),
#   (1, ('CGTTCAAG', 'ACTGAAATATAGTTATATGAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CGTTAGGG', 'CAGCTAATGTTGTTGCAACAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTATGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAACCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'CGGTTAAGTAGGTTATGTAAA')),
#   (1, ('CCATTACT', 'CCCAAAAGCCTCTTCAGCAAA')),
#   (1, ('CCATTACT', 'AGGGTAACGTAGTTGTTCTAA')),
#   (1, ('ACAGAGCC', 'GTTTGAACACACTTTTATGAA')),
#   (1, ('ACACGTGA', 'AGAGAAAGCGCATTGAAAGAA'))],
#  [(2, ('CTGAATCT', 'TTTGGAATAAGTTTTCTTTAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGTATGTTGTTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCTGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'ATAATAAAACTATTAGCGGAA')),
#   (1, ('CGTTAGGG', 'TCCCCAATGGAGTTACGAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA'))],
#  [(1, ('TTAATTAG', 'TTGGTAATGATTTTACATGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('CCATTACT', 'GCCCGAAGGGTTTTTGATTAA'))],
#  [(1, ('CGTTCAAG', 'TTGTGAAGGATTTTTCTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTGACGTAA'))],
#  {('CGTTCAAG', 'ACTGAAATATAGTTATATGAA'): 1},
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 2082

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
