# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist2.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 12530

# %%
afile = pysam.AlignmentFile("./final.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %%
totalUMI = 0
for cellUMI in cellbyUMI:
    totalUMI += len(cellbyUMI[cellUMI])
print(totalUMI)
# Out:
# 4966555

# %%
print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))
# Out:
# In Whitelist UMI: 12529
# Out Whitelist UMI: 472178
# In Whitelist Reads: 235227151
# Out Whitelist Reads: 76556299

# %%
import pickle
with open('cellbyUMI.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 71

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 12529

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 12435

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] < threshold: 
                print("Not past threshold: %s" % str(newUMI))
            else:
                ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
#_ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')

plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (4.10849017699553, 1, 1877, 1)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(count, bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 5029

# %%
len(whitelist)
# Out:
# 12530

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 7362

# %%
poorUMI
# Out:
# [[(3, ('ACACGTGA', 'GAAGGAATGGGGTTGTTGGAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA'))],
#  [(3, ('CGTTTCCT', 'TATTTAATACATTTTTTTGAA')),
#   (3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('GGTAGGGA', 'AATGGAAATACTTTATGAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACAGAGCC', 'TGATAAATCTGTTTAGGCGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'ACGATAATAGAGTTATTAAAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA'))],
#  [(2, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'TTTTTAAGTTTTTTTCGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGAGGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(3, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (3, ('ACAGAGCC', 'TGGGTAATCATTTTTAATTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA')),
#   (1, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA'))],
#  [(3, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('GTACTTGC', 'GGCTGAAGGTAATTTCGTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTAGGG', 'TACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('TTAATTAG', 'GGCGAAAGCAGGTTGGAAGAA')),
#   (1, ('GGTAGGGA', 'GCTTAAAAATGTTTTAGATAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGTCAAAGGTGTTGTTGTAA')),
#   (1, ('CAGTGCAT', 'CCCTTAAGGTCTTTCTGACAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(3, ('CTGAATCT', 'ATAAAAAAAATATTGAAGAAA')),
#   (3, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('GGTAGGGA', 'GGTACAAGCCACTTAGTCTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'AGTAGAAGGCTTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CCATTACT', 'CCTAAAAGCCTTTTTATAAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (1, ('GGTAGGGA', 'GGTACAAGCCACTTAGTCTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA'))],
#  [(3, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('CTGAATCT', 'ATAAAAAAAATATTGAAGAAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('CCATTACT', 'AGATCAATGAGGTTGGTAGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (3, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTATAAATATGATTCTTTCAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGTGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GGTTAAATATATTTACGTGAA')),
#   (1, ('GGTAGGGA', 'GCTTAAAAATGTTTTAGATAA')),
#   (1, ('GCCAATCG', 'TAGGCAAGTTGATTAACATAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('GGTAGGGA', 'AATGGAAATACTTTATGAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (2, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (2, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GTACTTGC', 'GACATAACTGATTTTGTGAAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (1, ('CGTTAGGG', 'TGGCCAATAAGATTGTTCTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'AGTAGAAGGCTTTTGGTGGAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TAGTTAATGGCCTTTTATAAA')),
#   (1, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA'))],
#  [(2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTGTAATATTGTTTGTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTGTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TTTGAAATGATTTTATTTTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(2, ('TTAATTAG', 'AACACAACCAAATTAAAAAAA')),
#   (2, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CCATTACT', 'TGTTCAAGTTGCTTTGGTTAA')),
#   (1, ('ACAGAGCC', 'GGTTAAAAGGAGTTGTCGAAA')),
#   (1, ('ACAGAGCC', 'AATTGAAAGTAGTTGGTAGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('TTAATTAG', 'TTTTAAATTTGTTTTTTTGAA')),
#   (2, ('TTAATTAG', 'TTATAAATATGATTCTTTCAA')),
#   (2, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGTTTGGGGAAA')),
#   (1, ('CTGAATCT', 'TTATAAACTTTTTTTTTTTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TCCTAAATATGATTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(3, ('CTGAATCT', 'TTATAAACTTTTTTTTTTTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TGGTTAAGGATTTTTTTTTAA')),
#   (1, ('GTACTTGC', 'GGCTGAAGGTAATTTCGTTAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('CCATTACT', 'AGAGAAATGGACTTGTTGGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA'))],
#  {('TTAATTAG', 'TTTTTAAATATTTTATTTTAA'): 2},
#  [(3, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (3, ('TTAATTAG', 'TTTTAAATTTGTTTTATTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA'))],
#  [(3, ('TTAATTAG', 'TTTTAAATTTGTTTTTTTGAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(4, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (3, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CGTTTCCT', 'TGTTGAAGATTTTTGAGTCAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'TAATAAAATTTCTTCGCTCAA')),
#   (1, ('ACAGAGCC', 'ATATCAACATTTTTACCTGAA'))],
#  [(2, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TCCTAAATATGATTCTTTTAA')),
#   (1, ('TTAATTAG', 'AACACAACCAAATTAAAAAAA')),
#   (1, ('CGTTAGGG', 'TGTGCAAGCCTGTTATAGTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (2, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATTTTGGATTAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTCCAAAGGGCCTTCCGTCAA')),
#   (1, ('TTAATTAG', 'GGCGAAAGCAGGTTGGAAGAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TGAGAAAAGGTGTTAAAGTAA')),
#   (1, ('CCATTACT', 'AGTACAAAGGCGTTAAAGCAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(2, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTATTTAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA'))],
#  [(2, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'TGTGCAAGCCTGTTATAGTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCATTCCCCCAA'))],
#  [(3, ('TTAATTAG', 'GGGGGAAGAGGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (2, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTCCAAAGGGCCTTCCGTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GGTACAAGCCACTTAGTCTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'TGATCAAGCTTGTTCTCACAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGGGAGAA'))],
#  [(2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'GGTGAAATAATATTATTTTAA')),
#   (1, ('GTACTTGC', 'GGCTGAAGGTAATTTCGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(3, ('ACAGAGCC', 'TTGCTAATTTGATTATTATAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTGTTTTTTTTTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA'))],
#  [(3, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('GGTAGGGA', 'GCTTAAAAATGTTTTAGATAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'CAAACAACCGGATTCCCAAAA'))],
#  [(3, ('ACAGAGCC', 'AAAGAAATTTAATTTTTCTAA')),
#   (2, ('TTAATTAG', 'AACACAACCAAATTAAAAAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'GGATTAATTTGGTTTGATAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(2, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTATTTTAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GTACTTGC', 'GGCTGAAGGTAATTTCGTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('CCATTACT', 'AGACAAACATGATTGGTTAAA'))],
#  [(2, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'GGCGAAAGCAGGTTGGAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGTTTGGGGAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA')),
#   (1, ('ACAGAGCC', 'AAGTTAAGCAATTTACTGTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGAGGGTTGTGAGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('GCCTACGT', 'GGCGGAAGGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('ACAGAGCC', 'AATTGAAAGTAGTTGGTAGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('GCCTACGT', 'TGCTGAATTTTGTTCTGGGAA')),
#   (2, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATTTTGGATTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('CCATTACT', 'AGATAAAATTTATTTAATGAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(3, ('TTAATTAG', 'TTTTAAATTTGTTTTTTTGAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('GTACTTGC', 'TTGTCAATAAAATTTAAGGAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA')),
#   (1, ('ACAGAGCC', 'AATTGAAAGTAGTTGGTAGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('ACACGTGA', 'GAAGGAATGGGGTTGTTGGAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('GTACTTGC', 'ACAGAAAGAAGCTTGGAGCAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'TAATAAAATTTCTTCGCTCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA'))],
#  [(1, ('TTAATTAG', 'TTCCAAAGGGCCTTCCGTCAA')),
#   (1, ('GGTAGGGA', 'TGTTCAAGTGGTTTACTTAAA')),
#   (1, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA'))],
#  [(4, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA'))],
#  [(4, ('GGTAGGGA', 'TTGTGAAGCATTTTTATTCAA')),
#   (4, ('ACAGAGCC', 'TTAATAATTGATTTAAGTAAA')),
#   (3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(1, ('TTAATTAG', 'TGTTTAATTTGTTTTCGTTAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTGTTTTTTTTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'GGATTAATGTTGTTCGACGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('TTAATTAG', 'TTATAAATATGATTCTTTCAA')),
#   (3, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA')),
#   (2, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('TTAATTAG', 'GAATGAAATAGTTTGGTATAA')),
#   (1, ('GTACTTGC', 'GGCTGAAGGTAATTTCGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCACTTCTCCCAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GGTAGGGA', 'GGTACAAGCCACTTAGTCTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('CATAGTCA', 'CTCACAAACGACTTTGCTCAA'))],
#  [(2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGTTAGGG', 'CAGAAAACCAAGTTCTGTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGTTTGGGGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTAGGG', 'TGGCCAATAAGATTGTTCTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(2, ('ACAGAGCC', 'TTAATAATTGATTTAAGTAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGTTTGGGGAAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(3, ('CTGAATCT', 'AAACAAACAACATTAAACAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GTACTTGC', 'GGCTGAAGGTAATTTCGTTAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGTTCAAG', 'TTTTTAAAAATGTTGGTATAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (2, ('CGGGAATG', 'AAAACAACAACATTAGCAAAA')),
#   (2, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CGTTCAAG', 'AAAACAACAGGTTTCTCCTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGTTAGGG', 'AGTGAAATATCGTTGACGTAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'AGTACAAAGGCGTTAAAGCAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAATTCCAAAAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (3, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA')),
#   (1, ('CGTTCAAG', 'TTCTAAATATGTTTTCATGAA')),
#   (1, ('CGGGAATG', 'GGTCCAACCCCGTTCTGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('GGTAGGGA', 'GGTACAAGCCACTTAGTCTAA')),
#   (1, ('CGGGAATG', 'GGTCCAACCCCGTTCTGTTAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(4, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('CTGAATCT', 'CCCTCAACCGACTTCCTTCAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACAGAGCC', 'AACCAAAGCACGTTGCTAGAA'))],
#  [(2, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA'))],
#  [(3, ('TTAATTAG', 'TCCTAAATACGATTCTTTTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACAGAGCC', 'ACCGAAACTTGTTTTAATAAA'))],
#  [(3, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CTATCAATCGGGTTCCAACAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATTTTGGATTAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAAAAGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'ACAACAACGCGTTTTAGGAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTAACAAGGGTTTTATTCAAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA')),
#   (1, ('ACAGAGCC', 'CATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGTGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGTTAGGG', 'ATTCCAAACGTTTTTGTAGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'AGAGAAATGGACTTGTTGGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAGTTAATGGCCTTTTATAAA'))],
#  [(3, ('TTAATTAG', 'TGGGAAAGGTTGTTTTATTAA')),
#   (3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGCGAAAGCAGGTTGGAAGAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGGGAATG', 'GTGAGAAGCGTTTTGGTGGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(2, ('CTGAATCT', 'TTGTAAACGTCTTTGTGTGAA')),
#   (1, ('TTAATTAG', 'TGTGAAATGATTTTATGTTAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA'))],
#  [(2, ('ACACGTGA', 'GGAGGAAAGGAATTGGAATAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGTGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CGTTAGGG', 'TGTGCAAGCCTGTTATAGTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GGTAGGGA', 'GGTACAAGCCACTTAGTCTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA'))],
#  [(3, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GTACTTGC', 'CTGGGAACAAATTTCCAACAA')),
#   (1, ('GGTAGGGA', 'GGTACAAGCCACTTAGTCTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CAGTGCAT', 'CCCTTAAGGTCTTTCTGACAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGTTTGGGGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA'))],
#  [(2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TGGTTAAGGATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGTTCAAG', 'TATGTAAATGAGTTAGTGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CAGTGCAT', 'TTGATAACCAGATTATGCTAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA'))],
#  [(2, ('CATAGTCA', 'GGCCCAAACTTATTTACGTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTGTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'TTTTGAATTTTTTTGTTTTAA')),
#   (1, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('ACACGTGA', 'TGATCAAGCTTGTTCTCACAA'))],
#  [(2, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (2, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TTATAAATATGATTCTTTCAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA'))],
#  [(3, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGTTTGGGGAAA')),
#   (2, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (2, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (2, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (2, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GTACTTGC', 'CGTACAAACGGATTCTTTTAA')),
#   (1, ('GGTAGGGA', 'TCAGAAATTGATTTCTCTTAA')),
#   (1, ('GGTAGGGA', 'CGTCAAAATAACTTGAATAAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TATTGAATTTTTTTGTTTTAA')),
#   (1, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (1, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (1, ('CGTTTCCT', 'TCGGGAAATGAGTTGTGTAAA')),
#   (1, ('CGTTAGGG', 'TGTGCAAGCCTGTTATAGTAA')),
#   (1, ('CGTTAGGG', 'TACTAAAATTGATTTCATAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('CCATTACT', 'AGTACAAAGGCGTTAAAGCAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAGTTAATGGCCTTTTATAAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA')),
#   (1, ('ACAGAGCC', 'AATTGAAAGTAGTTGGTAGAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (3, ('ACACGTGA', 'GAAGGAATGGGGTTGTTGGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CTGAATCT', 'CCAAAAACAACATTCAGTCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'GGCTGAAGGTAATTTCGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'AGTACAAAGGCGTTAAAGCAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTGGTGGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('CCATTACT', 'AGATCAATGAGGTTGGTAGAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA'))],
#  [(2, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('ACAGAGCC', 'TTCGCAAGTTTTTTTATTAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA'))],
#  [(1, ('GTACTTGC', 'CTGGGAACAAATTTCCAACAA')),
#   (1, ('CTGAATCT', 'AAAAGAAAAAAATTGAAGAAA')),
#   (1, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA'))],
#  [(4, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (4, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATTTTTTTTTTGAA'))],
#  [(1, ('TTAATTAG', 'TGTTTAATTTGTTTTCGTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATTTTGGATTAA')),
#   (1, ('GCCAATCG', 'TAGGCAAGTTGATTAACATAA')),
#   (1, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTAGAAAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('TTAATTAG', 'GGGTTAATTATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGTTTCCT', 'TGTTGAAGATTTTTGAGTCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA'))],
#  [(2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTGTAATATTGTTTGTTTAA')),
#   (1, ('TTAATTAG', 'GGCGAAAGCAGGTTGGAAGAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA'))],
#  [(3, ('TTAATTAG', 'TTATAAATATGATTCTTTCAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'TTGTCAATAAAATTTAAGGAA')),
#   (1, ('CGTTCAAG', 'AAAACAACAGGTTTCTCCTAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(1, ('CGTTCAAG', 'GCTGAAAATCCTTTAACAGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(3, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('TTAATTAG', 'TTCCAAAGGGCCTTCCGTCAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA'))],
#  [(1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'ACGCAAAAATCTTTAATCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(4, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (4, ('CCATTACT', 'CCCCCAAGCCCCTTCCACCAA')),
#   (3, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (3, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTGAAATGATTTTATTTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACAGAGCC', 'TCGGAAATTTCATTGAGCAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CGTTAGGG', 'TGTGCAAGCCTGTTATAGTAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(3, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('CGTTCAAG', 'TTTTTAAAAATGTTGGTATAA')),
#   (1, ('TTAATTAG', 'TTTGTAATATTGTTTGTTTAA')),
#   (1, ('TTAATTAG', 'TTCCAAAGGGCCTTCCGTCAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGCAACCCTCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CAGTGCAT', 'TTGATAACCAGATTATGCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA'))],
#  [(1, ('GCCAATCG', 'CCTCGAATGATATTCCGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (2, ('TTAATTAG', 'AACACAACCAAATTAAAAAAA')),
#   (2, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTGTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TGTTTAATTTGTTTTCGTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGTGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTCAAG', 'AAAACAACAGGTTTCTCCTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TTACAAAGGTGATTAACTAAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'TCGGAAATTTCATTGAGCAAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'AATTGAAAGTAGTTGGTAGAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (2, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTGTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TCCTAAATATGATTCTTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CTGAATCT', 'TCATAAACTTTCTTTTATTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGTTAAAATTGGTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'ACCGAAACTTGTTTTAATAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TGTTTAATTTGTTTTCGTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CCATTACT', 'TTCTTAATGGCCTTTGTTCAA')),
#   (1, ('ACAGAGCC', 'TTGCTAATTTGATTATTATAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTCTTTGAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('TTAATTAG', 'TTATAAATATGATTCTTTCAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTCAAG', 'GCTGAAAATCCTTTAACAGAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'GGGTTAATTATTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TTTTTAAGTTTTTTTCGTTAA')),
#   (1, ('CTGAATCT', 'CACCTAACCCACTTCCTCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAACGAACATTATTTGTCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGTGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAAACATTAAAAAAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
# ...
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'AACACAACCAAATTAAAAAAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CGTTAGGG', 'TACTAAAATTGATTTCATAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACAGAGCC', 'GGATTAATGTTGTTCGACGAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(3, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGTTAGGG', 'TGGCCAATAAGATTGTTCTAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTCTTTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('CATAGTCA', 'AAGCAAAAAAAATTAAAGCAA')),
#   (1, ('CAGTGCAT', 'CCCTTAAGGTCTTTCTGACAA'))],
#  [(1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGGGGGTTGTAAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (1, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA'))],
#  [(3, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (3, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (2, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAAGAATTGAAAAAA')),
#   (1, ('CGTTAGGG', 'TGTGCAAGCCTGTTATAGTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TGTGAAATGATTTTATGTTAA')),
#   (1, ('TTAATTAG', 'GGCGAAAGCAGGTTGGAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TGTGCAAGCCTGTTATAGTAA')),
#   (1, ('CGTTAGGG', 'TGGCCAATAAGATTGTTCTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'GTTGGAACGTCATTCTGTCAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'GTATAAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TTTGAAATGATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('CGGGAATG', 'TGCTGAACCCCTTTATATTAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (2, ('ACACGTGA', 'GGACCAACTCTGTTGCTATAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTAATAATTGATTTAAGTAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('TGTCTAGT', 'TCCCCAACCCATTTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(1, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'TGGCCAATAAGATTGTTCTAA')),
#   (1, ('ACACGTGA', 'TTATTAATAAGGTTTTCTTAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (3, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CCATTACT', 'TGGTCAAAGGTGTTGTTGTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'TTTGTAATTGTTTTTTTTGAA')),
#   (2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'GGGTTAATTATTTTTTTTTAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('GGTAGGGA', 'TGTTCAAGTGGTTTACTTAAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA')),
#   (1, ('ACAGAGCC', 'TAATTAAGACGATTTCGTGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA'))],
#  [(2, ('CGTTCAAG', 'TTTTTAAAAATGTTGGTATAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GTACTTGC', 'CTGGGAACAAATTTCCAACAA')),
#   (1, ('GGTAGGGA', 'TTGTGAAGCATTTTTATTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA'))],
#  [(1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CGTTTCCT', 'TGTAAAATGCATTTGTCGTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('GTACTTGC', 'CTGGGAACAAATTTCCAACAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGAGTTACATGAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CTGAATCT', 'CCACAAACCCCCTTCACCCAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(3, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (2, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('GGTAGGGA', 'GCTTAAAAATGTTTTAGATAA')),
#   (1, ('CGTTTCCT', 'GTATGAAACTTATTCTCAGAA')),
#   (1, ('CGTTCAAG', 'TTTTTAAAAATGTTGGTATAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGTTAAAATTGGTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'TGTTGAATCAATTTGAGAAAA')),
#   (1, ('ACACGTGA', 'TGTGTAATTTTTTTGTTTTAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('CTGAATCT', 'ATAAAAAAAATATTGAAGAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGTTTGGGGAAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA'))],
#  [(3, ('ACACGTGA', 'CTTTAAAATGTTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA'))],
#  [(2, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(3, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTCTTTTTTTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACAGAGCC', 'TTAATAATTGATTTAAGTAAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA'))],
#  [(3, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (3, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (3, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (2, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (2, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTGACAA')),
#   (1, ('GCCTACGT', 'TGCTGAATTTTGTTCTGGGAA')),
#   (1, ('CGTTAGGG', 'TGGCCAATAAGATTGTTCTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGTTAGGG', 'CAGAAAACCAAGTTCTGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA')),
#   (1, ('ACAGAGCC', 'ATTTGAAGGGATTTCTTTAAA'))],
#  [(3, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (2, ('CTGAATCT', 'CCCCCAACCCCCTTCCGCCAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'AGAGAAATGGACTTGTTGGAA')),
#   (1, ('CATAGTCA', 'AAGCAAAAAAAATTAAAGCAA')),
#   (1, ('CAGTGCAT', 'TTGATAACCAGATTATGCTAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (2, ('CGTTCAAG', 'TTTTTAAAAATGTTGGTATAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('GGTAGGGA', 'GCTTAAAAATGTTTTAGATAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('CCATTACT', 'TGAGAAAAGGTGTTAAAGTAA')),
#   (1, ('CCATTACT', 'TACCGAAGTGCGTTTTAGTAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA'))],
#  [(3, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTATAAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('CGGGAATG', 'GGTCCAACCCCGTTCTGTTAA')),
#   (1, ('CATAGTCA', 'AAGCAAAAAAAATTAAAGCAA')),
#   (1, ('ACAGAGCC', 'AAAGAAATTTAATTTCTCTAA'))],
#  [(3, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CCATTACT', 'AGTACAAAGGCGTTAAAGCAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTAAA')),
#   (1, ('CCATTACT', 'AGAGAAATGGACTTGTTGGAA'))],
#  [(3, ('ACACGTGA', 'GAAGGAATGGGGTTGTTGGAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('TTAATTAG', 'TTTTCAAGTAGTTTTTTACAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'GGTCCAACCCCGTTCTGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(3, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'GGCGAAAGCAGGTTGGAAGAA')),
#   (1, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAAATTGTTTCTTTTAA')),
#   (2, ('CCATTACT', 'TGAGAAACATAATTAAATAAA')),
#   (1, ('GCCTACGT', 'TGTGGAATGAGTTTGGGTTAA')),
#   (1, ('CTGAATCT', 'GTTTCAATTTGCTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('ACAGAGCC', 'AATTGAAAGTAGTTGGTAGAA')),
#   (1, ('ACACGTGA', 'GAAGGAATGGGGTTGTTGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTATCTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATTTTGGATTAA')),
#   (1, ('TTAATTAG', 'AACACAACCAAATTAAAAAAA')),
#   (1, ('TTAATTAG', 'AAAAAAACAAAGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('GCCTACGT', 'TGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTGAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('CCATTACT', 'CTTTAAACTGTCTTGGGCTAA'))],
#  [(2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('ACAGAGCC', 'TATAGAATTGATTTCCTAAAA'))],
#  [(1, ('CTGAATCT', 'AAACAAACAACATTAAACAAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'GTGAGAAGCGTTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATATTTTTTTGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'GGAACAAAAGGCTTGATAGAA'))],
#  [(2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('TTAATTAG', 'TAAGGAATAAAGTTAAATGAA')),
#   (1, ('GTACTTGC', 'ACAGAAAGAAGCTTGGAGCAA')),
#   (1, ('CTGAATCT', 'CACCCAACCCCCTTCCCCCAA')),
#   (1, ('CTGAATCT', 'AAACAAACAACATTAAACAAA')),
#   (1, ('CGTTAGGG', 'TGCGGAATTTATTTACGACAA')),
#   (1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CGGGAATG', 'TTTCTAATTTTTTTCTTTTAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAGGGGGTTGTGCGAA'))],
#  [(1, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (1, ('CCATTACT', 'GGGACAATGTTTTTTGGGAAA')),
#   (1, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA'))],
#  [(3, ('CTGAATCT', 'TTATAAACTTTTTTTTTTTAA')),
#   (3, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('GGTAGGGA', 'TAAAAAAGAGTGTTACATGAA')),
#   (1, ('GGTAGGGA', 'GCTTAAAAATGTTTTAGATAA')),
#   (1, ('CTGAATCT', 'ACACTAACTTCTTTATTTCAA')),
#   (1, ('CGGGAATG', 'GGTCCAACCCCGTTCTGTTAA')),
#   (1, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (1, ('CGGGAATG', 'CCCGAAACTACTTTCTCCCAA')),
#   (1, ('CCATTACT', 'TTCTTAATGGCCTTTGTTCAA')),
#   (1, ('CCATTACT', 'TGGGTAAAGGTGTTGGCGTAA')),
#   (1, ('ACACGTGA', 'GTATGAAAGGTATTGAGAGAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGTATTAGGTGAA')),
#   (1, ('ACACGTGA', 'AAAGGAAGCGTATTGGGGCAA'))],
#  [(3, ('GGTAGGGA', 'TGAATAATGTATTTGCCGTAA')),
#   (2, ('CGTTAGGG', 'GACGGAACATATTTAGTAAAA')),
#   (2, ('CGGGAATG', 'CCTCCAATCCTTTTTCTTGAA')),
#   (2, ('ACACGTGA', 'CACCAAATCCCCTTGGCCAAA')),
#   (1, ('GTACTTGC', 'TACATAACTGATTTTGTGAAA')),
#   (1, ('GGTAGGGA', 'TGGTAAAGTACTTTGTCAGAA')),
#   (1, ('GGTAGGGA', 'GTTGTAAGTCGATTTTATGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCACCAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTCTTCGCGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 5029

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
