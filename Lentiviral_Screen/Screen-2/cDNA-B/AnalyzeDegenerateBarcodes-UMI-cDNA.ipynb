# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist1.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 4957

# %%
afile = pysam.AlignmentFile("./final.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %%
totalUMI = 0
for cellUMI in cellbyUMI:
    totalUMI += len(cellbyUMI[cellUMI])
print(totalUMI)
# Out:
# 3914154

# %%
print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))
# Out:
# In Whitelist UMI: 4956
# Out Whitelist UMI: 511924
# In Whitelist Reads: 261238201
# Out Whitelist Reads: 42147878

# %%
import pickle
with open('cellbyUMI.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 36

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 4956

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 4812

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] < threshold: 
                print("Not past threshold: %s" % str(newUMI))
            else:
                ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
#_ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')

plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (8.973900399854598, 1, 788, 1.0)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(count, bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 2734

# %%
len(whitelist)
# Out:
# 4957

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 2032

# %%
poorUMI
# Out:
# [[(3, ('GGTAGGGA', 'GCTTCAAGGTCATTCGTTAAA')),
#   (2, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(1, ('CCATTACT', 'CCCCGAAGGTCATTACGCTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (3, ('ACAGAGCC', 'CGTATAATTTTCTTGGGTAAA')),
#   (2, ('GGTAGGGA', 'AATTAAAGTATGTTTCAGCAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('CTGAATCT', 'CCACCAACCTCATTACCACAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA')),
#   (1, ('GCCAATCG', 'GCAGCAAACCCATTCACTGAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGTTTCCT', 'TTTGCAATGCGTTTGAAATAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CCATTACT', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'CGTCTAATTATATTTCTTAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACAAATTGCCCAAA'))],
#  [(1, ('TTAATTAG', 'TTTTAAAATGTGTTATAATAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  {('CCATTACT', 'AAGAAAAATGAGTTAAAGTAA'): 2},
#  [(3, ('GCCTACGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GCTTTAAAGGTTTTTCAGAAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA'))],
#  [(1, ('GGTAGGGA', 'TATGGAAATTATTTCCTGTAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCTCTTTCACCGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'GGGCAAAATGGGTTGGAGAAA'))],
#  [(2, ('CGGGAATG', 'GGGAAAACAGTATTGATGAAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CTGAATCT', 'CCCCAAACCCGTTTCCCCTAA')),
#   (1, ('CTGAATCT', 'AAAGAAAGTGGCTTAGAACAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'GGGTGAATGAAGTTGGGTTAA'))],
#  [(2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'CTTTCAATTAAATTAATATAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'TGGTGAAGCGCGTTGGGGTAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'TTTATAATGGTTTTATGGTAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA'))],
#  [(1, ('GGTAGGGA', 'TTCCTAATTCTGTTATTCTAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'CAAGTAAAGAAATTCCATGAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (3, ('CTGAATCT', 'TTTTTAAGTTCTTTTTTTTAA')),
#   (3, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAAGCATCTTCTCGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('GTACTTGC', 'ATATAAAGTCTCTTGATCGAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CTGAATCT', 'TTATTAACTTCTTTTTTTTAA')),
#   (1, ('CCATTACT', 'CCCCGAAGGTCATTACGCTAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA'))],
#  [(2, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'GTTTGAATAGGTTTTTATGAA')),
#   (1, ('CTGAATCT', 'TTCTAAACCTCTTTTTTTCAA')),
#   (1, ('CTGAATCT', 'CCACCAACCTCATTACCACAA')),
#   (1, ('CGTTAGGG', 'TGAGGAATATGCTTATCCAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(4, ('GTACTTGC', 'CTTTGAATTAGCTTTATAGAA')),
#   (1, ('TTAATTAG', 'GCTTTAATATGTTTTTTACAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'AACCCAAGCTCGTTCGTATAA')),
#   (1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'CCCCCAACACCCTTCCTCCAA')),
#   (1, ('CGGGAATG', 'GGGAAAACAGTATTGATGAAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAAAAGTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'AGGTGAAAGGTTTTGTTGTAA'))],
#  [(1, ('GGTAGGGA', 'TTATGAACCACTTTTTAAAAA')),
#   (1, ('CGTTAGGG', 'GGCAAAAGTAAATTAGTTCAA')),
#   (1, ('CCATTACT', 'CCCTCAACGTTCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTATTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('CTGAATCT', 'TTATTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAAAAGTTAAAGGAA')),
#   (1, ('GTACTTGC', 'CTTAGAAAAGTATTTTTTCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(3, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA'))],
#  [(1, ('TGTCTAGT', 'TTTGTAATGTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('CGTTCAAG', 'ATGATAATTAAATTATTTGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'GGGTGAATGAAGTTGGGTTAA'))],
#  [(1, ('TTAATTAG', 'TGTTAAATGATTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('CTGAATCT', 'TCATTAAGATCTTTAATCTAA')),
#   (1, ('CGTTAGGG', 'GTGTGAACTTAATTAGATCAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('GTACTTGC', 'AGGATAAGCGGATTGCGTTAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TTGTTAAATGTTTTAGGGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'CACGAAACCCAATTCCTCCAA'))],
#  [(2, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('CCATTACT', 'CCCCGAAGGTCATTACGCTAA')),
#   (1, ('GGTAGGGA', 'TTGTCAATCATTTTCTAACAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CCATTACT', 'CACTCAACTTCATTGGACCAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA')),
#   (1, ('ACAGAGCC', 'ACTTCAATGTCGTTTGTTTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('GGTAGGGA', 'TTCCTAATTCTGTTATTCTAA')),
#   (1, ('CTGAATCT', 'AAAGAAAGTGGCTTAGAACAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'TTAGAAAGTAAATTATATCAA')),
#   (1, ('CTGAATCT', 'TTCTAAATTTTGTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGTTAGGG', 'TCTTGAATTTCATTTCAACAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACAGAGCC', 'CGTATAATTTTCTTGGGTAAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA'))],
#  [(2, ('CGGGAATG', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA')),
#   (1, ('CGTTTCCT', 'TTTGCAATGCGTTTGAAATAA')),
#   (1, ('CGTTCAAG', 'TAGAGAAGGTCCTTCTAGAAA')),
#   (1, ('CGTTCAAG', 'CACGGAATCTGGTTTTCGTAA')),
#   (1, ('CCATTACT', 'TGGTGAAAAAGGTTGGAGGAA')),
#   (1, ('ACAGAGCC', 'TAATAAACCACATTATATAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('GTACTTGC', 'GTGGCAATTTACTTTTGCGAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TTCTAAATTTTGTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('CCATTACT', 'AAGAAAAATGAGTTAAAGTAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA'))],
#  [(3, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CATAGTCA', 'AAACAAAAAAAATTAAAACAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'))],
#  [(1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'GGGAAAACAGTATTGATGAAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'GGAAAAAGGGCGTTGATGCAA')),
#   (1, ('ACAGAGCC', 'TAATAAACCACATTATATAAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('GGTAGGGA', 'ACAAGAAGGTGATTTCCCAAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('GTACTTGC', 'TGTTAAAGTCCCTTTTAATAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TCCAAAAATTTATTAGCAAAA')),
#   (1, ('ACAGAGCC', 'AGATTAAATGCCTTAATTAAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TATTTAATTGGATTTCCCCAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA'))],
#  [(3, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (3, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (2, ('CTGAATCT', 'AACCCAAAACCATTAAATAAA')),
#   (1, ('TTAATTAG', 'GGCGGAAGGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('GCCAATCG', 'GCAGCAAACCCATTCACTGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'CGTCTAATTATATTTCTTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(2, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'TGAGGAATATGCTTATCCAAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'GGGCAAAATGGGTTGGAGAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTTGCAATGCGTTTGAAATAA')),
#   (1, ('CCATTACT', 'CCCCGAAGGTCATTACGCTAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('GCCTACGT', 'AGTGGAAAGGGGTTGGGGGAA')),
#   (3, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('CATAGTCA', 'GGCGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('GGTAGGGA', 'GCTTTAAAGGTTTTTCAGAAA')),
#   (1, ('GGTAGGGA', 'GATTCAACTTATTTTTCAGAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGTTTCCT', 'TACAGAACTTCGTTCATGAAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CCATTACT', 'TGGGTAAATTGATTGGTGTAA')),
#   (1, ('CCATTACT', 'CCCCCAACCTCCTTCTCCCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'AGAACAAATTAATTAAAACAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAACAAAAACACTTTATAAAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTCAATTGGTTTAGCTTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAAAAGTTAGAAAAA')),
#   (1, ('CCATTACT', 'CAATGAAACGGATTGGACAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('TTAATTAG', 'TGTGTAAATATTTTTTTAGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGTTAGGG', 'GTGTGAACTTAATTAGATCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TATGAAAGGCTTTTGAGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TTAATTAG', 'AGGGAAATGTGCTTAGCGTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('CTGAATCT', 'TTCTTAACTTCTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACAGAGCC', 'GCATCAAATGCGTTATCGTAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'GCTTCAAGTAGTTTGGTCTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (3, ('CTGAATCT', 'TTATTAATTTTTTTTTTTTAA')),
#   (2, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('GGTAGGGA', 'AGATAAATTGGGTTCCCGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TTTGTAAGGTTTTTTCTGGAA')),
#   (1, ('ACAGAGCC', 'CGTCTAATTATATTTCTTAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('GTACTTGC', 'ATATAAAGTCTCTTGATCGAA')),
#   (1, ('GGTAGGGA', 'TTCCTAATTCTGTTATTCTAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCTCTTTCACCGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TGTGTAATTTGTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'TGGTTAATTTTGTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('TTAATTAG', 'TGTGGAAGGGGGTTGTAGGAA')),
#   (1, ('GTACTTGC', 'GTGGCAATTTACTTTTGCGAA')),
#   (1, ('CGGGAATG', 'GGTGTAATGGTGTTTTGTAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TTGTTAATCGTCTTTTCAGAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'AGTGGAATATTGTTAATACAA')),
#   (1, ('CCATTACT', 'CCGTAAATGTTATTGGGTAAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'TTATTAAATATTTTCGTATAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TTAATTAG', 'CACAAAATCTGATTCCCACAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('GGTAGGGA', 'ATACGAACTTAGTTTTTGCAA')),
#   (1, ('CTGAATCT', 'AAACAAAAACACTTTATAAAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CCATTACT', 'TAAAGAAGAAAATTACATAAA')),
#   (1, ('CCATTACT', 'AGGGAAAAGTAGTTGGATAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  {('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA'): 2},
#  [(2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TTAATTAG', 'GCTTTAATATGTTTTTTACAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTCTAAATTTTGTTTTTTTAA')),
#   (1, ('CTGAATCT', 'AAAATAAAAAAATTAAAACAA')),
#   (1, ('CGTTAGGG', 'TCGGGAAGTAGTTTGCTGGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGTTAGGG', 'CTGTAAAGCTTGTTTTAAGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'CCCGTAATCCTTTTTTCGGAA')),
#   (1, ('CCATTACT', 'AAAAAAATGTATTTCAAACAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('GGTAGGGA', 'TGCTTAATATGTTTTTATTAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'CTTAGAAAAGTATTTTTTCAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACAGAGCC', 'TATAGAACGTCGTTCAATCAA')),
#   (1, ('ACAGAGCC', 'GCATCAAATGCGTTATCGTAA'))],
#  [(2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGCGGAAGGAGGTTGTGAGAA')),
#   (1, ('GTACTTGC', 'AACCCAAGCTCGTTCGTATAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA'))],
#  [(2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TCGGAAAGAGGATTTTTTAAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('ACAGAGCC', 'ATTACAATTATTTTGCGGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GGTAGGGA', 'TTATGAACCACTTTTTAAAAA')),
#   (1, ('CGTTAGGG', 'CCCCCAATCGTATTCGCTCAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CAATGAAACGGATTGGACAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  {('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA'): 3},
#  [(2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TGTCTAGT', 'CGTTGAACCGTTTTTATGAAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('CGGGAATG', 'GGGAAAACAGTATTGATGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('CTGAATCT', 'CCACCAACCTCATTACCACAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TGTCTAGT', 'GGGGTAAGGATTTTGGAGGAA')),
#   (1, ('GTACTTGC', 'ATATAAAGTCTCTTGATCGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'GGAGGAAGCCCCTTTCGCAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('CTGAATCT', 'TTGGAAAGGTGTTTGGGGGAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGGGGGTTGGGGGAA'))],
#  [(2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGTTAGGG', 'AATCGAATAAGATTCCCTGAA'))],
#  [(3, ('ACAGAGCC', 'TTGTTAATCGTCTTTTCAGAA')),
#   (2, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('GTACTTGC', 'ATATAAAGTCTCTTGATCGAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTGGAAAGGTGTTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (3, ('ACAGAGCC', 'TTACAAATTTACTTTATTTAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'GGTGGAATTTGTTTGTTTCAA')),
#   (1, ('GTACTTGC', 'GTGGCAATTTACTTTTGCGAA')),
#   (1, ('GGTAGGGA', 'AGTGGAATATTGTTAATACAA')),
#   (1, ('CTGAATCT', 'AAAATAAAAAAATTAAAACAA'))],
#  [(1, ('TTAATTAG', 'TCCAAAATACTATTCCATCAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('CCATTACT', 'GGAGGAAGCCCCTTTCGCAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA'))],
#  [(3, ('GGTAGGGA', 'CCGTGAAACTTGTTGAATAAA')),
#   (2, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('GGTAGGGA', 'TTATGAACCACTTTTTAAAAA')),
#   (1, ('GGTAGGGA', 'GCTTTAAAGGTTTTTCAGAAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'CCCCAAACCCGTTTCCCCTAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'))],
#  [(1, ('TTAATTAG', 'TGTTAAATTCTTTTCTGTCAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTCTAAATTTTGTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('CTGAATCT', 'TTCTAAATTTTGTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('GGTAGGGA', 'AATTAAAGTATGTTTCAGCAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TAATAAACCACATTATATAAA')),
#   (1, ('ACAGAGCC', 'GCATCAAATGCGTTATCGTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTATAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'AGATTAAATGCCTTAATTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('TTAATTAG', 'GGAGAAAGGAAATTAAAAAAA')),
#   (1, ('CTGAATCT', 'TTGAAAACGTCTTTGTTATAA')),
#   (1, ('CGTTCAAG', 'CCTATAAACGTTTTCTCTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGTGGTTGGCGGAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'ACAAAAATAAAATTCTAAAAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'GGCGTAAAGACATTGATAAAA')),
#   (1, ('GGTAGGGA', 'CAAATAAATACATTATACAAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'GTACGAATTTGCTTTTATTAA')),
#   (1, ('ACAGAGCC', 'CGTCTAATTATATTTCTTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GGTAGGGA', 'GCTTTAAAGGTTTTTCAGAAA')),
#   (1, ('CCATTACT', 'GGAGGAAGCCCCTTTCGCAAA')),
#   (1, ('CCATTACT', 'AAGAAAAATGAGTTAAAGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGGAGGTTGTGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAAATTATTCTCTGAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTGTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('CGTTAGGG', 'GTGTGAACTTAATTAGATCAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGTTAGGG', 'ATACTAAGATTTTTTGTTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCTCTTTCACCGAA')),
#   (1, ('CCATTACT', 'TAGAAAAAGAGTTTTTGATAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (3, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (2, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (2, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('GGTAGGGA', 'CCGTGAAACTTGTTGAATAAA')),
#   (1, ('CTGAATCT', 'TTTTTAAGTTCTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CATAGTCA', 'TGAAGAATTGGGTTAGTTAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'GTGGGAAAACGCTTGGGCCAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA'))],
#  [(2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTATAAGAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'GGGAAAACAGTATTGATGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'CCCAAAATGGACTTAAGTAAA')),
#   (1, ('ACAGAGCC', 'GCATCAAATGCGTTATCGTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('CGGGAATG', 'TTTGAAAGGTACTTATGTTAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CCATTACT', 'AGAGAAAAGGGGTTAGGGAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('ACACGTGA', 'AGGTGAAAGGTTTTGTTGTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CCATTACT', 'CACTCAACTTCATTGGACCAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'))],
#  [(2, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('TTAATTAG', 'TTTTGAAAATCATTCTTTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'CCCTCAACGTTCTTCCCCCAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TAATAAACCACATTATATAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('CGGGAATG', 'ACCACAAACGTATTCTGCTAA')),
#   (1, ('CCATTACT', 'AAAAAAATGTATTTCAAACAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA'))],
#  [(3, ('GCCAATCG', 'GCAGCAAACCCATTCACTGAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACAGAGCC', 'AGTACAACGGATTTTGAAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAAATAAAAAAATTAAAACAA')),
#   (1, ('CGTTAGGG', 'TCTTGAATTTCATTTCAACAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'TCCAAAATACTATTCCATCAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'CGTATAAATAATTTATCATAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CTGAATCT', 'CCACCAACCTCATTACCACAA')),
#   (1, ('CGTTAGGG', 'AGTTTAACAGCGTTTTGGTAA')),
#   (1, ('CGGGAATG', 'TATCTAAGTGGGTTTGATGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'CCCCGAAGGTCATTACGCTAA')),
#   (1, ('ACAGAGCC', 'GTACGAATTTGCTTTTATTAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TGTCTAGT', 'AGGAGAAAAACATTGGAACAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA'))],
#  [(3, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('CATAGTCA', 'TGAAGAATTGGGTTAGTTAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (2, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TTAATTAG', 'ACAAAAATAAAATTCTAAAAA')),
#   (1, ('TGTCTAGT', 'TATGAAAGGCTTTTGAGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('GGTAGGGA', 'TAAGAAAATACGTTACGGCAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'ATTACAATTATTTTGCGGAAA')),
#   (1, ('ACAGAGCC', 'AGATAAACAATATTGAAGTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GGTAGGGA', 'TGCTTAATATGTTTTTATTAA')),
#   (1, ('GGTAGGGA', 'GGCTGAAAGTCTTTTCTGCAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA'))],
#  [(2, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTGGAAAGGTGTTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTATTAACTTCTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGGGAATG', 'CAACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TTACAAATTTACTTTATTTAA')),
#   (1, ('ACAGAGCC', 'TAATAAACCACATTATATAAA'))],
#  [(4, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (2, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('TGTCTAGT', 'TATGAAAGGCTTTTGAGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTTGCAATGCGTTTGAAATAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'))],
#  [(2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TGCTTAATATGTTTTTATTAA')),
#   (1, ('GGTAGGGA', 'TAAACAAGTCGCTTATTCGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('ACAGAGCC', 'TAATAAACCACATTATATAAA'))],
#  [(2, ('TCTGGGGC', 'CCCCCAATCTCCTTCTCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TTATGAACCACTTTTTAAAAA')),
#   (1, ('GGTAGGGA', 'GCTTCAAGGTCATTCGTTAAA')),
#   (1, ('GGTAGGGA', 'CCGTGAAACTTGTTGAATAAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'TCTTGAATTTCATTTCAACAA')),
#   (1, ('CCATTACT', 'TGGTTAATGTGATTTTGTGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')),
#   (3, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (2, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('TTAATTAG', 'GCTTTAATATGTTTTTTACAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA')),
#   (1, ('ACACGTGA', 'TTTTAAAAATTTTTCTTTTAA'))],
#  [(2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGTTAGGG', 'TCTTGAATTTCATTTCAACAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('CCATTACT', 'CCCCGAAGGTCATTACGCTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('TTAATTAG', 'GCTTTAATATGTTTTTTACAA')),
#   (1, ('GGTAGGGA', 'TTGTCAATCATTTTCTAACAA')),
#   (1, ('GGTAGGGA', 'AATTAAAGTATGTTTCAGCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA'))],
#  [(3, ('ACAGAGCC', 'CGGAAAATATTTTTTTATCAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'GAAAAAAAAAAATTAAAAAAA')),
#   (1, ('GTACTTGC', 'CTTTGAATTAGCTTTATAGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGTTAGGG', 'GTGTGAACTTAATTAGATCAA')),
#   (1, ('CCATTACT', 'GGTTCAAGGTGATTTTGATAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA'))],
#  {('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'): 2},
#  [(3, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('CTGAATCT', 'AAAGAAAGTGGCTTAGAACAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'CGAATAATTTGTTTCAGCGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAAGCATCTTCTCGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACTTTGAATCAA')),
#   (1, ('ACAGAGCC', 'AGATTAAATGCCTTAATTAAA'))],
#  [(3, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('GTACTTGC', 'GGCGTAAAGACATTGATAAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CACTCAACTTCATTGGACCAA')),
#   (1, ('CATAGTCA', 'GGGGCAAGCGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  {('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA'): 1},
#  [(3, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('TTAATTAG', 'GCTTTAATATGTTTTTTACAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CCATTACT', 'AGAGAAAAGGGGTTAGGGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('CTGAATCT', 'CCACCAACCTCATTACCACAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAAAAAAGTTAAAGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('GTACTTGC', 'TTAGGAAATAGGTTGTCTAAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('GCCAATCG', 'TGCTAAATTATGTTTCCCGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCTCTTTCACCGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(4, ('CCATTACT', 'TAAAGAAGAAAATTACATAAA')),
#   (1, ('GGTAGGGA', 'AATTAAAGTATGTTTCAGCAA'))],
#  [(2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGTTTCCT', 'TTTGCAATGCGTTTGAAATAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CCATTACT', 'TTGTTAAATGTTTTAGGGAAA')),
#   (1, ('CCATTACT', 'CCCCGAAGGTCATTACGCTAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(2, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GTACTTGC', 'ATATAAAGTCTCTTGATCGAA')),
#   (1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGGAAAACAGTATTGATGAAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('GTACTTGC', 'GTAACAAGAAGATTCGAATAA')),
#   (1, ('GCCTACGT', 'TGGGGAATCGGGTTTGTGGAA')),
#   (1, ('CTGAATCT', 'GTCCAAACACTTTTAGTCTAA')),
#   (1, ('CTGAATCT', 'AAAGAAAGTGGCTTAGAACAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAAAAGTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'TTGTTAATCGTCTTTTCAGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTATAAGAA')),
#   (1, ('CCATTACT', 'CCCTCAACCCCCTTCCGCCAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'AAAAAAAAACCATTAAATTAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GGTAGGGA', 'AGATAAATTGGGTTCCCGGAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGACATTTATTCAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAAGCATCTTCTCGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GTACTTGC', 'TTAGGAAATAGGTTGTCTAAA')),
#   (1, ('GGTAGGGA', 'CCGTGAAACTTGTTGAATAAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGTTAGGG', 'ATACTAAGATTTTTTGTTTAA')),
#   (1, ('CGGGAATG', 'GGACTAAGGATTTTGGTTGAA')),
#   (1, ('CCATTACT', 'TTTGTAAGGTTTTTTCTGGAA')),
#   (1, ('CCATTACT', 'GGAGGAAGCCCCTTTCGCAAA')),
#   (1, ('CCATTACT', 'AGCGTAAAGTGGTTGGAGGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'GCTTAAAATTACTTATGCGAA'))],
#  [(2, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (2, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TCAAAAATAATTTTCTATAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GCTTTAAAGGTTTTTCAGAAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAAAAATTAACACAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TTGTTAATCGTCTTTTCAGAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGGGGAA'))],
#  [(2, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TGCTTAATATGTTTTTATTAA')),
#   (1, ('GGTAGGGA', 'TCGGAAAGAGGATTTTTTAAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CCATTACT', 'TAGAAAAAGAGTTTTTGATAA')),
#   (1, ('ACAGAGCC', 'GCATCAAATGCGTTATCGTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'GATCGAAACGGTTTGTTTGAA'))],
#  [(1, ('GTACTTGC', 'TGAGGAACGCTATTCAAAGAA')),
#   (1, ('CTGAATCT', 'TTATTAACTTCTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('ACAGAGCC', 'CGTATAATTTTCTTGGGTAAA'))],
#  [(1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAAGAAAGTGGCTTAGAACAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GGTAGGGA', 'CCGTGAAACTTGTTGAATAAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('ACAGAGCC', 'CGTCTAATTATATTTCTTAAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'AGTACAACGGATTTTGAAAAA'))],
#  [(1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTCAAG', 'CCTATAAACGTTTTCTCTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('CGGGAATG', 'TTTTTAATTTTTTTTTCTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAAATTTATTCTTTTAA'))],
#  [(2, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGGGAATG', 'CCCGCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAAAAGTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACAGAGCC', 'GCTTAAAATTACTTATGCGAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('ACAGAGCC', 'ATTACAATTATTTTGCGGAAA')),
#   (1, ('ACAGAGCC', 'AGATTAAATGCCTTAATTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTGAAAACGTTTTTGTTATAA')),
#   (1, ('CTGAATCT', 'CCACCAACCTCATTACCACAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACACGTGA', 'CAAACAACCACATTACTACAA'))],
#  [(3, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (2, ('ACAGAGCC', 'CGTATAATTTTCTTGGGTAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA'))],
#  [(2, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
# ...
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CGGGAATG', 'TTTGAAAGGTACTTATGTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  {('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'): 1},
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('CATAGTCA', 'TGAAGAATTGGGTTAGTTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('ACAGAGCC', 'TCGGGAACGTGATTCGTAAAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CCATTACT', 'CCCTCAACCCCCTTCCGCCAA')),
#   (1, ('ACACGTGA', 'AAAAGAAGCGGATTGCGAAAA'))],
#  [(2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA'))],
#  [(2, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAAAATTAAAAAAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('CGGGAATG', 'GGTGTAATGGTGTTTTGTAAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'CAATGAAACGGATTGGACAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'TAGAGAATCTCATTCGTTTAA')),
#   (1, ('ACAGAGCC', 'AGATAAACAATATTGAAGTAA'))],
#  [(1, ('GGTAGGGA', 'AATTAAAGTATGTTTCAGCAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'))],
#  {('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA'): 1},
#  [(2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(1, ('ACAGAGCC', 'TAATAAACCACATTATATAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TGTCTAGT', 'TATGAAAGGCTTTTGAGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  {('CCATTACT', 'CAATGAAACGGATTGGACAAA'): 1},
#  [(1, ('CCATTACT', 'CCCTCAACCCCCTTCCGCCAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'GGCCAAAGGTTTTTATCCAAA')),
#   (1, ('GCCTACGT', 'TGGGGAATCGGGTTTGTGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'GCAGCAAACCCATTCACTGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'TGAGGAATATGCTTATCCAAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('TTAATTAG', 'GGAGAAAAGAGGTTATAAGAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCCCAATATTATTCTATGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTTGTGGAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('GGTAGGGA', 'TTATGAACCACTTTTTAAAAA')),
#   (1, ('CTGAATCT', 'CACCCAATACACTTCCCCCAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'CAAGTAAAGAAATTCCATGAA')),
#   (1, ('CGGGAATG', 'GGGAAAACAGTATTGATGAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('CGTTTCCT', 'TTTGCAATGCGTTTGAAATAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTATTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'AGATAAATTGGGTTCCCGGAA'))],
#  [(1, ('GTACTTGC', 'GTGGCAATTTACTTTTGCGAA')),
#   (1, ('GCCAATCG', 'GCAGCAAACCCATTCACTGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAAAAGTTAGAAAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTATAAGAA')),
#   (1, ('TTAATTAG', 'CACAAAATCTGATTCCCACAA')),
#   (1, ('TTAATTAG', 'ACAAAAATAAAATTCTAAAAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('GGTAGGGA', 'TAAACAAGTCGCTTATTCGAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAAACATTAGCACAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TCCAAAAATTTATTAGCAAAA')),
#   (1, ('CATAGTCA', 'GGGGCAAGCGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'GTACGAATTTGCTTTTATTAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('GGTAGGGA', 'AGATAAATTGGGTTCCCGGAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'AGGTGAAAGGTTTTGTTGTAA'))],
#  [(2, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CTGAATCT', 'CCACCAACCTCATTACCACAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTCAAG', 'TATTTAATTGGATTTCCCCAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TCCAAAAATTTATTAGCAAAA')),
#   (1, ('CCATTACT', 'CGTCTAACGGTTTTTGGCAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('GGTAGGGA', 'GCTTTAAAGGTTTTTCAGAAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA'))],
#  {('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'): 1},
#  [(2, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (2, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (2, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (2, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('GCCAATCG', 'ATTTGAAATCAATTATGACAA')),
#   (1, ('CTGAATCT', 'TTGAAAAGGAGTTTGATTTAA')),
#   (1, ('CGTTAGGG', 'GCTTCAAGTAGTTTGGTCTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'TTGTTAAATGTTTTAGGGAAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'AAAAAAAAGTGCTTGACAAAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA'))],
#  [(1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('CCATTACT', 'AGGGAAAAGTAGTTGGATAAA')),
#   (1, ('GTACTTGC', 'AACCCAAGCTCGTTCGTATAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA'))],
#  [(1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'CAAATAAATACATTATACAAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CGGGAATG', 'AAAAGAAAAAGATTAAAAAAA'))],
#  [(1, ('GTACTTGC', 'GTAACAAGAAGATTCGAATAA')),
#   (1, ('GGTAGGGA', 'CAAATAAATACATTATACAAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTAGGG', 'CAAGTAAAGAAATTCCATGAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('ACACGTGA', 'GGGTGAATGAAGTTGGGTTAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAACCTTTTTTTGTGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'CAGTCAAAGTCATTGCGCTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('GGTAGGGA', 'TTGTCAATCATTTTCTAACAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GTGATAAGGGAGTTAAAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'CTTTGAATTAGCTTTATAGAA')),
#   (1, ('CTGAATCT', 'TCACCAACCCCTTTCCGTCAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGTTCAAG', 'GTCATAAACGATTTCTTATAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GGTAGGGA', 'TTATGAACCACTTTTTAAAAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('GTACTTGC', 'GTGGCAATTTACTTTTGCGAA')),
#   (1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('GGTAGGGA', 'AATTAAAGTATGTTTCAGCAA')),
#   (1, ('CTGAATCT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'AGAATAACTTGTTTAGATTAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACAGAGCC', 'AGATTAAATGCCTTAATTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'AGAATAACTTGTTTAGATTAA')),
#   (1, ('CCATTACT', 'AAAAAAATGTATTTCAAACAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTATAAGAA')),
#   (1, ('GGTAGGGA', 'TTGTCAATCATTTTCTAACAA')),
#   (1, ('GCCTACGT', 'AGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'ATACTAAGATTTTTTGTTTAA')),
#   (1, ('CCATTACT', 'TAGAAAAAGAGTTTTTGATAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(3, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'GGCGGAAGGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTATAAGAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('ACAGAGCC', 'TTACAAACATGTTTAATAAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('GTACTTGC', 'TTACAAAAATTGTTGTGAAAA')),
#   (1, ('GTACTTGC', 'TGAGTAATCAGCTTGACACAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACACGTGA', 'TGGTTAATTTTGTTTTTTGAA'))],
#  [(1, ('GTACTTGC', 'ATATAAAGTCTCTTGATCGAA')),
#   (1, ('CATAGTCA', 'AAACAAAAAAAATTAAAACAA')),
#   (1, ('ACAGAGCC', 'ATTACAATTATTTTGCGGAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('CCATTACT', 'TCCAAAAATTTATTAGCAAAA'))],
#  [(1, ('TCTGGGGC', 'TGGTGAAAGTGTTTGGTTTAA')),
#   (1, ('ACAGAGCC', 'TTGTTAATCGTCTTTTCAGAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(1, ('CGTTCAAG', 'GTCATAAGTATTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'GTGGGAAAACGCTTGGGCCAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(1, ('TTAATTAG', 'TATATAATTTTCTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAACGAGGTTGTCGGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GCTTTAAAGGTTTTTCAGAAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CCATTACT', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('CCATTACT', 'AGAATAACTTGTTTAGATTAA')),
#   (1, ('ACAGAGCC', 'AGTACAACGGATTTTGAAAAA'))],
#  [(3, ('CTGAATCT', 'TTGAAAACGTCTTTGTTATAA')),
#   (1, ('CGTTAGGG', 'TCTTGAATTTCATTTCAACAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'AAAACAACACGGTTCCAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GGCTGAAAGTCTTTTCTGCAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCTCTTTCACCGAA')),
#   (1, ('CCATTACT', 'TGTTTAATTTATTTTTGGTAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAATACATTGAATCAA')),
#   (1, ('ACAGAGCC', 'CGTCTAATTATATTTCTTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGAGGTTGGGAGAA')),
#   (1, ('CGTTAGGG', 'TTGAGAATCTCCTTAGCAGAA')),
#   (1, ('CGTTAGGG', 'GTTCCAAGGACATTAACATAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('ACAGAGCC', 'AAGGTAAAAAACTTTGTATAA')),
#   (1, ('ACACGTGA', 'AAAAGAAGCGGATTGCGAAAA'))],
#  [(2, ('TTAATTAG', 'TTTTCAATATTATTCTTATAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('CGTTTCCT', 'TTTGCAATGCGTTTGAAATAA')),
#   (1, ('ACAGAGCC', 'CGTATAATTTTCTTGGGTAAA'))],
#  [(1, ('TTAATTAG', 'TTTCAAACTTACTTCTCGCAA')),
#   (1, ('TGTCTAGT', 'TATGAAAGGCTTTTGAGGGAA')),
#   (1, ('GGTAGGGA', 'TCCAAAAATATTTTAAGTTAA')),
#   (1, ('GCCAATCG', 'GCAGCAAACCCATTCACTGAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'GGTTCAAGGTGATTTTGATAA'))],
#  [(2, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('CTGAATCT', 'AAAGAAAGTGGCTTAGAACAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  [(2, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (2, ('ACAGAGCC', 'TCGGGAACGTGATTCCTAAAA')),
#   (1, ('GCCTACGT', 'TGGGGAATCGGGTTTGTGAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('CCATTACT', 'CCCGTAATCCTTTTTTCGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('ACACGTGA', 'GGGTGAATGAAGTTGGGTTAA'))],
#  {('ACACGTGA', 'TTTTTAAATTTTTTCTTTTAA'): 1},
#  [(1, ('GTACTTGC', 'TTAGGAAATAGGTTGTCTAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GGGTGAATGAAGTTGGGTTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGTAAGGATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCATTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTACAAATTTACTTTATTTAA'))],
#  [(2, ('CGGGAATG', 'CCACGAAAATGATTCAAGAAA')),
#   (1, ('GGTAGGGA', 'CAAATAAATACATTATACAAA')),
#   (1, ('GCCTACGT', 'AGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TCCAGAAGGCCATTTATTCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CATAGTCA', 'GGCGGAAGCGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'TTTTGAAGGTTTTTGATGTAA'))],
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 2734

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
