# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist3.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7902

# %%
afile = pysam.AlignmentFile("./final.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %%
totalUMI = 0
for cellUMI in cellbyUMI:
    totalUMI += len(cellbyUMI[cellUMI])
print(totalUMI)
# Out:
# 8585067

# %%
print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))
# Out:
# In Whitelist UMI: 7902
# Out Whitelist UMI: 527149
# In Whitelist Reads: 197914931
# Out Whitelist Reads: 52346255

# %%
import pickle
with open('cellbyUMI.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 66

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 7902

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 7837

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] < threshold: 
                print("Not past threshold: %s" % str(newUMI))
            else:
                ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
#_ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')

plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# is zero

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (31.385220125786162, 1, 2334, 1.0)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(count, bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 7485

# %%
len(whitelist)
# Out:
# 7902

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 351

# %%
poorUMI
# Out:
# [[(24, ('CCATTACT', 'TGTAGAAGGTGGTTTGCACAA')),
#   (21, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(64, ('GGTAGGGA', 'ATGTCAATGAGATTTGGCGAA')),
#   (60, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(29, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (28, ('CTGAATCT', 'TTGTTAATGTTTTTTTTTTAA'))],
#  [(29, ('TTAATTAG', 'ATCGGAAGGCGTTTTAAGAAA')),
#   (27, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(5, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (3, ('CCATTACT', 'ATAGTAAAATAGTTACAATAA'))],
#  [(30, ('TTAATTAG', 'TGAGAAATTATGTTATTTGAA')),
#   (27, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(5, ('TTAATTAG', 'AACAAAAACGGATTATACAAA')),
#   (3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(35, ('GCCTACGT', 'TGTTGAATGTGTTTGTTATAA')),
#   (28, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(4, ('GGTAGGGA', 'AAATTAAAAAGTTTTTGTGAA')),
#   (2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(34, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (32, ('CTGAATCT', 'TTTTTAATCTTTTTTTTTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'TTGACAACATCATTGCTTGAA'))],
#  [(3, ('CCATTACT', 'AGGTTAAAGGTTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(22, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (21, ('TGTCTAGT', 'GGTGGAAGTTTGTTGGGGTAA'))],
#  [(4, ('TTAATTAG', 'TTTTTAAATTTTTTCTTTTAA')),
#   (2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(35, ('ACAGAGCC', 'CGTATAAAATTATTATATGAA')),
#   (30, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(4, ('GGTAGGGA', 'ACTTTAATATGGTTACTATAA')),
#   (4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAATTTGTTTGGTGAA')),
#   (1, ('ACACGTGA', 'GAATGAAACGTATTGGCAGAA'))],
#  [(22, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (20, ('CCATTACT', 'AAAAAAAAGTGCTTAAAAAAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'GGCAAAAAAATGTTAAAACAA')),
#   (1, ('GTACTTGC', 'GACGCAAAGGGCTTGAAAGAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  [(38, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (34, ('ACAGAGCC', 'CACATAATGTCATTAGGTTAA'))],
#  [(15, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (11, ('ACAGAGCC', 'GTGTAAACGGATTTTCTTTAA'))],
#  [(8, ('GGTAGGGA', 'TTGCTAACAAAGTTGCCCCAA')),
#   (8, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA'))],
#  [(15, ('GCCTACGT', 'TGTTGAATGTGTTTGTTATAA')),
#   (9, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(4, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA')),
#   (3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(10, ('ACAGAGCC', 'CACATAATGTCATTAGGTTAA')),
#   (9, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(9, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA')),
#   (5, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'AACAAAAACGGATTATACAAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAATTTGTTTGGTGAA'))],
#  [(9, ('CCATTACT', 'CCTCCAAGCCCCTTCCACAAA')),
#   (5, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('CGTTAGGG', 'GTCGTAAGTGACTTATCTTAA')),
#   (2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(15, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (14, ('GCCTACGT', 'TTGGGAATGTTTTTTTTGTAA'))],
#  [(6, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (4, ('CGTTCAAG', 'GCTGGAATGTGTTTCAGGGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(6, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (5, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA')),
#   (2, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(6, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (4, ('TGTCTAGT', 'GGTGGAAGTTTGTTGGGGTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(6, ('TTAATTAG', 'GGCAAAAAAATGTTAAAACAA')),
#   (3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(13, ('GGTAGGGA', 'ATGTCAATGAGATTTGGCGAA')),
#   (13, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA'))],
#  [(1, ('GTACTTGC', 'TATTTAATGCTGTTACTTTAA')),
#   (1, ('ACAGAGCC', 'AGTCTAACACTTTTGCTACAA')),
#   (1, ('ACACGTGA', 'GAATGAAACGTATTGGCAGAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA')),
#   (1, ('CGGGAATG', 'GAATAAAGCCATTTCTCCCAA'))],
#  [(15, ('GGTAGGGA', 'GAACGAAGCCTCTTAGTACAA')),
#   (11, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA')),
#   (3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  [(19, ('GGTAGGGA', 'ACACTAATTATATTTTGTAAA')),
#   (13, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(7, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (3, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGTTTGTTGGGGTAA'))],
#  [(5, ('CCATTACT', 'CCCCTAACCTGCTTCAGTTAA')),
#   (3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(4, ('GGTAGGGA', 'CTAATAAAAAATTTATTCGAA')),
#   (4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CTGAATCT', 'TTTTTAATCTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCGGTTTTGGTTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'TAGACAATGTGTTTCCTTGAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'TTTCGAATTTTCTTGATATAA')),
#   (1, ('CCATTACT', 'TGTTTAATTATTTTTGGTTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGTGAGTTGGAGGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(2, ('TTAATTAG', 'AACAAAAACGGATTATACAAA')),
#   (2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACACGTGA', 'GAATGAAACGTATTGGCAGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(3, ('TTAATTAG', 'GGCAAAAAAATGTTAAAACAA')),
#   (3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'TGGGAAAACAGTTTTTACAAA')),
#   (1, ('ACAGAGCC', 'AGTCTAACACTTTTGCTACAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(1, ('TTAATTAG', 'TTTTTAATAATTTTTTTTTAA')),
#   (1, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACACGTGA', 'GGAAAAACCGGATTGGAAGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAATTTGTTTGGTGAA')),
#   (1, ('ACACGTGA', 'GAATGAAACGTATTGGCAGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(2, ('ACACGTGA', 'ACCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACACGTGA', 'GAATGAAACGTATTGGCAGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCGGTTTTGGTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(7, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (3, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (2, ('GGTAGGGA', 'GAAAAAAGTAAATTTCTCAAA')),
#   (1, ('CTGAATCT', 'ACACCAACCCCCTTCCACCAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CTGAATCT', 'TTGTTAATGTTTTTTTTTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('CCATTACT', 'TTCTTAATGTTATTTTGCAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'TGGGAAAACAGTTTTTACAAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'AACAAAAACGGATTATACAAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'TTTCGAATTTTCTTGATATAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (2, ('GGTAGGGA', 'GGTTGAAAAAATTTCACATAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('TTAATTAG', 'TTTTTAATATTTTTCTATCAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('CGGGAATG', 'GGGGGAAGGGGGTTTGGGGAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CTGAATCT', 'CTCCCAAGCCACTTCCATCAA'))],
#  [(1, ('CGTTCAAG', 'GCTGGAATGTGTTTCAGGGAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGTATTTCGAGGAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTTGGGGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGAACAATGAATTTTTTTCAA')),
#   (1, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('ACAGAGCC', 'AGTCTAACACTTTTGCTACAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGTTAGGG', 'TTGGCAATTTTCTTGCATCAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GTACTTGC', 'TATTTAATGCTGTTACTTTAA'))],
#  {('ACAGAGCC', 'GTTATAAGTCATTTCTTTTAA'): 1},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'AGGTTAAAGGTTTTGGTGGAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGTTTGTTGGGGTAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACAGAGCC', 'CACATAATGTCATTAGGTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('TTAATTAG', 'AACAAAAACGGATTATACAAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('GGTAGGGA', 'TCATTAAATATTTTATTTAAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'CCCCTAACCTGCTTCAGTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'TTCTTAATGTTATTTTGCAAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GTACTTGC', 'TATTTAATGCTGTTACTTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(1, ('ACACGTGA', 'TGTTTAATTTTTTTGTTTGAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCAAACCCGGTTCCCCTAA'): 2},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GTATTAAGGTCGTTGAATCAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GCCAATCG', 'TATCTAAATTCATTTGCTGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'AGGTTAAAGGTTTTGGTGGAA'))],
#  [(1, ('ACAGAGCC', 'AGTCTAACACTTTTGCTACAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCGGTTTTGGTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('TGTCTAGT', 'GGTGGAAGTTTGTTGGGGTAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'TGTATAATTCGTTTGGAGTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('GGTAGGGA', 'TACACAACCTATTTGGGACAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GTACTTGC', 'GCCTAAATTCTCTTAGCCTAA')),
#   (1, ('CGTTCAAG', 'AATCAAAACTGGTTGTTACAA')),
#   (1, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTTGGGGAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACAGAGCC', 'TGGTCAAACTTTTTGCCTGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGTTAGGG', 'GTCTCAATTAATTTGCGAAAA'))],
#  [(1, ('GTACTTGC', 'TCACTAATGTTGTTAATACAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'AGGTTAAAGGTTTTGGTGGAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTACATAA')),
#   (1, ('CCATTACT', 'AGGTTAAAGGTTTTGGTGGAA'))],
#  [(1, ('CTGAATCT', 'TTACTAAAATCATTTTGTTAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GTACTTGC', 'TATTTAATGCTGTTACTTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('GTACTTGC', 'TATTTAATGCTGTTACTTTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAATTTGTTTGGTGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(1, ('CCATTACT', 'AAAAAAAAGTGCTTAAAAAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('CTGAATCT', 'TTACTAAAATCATTTTGTTAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCGGTTTTGGTTAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'ATGTCAATGAGATTTGGCGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACAGAGCC', 'CACATAATGTCATTAGGTTAA'))],
#  [(1, ('GCCTACGT', 'TTGGGAATGTTTTTTTTGTAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGTTCAAG', 'TATAGAATACTCTTAATGTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  [(1, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA')),
#   (1, ('GGTAGGGA', 'ACCAGAAAACTATTAAGATAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'TACACAACCTATTTGGGACAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGTTCAAG', 'AAGTTAACATATTTGCTTTAA')),
#   (1, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'AACAAAAACGGATTATACAAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('CGTTTCCT', 'AACACAATCGTTTTTATAAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGTGAGTTGGAGGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GCCAATCG', 'TATCTAAATTCATTTGCTGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('TTAATTAG', 'AACAAAAACGGATTATACAAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('TTAATTAG', 'TCCGGAATATTTTTCTATCAA'): 1},
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CGTTCAAG', 'GCTGGAATGTGTTTCAGGGAA'))],
#  [(2, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACAGAGCC', 'CACATAATGTCATTAGGTTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('TTAATTAG', 'AACAAAAACGGATTATACAAA'): 1},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('ACAGAGCC', 'AGTCTAACACTTTTGCTACAA'))],
#  [(1, ('CTGAATCT', 'TTGTTAATGTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCAAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (2, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'AGCCAAAAGAAATTCAATAAA'))],
#  [(1, ('TTAATTAG', 'AACAAAAACGGATTATACAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('CCATTACT', 'AGGTTAAAGGTTTTGGTGGAA'))],
#  [(4, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('TTAATTAG', 'GGAGCAAAGAGGTTGGGGGAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('GGTAGGGA', 'GACGAAAGACAGTTCGGGAAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(3, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA')),
#   (1, ('GGTAGGGA', 'TCATTAAATATTTTATTTAAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('TTAATTAG', 'TCCGGAATATTTTTCTATCAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  [(1, ('GGTAGGGA', 'GGGACAAATATTTTTCCATAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('CGGGAATG', 'GGGGGAAGTGAGTTGGAGGAA')),
#   (1, ('CCATTACT', 'TGGTTAAGGATTTTGTGGTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  [(1, ('GGTAGGGA', 'TTCCTAAAGTGTTTTATTTAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('CGTTAGGG', 'AACACAAGATCTTTCCCGGAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('CCATTACT', 'AGGTTAAAGGTTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('TTAATTAG', 'GGAGCAAAGAGGTTGGGGGAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 3},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  [(1, ('TGTCTAGT', 'GGGGGAATTTCATTAGTCGAA')),
#   (1, ('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'))],
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 2},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1},
#  {('ACACGTGA', 'CCCCGAACCCGGTTCCCCTAA'): 1}]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 7485

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
