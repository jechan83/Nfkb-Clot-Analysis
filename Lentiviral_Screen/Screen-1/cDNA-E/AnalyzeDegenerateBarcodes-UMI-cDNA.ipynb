# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist5.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 9472

# %% [raw]
# afile = pysam.AlignmentFile("./final.bam")
# hashcount = {}
# hashset = {}
# cellhash = {}
# taghash = {}
# readcount = {}
# barcodehash = {} # barcodes listing shRNAID
# barcodebycellUMI = {} # barcode listing cellUMI
# doublecounts = 0
# cellbyUMI = {}
# inwhitelist = set()
# inwhitelistcount = 0
# outwhitelist = set()
# outwhitelistcount = 0
# for seq_record in afile.fetch(until_eof=True):
#     cellUMI = None  # here this is the CellRanger cell UMI
#     UMI = None
#     if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
#     cellUMI = seq_record.get_tag("CB")
#     if cellUMI not in whitelist:
#         outwhitelistcount +=1
#         if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
#         continue
#     else:
#         inwhitelistcount += 1
#         if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
#     UMI = seq_record.get_tag("UB") # umi barcode
#
#     m = hashmatch.search(seq_record.query_sequence)
#     if m == None or (m.end() + 8) > len(seq_record.query_sequence):
#         #print("Error, match not found")
#         continue
#     shRNAID = seq_record.query_sequence[m.end():m.end()+8]
#     barcode = seq_record.query_sequence[m.end()-21:m.end()]
#     sbID = (shRNAID,barcode)
#     if shRNAID not in hashes: continue
#     if cellUMI not in cellbyUMI:
#         cellbyUMI[cellUMI] = {}
#     if UMI not in cellbyUMI[cellUMI]:
#         cellbyUMI[cellUMI][UMI] = {sbID: 1}
#         continue
#     if sbID in cellbyUMI[cellUMI][UMI]:
#         cellbyUMI[cellUMI][UMI][sbID] += 1
#     else:
#         hamming = False
#         for x in cellbyUMI[cellUMI][UMI]:
#             if hammingDistance(sbID[1],x[1]) <= 2:
#                 cellbyUMI[cellUMI][UMI][x] += 1
#                 hamming = True
#                 break
#         if hamming: continue
#         cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle
cellbyUMI = False
with open('cellbyUMI.pickle', 'rb') as f:
    cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 48

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 9471

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 8961

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] > threshold: 
                ncellbyUMI[y] = newUMI[0][1]
            else:
                print("Not past threshold: %s" % str(newUMI))
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        #print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (9.851037746607366, 1, 2228, 1.0)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 3537

# %%
len(whitelist)
# Out:
# 9472

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 5343

# %%
poorUMI
# Out:
# [[(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CTGAATCT', 'TTTTAAACGCTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCAACCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'CCTTTAACACACTTGCACCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('CTGAATCT', 'CCATAAACCCCCTTACTCCAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTGGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'GGTGAAATGGTGTTAAGACAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'GCTTCAAGATGTTTACGAGAA')),
#   (1, ('GGTAGGGA', 'AACTTAAAGATCTTATTAAAA')),
#   (1, ('CGTTCAAG', 'GTTATAATTCAATTTCTAGAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TGTCGAAGTAGGTTCTGTTAA')),
#   (1, ('CATAGTCA', 'TGAAAAAGCATGTTGCGGGAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTGTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATGTCGTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TGGCCAACGTTGTTATCAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CTTAAAACGCTGTTTTCCCAA')),
#   (1, ('CGTTCAAG', 'GTTATAATTCAATTTCTAGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TTAATTAG', 'GGTGTAATTATTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'CCCAAAAAACACTTAACCCAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CGCTGAATACCTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (1, ('ACAGAGCC', 'TTTGTAATTTATTTGTATGAA')),
#   (1, ('ACACGTGA', 'GGGTGAAGGGTTTTTGATGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'TATGTAATCAGCTTCGCTAAA')),
#   (1, ('GGTAGGGA', 'TTACTAATAGCCTTATTGGAA')),
#   (1, ('ACAGAGCC', 'TTAAAAAAAAGGTTCCGTAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGGTGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GAAGGAAGGAAGTTAAGACAA')),
#   (1, ('TTAATTAG', 'CAAGGAACAAGGTTATAAAAA')),
#   (1, ('TTAATTAG', 'AATGGAATATCTTTCTCTCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACCCGCTTCCCCGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CAATTAAACACATTACAAGAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGTGAATTGTGTTTGTGTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAGATTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA')),
#   (1, ('ACACGTGA', 'ATGAGAAACGAGTTTGAATAA'))],
#  [(3, ('TGTCTAGT', 'TCTTAAATTTTTTTTATTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(1, ('TGTCTAGT', 'CACCCAACGCAATTCCAACAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  [(3, ('CGGGAATG', 'CCCCCAAAACCCTTTTCGCAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTGTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('GTACTTGC', 'GTCACAATGCACTTAACAAAA')),
#   (1, ('CTGAATCT', 'TGGCCAATCTTTTTCAGTTAA')),
#   (1, ('CTGAATCT', 'AAAAAAAACGGATTGATAGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTTCCT', 'AAGAAAACTACTTTTCGTTAA')),
#   (1, ('CGTTAGGG', 'GTTACAAATGAGTTGGATAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA')),
#   (1, ('CCATTACT', 'CTTTTAATTGCATTTTGTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTCTAATACTTTTATTTCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('CGTTAGGG', 'CCCGTAACGAGGTTTACCAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CAGTGCAT', 'TGCATAAGTCCATTGTTGTAA'))],
#  [(2, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA'))],
#  [(4, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTGGTTGGTGGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTCAAG', 'GAATGAATCGAATTGTATCAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGTTGGTTTTTTGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCGCTTTCCGGAAA')),
#   (1, ('ACAGAGCC', 'ATGATAATAGCGTTTATGCAA'))],
#  [(1, ('TTAATTAG', 'TTCGGAAATATTTTCGTATAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('CGGGAATG', 'TCTGTAATTGGGTTTGATGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCAACCAA')),
#   (1, ('CCATTACT', 'TGGTGAACGTGTTTATATTAA'))],
#  [(3, ('CGTTAGGG', 'GAACGAATAACGTTGATAAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTAGGG', 'TCATAAACAAAATTTCTCAAA'))],
#  [(5, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('CTGAATCT', 'CCACCAACAACCTTCACTCAA'))],
#  [(2, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CGGGAATG', 'CCCCCAAAACCCTTTTCGCAA')),
#   (1, ('CCATTACT', 'TGGGCAATGCGGTTTAACGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'AGACGAAGGGGGTTGGGGTAA')),
#   (1, ('CCATTACT', 'CTTTTAATTGCATTTTGTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA'))],
#  [(2, ('TTAATTAG', 'AAGACAAGAAAATTCAACAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATAATTTTCTTTCAA')),
#   (1, ('TGTCTAGT', 'TTTTGAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'TGGCCAACGTTGTTATCAGAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTGGTTGGGTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'TACAAAACCCGATTCAGTCAA')),
#   (1, ('CGTTAGGG', 'GTGTAAATCCGTTTGCGAAAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('CCATTACT', 'AGGGAAAGGAAGTTTAGGGAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA'))],
#  [(4, ('TGTCTAGT', 'TCGAGAAGCCCTTTGACGCAA')),
#   (4, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA'))],
#  [(1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'CGCCCAACCACCTTCACCAAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('CGTTAGGG', 'TATAGAACTAGTTTAACTCAA'))],
#  [(3, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(2, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CAAGAAACTGGATTAAAAGAA'))],
#  [(2, ('TGTCTAGT', 'AAGAGAAAACGATTAGAAAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTTCCT', 'TACAAAACCCGATTCAGTCAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('CATAGTCA', 'AACTAAAGGATCTTGGTCCAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'TACAAAACCCGATTCAGTCAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('CGGGAATG', 'GGGAGAAAAGAGTTGAAGGAA')),
#   (1, ('TTAATTAG', 'TGTTAAATGAGTTTCTTTGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'GTGAGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TGTGCAAAGCTTTTGTGGTAA')),
#   (1, ('TTAATTAG', 'GAAGGAAGGAAGTTAAGACAA')),
#   (1, ('TGTCTAGT', 'CAAACAAAAACATTAAAACAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA')),
#   (1, ('CCATTACT', 'CTATTAACTCCGTTACTCTAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGTTTGGAGAAA')),
#   (1, ('ACAGAGCC', 'TGAAAAATTGGTTTGATATAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('GGTAGGGA', 'TCCTGAACGTTTTTTTCCTAA')),
#   (3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('CGTTCAAG', 'TTTAAAAGATTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'AAATCAATACAATTAAAGCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GGCCAAATCTTCTTTCACGAA')),
#   (1, ('ACAGAGCC', 'CGGCTAACGACTTTAACCTAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACCCGCTTCCCCGAA')),
#   (1, ('TGTCTAGT', 'AAGAGAAAACGATTAGAAAAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAACACTTAAAAGAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCGCTTTCCGGAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(3, ('TTAATTAG', 'TTTTTAAATTTTTTCTTTCAA')),
#   (1, ('CCATTACT', 'TGGTGAACGTGTTTATATTAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGAGTTAGAAGAA')),
#   (1, ('GTACTTGC', 'GCTTCAAGATGTTTACGAGAA')),
#   (1, ('GGTAGGGA', 'GCGGCAACGCAATTCCGTCAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('CGTTTCCT', 'AAGAAAACTACTTTTCGTTAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'TGGTGAAGGTTGTTGTGTGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CAGTGCAT', 'TGCATAAGTCCATTGTTGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CGAGTAATCCTTTTGTTTAAA')),
#   (1, ('ACACGTGA', 'CACCAAACACAGTTCCGATAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAGTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATGTGGTTGATGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CCTTTAACGTTCTTATTGTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('ACAGAGCC', 'TGAATAACGTATTTAGACAAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA'))],
#  [(2, ('TGTCTAGT', 'TTTTTAATGTCGTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TCTTAAAAATTTTTCTTGCAA')),
#   (1, ('TTAATTAG', 'GCCTAAAGACCCTTCCTACAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GTACTTGC', 'TATGTAATCAGCTTCGCTAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(2, ('CGTTTCCT', 'CAAATAAGCGCCTTTTAATAA')),
#   (1, ('TGTCTAGT', 'AAAGCAAAAAAATTATAAAAA')),
#   (1, ('CGTTTCCT', 'AAGAAAACTACTTTTCGTTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATATTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGGGTTGGGGGAA')),
#   (1, ('TCTGGGGC', 'AACAAAAAAAAATTAACAAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTAGGG', 'GTTACAAATGAGTTGGATAAA')),
#   (1, ('CCATTACT', 'ATGAAAAACGGCTTGGTATAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GCCAATCG', 'TTAGAAAAGGAGTTTATTAAA')),
#   (1, ('CTGAATCT', 'CCACCAACAACCTTCACTCAA')),
#   (1, ('CCATTACT', 'GCAGGAAGTATTTTACTAGAA')),
#   (1, ('ACAGAGCC', 'TGAATAACGTATTTAGACAAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCAAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'TTTTTAACTGATTTCCTATAA')),
#   (1, ('GGTAGGGA', 'CCTTTAACGTTCTTATTGTAA')),
#   (1, ('GGTAGGGA', 'AATCCAAACGCGTTTGCTTAA')),
#   (1, ('GCCAATCG', 'TTAGAAAAGGAGTTTATTAAA')),
#   (1, ('CTGAATCT', 'CTCTTAACCCCCTTTCCCAAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCAGTTTCGAGGAA')),
#   (1, ('CCATTACT', 'TGCCGAAGTGTTTTTTGTGAA')),
#   (1, ('CCATTACT', 'ATGAAAAACGGCTTGGTATAA')),
#   (1, ('CATAGTCA', 'TGAAAAAGCATGTTGCGGGAA')),
#   (1, ('ACACGTGA', 'CAAACAAGCGGATTGGGGGAA'))],
#  [(3, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'ATGCAAAAGAAATTAGAGGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  {('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA'): 1},
#  [(2, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TGTGCAAAGCTTTTGTGGTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CAACCAACGATTTTACACTAA')),
#   (1, ('TGTCTAGT', 'AGACGAAGGGGGTTGGGGTAA')),
#   (1, ('GGTAGGGA', 'AACTTAAAGATCTTATTAAAA')),
#   (1, ('CTGAATCT', 'GTGTAAATGTTGTTTTTTTAA')),
#   (1, ('CTGAATCT', 'AAAAAAAACGGATTGATAGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  [(3, ('GCCTACGT', 'GAAAAAAAAAAATTAAAAAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'ATGAGAAACGAGTTTGAATAA'))],
#  [(1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA')),
#   (1, ('CGGGAATG', 'CCCAAAAAACACTTAACCCAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TGCAGAAGAGGGTTAGGAGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('ACAGAGCC', 'TTTGTAATTTATTTGTATGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTCAATTTTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GTTTTAATTTCTTTGCTTTAA')),
#   (1, ('TGTCTAGT', 'GTGTGAATTGTGTTTGTGTAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'GGGTGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GCATAAATGCGGTTATGAGAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTTATTGGGGTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('CTGAATCT', 'CCATAAACCCCCTTACTCCAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAACTTCATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA'))],
#  [(7, ('TGTCTAGT', 'CGCTGAATACCTTTTATTTAA')),
#   (3, ('CGTTCAAG', 'GCGTAAACAACTTTAGAGCAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (3, ('CGGGAATG', 'TTTTTAAGTTGGTTTTTTGAA')),
#   (2, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGAAATTAGAAGAA')),
#   (1, ('CGTTCAAG', 'TCTATAACGAATTTTACGAAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGCGGTTTAACGAA'))],
#  [(2, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('TTAATTAG', 'TGTTAAATGAGTTTCTTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTGTGTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CAACCAACGATTTTACACTAA')),
#   (1, ('GTACTTGC', 'GCTTCAAGATGTTTACGAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA')),
#   (1, ('CCATTACT', 'TGTCGAAGTAGGTTCTGTTAA'))],
#  [(1, ('TTAATTAG', 'TTCGGAAATATTTTCGTATAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGCAAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCAATCG', 'TTAGAAAAGGAGTTTATTAAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTCGGAAA')),
#   (1, ('CGTTCAAG', 'GGGGAAACGAGGTTTATTTAA')),
#   (1, ('CCATTACT', 'CTATTAACTCCGTTACTCTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GCCTACGT', 'TTTGCAAGAAATTTTATATAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CGCTGAATACCTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('CTGAATCT', 'CCACCAACAACCTTCACTCAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTCCCAA')),
#   (1, ('CGGGAATG', 'CCCAAAAAACACTTAACCCAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'ATCAAAAAAAAATTAGATTAA')),
#   (1, ('GTACTTGC', 'GTCACAATGCACTTAACAAAA'))],
#  [(3, ('CGTTAGGG', 'TCATAAACAAAATTTCTCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'AAGAAAACTACTTTTCGTTAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('CCATTACT', 'ATGAAAAACGGCTTGGTATAA')),
#   (1, ('ACAGAGCC', 'TGATCAACGACATTCATTAAA'))],
#  [(3, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTGTTAA')),
#   (1, ('TTAATTAG', 'TTCGGAAATATTTTCGTATAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CCATTACT', 'CTTTTAATTGCATTTTGTTAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('ACAGAGCC', 'ATGATAATAGCGTTTATGCAA')),
#   (1, ('TTAATTAG', 'TTTTCAATTTTATTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAACTTCATTGGGAGAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGTTAGGG', 'CGCTAAATGACTTTGTCCTAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCGCTTTCCGGAAA')),
#   (1, ('CATAGTCA', 'TGAAAAAGCATGTTGCGGGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGCAAA')),
#   (1, ('CGTTCAAG', 'GGGGAAACGAGGTTTATTTAA'))],
#  [(1, ('TTAATTAG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GAAGGAAGGAAGTTAAGACAA')),
#   (1, ('TTAATTAG', 'AACGCAAAGAATTTAATACAA')),
#   (1, ('TCTGGGGC', 'TACTCAAGGGGCTTATCTAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTTGATTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTCAAG', 'TTTAGAAGTTTTTTCCAGTAA')),
#   (1, ('CGTTAGGG', 'AAATAAAAATTTTTCTGAGAA')),
#   (1, ('CGGGAATG', 'TTTTGAATCTGTTTTGTTGAA')),
#   (1, ('CAGTGCAT', 'TTTATAACATTATTTATTGAA')),
#   (1, ('CAGTGCAT', 'TGCATAAGTCCATTGTTGTAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACAGAGCC', 'TTTGTAATTTATTTGTATGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CAAAAAAGCGAATTGAGAAAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'CCCTCAACCCCCTTCCCCCAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAACAATTAAAAGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACAGAGCC', 'CTCTTAAACATTTTTGTATAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('CAGTGCAT', 'GTCTTAATATATTTTGCACAA'))],
#  [(2, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGTTGAAGGTCGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'AAAGAAAATAAATTAAACGAA')),
#   (1, ('TCTGGGGC', 'TTTACAATCATTTTCTCCTAA')),
#   (1, ('GGTAGGGA', 'CCTTTAACGTTCTTATTGTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCTTTTCGCTTAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGTTTGGAGAAA'))],
#  [(3, ('TGTCTAGT', 'GGTTGAAGGTCGTTGGGGGAA')),
#   (3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTCCCAA')),
#   (1, ('CAGTGCAT', 'GTATGAAGGAAGTTCGTACAA'))],
#  [(1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('CGTTTCCT', 'TACAAAACCCGATTCAGTCAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'TGTGCAAAGCTTTTGTGGTAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CGGGTAATCCTTTTGTTTAAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATCATTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGGGAATG', 'GGGAGAAAAGAGTTGAAGGAA'))],
#  [(1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CAGTGCAT', 'TTTTCAAAGTACTTACCACAA')),
#   (1, ('ACAGAGCC', 'TTTGTAATTTATTTGTATGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  [(1, ('GGTAGGGA', 'TGTGCAATGATCTTGCATTAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('CGTTAGGG', 'TATTGAAATCGGTTTGAACAA'))],
#  [(1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACCCGCTTCCCCGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CCATTACT', 'ACAAAAAGGAGATTAAAAAAA')),
#   (1, ('ACAGAGCC', 'TGAAAAATTGGTTTGATATAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'AAAGAAAATAAATTAAACGAA')),
#   (1, ('GTACTTGC', 'TATGTAATCAGCTTCGCTAAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('CGTTAGGG', 'GTTACAAATGAGTTGGATAAA')),
#   (1, ('CGGGAATG', 'GAACTAAGGAATTTAACAAAA')),
#   (1, ('CCATTACT', 'TGGGCAATGCGGTTTAACGAA')),
#   (1, ('ACAGAGCC', 'ATGATAATAGCGTTTATGCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GTACTTGC', 'GAAGAAATCAACTTGCCTAAA')),
#   (1, ('CGGGAATG', 'CCCAAAAAACACTTAACCCAA'))],
#  [(3, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('TTAATTAG', 'GGGGAAAGGGTGTTATGCCAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'AAAGAAAATAAATTAAACGAA')),
#   (1, ('TCTGGGGC', 'AACAAAAAAACATTAACCGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'TCTGTAATTGGGTTTGATGAA')),
#   (1, ('CCATTACT', 'GGAACAAAGTAATTGGCAAAA'))],
#  [(1, ('CGTTCAAG', 'CCTCTAAATCTCTTGCCCTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  {('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA'): 1},
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TGTGCAAAGCTTTTGTGGTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCAGTTTCGAGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('TTAATTAG', 'ACCCGAAAGTACTTCACACAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATTTTATTTTTTCAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTATTGGAA')),
#   (1, ('TGTCTAGT', 'CAACCAACGATTTTACACTAA')),
#   (1, ('TGTCTAGT', 'AGACGAAGGGGGTTGGGGTAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGTTAGGG', 'ATACTAATCCAGTTTGAAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACTCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCAGTTTCGAGGAA')),
#   (1, ('ACAGAGCC', 'TGAATAACGTATTTAGACAAA')),
#   (1, ('ACAGAGCC', 'CGGCTAACGACTTTAACCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGTTTTAGGGAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'TTTTGAATCTGTTTTGTTGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'TTGTGAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTCAAG', 'CCTCTAAATCTCTTGCCCTAA')),
#   (1, ('CGGGAATG', 'TTTTGAATCTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TGATCAACGACATTCATTAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'CAAGGAACAAGGTTATAAAAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'AAAAAAAACGGATTGATAGAA')),
#   (1, ('CGGGAATG', 'CCCAAAAAACACTTAACCCAA')),
#   (1, ('CCATTACT', 'TGGTGAACGTGTTTATATTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('CTGAATCT', 'TGGCCAATCTTTTTCAGTTAA')),
#   (1, ('CGTTAGGG', 'CGCTAAATGACTTTGTCCTAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCAGTTTCGAGGAA')),
#   (1, ('ACACGTGA', 'ACAGGAAAGGTATTCGGGGAA'))],
#  [(3, ('GGTAGGGA', 'TGTGCAATGATCTTGCATTAA')),
#   (1, ('TGTCTAGT', 'GGTTGAAGGTCGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TCTGGGGC', 'AACAAAAAAAAATTAACAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(4, ('TTAATTAG', 'TTTTAAATAATTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATACTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TTAGGAAACAACTTGGGGAAA')),
#   (1, ('GGTAGGGA', 'AACTTAAAGATCTTATTAAAA')),
#   (1, ('CTGAATCT', 'CCATAAACCCCCTTACTCCAA')),
#   (1, ('CGTTAGGG', 'TCTTTAACAGGGTTCTAACAA')),
#   (1, ('CGGGAATG', 'CCCCCAACTCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGTGAACGTGTTTATATTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CATATAACCCGCTTAAGTGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA')),
#   (1, ('CATAGTCA', 'TATTTAATTTGTTTTTTATAA')),
#   (1, ('ACAGAGCC', 'CTCTTAAACATTTTTGTATAA')),
#   (1, ('ACAGAGCC', 'ATTTTAAGTATCTTAGAGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('CGTTAGGG', 'AGGATAAAGGATTTTGTGCAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA'))],
#  [(1, ('TTAATTAG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'ATGAGAAACGAGTTTGAATAA'))],
#  [(1, ('TTAATTAG', 'TGTTAAATGAGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGTTTTAGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTAAAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'AACTTAAAGATCTTATTAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTTTAAACGCTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'CCCCCAAAACCCTTTTCGCAA')),
#   (1, ('CCATTACT', 'TGGTGAACGTGTTTATATTAA')),
#   (1, ('CCATTACT', 'CCCGCAATGCCATTGAGTAAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCGCTTTCCGGAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA'))],
#  [(2, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTGGTTGGTGGAA')),
#   (1, ('TCTGGGGC', 'TGTTGAAGGGGATTATGGTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TGTCGAAGTAGGTTCTGTTAA')),
#   (1, ('ACAGAGCC', 'ATTTTAAGTATCTTAGAGTAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'AACGCAATAGTATTGAAGCAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACCCGCTTCCCCGAA')),
#   (1, ('TGTCTAGT', 'CACCCAACGCAATTCCAACAA')),
#   (1, ('GGTAGGGA', 'TGTGCAATGATCTTGCATTAA')),
#   (1, ('GGTAGGGA', 'CTTAAAACGCTGTTTTCCCAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTAGGG', 'ATACTAATCCAGTTTGAAAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA'))],
#  [(2, ('CGTTTCCT', 'CATATAACGTCTTTTTAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'ACCAGAAAAAAATTACTACAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(7, ('TTAATTAG', 'TTCGGAAATATTTTCGTATAA')),
#   (3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(3, ('TGTCTAGT', 'AAAACAAAGACATTAGAGGAA')),
#   (1, ('TGTCTAGT', 'TAGCCAATTTCCTTATATTAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCCCCTTCCCCCAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('CGTTAGGG', 'AAATAAAAATTTTTCTGAGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('CTGAATCT', 'TTTTTAATTTGTTTTTTGTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGGAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'CGCCCAACCCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'TGAGGAATTATTTTGTTATAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTTAGCCAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGGTTGCGGGAA')),
#   (1, ('TTAATTAG', 'ACCAAAAGAATATTCCATCAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGTTTTAGGGAA')),
#   (1, ('TGTCTAGT', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'GGGTGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCCCCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'CATGGAAGAGGGTTGAAGGAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('GGTAGGGA', 'GCGGCAACGCAATTCCGTCAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCAGTTTCGAGGAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('CCATTACT', 'CTTTTAATTGCATTTTGTTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA'))],
#  {('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'): 2},
#  [(1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('CTGAATCT', 'CCATAAACCCCCTTACTCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCAACCAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACAGAGCC', 'GTGTTAAGTCAGTTTTGGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCAAA')),
#   (1, ('ACACGTGA', 'CAATTAAACACATTACAAGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CATATAACCCACTTAAGTGAA')),
#   (1, ('TGTCTAGT', 'AAAGCAAAAAAATTATAAAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'TCGGTAACGTGTTTTTTGAAA')),
#   (1, ('CGTTTCCT', 'AAGAAAACTACTTTTCGATAA')),
#   (1, ('CGGGAATG', 'GGTATAAGGGGGTTGTAGGAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGTTTGGAGAAA'))],
#  [(3, ('CAGTGCAT', 'ATAGTAAGATACTTCATATAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('CTGAATCT', 'TGGGAAACATGTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'GTGTAAATGTTGTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTAGGG', 'CGCTAAATGACTTTGTCCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA'))],
#  [(1, ('TTAATTAG', 'TGTTAAATGAGTTTCTTTGAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGGGAATG', 'TTTTGAATCTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCAACCAA'))],
#  [(2, ('ACACGTGA', 'CAATTAAACACATTACAAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CAACCAACGATTTTACACTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA')),
#   (1, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA'))],
#  [(2, ('TCTGGGGC', 'AAAAAAAAAAACTTAAAAAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CAACCAACGATTTTACACTAA')),
#   (1, ('TGTCTAGT', 'AAAGCAAAAAAATTATAAAAA')),
#   (1, ('GCCAATCG', 'TTAGAAAAGGAGTTTATTAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(2, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TCTGGGGC', 'TACTCAAGGGGCTTATCTAAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAGATTTTTTTTTTAA')),
#   (1, ('CCATTACT', 'GGGGTAAATAAGTTGGGATAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(1, ('TTAATTAG', 'AACGCAAAGAATTTAATACAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'AAAAAAAAAAAATTAAAAAAA'))],
#  [(1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTCGGAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACCCGCTTCCCCGAA')),
#   (1, ('TGTCTAGT', 'ACAAAAACGCCATTGGAGCAA')),
#   (1, ('CGTTAGGG', 'CGCTAAATGACTTTGTCCTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'GTCCCAATGGATTTGTAAGAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  {('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'): 1},
#  [(1, ('TTAATTAG', 'TTTTTAATACTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'AAAGAAAATAAATTAAACGAA')),
#   (1, ('CGTTCAAG', 'GTTATAATTCAATTTCTAGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'CCCGCAATGCCATTGAGTAAA'))],
#  [(2, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (1, ('TTAATTAG', 'GAAGGAAGGAAGTTAAGACAA')),
#   (1, ('TGTCTAGT', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'GGGAGAAAAGAGTTGAAGGAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TGTCTAGT', 'GCGGGAATTTCATTGGTGTAA')),
#   (1, ('TGTCTAGT', 'AAAGAAAATAAATTAAACGAA')),
#   (1, ('GGTAGGGA', 'TTAGGAAACAACTTGGGGAAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTCCCAA'))],
#  [(1, ('TGTCTAGT', 'TCTCTAACTCCCTTGCGTCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('GGTAGGGA', 'CCTTTAACGTTCTTATTGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CAAAAAAGCGAATTGAGAAAA'))],
#  [(2, ('CTGAATCT', 'CCATAAACCCCCTTACTCCAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA'))],
#  [(1, ('TTAATTAG', 'AAAAGAAAGGAGTTGGTAGAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAACAATTAAAAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'CCCCAAACCAGTTTCGAGGAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAATTGGGTTGGTTGAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGGAGTTAAAGCAA')),
#   (1, ('TTAATTAG', 'CCTTTAACACACTTGCACCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CTTAAAACGCTGTTTTCCCAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('GCCAATCG', 'TTTGTAACGTACTTGCACCAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGTGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TTAATTAG', 'TCTTAAAAATTTTTCTTGCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('ACAGAGCC', 'TTTGTAATTTATTTGTATGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'GGGTGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(2, ('TTAATTAG', 'CTTTTAATATTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGAGGAAGGGCGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA'))],
#  [(2, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTCGGAAATATTTTCGTATAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('CGTTCAAG', 'GTTATAATTCAATTTCTAGAA')),
#   (1, ('CGTTAGGG', 'GAACGAATAACGTTGATAAAA')),
#   (1, ('CGTTAGGG', 'CGCTAAATGACTTTGTCCTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTATTTTAA')),
#   (1, ('TCTGGGGC', 'CCCCCAAACCCCTTAACCCAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('CGTTTCCT', 'AAGAAAACTACTTTTCGTTAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TTAATTAG', 'AACGCAATAGTATTGAAGCAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'CACCAAACACAGTTCCGATAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATACTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGGTGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AACGCAATAGTATTGAAGCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTCGGAGAA')),
#   (1, ('GGTAGGGA', 'GCCGCAACGCAATTCCGTCAA')),
#   (1, ('CGGGAATG', 'TTTTGAATCTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA')),
#   (1, ('ACAGAGCC', 'ATGATAATAGCGTTTATGCAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTGGTTGGGTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('ACACGTGA', 'GGGTTAATTTTGTTGTTTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('ACACGTGA', 'CAATTAAACACATTACAAGAA'))],
#  [(1, ('TTAATTAG', 'GGTGAAATGGTGTTAAGACAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('ACAGAGCC', 'TTTGTAATTTATTTGTATGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'ACCAGAAAAAAATTACTACAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA'))],
#  [(4, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'CCACCAACAACCTTCACTCAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTGTTAAGTGGTTTCTGTTAA')),
#   (1, ('ACAGAGCC', 'ATGATAATAGCGTTTATGCAA')),
#   (1, ('ACACGTGA', 'CAAAAAAGCGAATTGAGAAAA'))],
#  [(3, ('CATAGTCA', 'AACTAAAGGATCTTGGTCCAA')),
#   (1, ('TTAATTAG', 'TTCGAAAAAGCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TTAATTAG', 'CAAGGAACAAGGTTATAAAAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGGAGGTTGGTGAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCACTTCAACAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA')),
#   (1, ('ACACGTGA', 'CACCAAACACAGTTCCGATAA'))],
#  [(2, ('TGTCTAGT', 'ACAAAAAAGAAATTAAAAAAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGTGGTTGGTCGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'CCACCAACAACCTTCACTCAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCACTTCAACAAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('CGTTTCCT', 'AACGGAAAGACCTTCGTAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('ACAGAGCC', 'TCATGAAAGTCTTTCTAACAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA'))],
# ...
#   (1, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGCAAA')),
#   (1, ('CGTTCAAG', 'GTTATAATTCAATTTCTAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACTCCCTTCCCCCAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TTAATTAG', 'AACGCAATAGTATTGAAGCAA')),
#   (1, ('TCTGGGGC', 'CTCCCAACTCTCTTCGCCAAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA'))],
#  [(2, ('TTAATTAG', 'TTTTCAATTTTTTTTTTTCAA')),
#   (1, ('CGTTAGGG', 'GATCCAAACATTTTATTCGAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TTAATTAG', 'TTCGGAAATATTTTCGTATAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGTTGGTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA'))],
#  [(3, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('TGTCTAGT', 'CATGGAAGAGGGTTGAAGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('ACAGAGCC', 'TGAAAAATTGGTTTGATATAA')),
#   (1, ('ACAGAGCC', 'ATGATAATAGCGTTTATGCAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('CGTTAGGG', 'ACAAAAAATACTTTATGAAAA')),
#   (1, ('TTAATTAG', 'TGTTAAATGAGTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'CCTTTAACACACTTGCACCAA')),
#   (1, ('TGTCTAGT', 'GTGTGAATTGTGTTTGTGTAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GTACTTGC', 'GCTTCAAGATGTTTACGAGAA')),
#   (1, ('GTACTTGC', 'AGTGAAATTACATTGGGGAAA')),
#   (1, ('GGTAGGGA', 'TGTGCAATGATCTTGCATTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TGTCTAGT', 'GTGTGAAGGTTATTGGGGTAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('CGTTAGGG', 'GTTACAAATGAGTTGGATAAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGTTGGTTTTTTGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACAAAAAAAAAATTAAAAAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCCGCAATGCCATTGAGTAAA')),
#   (1, ('ACAGAGCC', 'TGAATAACGTATTTAGACAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CGAGTAATCCTTTTGTTTAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('CGTTCAAG', 'CAATAAACTTGCTTTTTAAAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTTTTTTTTTAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'TAATTAATTGCTTTCGGCTAA'))],
#  [(1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TTAATTAG', 'AACGCAAAGAATTTAATACAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('CGTTCAAG', 'GTTATAATTCAATTTCTAGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCAAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'TCTTTAACGTCCTTCTCTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTCGGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAAAAAAGTTAGAGGAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCAATCG', 'TTAGAAAAGGAGTTTATTAAA')),
#   (1, ('GCCAATCG', 'AAGGAAAAATTTTTTCTTTAA')),
#   (1, ('CTGAATCT', 'TGGCCAATCTTTTTCAGTTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA')),
#   (1, ('CGGGAATG', 'CCCAAAACCAGTTTCGAGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'CTCACAATTGTTTTATTTTAA'))],
#  [(1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'CCACCAACCCCCTTCCGCCAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CCATTACT', 'TGGTGAACGTGTTTATATTAA')),
#   (1, ('CAGTGCAT', 'GTCTTAATATATTTTGCACAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTGTAAAAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GCCAATCG', 'TTAGAAAAGGAGTTTATTAAA')),
#   (1, ('CGTTTCCT', 'TGGTGAAGGCTTTTTATTTAA')),
#   (1, ('CGTTTCCT', 'CAAATAAGCGCCTTTTAGTAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('CCATTACT', 'ATGAAAAACGGCTTGGTATAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('ACACGTGA', 'CAAAAAAGCGAATTGAGAAAA')),
#   (1, ('TGTCTAGT', 'TTGTGAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CAAATAATTGTCTTTGCTAAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAGATTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA')),
#   (1, ('CGTTAGGG', 'AAATAAAAATTTTTCTGAGAA')),
#   (1, ('CCATTACT', 'TGTCGAAGTAGGTTCTGTTAA'))],
#  [(1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA')),
#   (1, ('CGGGAATG', 'TTTTGAATCTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCAACCAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('CTGAATCT', 'GTGTAAATGTTGTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'ATACAAACGTAGTTTTTCGAA')),
#   (1, ('CGTTAGGG', 'GTGTAAATCCGTTTGCGAAAA')),
#   (1, ('CGGGAATG', 'GGTATAAGGGGGTTGTAGGAA'))],
#  [(1, ('TGTCTAGT', 'TTTGTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGTTGAAGGTCGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CAACCAACGATTTTACACTAA')),
#   (1, ('CTGAATCT', 'CTCTTAACCCCCTTTCCCAAA')),
#   (1, ('CCATTACT', 'CTATTAACTCCGTTACTCTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACAGAGCC', 'CGGCTAACGACTTTAACCTAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'CCTTTAACACACTTGCACCAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACAGAGCC', 'TGATCAACGACATTCATTAAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAGTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACCCGCTTCCCCGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTAGGG', 'GTTACAAATGAGTTGGATAAA')),
#   (1, ('CGTTAGGG', 'GTGTAAATCCGTTTGCGAAAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGTGAAATGGTGTTAAGACAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TGTCTAGT', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACACGTGA', 'GATGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  {('ACACGTGA', 'CCCCCAACCTCCTTCCCCAAA'): 1},
#  [(2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('TGTCTAGT', 'GCGGGAATTTCATTGGTGTAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('CTGAATCT', 'AAAAAAAACGGATTGATAGAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CGGGAATG', 'GGGAGAAAAGAGTTGAAGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  [(1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'CCATAAACCCCCTTACTCCAA')),
#   (1, ('CGGGAATG', 'GGGAGAAAAGAGTTGAAGGAA')),
#   (1, ('CGGGAATG', 'CGCCCAACCACCTTCACCAAA')),
#   (1, ('ACAGAGCC', 'CGGCTAACGACTTTAACCTAA'))],
#  [(2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATACTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'AACGCAATAGTATTGAAGCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CCATTACT', 'ATGAAAAACGGCTTGGTATAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  {('ACACGTGA', 'GGGGGAAAGGGGTTGTTTGAA'): 1},
#  [(1, ('TTAATTAG', 'TCTTTAACATTTTTTTTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA'))],
#  [(3, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTGTTAAGTGGTTTCTGTTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTTCCT', 'AAGAAAACTACTTTTCGTTAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  {('ACAGAGCC', 'ATGATAATAGCGTTTATGCAA'): 1},
#  [(3, ('TGTCTAGT', 'AAGAGAAAACGATTAGAAAAA')),
#   (1, ('TTAATTAG', 'GGGTGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTATTTAA')),
#   (1, ('TGTCTAGT', 'TCGCTAAAAGGATTCAAAAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCTTCCAA')),
#   (1, ('ACAGAGCC', 'TGAATAACGTATTTAGACAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('CGGGAATG', 'CCCCCAACCCCCTTCTCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TCTATAACGAATTTTACGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'GGTATAAGGGGGTTGTAGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAAAACCCTTTTCGCAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GTACTTGC', 'TTTAGAAGCCGATTCACAGAA')),
#   (1, ('GGTAGGGA', 'GTGTAAATTATTTTACTATAA'))],
#  [(1, ('TGTCTAGT', 'TTGAGAATGGGTTTTCAAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'TGTGCAATGATCTTGCATTAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCAATCG', 'TCGGAAACATAATTGTGATAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(1, ('TTAATTAG', 'AACGCAATAGTATTGAAGCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('TCTGGGGC', 'TACTCAAGGGGCTTATCTAAA')),
#   (1, ('GTACTTGC', 'GTCACAATGCACTTAACAAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('GCCAATCG', 'AAGGAAAAATTTTTTCTTTAA'))],
#  [(1, ('TGTCTAGT', 'GTTATAATTATGTTTTTGTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CTCTGAATGAACTTAGCCCAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  {('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'): 1},
#  [(1, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACCCGCTTCCCCGAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'TTACTAATAGCCTTATTGGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAGATTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CAATTAAACACATTACAAGAA'))],
#  [(1, ('TTAATTAG', 'CTTTTAATATTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GAGGGAAAAAAGTTAGAGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'GTGAGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  {('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'): 1},
#  [(2, ('CGTTTCCT', 'CTTGAAATAGAATTCCTATAA')),
#   (1, ('TGTCTAGT', 'GAGGGAACGACATTCGGAGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA'))],
#  [(1, ('TGTCTAGT', 'GTGTGAATTGTGTTTGTGTAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GGTAGGGA', 'AGATCAAGGAAATTGTGTGAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (3, ('CGGGAATG', 'CCCCCAACCCCCTTTAGCCAA')),
#   (1, ('TTAATTAG', 'TGTGAAATGATTTTTGTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGGTGTTTTGGGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAAAAAAGTTAGAGGAA')),
#   (1, ('CGTTAGGG', 'GTGTAAATCCGTTTGCGAAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (2, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('TTAATTAG', 'TTCGGAAATATTTTCGTATAA')),
#   (1, ('TTAATTAG', 'TCTTAAAAATTTTTCTTGCAA')),
#   (1, ('TGTCTAGT', 'AAAGAAAATAAATTAAACGAA')),
#   (1, ('CGTTTCCT', 'TGGTGAAGGCTTTTTATTTAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('CCATTACT', 'TGGTCAAGCTAGTTTGGCCAA')),
#   (1, ('ACACGTGA', 'ATGAGAAACGAGTTTGAATAA'))],
#  [(1, ('TGTCTAGT', 'TCCCCAACTACCTTCCCCAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TCTGGGGC', 'AACAAAAAAAAATTAACAAAA')),
#   (1, ('GGTAGGGA', 'GCGGCAACGCAATTCCGTCAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'GGGATAAATTTATTCGTGAAA'))],
#  [(1, ('TTAATTAG', 'GGGTGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAAGAAAGGAGTTGGTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTCGGAGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAAAAAAGTTAGAGGAA')),
#   (1, ('TGTCTAGT', 'CACCCAACGCAATTCCAACAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CGGGAATG', 'GTCCCAATGGATTTGTAAGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTATTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTCTTTCCTTCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCCCTTTCGCTTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAAGGGTTTGGTGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAAGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'CACCCAAACCTGTTGCTCCAA'))],
#  [(1, ('TGTCTAGT', 'TTACTAATGTCTTTTTTTTAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CACCCAACGCAATTCCAACAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA')),
#   (1, ('CTGAATCT', 'CCACCAACAACCTTCACTCAA'))],
#  [(3, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('TTAATTAG', 'GCCTAAAGACCCTTCCTACAA')),
#   (1, ('TTAATTAG', 'AACGCAATAGTATTGAAGCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('GGTAGGGA', 'GTCTTAAGGGATTTATTGTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CGTTCAAG', 'TTTAAAAGATTTTTTTTTTAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGTTTGGAGAAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCCGCTTACTGGAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  {('GGTAGGGA', 'CATGTAAGATACTTGACCTAA'): 1},
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'GTCATAAGCGACTTTATTTAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('ACAGAGCC', 'AGTATAACTATTTTATTTAAA'))],
#  [(2, ('TTAATTAG', 'GAGCAAATGATGTTAAAAAAA')),
#   (1, ('TGTCTAGT', 'GTGGGAAGGCGGTTGAAAGAA')),
#   (1, ('GGTAGGGA', 'CTTAAAACGCTGTTTTCCCAA')),
#   (1, ('GGTAGGGA', 'CATGTAAGATACTTGACCTAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCCTTCCCCCAA'))],
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 3537

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
