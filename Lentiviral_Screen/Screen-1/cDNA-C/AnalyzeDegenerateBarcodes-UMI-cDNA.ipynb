# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist3.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 11850

# %% [raw]
# afile = pysam.AlignmentFile("./final.bam")
# hashcount = {}
# hashset = {}
# cellhash = {}
# taghash = {}
# readcount = {}
# barcodehash = {} # barcodes listing shRNAID
# barcodebycellUMI = {} # barcode listing cellUMI
# doublecounts = 0
# cellbyUMI = {}
# inwhitelist = set()
# inwhitelistcount = 0
# outwhitelist = set()
# outwhitelistcount = 0
# for seq_record in afile.fetch(until_eof=True):
#     cellUMI = None  # here this is the CellRanger cell UMI
#     UMI = None
#     if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
#     cellUMI = seq_record.get_tag("CB")
#     if cellUMI not in whitelist:
#         outwhitelistcount +=1
#         if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
#         continue
#     else:
#         inwhitelistcount += 1
#         if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
#     UMI = seq_record.get_tag("UB") # umi barcode
#
#     m = hashmatch.search(seq_record.query_sequence)
#     if m == None or (m.end() + 8) > len(seq_record.query_sequence):
#         #print("Error, match not found")
#         continue
#     shRNAID = seq_record.query_sequence[m.end():m.end()+8]
#     barcode = seq_record.query_sequence[m.end()-21:m.end()]
#     sbID = (shRNAID,barcode)
#     if shRNAID not in hashes: continue
#     if cellUMI not in cellbyUMI:
#         cellbyUMI[cellUMI] = {}
#     if UMI not in cellbyUMI[cellUMI]:
#         cellbyUMI[cellUMI][UMI] = {sbID: 1}
#         continue
#     if sbID in cellbyUMI[cellUMI][UMI]:
#         cellbyUMI[cellUMI][UMI][sbID] += 1
#     else:
#         hamming = False
#         for x in cellbyUMI[cellUMI][UMI]:
#             if hammingDistance(sbID[1],x[1]) <= 2:
#                 cellbyUMI[cellUMI][UMI][x] += 1
#                 hamming = True
#                 break
#         if hamming: continue
#         cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle
cellbyUMI = False
with open('cellbyUMI.pickle', 'rb') as f:
    cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 56

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 11850

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 11532

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] > threshold: 
                ncellbyUMI[y] = newUMI[0][1]
            else:
                print("Not past threshold: %s" % str(newUMI))
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        #print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (6.96539244137563, 1, 757, 1.0)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 4486

# %%
len(whitelist)
# Out:
# 11850

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 7003

# %%
poorUMI
# Out:
# [[(3, ('GGTAGGGA', 'CATCGAACCTTTTTACGATAA')),
#   (1, ('TTAATTAG', 'GTTTCAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('GTACTTGC', 'CGAAGAAATACTTTCACATAA')),
#   (1, ('GGTAGGGA', 'GTTGAAATCAAATTTTCACAA')),
#   (1, ('GGTAGGGA', 'ATTAAAACGGATTTCTTTAAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'CTCCCAACCCCGTTCCTCTAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'CGATCAATTAACTTGACAGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CGTTAGGG', 'TGATAAACCTAGTTCTTTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('ACAGAGCC', 'AAAATAAGTCCTTTTGCGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CGACCAAACAACTTACCCTAA'))],
#  [(3, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (3, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (2, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGAAATTAGAAGAA')),
#   (1, ('GTACTTGC', 'TGATTAATTTTCTTAAAATAA')),
#   (1, ('GGTAGGGA', 'AGCTGAACGCAGTTTAGTGAA')),
#   (1, ('GCCAATCG', 'CTATGAACAGGTTTTAATCAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'CTTAGAAAGAGATTGGCAGAA')),
#   (1, ('CGTTTCCT', 'TTTATAATAGTTTTGTACTAA')),
#   (1, ('CGTTTCCT', 'GATGCAACGTCTTTCACTAAA')),
#   (1, ('CGTTCAAG', 'AGTCAAACTCCGTTAAGCCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'GCCACAACGTTGTTTACGGAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'TCTCTAAGTTACTTTCATAAA')),
#   (1, ('ACAGAGCC', 'TATGGAAAATTATTACTTTAA')),
#   (1, ('ACAGAGCC', 'TAAATAAGATCATTGAGTTAA')),
#   (1, ('ACAGAGCC', 'GCATTAATGTTTTTCTATGAA')),
#   (1, ('ACAGAGCC', 'CTATAAAACTTTTTAGAAAAA'))],
#  [(3, ('TTAATTAG', 'GGAGAAAAGATTTTATATGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA'))],
#  [(1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('GTACTTGC', 'GCTAGAATTTACTTCTTAGAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'GGGGTAACGTTGTTTGTATAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  {('GTACTTGC', 'CTTCAAAAAAATTTTATAGAA'): 3},
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'TCACGAATTCCTTTCCTTGAA')),
#   (1, ('TGTCTAGT', 'GGTAGAAGGTAGTTGGTAGAA')),
#   (1, ('GTACTTGC', 'TGCGGAATCCTATTGAGTCAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GTACTTGC', 'CGCCGAATGATGTTGACTCAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTCAAG', 'TATATAAATAAGTTATTAGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('CAGTGCAT', 'GATGAAATTCACTTAATCTAA')),
#   (1, ('ACAGAGCC', 'CTAAAAAACTTTTTAGAAAAA'))],
#  [(3, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (3, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (2, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (2, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GTTAGAAGGATGTTGTGTGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GTTTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CTCTGAAATCGTTTCTTCAAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'GTTATAAATAGCTTAACCGAA')),
#   (1, ('GGTAGGGA', 'TATAAAAGTTATTTTCATAAA')),
#   (1, ('GGTAGGGA', 'GTCACAATGTTTTTTTCGAAA')),
#   (1, ('GGTAGGGA', 'ATGCTAACACGGTTGTTAAAA')),
#   (1, ('GGTAGGGA', 'AGGAAAAGGTACTTAAATTAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'TGGAAAAAGTGTTTGAGAGAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTTATAATAGTTTTGTACTAA')),
#   (1, ('CGTTTCCT', 'TGGACAAAGGGTTTGTAATAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTAGGG', 'TGCTTAAACAGATTAATCGAA')),
#   (1, ('CGGGAATG', 'GGTGGAAGAGAGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'TATGGAAAATTATTACTTTAA')),
#   (1, ('ACAGAGCC', 'GGGGGAACCTTTTTTGGTGAA')),
#   (1, ('ACACGTGA', 'CCCACAACCGCATTCCCCCAA'))],
#  [(1, ('TGTCTAGT', 'GGTAGAAGGTAGTTGGTAGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('ACAGAGCC', 'TATGGAAAATTATTACTTTAA')),
#   (1, ('ACACGTGA', 'CGACCAAACAACTTACCCTAA'))],
#  [(1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (1, ('GTACTTGC', 'TGATTAATTTTCTTAAAATAA')),
#   (1, ('CGTTAGGG', 'ATAGGAAATGGCTTTGCATAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCGCCTTTGCACAA'))],
#  [(1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAAACCCCTTAACCGAA')),
#   (1, ('CGGGAATG', 'CCCACAACACCCTTCACCAAA')),
#   (1, ('ACAGAGCC', 'AAAATAAGTCCTTTTGCGGAA'))],
#  [(1, ('GTACTTGC', 'TGATTAATTTTCTTAAAATAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CGGGAATG', 'TCAAAAAAAGGATTAAATAAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA'))],
#  [(3, ('ACAGAGCC', 'AGTATAAACATTTTACACCAA')),
#   (2, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CTCTGAAATCGTTTCTTCAAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('CTGAATCT', 'CTCCTAACCCCCTTACTCTAA')),
#   (1, ('CGTTCAAG', 'GTGAAAATAATTTTAGGTTAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'TGGAAAACATTTTTACCATAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('ACACGTGA', 'GGATGAAACTGGTTGGGTGAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATGTAATTGTTTCAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA'))],
#  [(1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TTAATTAG', 'AACACAACACAATTCCATAAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'CGTGGAAGATTGTTCTGGAAA')),
#   (1, ('GGTAGGGA', 'TGATAAACGGAATTCTAGCAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCAAACACGATTCTCACAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('ACAGAGCC', 'TGGAAAACATTTTTACCATAA')),
#   (1, ('ACAGAGCC', 'GTATGAACGTCATTAAAGTAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'AACACAACACAATTCCATAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TGCAAAATCATATTATTAAAA')),
#   (1, ('CGTTCAAG', 'GTGAAAATAATTTTAGGTTAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA'))],
#  [(3, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (2, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('TTAATTAG', 'TTTGAAAGGATGTTAGGTTAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GGTAGAAGGTAGTTGGTAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTCTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGTGTTTTCTTTTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'AGGGAAAGGGAATTAAAATAA')),
#   (1, ('ACAGAGCC', 'GTCAAAAGCTAATTCGTGTAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(2, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('ACACGTGA', 'AATGAAATGAGCTTCTTGCAA'))],
#  [(1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GGTAGGGA', 'TAAGTAATCCCGTTTCTACAA'))],
#  [(3, ('ACAGAGCC', 'GGGGGAACCTTTTTTGGTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TAAAAAAGAGAATTAACGAAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA'))],
#  [(2, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTCCAAAGAATTTTCTGTCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GACACAATATAATTAAAGAAA')),
#   (1, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCACTTCGATCAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCTGATTGTAGGAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CTGAATCT', 'CATGAAAATTTTTTACTTCAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTCAAG', 'ACCTCAATATTTTTACGTCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'GACACAATGAACTTGAAACAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CAATCAATCCTGTTCTTCGAA'))],
#  [(2, ('ACAGAGCC', 'CTATAAAACTTTTTAGAAAAA')),
#   (1, ('TTAATTAG', 'TGTGTAATGATTTTATAGTAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('GCCAATCG', 'GATGCAAATAGATTTGGATAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'CATGAAAATTTTTTACTTCAA')),
#   (1, ('CTGAATCT', 'AAGAAAAACAAATTAAAAAAA')),
#   (1, ('CGTTTCCT', 'GGTCTAACCCCTTTCTAGAAA')),
#   (1, ('CGTTCAAG', 'TGTCAAACTATTTTGCACTAA')),
#   (1, ('CGTTAGGG', 'AACATAACTCCATTATTCAAA')),
#   (1, ('CGGGAATG', 'GGTGGAAGAGAGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'GGGTTAATGTGTTTGTTGAAA')),
#   (1, ('CCATTACT', 'AGGGAAAGGAAATTAAAATAA')),
#   (1, ('ACAGAGCC', 'GTCTCAATGGTTTTATTAGAA')),
#   (1, ('ACACGTGA', 'GAGGCAAGGGGTTTTTGGGAA')),
#   (1, ('ACACGTGA', 'AATGAAATGAGCTTCTTGCAA'))],
#  [(3, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA'))],
#  [(1, ('CTGAATCT', 'AAAAAAAAGATATTGATGCAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA'))],
#  [(1, ('TTAATTAG', 'TTTGAAAGGATGTTAGGTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('CTGAATCT', 'CTTATAACTCTTTTTTCCCAA')),
#   (1, ('CTGAATCT', 'CATGAAAATTTTTTACTTCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GTCTCAATGGTTTTATTAGAA')),
#   (1, ('ACAGAGCC', 'CTTTAAAAAGTCTTTAGGGAA')),
#   (1, ('ACACGTGA', 'CCTCCAACCTCGTTCCCCCAA'))],
#  [(3, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (2, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (2, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGTAGAAGGTAGTTGGAAGAA')),
#   (1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCACTTCGATCAA')),
#   (1, ('TGTCTAGT', 'ATTGTAACTCATTTGGTCTAA')),
#   (1, ('GGTAGGGA', 'TATAAAAGTTATTTTCATAAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAGATATTGATGCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGAGTTGTGGGAA')),
#   (1, ('CGGGAATG', 'ACAACAACAAAATTCACCGAA')),
#   (1, ('CCATTACT', 'TCGTCAACTTGTTTCTGTAAA')),
#   (1, ('CAGTGCAT', 'TATACAAGGGCTTTTGCTAAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'AAAAGAAACAACTTAACCCAA')),
#   (1, ('TGTCTAGT', 'GGTAGAAGGTAGTTGGTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'ACTTGAACGTCTTTTGTTGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('ACAGAGCC', 'TAAATAAGATCATTGAGTTAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA'))],
#  [(3, ('CGTTAGGG', 'ATAGGAAATGGCTTTGCATAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('CTGAATCT', 'TAAACAAGAGAATTAACGAAA')),
#   (1, ('CGTTTCCT', 'ATAGTAATTACCTTGGTAAAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('ACAGAGCC', 'CTTTAAAAAGTCTTTAGGGAA'))],
#  [(1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('GTACTTGC', 'GTTATAAATAGCTTAACCGAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCAAACACGATTCTCACAA'))],
#  [(2, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('CAGTGCAT', 'GTGCAAAATTTTTTGACGTAA')),
#   (1, ('ACAGAGCC', 'CTATAAAACTTTTTAGAAAAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA')),
#   (1, ('ACACGTGA', 'GGAGGAATGGGATTGGAGGAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('GGTAGGGA', 'TAAGAAAACCTTTTTTTTAAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TATATAAATAAGTTATTAGAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACACGTGA', 'GAATGAATCGGGTTTTGTGAA')),
#   (1, ('ACACGTGA', 'AATGAAATGAGCTTCTTGCAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGAGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'ATGCTAACACGGTTGTTAAAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAGATATTGATGCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCAAACACGATTCTCACAA'))],
#  [(3, ('CCATTACT', 'TCGTGAATGAGTTTTGGCGAA')),
#   (1, ('GGTAGGGA', 'GAGAAAATTGGGTTCTAAAAA')),
#   (1, ('GGTAGGGA', 'CTCTTAAGTCGATTCCCATAA')),
#   (1, ('CGTTAGGG', 'GCCTAAAAATGTTTAATTTAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('ACAGAGCC', 'TATGGAAAATTATTACTTTAA'))],
#  {('CTGAATCT', 'AAGAAAAACAAATTAAAAAAA'): 3},
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGCGGAAGGGGTTTAGATGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CTCTGAAATCGTTTCTTCAAA')),
#   (1, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCACCTTCTCCCAA')),
#   (1, ('GTACTTGC', 'CTTCAAAAAAATTTTATAGAA')),
#   (1, ('GTACTTGC', 'CGCCGAATGATGTTGACTCAA')),
#   (1, ('GGTAGGGA', 'CGAAGAATCAACTTTCTCTAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTAGGG', 'AATTCAAGTTTTTTTAACAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAATAAAAAAAATTATAAGAA')),
#   (1, ('ACAGAGCC', 'TTTTTAAGTCCTTTGAGGCAA')),
#   (1, ('ACAGAGCC', 'TATGGAAAATTATTACTTTAA')),
#   (1, ('ACAGAGCC', 'CTTTAAAAAGTCTTTAGGGAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTAGGGGAA'))],
#  [(1, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA'))],
#  [(3, ('TGTCTAGT', 'GTGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'AAGAAAAACAAATTAAAAAAA')),
#   (1, ('TTAATTAG', 'TTTGAAAGGATGTTAGGTTAA')),
#   (1, ('TTAATTAG', 'GGAGCAATGTGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'GCAACAACAAGATTCTAACAA')),
#   (1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TGTCTAGT', 'CCACCAACCCCCTTGCTCCAA')),
#   (1, ('GGTAGGGA', 'TTTGAAAAGTGATTGAATCAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('ACAGAGCC', 'GTCTCAATGGTTTTATTAGAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  [(2, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GCCAATCG', 'CTATGAACAGGTTTTAATCAA'))],
#  [(2, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGGGGTTTTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGACATTAATAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'TTGGAAATTTTCTTTATACAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAAAGAACAACATTTAAAAAA')),
#   (1, ('CGTTCAAG', 'GTGAAAATAATTTTAGGTTAA')),
#   (1, ('ACAGAGCC', 'CTTTAAAAAGTCTTTAGGGAA')),
#   (1, ('ACAGAGCC', 'CTGTAAATTCTATTAAATCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGTGTTTGGTGTAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA')),
#   (1, ('ACACGTGA', 'CGACCAAACAACTTACCCTAA'))],
#  [(1, ('TCTGGGGC', 'TCTTTAATTTTTTTCTTGTAA')),
#   (1, ('GGTAGGGA', 'TGATAAACGGAATTCTAGCAA')),
#   (1, ('CGTTTCCT', 'GATGCAACGTCTTTCACTAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('GTACTTGC', 'TGATTAATTTTCTTAAAATAA')),
#   (1, ('GGTAGGGA', 'TGCGTAAGTGTATTGTATAAA')),
#   (1, ('CGTTTCCT', 'GACATAAATTCATTGGCTCAA')),
#   (1, ('CGGGAATG', 'TTTGTAATTTGGTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'CATTTAAGGGCTTTTTTACAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA'))],
#  [(2, ('CTGAATCT', 'AAGATAAAGTGGTTGAGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TTATGAAACATTTTTTGATAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('GGTAGGGA', 'TGGGAAAATCACTTTATTTAA')),
#   (1, ('GGTAGGGA', 'CTAGAAAATCACTTCTGTTAA')),
#   (1, ('ACAGAGCC', 'TCTCTAAGTTACTTTCATAAA')),
#   (1, ('ACAGAGCC', 'CATTTAAGGGCTTTTTTACAA'))],
#  [(1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CCCACAACCGCATTCCCCCAA'))],
#  [(3, ('CGTTAGGG', 'TTCGCAATTTCATTTAAGGAA')),
#   (2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('GTACTTGC', 'CGCCGAATGATGTTGACTCAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GCCTACGT', 'TTGGGAATGGGGTTTTGGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  [(3, ('CGTTAGGG', 'GGCTGAATTCCTTTGATCTAA')),
#   (2, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'GCAACAACAAGATTCTAACAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GAGGGAAGGCTATTAGGAGAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGTTTCCT', 'GGTCTAACACTCTTACACAAA')),
#   (1, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA'))],
#  [(2, ('TGTCTAGT', 'ATTGTAACTCATTTGGTCTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGGTGAAACAGGTTAGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'TGCAAAATCATATTATTAAAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAAAAATTAATAAAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTCTTTTTTTAA')),
#   (1, ('CGGGAATG', 'TTGTTAAAGTATTTTATGGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGAGTTGTGGGAA')),
#   (1, ('CCATTACT', 'TGAAAAAAGTAATTAAAAAAA')),
#   (1, ('ACAGAGCC', 'TCAAGAAAATTGTTGATGGAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA')),
#   (1, ('ACAGAGCC', 'GTCAAAAGCTAATTCGTGTAA')),
#   (1, ('ACAGAGCC', 'GCGCGAAGGTCCTTTTACAAA')),
#   (1, ('ACACGTGA', 'GTATTAATTTTTTTATTGTAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA')),
#   (1, ('ACACGTGA', 'CATCAAAATCTGTTCCCGCAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'GTTTCAATATTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCTTCAATTTACTTGTTTTAA')),
#   (1, ('GGTAGGGA', 'TGATAAACGGAATTCTAGCAA')),
#   (1, ('CTGAATCT', 'TGGAAAAAGTGTTTGAGAGAA')),
#   (1, ('CGTTCAAG', 'TATTTAAAATTTTTTATTGAA')),
#   (1, ('CGTTCAAG', 'CTGAAAAATGGATTGTTCAAA')),
#   (1, ('ACACGTGA', 'GGTGGAAAGGTGTTTTGTTAA'))],
#  [(1, ('TTAATTAG', 'TTCCAAAGAATTTTCTGTCAA')),
#   (1, ('TTAATTAG', 'TGTGTAATGATTTTATAGTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTAGCTGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'CCGATAAGACTTTTAAAAAAA')),
#   (1, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('CCATTACT', 'CCGGCAACGTCCTTTGCCCAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'TGGTTAATAGGTTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA')),
#   (1, ('ACAGAGCC', 'TAGATAATCAGGTTGAAATAA')),
#   (1, ('ACACGTGA', 'TGGGTAATTGTTTTGGTGTAA'))],
#  [(1, ('CTGAATCT', 'TTTTTAATGTCTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGAGTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'CATTCAACCCCCTTCCCTCAA')),
#   (1, ('CGTTCAAG', 'GGGGTAACGTTGTTTGTATAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('CGTTAGGG', 'GTACAAAACTTTTTATCCTAA')),
#   (1, ('ACAGAGCC', 'GTATGAACGTCATTAAAGTAA'))],
#  [(1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TTAATTAG', 'AAAGAAAAATAATTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'CTTTAAAAAGTCTTTAGGGAA')),
#   (1, ('ACACGTGA', 'GAGGCAAGGGGTTTTTGGGAA'))],
#  [(3, ('CGTTAGGG', 'CTGCTAATTTCCTTCTCGAAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGAGAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAGATAAAGTGGTTGAGGGAA')),
#   (1, ('CTGAATCT', 'AAGAAAAACAAATTAAAAAAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CAGTGCAT', 'TTGAGAACATAATTTTTATAA')),
#   (1, ('ACAGAGCC', 'CTTTAAAAAGTCTTTAGGGAA'))],
#  [(3, ('TGTCTAGT', 'TTTCTAATTTTTTTTTTCTAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('CGTTTCCT', 'TTTATAATAGTTTTGTACTAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA'))],
#  [(1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGAGGGAA')),
#   (1, ('TGTCTAGT', 'CTCTGAAATCGTTTCTTCAAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGGGAATG', 'TTGTTAATCTTTTTTTTCCAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('ACAGAGCC', 'GCATTAATGTTTTTCTATGAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA'))],
#  [(3, ('CGTTTCCT', 'GGTCTAACCCCTTTCTAGAAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTGTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'GTTTTAAGTATCTTAAAATAA')),
#   (1, ('CGTTTCCT', 'GGTCTAACACTCTTACACAAA')),
#   (1, ('CCATTACT', 'CCGGCAACGTCCTTTGCCCAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('ACACGTGA', 'GGAGGAATGGGATTGGAGGAA'))],
#  [(3, ('GGTAGGGA', 'GCGGGAAATATTTTCGTGCAA')),
#   (1, ('TTAATTAG', 'GTATTAATCTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('GTACTTGC', 'CGCCGAATGATGTTGACTCAA')),
#   (1, ('GGTAGGGA', 'ATGCTAACACGGTTGTTAAAA')),
#   (1, ('CCATTACT', 'AGTCAAAAGAGGTTGGGTGAA')),
#   (1, ('ACAGAGCC', 'TGAGGAAGTATTTTTTGTAAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA')),
#   (1, ('ACACGTGA', 'CCCACAACCGCATTCCCCCAA'))],
#  [(2, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGGGTTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TGTCTAGT', 'ACAAAAAACAACTTCAAAAAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGTGTTTTCTTTTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCTCCAACACTCTTTACCAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CACCAAAACCCCTTCCCCCAA'))],
#  [(2, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (2, ('ACAGAGCC', 'TGGAAAACATTTTTACCATAA')),
#   (1, ('TTAATTAG', 'GGCGGAAGGGGTTTAGATGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTGCAATAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (1, ('TCTGGGGC', 'CGCCCAACCGCCTTCGCCCAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GCCAATCG', 'GATGCAAATAGATTTGGATAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCTCAACCCCCTTTTTCGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTTTTATAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CACACAATACCCTTTAATTAA')),
#   (1, ('GGTAGGGA', 'GAAAAAAAGGATTTACGTCAA')),
#   (1, ('GCCAATCG', 'ATATCAATAATTTTGTTTTAA')),
#   (1, ('CTGAATCT', 'CATGAAAATTTTTTACTTCAA')),
#   (1, ('CCATTACT', 'GGGTTAATGTGTTTGTTGAAA')),
#   (1, ('ACAGAGCC', 'GGGGGAACCTTTTTTGGTGAA')),
#   (1, ('ACAGAGCC', 'GGGCTAAATTTGTTTTCGGAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'TTCCAAAGAATTTTCTGTCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTGCAATAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('CTGAATCT', 'AAGATAAAGTGGTTGAGGGAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA'))],
#  [(4, ('CGTTAGGG', 'CCATTAACAGACTTATGAAAA')),
#   (1, ('TTAATTAG', 'AACACAACACAATTCCATAAA'))],
#  [(2, ('GGTAGGGA', 'TACATAATGTGGTTTTGCCAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('CGTTCAAG', 'GTGAAAATAATTTTAGGTTAA')),
#   (1, ('CCATTACT', 'TCCCCAACCGCTTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TGTCTAGT', 'CATTCAACCCCCTTCCCTCAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GCCTACGT', 'GGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTTTTAACTTTTTTATTTTAA')),
#   (1, ('CTGAATCT', 'TAAACAAGAGAATTAACGAAA')),
#   (1, ('CTGAATCT', 'CTCCTAACCCCCTTACTCTAA')),
#   (1, ('CGTTCAAG', 'TCTAAAAGGAAATTATCTGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTGAAAGAA')),
#   (1, ('CGGGAATG', 'CCCCAAACACGATTCTCACAA')),
#   (1, ('ACAGAGCC', 'CGCTCAACCTTGTTGCATAAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  [(2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGAGTAA')),
#   (1, ('GGTAGGGA', 'ATTAAAACGGATTTCTTTAAA')),
#   (1, ('GCCTACGT', 'GGGGGAATGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GGCTGAATTCCTTTGATCTAA')),
#   (1, ('CCATTACT', 'GCCACAACGTTGTTTACGGAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'ATTGTAACTCATTTGGTCTAA')),
#   (1, ('GTACTTGC', 'AGTAGAACTCGTTTGACAGAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CCATTACT', 'TTTTTAATGTCATTTGGTGAA')),
#   (1, ('CCATTACT', 'TCGTGAATGAGTTTTGGCGAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATGTAATTGTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'CCGAAAAGGGGCTTGACAGAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('CGTTTCCT', 'TGGACAAAGGGTTTGTAATAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTCAAG', 'TATATAAATAAGTTATTAGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TGTTGAATGTATTTGGGATAA')),
#   (1, ('ACAGAGCC', 'GTATGAACGTCATTAAAGTAA')),
#   (1, ('ACAGAGCC', 'AAAATAAGTCCTTTTGCGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGGGTTGGAATAA'))],
#  [(1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('ACACGTGA', 'TGGGTAATTGTTTTGGTGTAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TCTGGGGC', 'TCTTTAATTTTTTTCTTGTAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GGTAGGGA', 'GTTGAAATCAAATTTTCACAA')),
#   (1, ('GGTAGGGA', 'CGATCAATTAACTTGACAGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCAGCAACCCCCTTTCGACAA'))],
#  [(1, ('TTAATTAG', 'AACACAACACAATTCCATAAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GCCTACGT', 'TTGGGAATGGGGTTTTGGGAA')),
#   (1, ('CTGAATCT', 'CATGAAAATTTTTTACTTCAA')),
#   (1, ('CGTTTCCT', 'GGTCTAACACTCTTACACAAA')),
#   (1, ('CGTTAGGG', 'GTACAAAACTTTTTATCCTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTCTTTTGGGGAA')),
#   (1, ('CGGGAATG', 'GGCAGAAACGTGTTAAGAGAA')),
#   (1, ('CGGGAATG', 'CCCCAAACACGATTCTCACAA')),
#   (1, ('ACAGAGCC', 'GCGCGAAGGTCCTTTTACAAA')),
#   (1, ('ACAGAGCC', 'CTGTAAATTCTATTAAATCAA')),
#   (1, ('ACAGAGCC', 'AAAATAAGTCCTTTTGCGGAA')),
#   (1, ('ACACGTGA', 'CGACCAAACAACTTACCCTAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'ATTGTAACTCATTTGGTCTAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAATAAATTAAAAAAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GGTAGGGA', 'GTCACAATGTTTTTTTCGAAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGTGTTTTCTTTTAA'))],
#  [(1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('TGTCTAGT', 'GTTTTAATTTTGTTTGATTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGAGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CGTTAGGG', 'CTGCGAAGAATATTGCGACAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTGGTTTGGAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'TTGAGAACATAATTTTTATAA')),
#   (1, ('CAGTGCAT', 'TATACAAGGGCTTTTGCTAAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))],
#  [(3, ('CAGTGCAT', 'AGAGTAAACAGCTTTTTAAAA')),
#   (2, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAAAGAGGTTATAGGAA')),
#   (1, ('GGTAGGGA', 'TGCGTAAGTGTATTGGATAAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CTGAATCT', 'CTTAGAAAGAGATTGGCAGAA')),
#   (1, ('CGTTTCCT', 'ATAGTAATTACCTTGGTAAAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTAGGG', 'TCGGGAATCGGGTTCACGGAA')),
#   (1, ('CGTTAGGG', 'GCCTAAAAATGTTTAATTTAA')),
#   (1, ('CGTTAGGG', 'CGGCTAACTCGTTTCAAGGAA')),
#   (1, ('CCATTACT', 'GGGTTAATGTGTTTGTTGAAA')),
#   (1, ('ACAGAGCC', 'TCGTGAACATTGTTAGGATAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA')),
#   (1, ('ACACGTGA', 'GAAGGAAAGGGGTTGGAATAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'TTCCAAAGAATTTTCTGTCAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGTTCAAG', 'GATACAATTCTTTTAAAGTAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(2, ('TTAATTAG', 'ATTTAAATTTTTTTTGTATAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('ACACGTGA', 'TGGGTAATTGTTTTGGTGTAA'))],
#  [(1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'TGCGGAATCCTATTGAGTCAA')),
#   (1, ('GTACTTGC', 'CATCAAATGTCATTGAGCAAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CCATTACT', 'ATTGGAAATCACTTAACAAAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'TGCAAAATCAGATTATTAAAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(2, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (2, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCACCTTCTCCCAA')),
#   (1, ('CGTTCAAG', 'TATATAAATAAGTTATTAGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGAAA'))],
#  [(3, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'TTTGAAAGGATGTTAGGTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CTCTGAAATCGTTTCTTCAAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GGTAGGGA', 'TGCCTAAAGCAATTGCAGGAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGAGAA')),
#   (1, ('GCCAATCG', 'CTATGAACAGGTTTTAATCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TCGTCAACTTGTTTCTGTAAA')),
#   (1, ('CCATTACT', 'ATTTTAACCACCTTCTCGAAA')),
#   (1, ('ACAGAGCC', 'GCATTAATGTTTTTCTATGAA'))],
#  [(2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATTTCATTCTTTTAA')),
#   (2, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (2, ('CGTTCAAG', 'AGTCAAACTCCGTTAAGCCAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GCAACAACAAGATTCTAACAA')),
#   (1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('TGTCTAGT', 'TTTGAAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('GGTAGGGA', 'TTTGAAAAGTGATTGAATCAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TGGACAAAGGGTTTGTAATAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('CCATTACT', 'AGGAAAAGGAAATTAAAATAA')),
#   (1, ('CCATTACT', 'AAGAAAACTCAATTAAAGAAA')),
#   (1, ('ACAGAGCC', 'GTCTCAATGGTTTTATTAGAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA')),
#   (1, ('ACACGTGA', 'GAGGCAAGGGGTTTTTGGGAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('CGTTAGGG', 'CTGCGAAGAATATTGCGACAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CAGTGCAT', 'TATTAAATTTATTTAGCGCAA')),
#   (1, ('ACAGAGCC', 'GCGCGAAGGTCCTTTTACAAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CAGTGCAT', 'GTGCAAAATTTTTTGACGTAA')),
#   (1, ('ACAGAGCC', 'TGTTGAATGTATTTGGGATAA'))],
#  [(2, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (2, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGAGGGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (1, ('TGTCTAGT', 'ATTGTAACTCATTTGGTCTAA')),
#   (1, ('GGTAGGGA', 'CGATCAATTAACTTGACAGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CGGGAATG', 'GAACAAAGTACATTGTGTGAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'GCATTAATGTTTTTCTATGAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCATTCCCCCAA')),
#   (1, ('CGTTAGGG', 'GGCTGAATTCCTTTGATCTAA')),
#   (1, ('CCATTACT', 'TGGTTAAATAAGTTTGTGGAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA'))],
#  [(1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'CCACCAACCCCCTTGCTCCAA')),
#   (1, ('GTACTTGC', 'CGCCGAATGATGTTGACTCAA')),
#   (1, ('GGTAGGGA', 'CTAGAAAATCACTTCTGTTAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTAGGG', 'ACATTAATTGTTTTTACTGAA')),
#   (1, ('CGGGAATG', 'TTGTCAACCCCCTTCTTCCAA')),
#   (1, ('CGGGAATG', 'AAATAAAAAAAATTATAAGAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA'))],
#  [(2, ('CAGTGCAT', 'ACGAGAATATCCTTTGGTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'GTTATAATTCGTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GTAGAAATTTCCTTGGACTAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CGTTCAAG', 'GGATGAAAGCTTTTCGGATAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GAGGAAAAGGAATTAAAAGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'CTCCTAACCCCCTTACTCTAA')),
#   (1, ('CGGGAATG', 'GACACAATGAACTTGAAACAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA'))],
#  [(2, ('CGTTCAAG', 'AGTCAAACTCCGTTAAGCCAA')),
#   (1, ('TTAATTAG', 'GTTTCAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'CTCTTAAGTCGATTCCCATAA')),
#   (1, ('CGTTCAAG', 'TATATAAATAAGTTATTAGAA')),
#   (1, ('ACAGAGCC', 'CTTTAAAAAGTCTTTAGGGAA'))],
#  [(3, ('TGTCTAGT', 'CCCCCAACCCCATTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GCAGTAACATCGTTCCTCGAA')),
#   (1, ('GTACTTGC', 'GTTATAAATAGCTTAACCGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA'))],
#  [(3, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'GATGCAACGTCTTTCACTAAA'))],
#  [(3, ('CGTTAGGG', 'AACATAACTCCATTATTCAAA')),
#   (2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (2, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATGTAGTTTGTGGAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'TATAAAAGTTATTTTCATAAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'TGGAAAAAGTGTTTGAGAGAA')),
#   (1, ('CTGAATCT', 'TAAACAAGAGAATTAACGAAA')),
#   (1, ('CTGAATCT', 'CTTATAACTCTTTTTTCCCAA')),
#   (1, ('CCATTACT', 'AGGGAAAGGAAATTAAAATAA')),
#   (1, ('ACAGAGCC', 'TGTTGAATGTATTTGGGATAA')),
#   (1, ('ACAGAGCC', 'GTATGAACGTCATTAAAGTAA'))],
#  [(1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('GTACTTGC', 'GTTATAAATAGCTTAACCGAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA'))],
#  [(2, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TTAATTAG', 'AAAGAAAAATAATTCCAAAAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGAGTTGTGGGAA')),
#   (1, ('CCATTACT', 'CCGGCAACGTCCTTTGCCCAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('GGTAGGGA', 'GTTGAAATCAAATTTTCACAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('GGTAGGGA', 'AGCTGAACGCAGTTTAGTGAA')),
#   (1, ('GGTAGGGA', 'ACTACAATTTGTTTGTGTGAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('ACAGAGCC', 'GCATTAATGTTTTTCTATGAA'))],
#  [(1, ('TTAATTAG', 'GGTGGAAAGCTGTTGTAATAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('GGTAGGGA', 'CCATCAATACATTTTCGGAAA')),
#   (1, ('GCCTACGT', 'TTGGGAATGGGGTTTTGGGAA')),
#   (1, ('CTGAATCT', 'CTCCTAACCCCCTTACTCTAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGTTAGGG', 'ATAGGAAATGGCTTTGCATAA')),
#   (1, ('CGTTAGGG', 'AAGGCAATGGAATTCTTTAAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CGGGAATG', 'CCCCAAACACGATTCTCACAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('CAGTGCAT', 'TATACAAGGGCTTTTGCTAAA'))],
#  [(2, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (2, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (2, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (2, ('CCATTACT', 'AGGGAAAGGAAATTAAAATAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('CGTTCAAG', 'CGTTGAAGTTACTTAATTGAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGTTAGGG', 'GCGCAAATTGTTTTGAAGAAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('ACAGAGCC', 'TCTCTAAGTTACTTTCATAAA')),
#   (1, ('ACAGAGCC', 'CTATAAAACTTTTTAGAAAAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA')),
#   (1, ('ACACGTGA', 'AATGAAATGAGCTTCTTGCAA'))],
#  [(1, ('TTAATTAG', 'TTTGAAAGGATGTTAGGTTAA')),
#   (1, ('TTAATTAG', 'ATCACAAAGATTTTCGAACAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'GTTATAAATAGCTTAACCGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGTGTTGAAAGAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CCATTACT', 'GGGTTAATGTGTTTGTTGAAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA')),
#   (1, ('ACACGTGA', 'CGACCAAACAACTTACCCTAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA'))],
#  [(3, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (3, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (2, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (2, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGCGGAAGGGGTTTAGATGAA')),
#   (1, ('TTAATTAG', 'GCAACAACAAGATTCTAACAA')),
#   (1, ('TTAATTAG', 'AACACAACACAATTCCATAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'GCTCTAAGACTCTTTAAAGAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'GGTCTAACCCCTTTCTCGAAA')),
#   (1, ('CGTTTCCT', 'GACATAAATTCATTGGCTCAA')),
#   (1, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'TTGTCAACCCCCTTCTTCCAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA'))],
#  {('TTAATTAG', 'CCCCAAATGTGATTTCCTCAA'): 1},
#  [(2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TGTAGAATTGTTTTGAGGTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('GTACTTGC', 'CATCAAATGTCATTGAGCAAA')),
#   (1, ('GGTAGGGA', 'TGCCTAAAGCAATTGCAGGAA')),
#   (1, ('GCCAATCG', 'GATGCAAATAGATTTGGATAA')),
#   (1, ('CGTTTCCT', 'GACATAAATTCATTGGCTCAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTGTGACAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGTCATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'GAGGGAACCCGCTTAAGGTAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAGATAAAGTGGTTGAGGGAA')),
#   (1, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'TTGTCAACCCCCTTCTTCCAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('CAGTGCAT', 'TATACAAGGGCTTTTGCTAAA')),
#   (1, ('ACAGAGCC', 'GTCTCAATGGTTTTATTAGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGTGTTTGGTGTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCGCCCAA'))],
#  [(3, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (2, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'CCTTCAATTTACTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCACCTTCCAACAA')),
#   (1, ('GGTAGGGA', 'ATTAAAACGGATTTCTTTAAA')),
#   (1, ('CGTTAGGG', 'GAGCTAAGTTACTTCTTTAAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGCGGTAA')),
#   (1, ('CCATTACT', 'GGGTTAAGGGGTTTATGGTAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA'))],
#  [(2, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TTTGAAAGGATGTTAGGTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'TTATCAAAAACATTCATCAAA')),
#   (1, ('TGTCTAGT', 'GGGTGAATGTTGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAGAAAATTAAAAGAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCTGATTGTAGGAA')),
#   (1, ('GGTAGGGA', 'GAAAAAAAGGATTTACGTCAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'GTTTCAACCTGGTTGTTATAA')),
#   (1, ('CGTTCAAG', 'TATATAAATAAGTTATTAGAA')),
#   (1, ('CGTTCAAG', 'GATACAATTCTTTTAAAGTAA')),
#   (1, ('CGTTCAAG', 'GACACAAACATGTTCAGTCAA')),
#   (1, ('CGTTAGGG', 'TGGTGAATTTCATTCCATCAA')),
#   (1, ('CGTTAGGG', 'AAGGCAATGGAATTCTTTAAA')),
#   (1, ('CGGGAATG', 'TTGTTAAGTTGTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGCGGTAA')),
#   (1, ('ACAGAGCC', 'TATGGAAAATTATTACTTTAA')),
#   (1, ('ACACGTGA', 'GGTGGAAGGTGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')),
# ...
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('GCCAATCG', 'CTATGAACAGGTTTTAATCAA')),
#   (1, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'GCATTAATGTTTTTCTATGAA')),
#   (1, ('ACACGTGA', 'GGAGGAATGGGATTGGAGGAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(3, ('TTAATTAG', 'GGAGGAAGAAAGTTAATCGAA')),
#   (2, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('ACACGTGA', 'GGAAGAAGGGGATTAGGGGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTTTTTTATATAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTGTGACAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('CTGAATCT', 'TAAACAAGAGAATTAACGAAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CAGTGCAT', 'ACGAGAATATCCTTTGGTTAA'))],
#  [(1, ('TTAATTAG', 'TTCCAAAGAATTTTCTGTCAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATGTAATTGTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'CCGCCAATGTTCTTACTCTAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCACCCAA')),
#   (1, ('GGTAGGGA', 'TGCAAAATCATATTATTAAAA')),
#   (1, ('GGTAGGGA', 'GAATCAACGAGATTTGGGTAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CTGAATCT', 'AAGATAAAGTGGTTGAGGGAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGGGAATG', 'GAACAAAGTACATTGTGTGAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('CCATTACT', 'AGGGAAAGGAAATTAAAATAA')),
#   (1, ('ACAGAGCC', 'GTCAAAAGCTAATTCGTGTAA')),
#   (1, ('ACACGTGA', 'GAGGCAAGGGGTTTTTGGGAA'))],
#  [(1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGGGAAGGGTATTAGGAGAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CTGAATCT', 'CTCCTAACCCCCTTACTCTAA')),
#   (1, ('CGGGAATG', 'TTGTTAATCTTTTTTTTCCAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'GGGTTAAGGGGTTTATGGTAA')),
#   (1, ('CCATTACT', 'AGGAAAAGGAAATTAAAATAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))],
#  [(2, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (2, ('CATAGTCA', 'TCCTTAACGACCTTCCTCCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCATTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAATGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'GATGCAAATAGATTTGGATAA')),
#   (1, ('CGTTAGGG', 'AAGGCAATGGAATTCTTTAAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'GAACAAAGTACATTGTGTGAA')),
#   (1, ('CCATTACT', 'AAAAAAAGAGAATTAAATGAA'))],
#  [(3, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CGTTAGGG', 'GGCTGAATTCCTTTGATCTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTGAA')),
#   (1, ('CGGGAATG', 'CCTCCAACACTCTTTACCAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAAACCCCTTAACCGAA')),
#   (1, ('ACAGAGCC', 'TAGGGAAGAGGTTTGATGGAA'))],
#  {('GGTAGGGA', 'GTTTAAATAGTTTTCTCTTAA'): 2},
#  [(2, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'CCCCGAACCCACTTGCCGCAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('GCCTACGT', 'TTGGGAATGGGGTTTTGGGAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('CCATTACT', 'GGGTTAATGTGTTTGTTGAAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA')),
#   (1, ('ACACGTGA', 'CTCCCAACTTTTTTCCCCAAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTATTTTCTTTGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CCATTACT', 'GCCACAACGTTGTTTACGGAA')),
#   (1, ('ACACGTGA', 'GGGGTAAGGGGGTTGGTTGAA'))],
#  [(2, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'AGAACAATGTTTTTTATCCAA')),
#   (1, ('CGTTAGGG', 'AAGGCAATGGAATTCTTTAAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('ACACGTGA', 'TGGGGAAGGCAGTTGGTGAAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'GGGTAAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGAGTAA')),
#   (1, ('ACAGAGCC', 'TGTTGAATGTATTTGGGATAA')),
#   (1, ('ACAGAGCC', 'TAAATAAGATCATTGAGTTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('GCCTACGT', 'TGGGAAAGGGTGTTCTCGGAA')),
#   (1, ('CTGAATCT', 'AAGATAAAGTGGTTGAGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAATCCGTTTTTCCGAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'GCCACAACGTTGTTTACGGAA')),
#   (1, ('ACACGTGA', 'CAATCAATCCTGTTCTTCGAA'))],
#  [(1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'AACATAAATAAATTCAGAAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TTAATTAG', 'AAAGAAAAATAATTCCAAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACACCTTTCCTCCAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GGTAGGGA', 'TATAAAAAAGGCTTGGTTTAA')),
#   (1, ('GGTAGGGA', 'CTCTTAAGTCGATTCCCATAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GCCTAAAAATGTTTAATTTAA'))],
#  [(1, ('TGTCTAGT', 'TTGTTAACCTTATTCATTTAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('GTACTTGC', 'GTTATAAATAGCTTAACCGAA')),
#   (1, ('GCCAATCG', 'CTATGAACAGGTTTTAATCAA')),
#   (1, ('CAGTGCAT', 'GTGCAAAATTTTTTGACGTAA')),
#   (1, ('ACAGAGCC', 'CTATAAAACTTTTTAGAAAAA'))],
#  [(2, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTGTGACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TGCCTAAAGCAATTGCAGGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAGCTGATTGTAGGAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GCCAATCG', 'ATATCAATAATTTTGTTTTAA')),
#   (1, ('CTGAATCT', 'AAAAGAAAGCAATTGCAAAAA')),
#   (1, ('ACAGAGCC', 'TAAATAAGATCATTGAGTTAA')),
#   (1, ('ACACGTGA', 'GGACAAATCTGGTTCTTTGAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'AACACAACACAATTCCATAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTGTTTTGTTAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TCTGGGGC', 'CGCCCAACCGCCTTCGCCCAA')),
#   (1, ('GTACTTGC', 'GCTAGAATTTACTTCTTAGAA')),
#   (1, ('GGTAGGGA', 'TATAAAAGTTATTTTCATAAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGGGAATG', 'CCCCAAACACGATTCTCGCAA')),
#   (1, ('ACAGAGCC', 'TGGAAAACATTTTTACCATAA'))],
#  [(2, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('TTAATTAG', 'GGTGGAAAGCTGTTGTAATAA')),
#   (1, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('GGTAGGGA', 'TGCCTAAAGCAATTGCAGGAA')),
#   (1, ('GGTAGGGA', 'GAAAAAAAGGATTTACGTCAA')),
#   (1, ('CTGAATCT', 'AAGATAAAGTGGTTGAGGGAA')),
#   (1, ('CGTTAGGG', 'TCGGGAATCGGGTTCACGGAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCGCCTTTGCACAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGAGTTGTGGGAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA')),
#   (1, ('ACAGAGCC', 'GGGGGAACCTTTTTTGGTGAA')),
#   (1, ('ACAGAGCC', 'CTATAAAACTTTTTAGAAAAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(2, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (2, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GCCAATCG', 'GATGCAAATAGATTTGGATAA')),
#   (1, ('CGTTAGGG', 'AAGGCAATGGAATTCTTTAAA')),
#   (1, ('CGGGAATG', 'TTGTCAACCCCCTTCTTCCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'GCCACAACGTTGTTTACGGAA')),
#   (1, ('CAGTGCAT', 'TATACAAGGGCTTTTGCTAAA'))],
#  [(2, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTGTTTTTGTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'AGGGGAATGGGGTTGGGGTAA'))],
#  [(3, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (2, ('ACAGAGCC', 'TGACTAACTTAATTTTGTAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCATTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTCCTTTCGGTTAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GGTAGGGA', 'CTCTTAAGTCGATTCCCATAA')),
#   (1, ('GCCTACGT', 'TTGGGAATGGGGTTTTGGGAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CTGAATCT', 'CTTAGAAAGAGATTGGCAGAA')),
#   (1, ('CGTTTCCT', 'GATGCAACGTCTTTCACTAAA')),
#   (1, ('CGTTCAAG', 'GGGGTAACGTTGTTTGTATAA')),
#   (1, ('CGTTCAAG', 'GATACAATTCTTTTAAAGTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('ACAGAGCC', 'TAAATAAGATCATTGAGTTAA'))],
#  [(3, ('CGTTAGGG', 'AACATAACTCCATTATTCAAA')),
#   (2, ('TTAATTAG', 'ATTTAAATTTTTTTTTTATAA')),
#   (2, ('ACACGTGA', 'CCCACAACCGCATTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('CGTTTCCT', 'TTTATAATAGTTTTGTACTAA')),
#   (1, ('CGTTCAAG', 'TATATAAATAAGTTATTAGAA')),
#   (1, ('CGTTCAAG', 'GATACAATTCTTTTAAAGTAA')),
#   (1, ('CGTTAGGG', 'TGGTGAATTTCATTCCATCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TGGGTAAGGAGGTTGCGGTAA')),
#   (1, ('ACAGAGCC', 'TATACAATTAATTTTGCATAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAAATTTTTTATTTTAA')),
#   (2, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (2, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GAAGAAAAGGAGTTAAATAAA')),
#   (1, ('TGTCTAGT', 'TAACTAAACCTCTTTCCCCAA')),
#   (1, ('TGTCTAGT', 'GTGGAAATTTTCTTAGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGACATTAATAGAA')),
#   (1, ('TGTCTAGT', 'GCGTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'CTCTGAAATCGTTTCTTCAAA')),
#   (1, ('GGTAGGGA', 'GAAAAAAAGGATTTACGTCAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'CTCCTAACCCCCTTACTCTAA')),
#   (1, ('CTGAATCT', 'CATGAAAATTTTTTACTTCAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CGTTCAAG', 'ACCTCAATATTTTTACGTCAA')),
#   (1, ('CGTTAGGG', 'TCGTTAAGGTCCTTAATAAAA')),
#   (1, ('CGTTAGGG', 'CCTCAAAATTTCTTGGTGAAA')),
#   (1, ('CGTTAGGG', 'AACATAACTCCATTATTCAAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGTGTTTTCTTTTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGAGTTGTGGGAA')),
#   (1, ('CGGGAATG', 'CCTCCAACACTCTTTACCAAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('CCATTACT', 'CCGGCAACGTCCTTTGCCCAA')),
#   (1, ('CAGTGCAT', 'TATACAAGGGCTTTTGCTAAA')),
#   (1, ('CAGTGCAT', 'CATCCAAGAACTTTCGCCAAA')),
#   (1, ('ACAGAGCC', 'CTATAAAACTTTTTAGAAAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGTGTTTGGTGTAA')),
#   (1, ('ACACGTGA', 'CATTAAAACTGGTTGGTTGAA'))],
#  [(1, ('CCATTACT', 'AGGGTAAAGGGGTTGGAGTAA')),
#   (1, ('CAGTGCAT', 'GATGAAATTCACTTAATCTAA')),
#   (1, ('ACAGAGCC', 'CATTTAAGGGCTTTTTTACAA')),
#   (1, ('ACACGTGA', 'GTCTAAACGTCATTCACGTAA'))],
#  [(1, ('TGTCTAGT', 'CGCGAAATAAAGTTGGGTCAA')),
#   (1, ('GTACTTGC', 'TGATTAATTTTCTTAAAATAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('CGTTCAAG', 'CGTTGAAGTTACTTAATTGAA')),
#   (1, ('CGGGAATG', 'TTGTCAACCCCCTTCTTCCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGCGTTGGGGGAA'))],
#  [(1, ('TTAATTAG', 'TGTGTAATGATTTTATAGTAA')),
#   (1, ('TTAATTAG', 'GGTGGAAAGCTGTTGTAATAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGACATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAAAGAAATTAGAAGAA')),
#   (1, ('GGTAGGGA', 'TATAAAAGTTATTTTCATAAA')),
#   (1, ('GCCTACGT', 'GCTGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'AAAAAAAAGAGGTTAGACAAA')),
#   (1, ('CCATTACT', 'TCAACAAAATGATTAGAGAAA')),
#   (1, ('ACACGTGA', 'CATTAAAACTGGTTGGTTGAA'))],
#  [(3, ('CGGGAATG', 'TTGAGAAGAGTTTTAAGATAA')),
#   (1, ('TTAATTAG', 'TGCCTAATTCTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('GTACTTGC', 'ATTAGAACTCGTTTGACATAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'ACAACAACAAAATTCACCGAA')),
#   (1, ('CCATTACT', 'CATTCAATGTTGTTTGTCAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('GGTAGGGA', 'TGATAAACGGAATTCTAGCAA')),
#   (1, ('GGTAGGGA', 'CTAGAAAATCACTTCTGTTAA'))],
#  [(3, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTGAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGAGAA')),
#   (2, ('CGTTCAAG', 'GTGAAAATAATTTTAGGTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGAGGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'GCCCAAACCCCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TGTCTAGT', 'CCACCAACCCCCTTGCTCCAA')),
#   (1, ('GGTAGGGA', 'GCTCTAAGACTCTTTAAAGAA')),
#   (1, ('GGTAGGGA', 'ACTTGAACGTCTTTTGTTGAA')),
#   (1, ('CTGAATCT', 'TTCTTAACATTTTTATTTTAA')),
#   (1, ('CTGAATCT', 'GCGTAAAAGTGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TATCAAACTATTTTGCACTAA')),
#   (1, ('CCATTACT', 'CTCCCAATACCCTTCGCCTAA')),
#   (1, ('ACAGAGCC', 'GTCTCAATGGTTTTATTAGAA')),
#   (1, ('ACAGAGCC', 'AATATAAGTCCTTTTGCGGAA')),
#   (1, ('ACACGTGA', 'CAAACAACCCCATTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'GTTTCAATATTTTTCTTTTAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('CGTTCAAG', 'GGGGTAACGTTGTTTGTATAA')),
#   (1, ('ACACGTGA', 'GAAGTAAGTCGTTTTTGTGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTATTTTCTTTGAA')),
#   (1, ('TTAATTAG', 'TTCCAAAGAATTTTCTGTCAA')),
#   (1, ('TTAATTAG', 'GGAGCAACGCGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'AACACAACCCACTTCCCTCAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCATTGAGCCAA')),
#   (1, ('TCTGGGGC', 'GTGTTAATTTTTTTTTTTTAA')),
#   (1, ('GTACTTGC', 'TCCTAAACGGATTTGGACAAA')),
#   (1, ('GGTAGGGA', 'TTTGAAAAGTGATTGAATCAA')),
#   (1, ('GGTAGGGA', 'CCAGAAAACAATTTTAGTTAA')),
#   (1, ('GGTAGGGA', 'ACTTGAACGTCTTTTGTTGAA')),
#   (1, ('GGTAGGGA', 'AATTAAATGTGGTTAAATTAA')),
#   (1, ('CTGAATCT', 'TGGAAAAAGTGTTTGAGAGAA')),
#   (1, ('CGGGAATG', 'CCGCTAATCGTCTTCGGCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CCATTACT', 'GCCACAACGTTGTTTACGGAA')),
#   (1, ('CAGTGCAT', 'TATACAAGGGCTTTTGCTAAA')),
#   (1, ('ACACGTGA', 'TGTTTAAATTTTTTGGTTGAA'))],
#  [(2, ('TTAATTAG', 'GGAGAAAAGAGGTTAGAAGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAAGGGGTTGTAGGAA')),
#   (1, ('TGTCTAGT', 'GGCTTAAGCCCCTTTGTCTAA')),
#   (1, ('CTGAATCT', 'TTCTCAATTTAGTTTTGTAAA')),
#   (1, ('CGTTAGGG', 'CTGCTAATTTCCTTCTCGAAA')),
#   (1, ('CGGGAATG', 'CCTCCAACACTCTTTACCAAA')),
#   (1, ('CCATTACT', 'GCCACAACGTTGTTTACGGAA')),
#   (1, ('ACACGTGA', 'AATGAAATGAGCTTCTTGCAA'))],
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 4486

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
