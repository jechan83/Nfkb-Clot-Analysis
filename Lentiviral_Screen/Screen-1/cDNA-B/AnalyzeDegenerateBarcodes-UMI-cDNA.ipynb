# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist1.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 8700

# %% [raw]
# afile = pysam.AlignmentFile("./final.bam")
# hashcount = {}
# hashset = {}
# cellhash = {}
# taghash = {}
# readcount = {}
# barcodehash = {} # barcodes listing shRNAID
# barcodebycellUMI = {} # barcode listing cellUMI
# doublecounts = 0
# cellbyUMI = {}
# inwhitelist = set()
# inwhitelistcount = 0
# outwhitelist = set()
# outwhitelistcount = 0
# for seq_record in afile.fetch(until_eof=True):
#     cellUMI = None  # here this is the CellRanger cell UMI
#     UMI = None
#     if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
#     cellUMI = seq_record.get_tag("CB")
#     if cellUMI not in whitelist:
#         outwhitelistcount +=1
#         if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
#         continue
#     else:
#         inwhitelistcount += 1
#         if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
#     UMI = seq_record.get_tag("UB") # umi barcode
#
#     m = hashmatch.search(seq_record.query_sequence)
#     if m == None or (m.end() + 8) > len(seq_record.query_sequence):
#         #print("Error, match not found")
#         continue
#     shRNAID = seq_record.query_sequence[m.end():m.end()+8]
#     barcode = seq_record.query_sequence[m.end()-21:m.end()]
#     sbID = (shRNAID,barcode)
#     if shRNAID not in hashes: continue
#     if cellUMI not in cellbyUMI:
#         cellbyUMI[cellUMI] = {}
#     if UMI not in cellbyUMI[cellUMI]:
#         cellbyUMI[cellUMI][UMI] = {sbID: 1}
#         continue
#     if sbID in cellbyUMI[cellUMI][UMI]:
#         cellbyUMI[cellUMI][UMI][sbID] += 1
#     else:
#         hamming = False
#         for x in cellbyUMI[cellUMI][UMI]:
#             if hammingDistance(sbID[1],x[1]) <= 2:
#                 cellbyUMI[cellUMI][UMI][x] += 1
#                 hamming = True
#                 break
#         if hamming: continue
#         cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle
cellbyUMI = False
with open('cellbyUMI.pickle', 'rb') as f:
    cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 38

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 8697

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 8450

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] > threshold: 
                ncellbyUMI[y] = newUMI[0][1]
            else:
                print("Not past threshold: %s" % str(newUMI))
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (8.117900896728834, 1, 2342, 1.0)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 3695

# %%
len(whitelist)
# Out:
# 8700

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 4696

# %%
poorUMI
# Out:
# [[(3, ('TTAATTAG', 'TGGGAAATGATTTTTGTGCAA')),
#   (1, ('TTAATTAG', 'TGTTGAAAAAGTTTCTAAGAA')),
#   (1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCAATCG', 'TGTTGAATAGTTTTTCCTTAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('ACAGAGCC', 'TCAATAATATCTTTTACGGAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (3, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'TTTCTAATGTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGCGAA')),
#   (1, ('TGTCTAGT', 'CCAACAACGCGATTCCACCAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'GGTGTAAATGCATTTCTTCAA')),
#   (1, ('GGTAGGGA', 'ATCACAAAGCGATTAAGTCAA')),
#   (1, ('CTGAATCT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'GGCTGAAGTTTTTTGTTGTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(4, ('TGTCTAGT', 'AAAAAAAATAAATTCGAAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGTGAA')),
#   (1, ('GTACTTGC', 'TAACCAAAGGCGTTTTCGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'GAAGAAACAAAATTCTATAAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCATGTTGGAGGAA')),
#   (1, ('GTACTTGC', 'TGGGTAACCATTTTTAGCTAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('CTGAATCT', 'CTTTTAATCTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATCCTTTTTTTTCAA')),
#   (1, ('CGGGAATG', 'CCACAAACCCCATTCTCCCAA')),
#   (1, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA')),
#   (1, ('ACACGTGA', 'GGCTGAAGTTTTTTGTTGTAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCATGTTGGAGGAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAATTGTTTGTAGAAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAAACGGCTTTTTGTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTATCAACCTTTTTGTGTCAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('ACACGTGA', 'GGCTGAAGTTTTTTGTTGTAA'))],
#  [(1, ('TTAATTAG', 'TTCCAAAACTCGTTCTCTCAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA'))],
#  [(3, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (2, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('GCCAATCG', 'ATTCAAATTACATTACTCAAA')),
#   (1, ('ACAGAGCC', 'GAACAAAGATTCTTATACGAA')),
#   (1, ('ACACGTGA', 'GGGGGAATTGGGTTGGTGGAA'))],
#  [(3, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTATGTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('TGTCTAGT', 'CTTCGAAGTTACTTGGGACAA')),
#   (1, ('GGTAGGGA', 'TGAGAAATGAGATTGAATAAA')),
#   (1, ('CTGAATCT', 'TTTTGAATTTGGTTATTATAA')),
#   (1, ('CGTTAGGG', 'ACGAAAACACGTTTAGGTAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAGATGTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTGTGTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGAGGAATGTCATTGTGGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('CGTTCAAG', 'GTTAAAAACTTTTTGTTAAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTTTTTTTTTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (2, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGCGAA')),
#   (1, ('TGTCTAGT', 'AGGGGAAGGTGATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TTGCAAAATATGTTATGCTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GGGGGAATTGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA')),
#   (1, ('ACACGTGA', 'AAGGGAAGGGTGTTGGGTGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'GAGTCAAGGACATTTTACTAA')),
#   (1, ('CTGAATCT', 'TTCTTAACTTTTTTTATTGAA')),
#   (1, ('ACAGAGCC', 'CTCGTAATATGATTTTAGAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGAGTTTGGTTGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('GGTAGGGA', 'TTGAAAATAGGTTTGGGTTAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('ACAGAGCC', 'TCAATAATATCTTTTACGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA'))],
#  [(1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'CGGGTAATAGTTTTTCTAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGTGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TACGGAATTCTTTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'C
A')),
#   (1, ('CGTTCAAG', 'ACCTTAATTGAGTTGTTGGAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('CCATTACT', 'AGGTAAATGGGGTTAGATGAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('ACACGTGA', 'GGGGGAATTGGGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GGGTGAAAGTGGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATTTCATTCGAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TCTGGGGC', 'GGGCTAATGTGTTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'GAGTCAAGGACATTTTACTAA')),
#   (1, ('GGTAGGGA', 'CGTCAAAGTTTTTTTCTTCAA')),
#   (1, ('GGTAGGGA', 'AAGGAAACCGTGTTATATAAA')),
#   (1, ('CCATTACT', 'CGAGCAACGTAATTCCCCTAA')),
#   (1, ('ACAGAGCC', 'TCTCAAACGTTTTTAGACGAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(2, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGGAATGTCATTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTTTCAAATACTTTTCCCTAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA'))],
#  [(3, ('GGTAGGGA', 'AAGGAAACCGTGTTATATAAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGTTAGGG', 'GACTTAATCAGATTTTCGGAA')),
#   (1, ('CGTTAGGG', 'CGCCTAAGTTCGTTTCATTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CCCACAATTACTTTGCAGCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'TTACCAAATGTGTTACTTAAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'ACTTAAACGCATTTGTGAAAA')),
#   (1, ('CGTTTCCT', 'TGGGGAAGTTTGTTGGGGTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('TTAATTAG', 'TTAACAATAATGTTAGATTAA')),
#   (1, ('TTAATTAG', 'TATTCAATTATTTTTTTTCAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (3, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (2, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (2, ('CGGGAATG', 'CCTCTAACCCCCTTTGTTCAA')),
#   (2, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('TTAATTAG', 'GTAGCAATAATGTTAGATTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACACACTTCCACCAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'GAGTCAAGGACATTTTACTAA')),
#   (1, ('GGTAGGGA', 'CTTCCAAAGCACTTGGTTAAA')),
#   (1, ('GGTAGGGA', 'AAGGAAACCGTGTTATATAAA')),
#   (1, ('GCCTACGT', 'TTCTGAATTTTTTTTTTTGAA')),
#   (1, ('CTGAATCT', 'TTTTTAACTTTTTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'GGAGTAAAGGTATTTTGATAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGGAGAATGAAGTTAAGGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTGTTTGTATTAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('CGTTAGGG', 'CAGCCAATGGTATTACGGTAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('GGTAGGGA', 'CAGCCAAAGCATTTCGATAAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('ACAGAGCC', 'CGATTAACCAGGTTTTGTCAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GGTAGGGA', 'CGGGTAATAGTTTTTCTAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA'))],
#  [(5, ('GGTAGGGA', 'TTGGCAATTCGTTTTAAAGAA')),
#   (4, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('CCATTACT', 'AGGTAAATGGGGTTAGATGAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TGTGCAATGATGTTTTAATAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('TGTCTAGT', 'GTTGTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GGTAGGGA', 'TTCTGAAAGCTCTTCTTGCAA')),
#   (1, ('GGTAGGGA', 'CAGCCAAAGCATTTCGATAAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACAGAGCC', 'GGAGTAAAGGTATTTTGATAA')),
#   (1, ('ACAGAGCC', 'CGATTAACCAGGTTTTGTCAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA')),
#   (1, ('ACACGTGA', 'GGGGGAACGGTGTTCGGGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(3, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCTTTTTCCTCAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TCTAAAAACATCTTGTTGTAA')),
#   (1, ('ACACGTGA', 'CACCCAAACCCATTCCCCCAA'))],
#  [(2, ('TGTCTAGT', 'TTTTTAATTTTTTTGATTTAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTGTTTGTATTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TCTCAAACGTTTTTAGACGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GGCGGAACAAACTTGTGAAAA')),
#   (1, ('CGGGAATG', 'TTTTTAATCCTTTTTTTTCAA'))],
#  [(2, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'AAGGAAACCGTGTTATATAAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('CCATTACT', 'CGTCGAATGGTATTGGGTAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTGGAAATTATGTTATTAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GTACTTGC', 'GATCAAATATGATTATATAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGTTTCCT', 'GGCAAAATGGATTTCCTATAA')),
#   (1, ('CGTTAGGG', 'TCCACAAACAGATTAACATAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCATTATCCCAA')),
#   (1, ('CCATTACT', 'AGGTAAATGGGGTTAGATGAA')),
#   (1, ('ACAGAGCC', 'TCAATAATATCTTTTACGGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGTGAA')),
#   (1, ('TGTCTAGT', 'CCAACAAAGCACTTCCAACAA')),
#   (1, ('TCTGGGGC', 'GGGCTAATGTGTTTGGTTGAA')),
#   (1, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (1, ('GGTAGGGA', 'TGGAGAAATTTTTTTCTGAAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAGACATTGAAACAA')),
#   (1, ('CGTTCAAG', 'GGCTTAACAAGCTTTTTGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCTTCCAA')),
#   (1, ('ACAGAGCC', 'GGAGTAAAGGTATTTTGATAA')),
#   (1, ('ACACGTGA', 'GGCTGAAGTTTTTTGTTGTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(4, ('GGTAGGGA', 'CAGCCAAAGCATTTCGATAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTTTTTTTTTTAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'CTTCCAAAGCACTTGGTTAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAGTAATTTGTTTGAA')),
#   (1, ('ACACGTGA', 'GGGTGAAGGGGGTTGGGTGAA'))],
#  [(3, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (2, ('TGTCTAGT', 'GAAAAAACAGTATTAAAAAAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GTTGTAATGTTGTTTGTCTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('CTGAATCT', 'TTTTGAATTTGGTTATTATAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGAACTTTGGCTTAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('ACAGAGCC', 'TCAATAATATCTTTTACGGAA')),
#   (1, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CAAACAAACGGATTGACAAAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CGGGAATG', 'GGGTGAAGGGTGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'GGCTGAAGTTTTTTGTTGTAA')),
#   (1, ('ACACGTGA', 'GCCCAAACCCAGTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TCTCAAACGTTTTTAGACGAA'))],
#  [(2, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('TGTCTAGT', 'GTTGTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGTGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAAGCGCATTCCACAAA')),
#   (1, ('TGTCTAGT', 'CCACCAACTCCCTTCCCACAA')),
#   (1, ('GGTAGGGA', 'GGTTCAAACGGCTTTTTGTAA')),
#   (1, ('GGTAGGGA', 'AGGGTAATCTTGTTTGTAGAA')),
#   (1, ('GGTAGGGA', 'AGATAAATCGCATTGTATGAA')),
#   (1, ('CCATTACT', 'AGAAAAAAGTAGTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TCCCAAAAATTTTTCTGTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'GAGTCAAAAGAATTTAGGCAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('TTAATTAG', 'AAGACAACGTAATTCAATCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('GTACTTGC', 'GATCAAATATGATTATATAAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('CGTTAGGG', 'AAACAAAAGCAGTTTCGGGAA')),
#   (1, ('CCATTACT', 'TGGCAAATGTTGTTTGTGCAA')),
#   (1, ('ACAGAGCC', 'CGATGAAACTCTTTACCTGAA')),
#   (1, ('ACACGTGA', 'GGGGGAACGGCGTTCGGGGAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA')),
#   (1, ('ACACGTGA', 'GAAAGAATCGGTTTGGACGAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCGAGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAAAAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TCTAAAAACATCTTGTTGTAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TGTTGAAAAAGTTTCTAAGAA')),
#   (1, ('TGTCTAGT', 'TTTGTAACTTGTTTTGTAGAA')),
#   (1, ('TGTCTAGT', 'TATGGAAGGAGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'TTTTTAATCCGTTTTTTGTAA')),
#   (1, ('CTGAATCT', 'TTTTGAATTTGGTTATTATAA')),
#   (1, ('CTGAATCT', 'TCCTAAATTTCTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'CGCCTAAGTTCGTTTCATTAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (3, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTGTAAAGATTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TCTGGGGC', 'GGGCTAATGTGTTTGGTTGAA')),
#   (1, ('GTACTTGC', 'TGGGTAACCATTTTTAGCTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CAGTGCAT', 'TCATTAAATACGTTTATCAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGAGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('GCCTACGT', 'TGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTAGCAATAAGGTTAGATTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGATGGAA')),
#   (1, ('ACAGAGCC', 'GGAGTAAAGGTATTTTGATAA')),
#   (1, ('ACACGTGA', 'GGGTGAAGGGGTTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GGGCGAATCCTGTTAGCGGAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'TTAGCAATAATGTTAGATTAA')),
#   (1, ('TTAATTAG', 'ATTAAAATCTGTTTCGATAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCACCAACTCCCTTCCCACAA')),
#   (1, ('GTACTTGC', 'TGGGTAACCATTTTTAGCTAA')),
#   (1, ('GCCAATCG', 'TTCTTAAAATTTTTGGTTTAA')),
#   (1, ('CGTTCAAG', 'TATTGAACAAAATTATGCTAA')),
#   (1, ('CGGGAATG', 'GGGTGAAGGGTGTTGTGGGAA'))],
#  [(1, ('TGTCTAGT', 'GTTGTAATTTCTTTTGTTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAACGGCGTTCGGGGAA'))],
#  [(3, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (2, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(1, ('TTAATTAG', 'TTAGCAATAATGTTAGATTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('CGTTAGGG', 'GGCGGAACAAACTTGTGAAAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GCCAATCG', 'TTTGGAATCTCTTTTGGAAAA')),
#   (1, ('CAGTGCAT', 'TGTGTAATAGATTTTTATAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TTAATTAG', 'CTCACAAAACTATTCCATCAA')),
#   (1, ('TTAATTAG', 'CCACAAATTCCTTTCTCTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'TTGGAAATTGAGTTTGATTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGTTAGGG', 'GACTTAATCAGATTTTCGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCATTATCCCAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('TCTGGGGC', 'GGGCTAATGTGTTTGGTTGAA')),
#   (2, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA')),
#   (1, ('TGTCTAGT', 'GTGTTAAGGTTTTTGTTTAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGAGGAATGTCATTGTGGGAA')),
#   (1, ('GGTAGGGA', 'TGAGAAATGAGATTGAATAAA')),
#   (1, ('GGTAGGGA', 'AGGGTAATCTTGTTTGTAGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CATAGTCA', 'TGTTGAAAGGCCTTTTTCGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTGGAAATTGAGTTTGATTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTAGAAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCTTTTTTGTCTAA')),
#   (1, ('CAGTGCAT', 'ATTTTAATCACATTTGAGAAA')),
#   (1, ('ACAGAGCC', 'TCTAAAAACATCTTGTTGTAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA')),
#   (1, ('ACACGTGA', 'GGAAGAAAGGGATTGAAAGAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGAGGAATGTCATTGTGGGAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('GCCTACGT', 'TGAGGAAGGTGGTTGTGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CGTTAGGG', 'AAACAAAAGCAGTTTCGGGAA')),
#   (1, ('CCATTACT', 'AGGTAAATGGGGTTAGATGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(3, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACACACTTCCACCAA')),
#   (1, ('GGTAGGGA', 'AAGGAAACCGTGTTATATAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCGAGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCTCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA')),
#   (1, ('ACACGTGA', 'GAAAGAATCGGTTTGGACGAA'))],
#  [(2, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TGGAGAAATTTTTTTCTGAAA')),
#   (1, ('GGTAGGGA', 'CGTCAAAGTTTTTTTCTTCAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGTTCAAG', 'TTTATAATGATATTAGCACAA')),
#   (1, ('CGTTAGGG', 'TCTCGAAGTGTCTTGATTAAA')),
#   (1, ('CCATTACT', 'CGTCGAATGGTATTGGGTAAA')),
#   (1, ('CAGTGCAT', 'ATTTTAATCACATTTGAGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTATGTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GGTAGGGA', 'GGTTCAAACGGCTTTTTGTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACACGTGA', 'GGGGGAACGGCGTTCGGGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GTTGTAATTTCTTTTGTCTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAATAAATTCGAAAAA')),
#   (1, ('GCCAATCG', 'TTGTAAAAAGATTTTCGATAA')),
#   (1, ('GCCAATCG', 'ATTCAAATTACATTACTCAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCATTATCCCAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGCGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (2, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'CTTCCAAAGCACTTGGTTAAA')),
#   (1, ('CTGAATCT', 'CCATAAAAACCCTTGTCACAA')),
#   (1, ('CGTTCAAG', 'TATTGAACAAAATTATGCTAA')),
#   (1, ('CGGGAATG', 'GGGTGAAGGGTGTTGTGGGAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACAGAGCC', 'CTCGTAATATGATTTTAGAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAGTAATTTGTTTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'GGTGGAATGAGGTTGAGGTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCATCAACTCCTTTCTCTCAA')),
#   (1, ('ACAGAGCC', 'TTGGTAAAATAATTGACTGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TCCCCAAAACCCTTCCTTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('CGTTAGGG', 'TGCATAATATTCTTTTAATAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATTTCATTCGAAGAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
# ...
#   (1, ('GGTAGGGA', 'GGAGTAAAGGAATTATTTAAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('CCATTACT', 'AGAAAAAACGAATTCATAAAA'))],
#  [(1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGTTAAGGTTTTTGTTTAAA')),
#   (1, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TTGAGAAGACATTTGTTCAAA')),
#   (1, ('CGTTCAAG', 'ACCTTAATTGAGTTGTTGGAA')),
#   (1, ('CGGGAATG', 'TCTTTAATCGTTTTTTTCTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CATAGTCA', 'GGGTCAAGCTGGTTTGGGAAA'))],
#  [(1, ('TGTCTAGT', 'GGGTGAAAGTGGTTGGAGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACAGAGCC', 'TCGGGAACATAATTTGAATAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'TTGGGAAGGTTGTTTGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('TGTCTAGT', 'CCCCTAACCAACTTACAACAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TAGTTAAATTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'TCCACAAACAGATTAACATAA')),
#   (1, ('ACACGTGA', 'GGCTGAAGTTTTTTGTTGTAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTGTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GTGTTAAGGTTTTTGTTTAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGCGAA')),
#   (1, ('TCTGGGGC', 'GGGCTAATGTGTTTGGTTGAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'CTTCCAAAGCACTTGGTTAAA')),
#   (1, ('GGTAGGGA', 'CAGCCAAAGCATTTCGATAAA')),
#   (1, ('CGTTCAAG', 'GTTGTAATGAATTTCTGTAAA')),
#   (1, ('CGGGAATG', 'GAGTCAAAAGAATTTAGGCAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGTGGAATGAGGTTGAGGTAA')),
#   (1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CGGGAATG', 'GAGTCAAAAGAATTTAGGCAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCATTATCCCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GGTAGGGA', 'GAGTCAAGGACATTTTACTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCATTATCCCAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GGGGGAACGGCGTTTGGGGAA'))],
#  [(1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TTCTTAACTTTTTTTTTTGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (2, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'GAGTCAAGGACATTTTACTAA')),
#   (1, ('CGTTCAAG', 'ACCTTAATTGAGTTGTTGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GGGAGAAAGGGGTTGGGTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGTGTTTGGGGAA')),
#   (2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TTAATTAG', 'TTAGCAATAATGTTAGATTAA')),
#   (1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('TGTCTAGT', 'CTTCGAAGTTACTTGGGACAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('GCCAATCG', 'ATTCAAATTACATTACTCAAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CTGAATCT', 'CTTTTAATCTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'TTATGAAGATCTTTTTGCGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATCCTTTTTTTTCAA')),
#   (1, ('CCATTACT', 'AGAAAAAAGTAGTTAGAAAAA')),
#   (1, ('ACAGAGCC', 'TCTCAAACGTTTTTAGACGAA')),
#   (1, ('ACAGAGCC', 'GGAGTAAAGGTATTTTGATAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGAGTTTGGTTGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'GGGTGAAGGGTGTTGTGGGAA')),
#   (2, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA')),
#   (1, ('TTAATTAG', 'GGCAAAAGCAATTTAAAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (1, ('GGTAGGGA', 'TTGAAAATAGGTTTGGGTTAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GGTAGGGA', 'AAGATAAAGTTGTTTTAAAAA')),
#   (1, ('CGTTCAAG', 'TATTGAACAAAATTATGCTAA'))],
#  [(1, ('GCCTACGT', 'GGGGGAAGGTGGTTGGGGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGAGTTTGGTTGAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTGTTAAATTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAACGGCGTTCGGGGAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('GCCTACGT', 'TGAGGAAGGTGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTCTTAATACTTTTCTTTTAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CTGAATCT', 'CCATAAAAACCCTTGTCACAA')),
#   (1, ('CGGGAATG', 'CCCTCAACCCCCTTCCTCCAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CAGTGCAT', 'TGTGTAATAGATTTTTATAAA')),
#   (1, ('ACAGAGCC', 'GGAGTAAAGGTATTTTGATAA')),
#   (1, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA')),
#   (1, ('ACAGAGCC', 'CGATTAACCAGGTTTTGTCAA')),
#   (1, ('ACACGTGA', 'GGGTGAAGGGGGTTGGGTGAA')),
#   (1, ('ACACGTGA', 'GGGGGAATTGGGTTGGTGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GTACTTGC', 'TGGGTAACCATTTTTAGCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACAGAGCC', 'TCAATAATATCTTTTACGGAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('CCATTACT', 'TGCCGAAGTGTTTTTTGTGAA')),
#   (1, ('ACAGAGCC', 'TCAATAATATCTTTTACGGAA')),
#   (1, ('ACACGTGA', 'GGGGGAACGGCGTTCGGGGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTCTTAAGATGTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGAGAAGGGAGTTGGCGGAA')),
#   (1, ('GGTAGGGA', 'CTTCCAAAGCACTTGGTTAAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACACGTGA', 'GGCTGAAGTTTTTTGTTGTAA'))],
#  [(1, ('TTAATTAG', 'GGCGGAATTAGGTTGAGTGAA')),
#   (1, ('TTAATTAG', 'GACACAAATTAATTAATAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAGACATTGAAACAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(2, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (2, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTGTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGTGAA')),
#   (1, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA')),
#   (1, ('ACACGTGA', 'GTTCAAATTTAATTGTCTTAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('TGTCTAGT', 'GTGTTAAGGTTTTTGTTTAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAGTAATTTGTTTGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TGAATAAGGATATTAGTCCAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GGTAGGGA', 'GAGTCAAGGACATTTTACTAA')),
#   (1, ('CGTTCAAG', 'TGATAAAATTATTTCATCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCATTATCCCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  {('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA'): 1},
#  {('CGTTCAAG', 'ACCTTAATTGAGTTGTTGGAA'): 1},
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GGTAGGGA', 'GAGTCAAGGACATTTTACTAA')),
#   (1, ('GGTAGGGA', 'ACTTAAACGCATTTGTGAAAA')),
#   (1, ('CGTTCAAG', 'TATTGAACAAAATTATGCTAA')),
#   (1, ('CCATTACT', 'TGGCTAATGTTGTTTGTGCAA')),
#   (1, ('ACAGAGCC', 'TCTCAAACGTTTTTAGACGAA')),
#   (1, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA'))],
#  [(1, ('CTGAATCT', 'AAAAAAAAGACATTGAAACAA')),
#   (1, ('CGGGAATG', 'TCTTTAATCGTTTTTTTCTAA')),
#   (1, ('CGGGAATG', 'GAGTCAAAAGAATTTAGGCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAGACAAAGTAATTCAATCAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('TGTCTAGT', 'CCCCTAACCAACTTACAACAA')),
#   (1, ('CGTTAGGG', 'CGTTCAAAGTGTTTGTCGAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))],
#  [(1, ('TGTCTAGT', 'GGAGGAATGTCATTGTGGGAA')),
#   (1, ('TGTCTAGT', 'CCAACAACGCGATTCCACCAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAGCTATTCTCTAAA')),
#   (1, ('GTACTTGC', 'GATCAAATATGATTATATAAA')),
#   (1, ('GGTAGGGA', 'CGTCAAATGGTATTGAGCCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATTCAAATTACATTACTCAAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('CTGAATCT', 'TTAAAAACTTCTTTTTTCCAA')),
#   (1, ('CTGAATCT', 'CCTCAAACTCCCTTCACACAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAGACATTGAAACAA')),
#   (1, ('CGGGAATG', 'CCTTTAATTTTTTTTTTTTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('ACAGAGCC', 'GGAGTAAAGGTATTTTGATAA')),
#   (1, ('ACACGTGA', 'GGGTGAAGGGGGTTGGGTGAA'))],
#  [(1, ('TTAATTAG', 'AAAAAAAACAAATTCAAACAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('ACAGAGCC', 'CGATTAACCAGGTTTTGTCAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGAGAAGGGAGTTGGCGGAA')),
#   (1, ('TGTCTAGT', 'CCAACAACGCGATTCCACCAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAATAAATTCGAAAAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('CTGAATCT', 'TTTTGAATTTGGTTATTATAA')),
#   (1, ('CGTTCAAG', 'ATTTTAAGAACTTTGGCTTAA'))],
#  [(3, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GTACTTGC', 'AGGACAAGACTCTTCATAGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(1, ('TGTCTAGT', 'AAAAAAAATAAATTCGAAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CGTTAGGG', 'TCCACAAACAGATTAACATAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CAGTGCAT', 'TGTTTAAGTACTTTAAACCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAGACATTGAAACAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCTAACCAACTTACAACAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGGAATGTCATTGTGGGAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGGGAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTAGCAATAATGTTAGATTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGCTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('TGTCTAGT', 'CCACCAACTCCCTTCCCACAA')),
#   (1, ('GCCAATCG', 'TAAGGAAGTATGTTGATGTAA')),
#   (1, ('CGTTAGGG', 'CGCCTAAGTTCGTTTCATTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAGGGGGTTGGGTGAA'))],
#  [(2, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CGTTCAAG', 'ACCTTAATTGAGTTGTTGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCATTATCCCAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGATTCGAAGAA'))],
#  [(1, ('TTAATTAG', 'ATGGCAAAATCTTTCTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCATGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'CCAACAACGCGATTCCACCAA')),
#   (1, ('TCTGGGGC', 'CCAACAACCAAATTAAAGGAA')),
#   (1, ('GTACTTGC', 'TGTAGAATATACTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'CAGCCAAAGCATTTCGATAAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAGACATTGAAACAA'))],
#  [(3, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (2, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACAGAGCC', 'GAAGTAATTTGCTTTCACTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'CCAACAAAGCACTTCCAACAA')),
#   (1, ('GTACTTGC', 'CTTAGAATTTCATTATGTTAA')),
#   (1, ('CGTTCAAG', 'ACCTTAATTGAGTTGTTGGAA')),
#   (1, ('CGTTAGGG', 'TGCATAATATTCTTTTAATAA')),
#   (1, ('CGGGAATG', 'TCGCTAATCTTTTTTGTCTAA')),
#   (1, ('ACACGTGA', 'GAAAGAATCGGTTTGGACGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('CAGTGCAT', 'ATTTTAATCACATTTGAGAAA'))],
#  [(2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GAAAAAACAGAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'CGTCAAAGTTTTTTTCTTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'TCTTTAATCGTTTTTTTCTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CCATTACT', 'AGGTAAATGGGGTTAGATGAA')),
#   (1, ('ACAGAGCC', 'CGATTAACCAGGTTTTGTCAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GTGTTAAGGTTTTTGTTTAAA')),
#   (1, ('TGTCTAGT', 'AAAAGAAACGCATTAAAAAAA')),
#   (1, ('GTACTTGC', 'TGGGTAACCATTTTTAGCTAA')),
#   (1, ('GCCTACGT', 'TTTTTAATCCGTTTTTTGTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTACAAAGATTTTTTTGTCAA'))],
#  [(2, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TCCCCAAAACCCTTCCTTCAA')),
#   (1, ('TTAATTAG', 'ATTAAAATCTGTTTCGATAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GGTAGGGA', 'AAGGAAACCGTGTTATATAAA')),
#   (1, ('CGTTTCCT', 'TGGGGAAGTTTGTTGGGGTAA')),
#   (1, ('CGGGAATG', 'CCTTTAATTTTTTTTTTTTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACACACTTCCACCAA')),
#   (1, ('GTACTTGC', 'TGGGTAACCATTTTTAGCTAA')),
#   (1, ('CGTTAGGG', 'AAACAAAAGCAGTTTCGGGAA')),
#   (1, ('CGGGAATG', 'CCCCAAATCACCTTGTTTCAA')),
#   (1, ('ACACGTGA', 'CCCACAATTACTTTGCAGCAA'))],
#  [(1, ('TTAATTAG', 'TTAGCAATAATGTTAGATTAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTCTAA')),
#   (1, ('ACACGTGA', 'GAAAGAATCGGTTTGGACGAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGCGTTGGGCGAA')),
#   (1, ('GGTAGGGA', 'TTGGCAATTCGTTTTAAAGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATTTCTTTCCTGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTGTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TAAGTAAGACATTTGTGTCAA')),
#   (1, ('CGGGAATG', 'GGGTGAAGGGTGTTGTGGGAA')),
#   (1, ('CGGGAATG', 'CTCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'GGGTGAAGGGGTTTGGGGGAA'))],
#  [(2, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTAGCAATAATGTTAGATTAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTGTTTGTATTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTAGTTGTTGGAA')),
#   (1, ('GGTAGGGA', 'TTGCAAAATATGTTATGCTAA')),
#   (1, ('CCATTACT', 'TGGGCAATGGGATTATAGCAA'))],
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 3695

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
