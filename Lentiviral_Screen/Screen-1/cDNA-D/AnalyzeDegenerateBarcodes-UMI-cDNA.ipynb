# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist4.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 4831

# %% [raw]
# afile = pysam.AlignmentFile("./final.bam")
# hashcount = {}
# hashset = {}
# cellhash = {}
# taghash = {}
# readcount = {}
# barcodehash = {} # barcodes listing shRNAID
# barcodebycellUMI = {} # barcode listing cellUMI
# doublecounts = 0
# cellbyUMI = {}
# inwhitelist = set()
# inwhitelistcount = 0
# outwhitelist = set()
# outwhitelistcount = 0
# for seq_record in afile.fetch(until_eof=True):
#     cellUMI = None  # here this is the CellRanger cell UMI
#     UMI = None
#     if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
#     cellUMI = seq_record.get_tag("CB")
#     if cellUMI not in whitelist:
#         outwhitelistcount +=1
#         if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
#         continue
#     else:
#         inwhitelistcount += 1
#         if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
#     UMI = seq_record.get_tag("UB") # umi barcode
#
#     m = hashmatch.search(seq_record.query_sequence)
#     if m == None or (m.end() + 8) > len(seq_record.query_sequence):
#         #print("Error, match not found")
#         continue
#     shRNAID = seq_record.query_sequence[m.end():m.end()+8]
#     barcode = seq_record.query_sequence[m.end()-21:m.end()]
#     sbID = (shRNAID,barcode)
#     if shRNAID not in hashes: continue
#     if cellUMI not in cellbyUMI:
#         cellbyUMI[cellUMI] = {}
#     if UMI not in cellbyUMI[cellUMI]:
#         cellbyUMI[cellUMI][UMI] = {sbID: 1}
#         continue
#     if sbID in cellbyUMI[cellUMI][UMI]:
#         cellbyUMI[cellUMI][UMI][sbID] += 1
#     else:
#         hamming = False
#         for x in cellbyUMI[cellUMI][UMI]:
#             if hammingDistance(sbID[1],x[1]) <= 2:
#                 cellbyUMI[cellUMI][UMI][x] += 1
#                 hamming = True
#                 break
#         if hamming: continue
#         cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle
cellbyUMI = False
with open('cellbyUMI.pickle', 'rb') as f:
    cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 23

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 4831

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 4648

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] > threshold: 
                ncellbyUMI[y] = newUMI[0][1]
            else:
                print("Not past threshold: %s" % str(newUMI))
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        #print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (13.371711992866697, 1, 1390, 1.0)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 1458

# %%
len(whitelist)
# Out:
# 4831

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 3133

# %%
poorUMI
# Out:
# [[(3, ('CCATTACT', 'CGCTAAATACGCTTCTTCTAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('GGTAGGGA', 'TTCCCAACTGCATTAACAAAA')),
#   (1, ('GGTAGGGA', 'GTTGGAATGTCGTTGAAGCAA')),
#   (1, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGGGAATG', 'GTGAGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('ACAGAGCC', 'TAGTGAATACGATTATTCCAA'))],
#  [(3, ('TTAATTAG', 'TTTTTAAATTTTTTTTTTTAA')),
#   (2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GATTTAAGCTTATTTTTTTAA')),
#   (1, ('TCTGGGGC', 'TTTTTAAGGTTTTTTTTTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA'))],
#  [(1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAGAAATTTAATAAA')),
#   (1, ('TGTCTAGT', 'GTTGGAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGATGATTGGGAGAA')),
#   (1, ('GGTAGGGA', 'TCGATAAGCGATTTTTGTCAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA'))],
#  [(3, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (2, ('CGTTCAAG', 'GTTTTAATTAGCTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'ACAACAACAACATTAACAAAA')),
#   (1, ('CTGAATCT', 'AATCAAAAAACATTAAGTCAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CGGGAATG', 'CCTCCAACCCTATTTTCTCAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TGCGAAATTATGTTATTTGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'GGAAAAATGAGGTTGGGAGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GAGAGAATGACATTGGAAGAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAACAATTAAAAGAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GCCTACGT', 'TGGTGAATTTTTTTTTTGTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTAGGG', 'TCAGAAAAGATATTGGTTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAAAACCCTTTTCGCAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA')),
#   (1, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA'))],
#  [(3, ('ACAGAGCC', 'TGATAAAAAATCTTCGAGAAA')),
#   (2, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGCGGAATGTGGTTGAGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('ACAGAGCC', 'TGAATAACTATTTTTTTGAAA')),
#   (1, ('ACAGAGCC', 'GTGACAATTATCTTATATAAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TGCGAAATTATTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CTGAATCT', 'CCCACAAACCCATTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA'))],
#  [(1, ('TGTCTAGT', 'GGTGGAATTTTGTTTTTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'GAAAGAAAAAAATTAAAACAA')),
#   (1, ('TGTCTAGT', 'TAGCCAATTTCCTTATATTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CTGAATCT', 'AACCCAACTTCATTGTTCTAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCATTTTTTCCCAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTAGTCCAA'))],
#  [(2, ('TGTCTAGT', 'CCGTAAATAATTTTCACATAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('ACACGTGA', 'GGGGAAAGAAGATTAACAAAA'))],
#  [(1, ('TTAATTAG', 'GAAAGAAAAAAATTAAAACAA')),
#   (1, ('GGTAGGGA', 'CGGAAAAATACGTTTGCGTAA')),
#   (1, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAGAAATTTAATAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTAGGAGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTAGGG', 'TAAGAAAGTAGCTTTCTTAAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA')),
#   (1, ('ACAGAGCC', 'TATCAAATGCGTTTCTAGTAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(3, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (2, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATAATTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'GAAAGAAAAAAATTAAAACAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TAGGGAATTTGGTTTGTGGAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGATGATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GACTTAATTGTCTTCTTCTAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('GGTAGGGA', 'TTCAAAACTAGATTTATTGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTCAAG', 'CATGCAAACGTATTTGATCAA')),
#   (1, ('CGTTAGGG', 'GCAAGAACACAATTTTAAAAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA')),
#   (1, ('CCATTACT', 'AGTTAAAAGGGATTTTTGTAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA')),
#   (1, ('ACACGTGA', 'GAATGAATGTGTTTGTCTGAA'))],
#  [(2, ('TGTCTAGT', 'GACTTAATTGTCTTCTTCTAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TGTCTAGT', 'TAGGGAATTTGGTTTGTGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GCCTCAATAGCTTTGTAAGAA')),
#   (1, ('ACAGAGCC', 'CATGGAAGTACTTTGACGCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'ATTTTAATTTTTTTCTTTCAA'))],
#  [(2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GGTAGGGA', 'CAAATAATTGTCTTTGCTAAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTCAAG', 'TCTACAAAAAGTTTGCGGTAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACAGAGCC', 'CATGGAAGTACTTTGACGCAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(3, ('CTGAATCT', 'TTGTAAAAGTCTTTGCGTGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GTACTTGC', 'ACCCAAACTCTGTTAAAATAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA')),
#   (1, ('CGGGAATG', 'ATTGTAAATTGGTTTTGTGAA')),
#   (1, ('CCATTACT', 'TTTTTAATAATCTTATGTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAGAAATTTAATAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('CTGAATCT', 'CCCCTAATCCCATTCTCCCAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTGTTTTTTTGGAA')),
#   (1, ('ACACGTGA', 'CGCTTAAACCCGTTCGTCCAA'))],
#  [(2, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (2, ('CTGAATCT', 'TTGTTAACTTTGTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGTGGAATTTTGTTTTTAGAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA'))],
#  [(1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA'))],
#  {('GCCTACGT', 'GAAAAAAAAAAATTAAAAAAA'): 2},
#  [(3, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAGAAATTTAATAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGTTTCCT', 'AAGAAAACTACTTTTCGTTAA'))],
#  [(2, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('TGTCTAGT', 'TATCCAATCACCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA'))],
#  [(3, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (2, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTCTTTCCTTCAA')),
#   (1, ('TGTCTAGT', 'TCGGTAACTTCCTTCGTTCAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  {('GTACTTGC', 'ACCCAAACTCTGTTAAAATAA'): 1},
#  [(1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGAAATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GGTAGGGA', 'TATTTAACTCCATTAGATTAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTTCCT', 'CAAATAAGCGCCTTTTAATAA')),
#   (1, ('CGTTAGGG', 'GACAAAAATTTATTTGCAGAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('CCATTACT', 'AGTTAAAAGGGATTTTTGTAA')),
#   (1, ('ACAGAGCC', 'TGTCTAAGTGGTTTTTGAAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAAGGAGGTTATGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TATCCAATCACCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCACCCAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACAGAGCC', 'TATCAAATGCGTTTCTAGTAA'))],
#  [(2, ('ACAGAGCC', 'TGATAAAAAATCTTCGAGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'TGCGAAATTATTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GACTTAATTGTCTTCTTCTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGAGAAAGGAATTGCGGGAA')),
#   (1, ('TGTCTAGT', 'ACTACAACCTCCTTCCTCTAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(1, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CCATTACT', 'CAGGGAAGAGGGTTTGGGTAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (1, ('GGTAGGGA', 'GTTGGAATGTCGTTGAAGCAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA'))],
#  [(3, ('CGTTAGGG', 'GGAGCAACCGGGTTTTTCAAA')),
#   (2, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'TACAAAAAAAAATTCTAAAAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('CTGAATCT', 'AAAACAAAAAAATTAGAAAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'TCGGTAACTTCCTTCGTTCAA')),
#   (1, ('GGTAGGGA', 'GTTGGAAAGACTTTATCCAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'CACCTAATTTTTTTCGTTCAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'GGTCTAAATTTGTTGGTATAA'))],
#  [(2, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (2, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TATCCAATCACCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTGGTTGGGTGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'TTACAAATATTATTAGTAAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'AAAACAAGAGAGTTGATAAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CTGAATCT', 'CCCCTAATCCCATTCTCCCAA')),
#   (1, ('CGTTCAAG', 'TTTGTAATCTCGTTACGCCAA')),
#   (1, ('CGTTCAAG', 'TAGGGAATCTCTTTATGTCAA')),
#   (1, ('CGTTCAAG', 'GGTGTAAGGGAATTATCTAAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA')),
#   (1, ('ACAGAGCC', 'TGAATAACTATTTTTTTGAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'CCCACAATAAATTTCGATCAA')),
#   (1, ('TGTCTAGT', 'GTTGGAATGATTTTTTTCTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGTTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'TAAGAAAGTAGCTTTCTTAAA')),
#   (1, ('CGGGAATG', 'CCCCCAAAACCCTTTTCGCAA'))],
#  [(1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('GGTAGGGA', 'CGGAAAAATACGTTTGCGTAA')),
#   (1, ('CTGAATCT', 'CCCCTAATCCCATTCTCCCAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA')),
#   (1, ('ACAGAGCC', 'GAGTGAAGGCGGTTGAGGTAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(2, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'ATTTTAATTTTTTTCTTTCAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA')),
#   (1, ('ACAGAGCC', 'TGAATAACTATTTTTTTGAAA'))],
#  [(3, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (2, ('GGTAGGGA', 'TATTTAACTCCATTAGATTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGCAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (1, ('TCTGGGGC', 'TTTTTAAGGTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('GGTAGGGA', 'GGCCCAAGGCGCTTATAGGAA')),
#   (1, ('GGTAGGGA', 'GCGAAAATCGGGTTAATCCAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA')),
#   (1, ('CGTTAGGG', 'GGAGCAACCGGGTTTTTCAAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA')),
#   (1, ('ACAGAGCC', 'CGGCTAACGACTTTAACCTAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTATGAGAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'TTTTAAATGTTTTTGTATTAA')),
#   (1, ('CTGAATCT', 'TATTAAAGGCGTTTATGGGAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TTAATTAG', 'CCTCGAAATTCATTACTCCAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTGGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GGAGGAAGGGTATTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GACTTAATTGTCTTCTTCTAA')),
#   (1, ('CTGAATCT', 'TTTTAAATTTTTTTTTTTTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CCATTACT', 'TGTGTAAAGAAGTTTTGGGAA')),
#   (1, ('ACACGTGA', 'GGAGTAAGGGAATTTTGGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CGTTCAAG', 'GGTGTAAGGGAATTATCTAAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'GGAAAAATGAGGTTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GGTAGGGA', 'CAAATAATTGTCTTTGCTAAA')),
#   (1, ('GCCAATCG', 'GTAATAAATGGATTCATATAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA')),
#   (1, ('CGTTAGGG', 'GGAGCAACCGGGTTTTTCAAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA'))],
#  [(2, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'CTGCGAAAGACCTTTCACAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'TGTCTAAGTGGTTTTTGAAAA')),
#   (1, ('ACAGAGCC', 'ATCTGAAGGATTTTATCGCAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('GGTAGGGA', 'TTACAAATATTATTAGTAAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'TGGTGAAGGTTGTTGTGTGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CTGAATCT', 'AACCCAACTTCATTGTTCTAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(1, ('TTAATTAG', 'GGAAAAATGAGGTTGGGAGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('GCCTACGT', 'TGGTGAATTTTTTTTTTGTAA')),
#   (1, ('CGTTAGGG', 'TCAGAAAAGATATTGGTTTAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACAGAGCC', 'GAGTGAAGGCGGTTGAGGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGAGAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGGGAATG', 'GTGAGAAGGGGGTTGGGGGAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCGCTTTCCGGAAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA'))],
#  [(1, ('GGTAGGGA', 'GGCCCAAGGCGCTTATAGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATAATTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAGAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CTGAATCT', 'AAAACAAAAAAATTAGAAAAA')),
#   (1, ('CGTTCAAG', 'TAGGGAATCTCTTTATGTCAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (1, ('GTACTTGC', 'ACCCAAACTCTGTTAAAATAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGTTCAAG', 'TAGGGAATCTCTTTATGTCAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'TATCAAATGCGTTTCTAGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTCTTTCCTTCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CCATTACT', 'CAGGGAAGAGGGTTTGGGTAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACTCTCTTGCCCCAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CTGAATCT', 'AAAACAAAAAAATTAGAAAAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(3, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGAAAGGATTTTAGTATAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA')),
#   (1, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('CTGAATCT', 'CCCCTAATCCCATTCTCCCAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGGGAATG', 'CCTCCAACCCTATTTTCTCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA')),
#   (1, ('CCATTACT', 'AGGGGAAAAGAGTTGGATAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCCAAATAGTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GAAAGAAAAAAATTAAAACAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAACAATTAAAAGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA')),
#   (1, ('ACAGAGCC', 'TAGACAAGATGGTTGCTATAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGATGATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GCCTACGT', 'TTATTAAGATCATTTAAACAA')),
#   (1, ('CGTTAGGG', 'TCCCAAAGGATGTTGAGAGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TACAAAAAAAAATTCTAAAAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAGAATTAAAAAAA')),
#   (1, ('GGTAGGGA', 'TTCAAAACTAGATTTATTGAA')),
#   (1, ('CTGAATCT', 'CCCCTAATCCCATTCTCCCAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GAAAGAAAAAAATTAAAACAA')),
#   (1, ('TTAATTAG', 'ACCCAAAGAAAGTTACAACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CTGAATCT', 'TTCTTAACCTTTTTCTATCAA')),
#   (1, ('CGTTAGGG', 'GGGGTAATTAGGTTTCGGAAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CAGTGCAT', 'TTTTCAAAGTACTTACCACAA'))],
#  [(3, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TTAATTAG', 'GACACAAGAAGGTTAAATAAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TCGGTAACTTCCTTCGTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GTACTTGC', 'GTCACAATGCACTTAACAAAA')),
#   (1, ('GCCAATCG', 'GTGAAAATTGTGTTCTTTAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA')),
#   (1, ('ACAGAGCC', 'TAGTGAATACGATTATTCCAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGCGGGTTGGGGGAA'))],
#  [(1, ('TTAATTAG', 'GGAAAAATGAGGTTGGGAGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA'))],
#  [(2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAACAATTAAAAGAA')),
#   (1, ('GTACTTGC', 'GAAGAAATCAACTTGCCTAAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GGTAGGGA', 'CGGAAAAATACGTTTGCGTAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTAGGG', 'TCCCAAAGGATGTTGAGAGAA')),
#   (1, ('CGTTAGGG', 'GGAGCAACCGGGTTTTGCAAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAAAACCCTTTTCGCAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TACAAAAAAAAATTCTAAAAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GTGAGAATAGCATTAGAAGAA')),
#   (1, ('GTACTTGC', 'ACCCAAACTCTGTTAAAATAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTCTTTCCTTCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GGTAGGGA', 'GTTGGAATGTCGTTGAAGCAA')),
#   (1, ('GGTAGGGA', 'GTTGGAAAGACTTTATCCAAA')),
#   (1, ('CGTTTCCT', 'TTTTAAAGTGGTTTAGTGTAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTCAAG', 'TAGGGAATCTCTTTATGTCAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA'))],
#  [(2, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'AACCCAACTTCATTGTTCTAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('CGGGAATG', 'AAGAAAAATATCTTAAGAAAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACAGAGCC', 'CGGCTAACGACTTTAACCTAA'))],
#  [(1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGAAAGGGTGTTATGCCAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'TATTAAAGGCGTTTATGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TAGCCAATTTCCTTATATTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('CGGGAATG', 'CCCACAACCTCCTTCCTATAA'))],
#  {('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA'): 1},
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGAAAAAATGTTGGGGTAA')),
#   (1, ('GTACTTGC', 'GCATTAATTTTTTTGTCACAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TGTCTAGT', 'GTGTGAAGGTGGTTGGGTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GGTAGGGA', 'GTTGGAATGTCGTTGAAGCAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GTTGGAAAGACTTTATCCAAA')),
#   (1, ('GGTAGGGA', 'GGCCCAAGGCGCTTATAGGAA')),
#   (1, ('CGTTAGGG', 'TGAACAACTCAGTTGCAAAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'CCCCAAACGCCCTTCCCGCAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTCTAATTATTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TGTGAAATTATTTTATAGCAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTCAAG', 'CATGCAAACGTATTTGATTAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTCAAG', 'GGTGTAAGGGAATTATCTAAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('ACAGAGCC', 'TAGTGAATACGATTATTCCAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TGCGAAATTATTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'ACCCAAAGAAAGTTACAACAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGAGAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GGTAGGGA', 'ACCGGAAATTGCTTCTGCAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AACCCAACTACATTGTTCTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAAAATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('TGTCTAGT', 'GGAGGAAGGGTATTGTGAGAA')),
#   (1, ('GGTAGGGA', 'CAAATAATTGTCTTTGCTAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CTGAATCT', 'AACCCAACTTCATTGTTCTAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('ACAGAGCC', 'TATCAAATGCGTTTCTAGTAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGAGAAATGATTTTTTAAGAA')),
#   (1, ('TGTCTAGT', 'TATCCAATCACCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGTTTCCT', 'ATTTAAATATATTTTGGAAAA')),
#   (1, ('CGTTCAAG', 'TAGGGAATCTCTTTATGTCAA')),
#   (1, ('ACAGAGCC', 'TATCAAATGCGTTTCTAGTAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TCGGTAACTTCCTTCGTTCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGTGGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GCGGTAATTTGGTTGGTTGAA')),
#   (1, ('GGTAGGGA', 'CAAATAATTGTCTTTGCTAAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('CGTTCAAG', 'CATGCAAACGTATTTGATTAA')),
#   (1, ('CGTTAGGG', 'GGAGCAACCGGGTTTTTCAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA')),
#   (1, ('ACAGAGCC', 'TTGTCAAACAAATTGTAGTAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'TCGGTAACTTCCTTCGTTCAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGATGATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CTGCGAAAGACCTTTCACAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTCAAG', 'GTTTTAATTAGCTTGTGAGAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(4, ('TGTCTAGT', 'CTGCGAAAGACCTTTCACAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  {('CGGGAATG', 'CCTCCAACCCTATTTTCTCAA'): 3},
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('GCCTACGT', 'GGGGGAATGGCGTTTGGGTAA')),
#   (1, ('ACAGAGCC', 'CTTAAAATGTGATTGGTAGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'AAAGAAAGCGAATTGGAAAAA'))],
#  [(3, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (2, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (2, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CAGTGCAT', 'TTTTCAAAGTACTTACCACAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(2, ('TTAATTAG', 'GGAGGAAGGAGGTTATGAGAA')),
#   (2, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('ACAGAGCC', 'ATAGTAATTCTCTTTTATTAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTTGGAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(2, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GACTTAATTGTCTTCTTCTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (1, ('GGTAGGGA', 'TTCAAAACTAGATTTATTGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CTGAATCT', 'ACAACAACAACATTAACAAAA')),
#   (1, ('CTGAATCT', 'AAAACAAAAAAATTAGAAAAA')),
#   (1, ('CGTTTCCT', 'ATTTAAATAAATTTTGGAAAA')),
#   (1, ('CGTTAGGG', 'GGAGCAACCGGGTTTATCAAA')),
#   (1, ('CGTTAGGG', 'GCAAGAACACAATTTTAAAAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('ACAGAGCC', 'ATCTGAAGGATTTTATCGCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('ACACGTGA', 'TTTATAATGTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (2, ('TGTCTAGT', 'TTTTAAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATTGGAATCAATTTCAATGAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCTCCTTCCCCCAA'))],
#  [(2, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA'))],
#  [(3, ('GCCTACGT', 'GAAAAAAAAAAATTAAAAAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAGAAATTTAATAAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TACAAAAAAAAATTCTAAAAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TTAATTAG', 'AAACAAAAAAAATTCCAGCAA')),
#   (1, ('TGTCTAGT', 'TTGTGAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTAGGG', 'TTCATAAAGAGTTTCGTTAAA'))],
#  [(1, ('TTAATTAG', 'GGCGGAATGTGGTTGAGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA')),
#   (1, ('ACAGAGCC', 'ACCTGAAACTTTTTAATCTAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAATGAATGTGTTTGTCTGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('CTGAATCT', 'TTTCAAATTGTTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'GTTTTAATTAGCTTGTGAGAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TTCAAAACTAGATTTATTGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTAGGG', 'GCAAGAACACAATTTTAAAAA')),
#   (1, ('CGGGAATG', 'CCTCCAACCCTATTTTCTCAA'))],
#  [(2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'AAAAAAAAACAATTAAAAGAA')),
#   (1, ('GTACTTGC', 'ACCCAAACTCTGTTAAAATAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('ACAGAGCC', 'ATAGTAATTCTCTTTTATTAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGTGGAA')),
#   (2, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACACGTGA', 'AAAGAAAGCGAATTGGAAGAA'))],
#  [(3, ('TGTCTAGT', 'GTTTTAATTTTTTTTTTCTAA')),
#   (3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TGCGAAATTATGTTATTTGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGTTTTAGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACAGAGCC', 'TGAATAACTATTTTTTTGAAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA')),
#   (1, ('ACACGTGA', 'CGAGTAATCCTTTTGTTTAAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'GTAAAAACATAGTTCTGCGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))],
#  [(3, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TGCGAAATTATTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
# ...
#   (1, ('ACACGTGA', 'AAAGAAAGCGAATTGGAAGAA'))],
#  [(1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAGAAATTTAATAAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGTGGAATTTTGTTTTTAGAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('ACAGAGCC', 'ATAGTAATTCTCTTTTATTAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTCTTTCCTTCAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('GTACTTGC', 'ACCCAAACTCTGTTAAAATAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'CCCCAAACCTCTTTCCGCCAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('CGGGAATG', 'TCTTCAACCATTTTTTCCCAA')),
#   (1, ('ACAGAGCC', 'TATCAAATGCGTTTCTAGTAA')),
#   (1, ('ACAGAGCC', 'TAGTGAATACGATTATTCCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'CACACAACCCCCTTCCCCAAA'))],
#  [(1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TCTGGGGC', 'TTTTTAAGGTTTTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'CCAGTAAAATTGTTTCTATAA'))],
#  [(1, ('GCCAATCG', 'AGGCAAACCATATTTTATAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA'))],
#  [(1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('GGTAGGGA', 'CAAATAATTGTCTTTGCTAAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('GCCTACGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('ACAGAGCC', 'TGAATAACTATTTTTTTGAAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'TGTTTAATTATTTTATTATAA')),
#   (1, ('TTAATTAG', 'GGGGAAAAAATGTTGGGGTAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('CTGAATCT', 'CCCCAAACCTCTTTCCGCCAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  [(3, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTGTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('GGTAGGGA', 'TGTAAAATTTAATTGTGTGAA')),
#   (1, ('GCCTACGT', 'AAAACAAGAGAGTTGATAAAA')),
#   (1, ('CTGAATCT', 'AAAACAAAAAAATTAGAAAAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(1, ('TTAATTAG', 'GGCGGAATGTGGTTGAGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTATGAGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGAGGAAGGGTATTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA'))],
#  [(1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'CGGGGAAAGGAGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TTCCCAACTGCATTAACAAAA')),
#   (1, ('GCCTACGT', 'TGGTGAATTTTTTTTTTGTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CCATTACT', 'AGGGGAAAAGAGTTGGATAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTGTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TAGGGAATTTGGTTTGTGGAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('GCCTACGT', 'GGGGGAACGGTGTTGTGGGAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA'))],
#  [(2, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (2, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TCTGGGGC', 'TTTTCAATCTTTTTCTCCTAA')),
#   (1, ('CTGAATCT', 'AAAACAAAAAAATTAGAAAAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACACGTGA', 'GGGGAAAGAAGATTAACAAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  {('TGTCTAGT', 'TGTGTAATTTTTTTTTTCTAA'): 1},
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGTGGTTCGGGCAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATAATTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GCCTACGT', 'TGGTGAATTTTTTTTTTGTAA')),
#   (1, ('CGTTCAAG', 'ATAGGAAGTATTTTCAGATAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('CCATTACT', 'AGGGGAAAAGAGTTGGATAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('CGTTAGGG', 'AGAGAAAATAGGTTGGATAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TATCCAATCACCTTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTTGGAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACAGAGCC', 'ATCTGAAGGATTTTATCGCAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGAGGAAGGAGGTTATGAGAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CTGAATCT', 'CCCCAAACGCCCTTCCCGCAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTAGGG', 'CAGAGAAAAAGCTTAATGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCGTTTCCCCAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACAGAGCC', 'TGAATAACTATTTTTTTGAAA'))],
#  [(1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TGTCTAGT', 'TAGCCAATTTCCTTATATTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(3, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (2, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA')),
#   (1, ('TTAATTAG', 'GGAGGAAAGTAGTTAAAAAAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'ACTACAACCTCCTTCCTCTAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('ACACGTGA', 'GAATGAATGTGTTTGTCTGAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTTGGAATGATTTTTTTCTAA')),
#   (1, ('GGTAGGGA', 'TTCCCAACTGCATTAACAAAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTAGGG', 'TCAGAAAAGATATTGGTTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGGTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(1, ('TTAATTAG', 'GGCAAAATCTAATTCCCCGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CGTTAGGG', 'TAAGAAAGTAGCTTGCTTAAA')),
#   (1, ('CCATTACT', 'CAGGGAAGAGGGTTTGGGTAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'TTCAGAAGGTTGTTAAATTAA')),
#   (1, ('CTGAATCT', 'AACCCAACTTCATTGTTCTAA')),
#   (1, ('CGTTCAAG', 'TTTCGAATCAGGTTCTCAAAA')),
#   (1, ('CGTTAGGG', 'TCCCAAAGGATGTTGAGAGAA')),
#   (1, ('CCATTACT', 'ATAAAAAAAGAATTAAAAAAA'))],
#  [(2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TTAATTAG', 'TGTTTAATTATTTTATTATAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GTTGGAATTTGGTTGGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGAGAATAGCATTAGAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGTTTCCT', 'ATTTAAATATATTTTGGAAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA')),
#   (1, ('CCATTACT', 'CCCCCAAGCGCTTTCCGGAAA')),
#   (1, ('ACAGAGCC', 'CATGGAAGTACTTTGACGCAA'))],
#  [(1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'AAAACAACTAACTTACAACAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAAGGAGTTTTAGGGAA')),
#   (1, ('TTAATTAG', 'CCCGTAAGATCATTCCCGCAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGAAAGGATTTTAGTATAA')),
#   (1, ('TTAATTAG', 'GGAAGAATGAAATTAAAGAAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGGGAATG', 'CACACAACCGACTTCACCCAA')),
#   (1, ('CCATTACT', 'AGGGAAAGGAAGTTTAGGGAA')),
#   (1, ('ACACGTGA', 'GAATGAATGTGTTTGTCTGAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGAAGAAGAGAGTTAAGAGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAATCCCCTTTAACCAA')),
#   (1, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CGTTAGGG', 'TAGGGAAAGCATTTGGATTAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(1, ('TTAATTAG', 'TCCTCAATACAATTACAGTAA')),
#   (1, ('GCCAATCG', 'TTTTTAACCATGTTTGCTAAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'CGCTTAACCCCGTTCGTCCAA'))],
#  [(2, ('CTGAATCT', 'CCCCAAACGCCCTTCCCGCAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'TTGTGAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('GTACTTGC', 'AGAATAAAACGATTTATAGAA')),
#   (1, ('GCCAATCG', 'GTGAAAATTGTGTTCTTTAAA')),
#   (1, ('GCCAATCG', 'ATATAAACTGTTTTTTTAAAA')),
#   (1, ('CGTTTCCT', 'TTAAAAAATGTATTTAGGAAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGGGGGTTCGGAGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGATGATTGGGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CCATTACT', 'TTGTTAAGCCGCTTCACAAAA'))],
#  {('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA'): 1},
#  [(1, ('TTAATTAG', 'TTTTTAAATATTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'TGCGAAATTATTTTCTTTTAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA'))],
#  [(1, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(3, ('CGGGAATG', 'TTTGGAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('CCATTACT', 'CAGGGAAGAGGGTTTGGGTAA'))],
#  [(2, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('TTAATTAG', 'TTTTGAATTTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'GTTGGAAAGACTTTATCCAAA')),
#   (1, ('CGTTAGGG', 'GGGGTAATTAGGTTTCGGAAA')),
#   (1, ('ACACGTGA', 'GGAGGAAAGGGTTTGGTTGAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAAGGGGTTGGGAGAA')),
#   (2, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGAAAGGGTGTTATGCCAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAAGGGATTGGCGGAA')),
#   (1, ('TCTGGGGC', 'CCCCCAACCCCCTTCTCCCAA')),
#   (1, ('CTGAATCT', 'CCCCAAACGCCCTTCCCGCAA')),
#   (1, ('CTGAATCT', 'AACCCAACTTCATTGTTCTAA')),
#   (1, ('CGTTTCCT', 'CAAATAAGCGCCTTTTAATAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('CCATTACT', 'AGGGAAAGGAAGTTTAGGGAA')),
#   (1, ('CAGTGCAT', 'TTTTCAAAGTACTTACCACAA'))],
#  [(2, ('GCCAATCG', 'ATTGGAACCTAATTTCGCGAA')),
#   (1, ('CGGGAATG', 'AGAAAAAGAGTTTTGAGGAAA')),
#   (1, ('ACAGAGCC', 'GAGTGAAGGCGGTTGAGGTAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA')),
#   (1, ('ACACGTGA', 'CGAGTAATCCTTTTGTTTAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTCAA')),
#   (1, ('TTAATTAG', 'AAAAAAAAGAAATTTAATAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA'))],
#  [(1, ('TTAATTAG', 'TACAAAAAAAAATTCTAAAAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'TCTTAAATTTTTTTTTTTTAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'AAAACAAAAAAATTAGAAAAA')),
#   (1, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'AGAATAAAACGATTTATAGAA'))],
#  [(3, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (3, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGAGAAAAAAAGTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'AAAACAAAAAAATTAACGCAA')),
#   (1, ('GGTAGGGA', 'GGTTCAACGCGCTTACAGAAA')),
#   (1, ('CGTTAGGG', 'GCCTCAATAGCTTTGTAAGAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCCCTTTATCCCAA')),
#   (1, ('CAGTGCAT', 'TTTTCAAAGTACTTACCACAA')),
#   (1, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  [(2, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'GGGGAAAAAATGTTGGGGTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGAGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACCCAAAACCCCTTCCACCAA')),
#   (1, ('CGTTTCCT', 'AGATAAAATAATTTAAGCTAA')),
#   (1, ('CCATTACT', 'GGGGTAAATTAGTTGGGATAA'))],
#  {('ACACGTGA', 'CCCCCAACCCCCTTCCCCCAA'): 1},
#  [(2, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (2, ('ACACGTGA', 'GAATAAAACGCATTGGCGGAA')),
#   (1, ('TTAATTAG', 'GGGGGAAGCGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (1, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (1, ('CTGAATCT', 'CCCCAAACGCCCTTCCCGCAA')),
#   (1, ('CGGGAATG', 'ATTGTAATTTGGTTTTGTGAA')),
#   (1, ('ACACGTGA', 'AAAGAAAGCGAATTGGAAGAA'))],
#  [(1, ('TTAATTAG', 'TTCTTAAAACTTTTCTATTAA')),
#   (1, ('TTAATTAG', 'GGGGAAAAAATGTTGGGGTAA')),
#   (1, ('GGTAGGGA', 'CGGAAAAATACGTTTGCGTAA'))],
#  [(2, ('TTAATTAG', 'AAAACAACCGAATTAAACAAA')),
#   (2, ('TGTCTAGT', 'GTGGCAAGTAGGTTGGTGAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('TGTCTAGT', 'CCCCAAACGCACTTTCCGAAA')),
#   (2, ('CGTTCAAG', 'TTTTGAATCAGGTTCTCAAAA')),
#   (1, ('TGTCTAGT', 'GGCACAAGCTGGTTGGTCCAA')),
#   (1, ('TGTCTAGT', 'GACTTAATTGTCTTCTTCTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CTGAATCT', 'TTGTTAACTTTGTTTTTTTAA')),
#   (1, ('CGTTAGGG', 'TTCTGAAAGGTTTTAACAGAA')),
#   (1, ('CCATTACT', 'GGTATAAATTTATTCGTGAAA')),
#   (1, ('ACACGTGA', 'GAAACAAAGGGATTTTTAAAA'))],
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 1458

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
