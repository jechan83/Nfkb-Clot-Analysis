# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7114

# %%
afile = pysam.AlignmentFile("./final_0.7.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
_
# Out:
# (array([6.442346e+06, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         2.370768e+06, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 1.323089e+06,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         8.568990e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         5.883260e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 4.191570e+05,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 3.072880e+05, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         2.331710e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 1.803900e+05,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.431990e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.163150e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         9.704600e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 8.180600e+04,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 7.046500e+04, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 6.152400e+04,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 5.401800e+04, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 4.808500e+04, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 4.289400e+04,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         3.882800e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         3.545300e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         3.188800e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 2.899900e+04, 0.000000e+00, 0.000000e+00,
#         2.650500e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         2.450000e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         2.247500e+04, 0.000000e+00, 0.000000e+00, 2.073400e+04,
#         0.000000e+00, 0.000000e+00, 1.921100e+04, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 1.776100e+04, 0.000000e+00,
#         0.000000e+00, 1.661200e+04, 0.000000e+00, 0.000000e+00,
#         1.536000e+04, 0.000000e+00, 1.434700e+04, 0.000000e+00,
#         0.000000e+00, 1.334300e+04, 0.000000e+00, 0.000000e+00,
#         1.245100e+04, 0.000000e+00, 1.177000e+04, 0.000000e+00,
#         0.000000e+00, 1.074200e+04, 0.000000e+00, 1.019000e+04,
#         14.91805342, 14.93462903, 14.95120465, 14.96778026, 14.98435588,
#         15.00093149, 15.01750711, 15.03408272, 15.05065834, 15.06723395,
#         15.08380956, 15.10038518, 15.11696079, 15.13353641, 15.15011202,
#         15.16668764, 15.18326325, 15.19983887, 15.21641448, 15.2329901 ,
#         15.24956571, 15.26614133, 15.28271694, 15.29929256, 15.31586817,
#         15.33244379, 15.3490194 , 15.36559502, 15.38217063, 15.39874625,
#         15.41532186, 15.43189748, 15.44847309, 15.46504871, 15.48162432,
#         15.49819994, 15.51477555, 15.53135117, 15.54792678, 15.5645024 ,
#         15.58107801, 15.59765363, 15.61422924, 15.63080486, 15.64738047,
#         15.66395609, 15.6805317 , 15.69710732, 15.71368293, 15.73025855,
#         15.74683416, 15.76340978, 15.77998539, 15.79656101, 15.81313662,
#         15.82971224, 15.84628785, 15.86286347, 15.87943908, 15.8960147 ,
#         15.91259031, 15.92916593]),
#  [<matplotlib.patches.Polygon at 0x316c506d0>])

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 4:
        count = x
        break

# %%
count
# Out:
# 212

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 16

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
  
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
        else:
            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1 and list(UMIpairs.values())[0] >= 5:
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort()
    newUMI.reverse()
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if newUMI[0][0] < 5: continue
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# [(29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TTAATTAG', 'TTTTCAATGTTTTTATTTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TTAATTAG', 'TTTTCAATGATTTTATTTAAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(37, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(21, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (25, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (21, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (20, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (22, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('GTACTTGC', 'GTGGGAATCGACTTCTCACAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CGTTAGGG', 'GAAGGAATCAAATTTAACAAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(24, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(42, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')), (20, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TCTGGGGC', 'GCCCCAACCCGATTCATCTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(34, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAAACCCCTTCCTCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(43, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('CCATTACT', 'CTCGCAATCGTCTTGCCCCAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CCATTACT', 'CTCGCAATCGTCTTGCCCCAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GGTAGGGA', 'GAGGAAATTTACTTAGTCTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CGGGAATG', 'GTATGAAAGCCTTTTTTGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('TGTCTAGT', 'GGGGGAAGGAAGTTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')), (22, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGACCCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(39, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(23, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(32, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(32, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(19, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (21, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (21, ('CTGAATCT', 'CCCCCAAACCCTTTCCCCCAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (17, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTGGAA')), (22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('TTAATTAG', 'TTTTTAATTATTTTATTTTAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTACCCCAA'))]
# [(20, ('GCCTACGT', 'GCGTCAATTTGCTTGATTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(30, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA'))]
# [(25, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (25, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (23, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CTGAATCT', 'CCTGCAACACCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTTGTATAA')), (19, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('ACACGTGA', 'TGTTTAATTTTTTTTTCTGAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TTAATTAG', 'CTTTCAATCATTTTATTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTAATTGGTAGAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA'))]
# [(24, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (22, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA'))]
# [(24, ('ACAGAGCC', 'ACGATAATCAGTTTTACTAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(30, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CATCGAAGGACCTTACGATAA'))]
# [(28, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(28, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(28, ('ACACGTGA', 'CAAAAAAAAATCTTGTAAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('ACACGTGA', 'CAAAAAAAAATCTTGTAAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (28, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(27, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(30, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(22, ('ACAGAGCC', 'GGTCAAAAGTTGTTTACTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(39, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (36, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('GGTAGGGA', 'TGTATAAGGTTATTACTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(35, ('TGTCTAGT', 'GGGGGAAATGATTTGGGAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (26, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(31, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(22, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(34, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(24, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(38, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (26, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(36, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (33, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCACCAACCCCCTTCCCCCAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(26, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('GTACTTGC', 'GTTAAAAGGACATTGTACGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CGTTAGGG', 'GTAATAATGAGGTTATGCGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('ACACGTGA', 'GGGGTAAATGTTTTGGTTTAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGCTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(44, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))]
# [(26, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CGGGAATG', 'TTTGCAAGCACTTTTGTGTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTGATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(24, ('TTAATTAG', 'GTTTTAATTTTTTTTTTTAAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TTAATTAG', 'GTTTTAATTTTTTTTTTTAAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(40, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (33, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('ACACGTGA', 'GGGGGAAGGGGGTTGAGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))]
# [(34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')), (31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (32, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(30, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (35, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (29, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(32, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(18, ('CGTTTCCT', 'GGTCTAAGATAGTTGGGTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA'))]
# [(20, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(24, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(45, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (42, ('CAGTGCAT', 'GTGAAAATTTTATTGGTAGAA')), (35, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (35, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA'))]
# [(18, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TTAATTAG', 'GGCGGAATGATGTTGTGTTAA'))]
# [(22, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(29, ('ACACGTGA', 'TGGTTAAGGATTTTGGTTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('ACACGTGA', 'TGGTTAAGGATTTTGGTTGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (18, ('ACACGTGA', 'TGGTTAAGGATTTTGGTTGAA'))]
# [(25, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TTAATTAG', 'TCCTAAAATCCTTTATATCAA'))]
# [(27, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(20, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA'))]
# [(19, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA'))]
# [(26, ('TGTCTAGT', 'GGTGGAAGTGAGTTGGAGAAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(32, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA'))]
# [(27, ('GGTAGGGA', 'TGTCGAAAAGCCTTCGCTGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('ACACGTGA', 'CCCCCAATGCCATTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('ACACGTGA', 'CCCCCAATGCCATTCACACAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('ACACGTGA', 'CCCCCAATGCCATTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('ACACGTGA', 'CCCCCAATGCCATTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA'))]
# [(35, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CGTTCAAG', 'CCTGTAAGTCAATTCTTGCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA'))]
# [(25, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGTTAGAA'))]
# [(28, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTACAA'))]
# [(21, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CCATTACT', 'CCCCCAACCACCTTCCGCCAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# ...
# [(21, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(33, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (26, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CGTTCAAG', 'TAAGAAATACAGTTACTGTAA'))]
# [(21, ('CGGGAATG', 'TTGTGAATTGTTTTGGGTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(27, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(20, ('TGTCTAGT', 'TTTTCAATTTCCTTCCTCTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATGTTGTTATTAAAA'))]
# [(27, ('CGTTCAAG', 'ATCTAAAAACGATTGTTTAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(39, ('CGGGAATG', 'CCCCCAATGCCCTTTGCCAAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('CGTTCAAG', 'TGTTTAATGCATTTTCTTGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'GTCTGAAAGCCTTTTTTGGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGAAGTTGGGGGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (17, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(25, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(28, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('TGTCTAGT', 'CCTCCAATCTCCTTTGCCGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# is zero
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(20, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(30, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))]
# is zero
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# is zero
# [(35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# is zero
# [(23, ('ACAGAGCC', 'ATATAAAGGATATTAGTACAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(25, ('CGTTAGGG', 'CAGATAAGAGTGTTGTTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACTTAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'CCCCCAAACCCCTTCCCCCAA'))]
# is zero

# %%
print(sum(histogram_of_UMIs))
# Out:
# 66346

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# #plt.axvline()
# plt.show()

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# plt.axvline(x=cutoff2)
# plt.show()

# %% [raw]
# cutoff2 = 2**cutoff2
# print(cutoff2)

# %% [raw]
# ## counting total UMIs from dominant shRNA
# assignedCellshRNA = {}
# assignedCellbarcode = {}
# poorUMI = []
# poorUMI2 = []
# count = []
# threshold = cutoff
#
# for x in cellbyUMI:
#     ncellbyUMI = {}
#     for y in cellbyUMI[x]:
#         UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
#         UMIpairs.sort(reverse=True)
#         newUMI = []
#         while len(UMIpairs) != 0:
#             shRNAIDbarcodepair = UMIpairs.pop(0) #
#             toDelete = []
#             for z in range(0, len(UMIpairs)):
#                 if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
#                 if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
#                     toDelete.append(z)
#                     shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
#             newUMI.append(shRNAIDbarcodepair)
#             for z in sorted(toDelete, reverse = True):
#                 del UMIpairs[z]
#
#         if len(newUMI) == 1:
#         # uncomment here if we don't want to ignore single counts
#             if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
#             continue
#
#         # Shouldn't happen anymore with the cleaned up version
#         newUMI.sort(reverse=True)
#         if newUMI[0][0] < threshold: continue
#
#         totalUMI = sum([z[0] for z in newUMI])
#         if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
#             ncellbyUMI[y] = newUMI[0][1]
#         else:
#             print("multiple: %s" % str(newUMI))
#         #### end
#
#     UMIpairs = {}
#
#     if len(ncellbyUMI) == 0:
#         print("is zero")
#         continue
#
# #    if len(ncellbyUMI) == 1:
# #        continue
#         # uncomment here if we don't want to ignore UMIs assigned by single counts
#         #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
#         #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
#         #count.append(1)
#
#         #adding single UMIs to poorUMI list instead of assigning label
# #        poorUMI.append([(1,ncellbyUMI)])
# #        poorUMI2.append(x)
# #        continue
#
#     for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
#         if ncellbyUMI[y] in UMIpairs:
#             UMIpairs[ncellbyUMI[y]] += 1
#         else:
#             hamming=False
#             for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
#                 if z[0] != ncellbyUMI[y][0]: continue
#                 if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
#                     UMIpairs[z] += 1
#                     hamming=True
#                     break
#             if hamming: continue
#             UMIpairs[ncellbyUMI[y]] = 1
#
# #    if len(UMIpairs) == 0:
# #        print("UMIPairs")
# #        print(ncellbyUMI)
# #        print(cellbyUMI[x])
# #        print("error this shoudl not happen")
# #        continue
#
#     if len(UMIpairs) == 1:
#         if list(UMIpairs.values())[0] < cutoff2:
#             #print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
#             continue
#         assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
#         assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
#         count.append(list(UMIpairs.values())[0])
#         continue
#
#     newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
#     newUMI.sort(reverse=True)
#     if newUMI[0][0] < cutoff2: continue
#
#     totalUMI = sum([y[0] for y in newUMI])
#     count.extend([z[0] for z in newUMI])
#
#     if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
#         assignedCellshRNA[x] = newUMI[0][1][0]
#         assignedCellbarcode[x] = newUMI[0][1][1]
#         continue
#     else:
#         set_trace()
#     poorUMI.append(newUMI)
#     poorUMI2.append(x)

# %% [raw]
# import statistics
# sum(count)/len(count), min(count), max(count), statistics.median(count)

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(count), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# plt.show()

# %% [raw]
# len(assignedCellshRNA)

# %% [raw]
# len(whitelist)

# %% [raw]
# #count.sort()
# #count

# %% [raw]
# len(poorUMI)

# %% [raw]
# poorUMI

# %% [raw]
# #calculate average hammandDistance
# hdist = []
# for x in poorUMI:
#     if len(x) == 1:
# #        hdist.append(0)
#         continue
#     y = [(z[1][0], z[1][1]) for z in x]
#     pUMI = {}
#     for z in y:
#         if z[0] not in pUMI:
#             pUMI[z[0]] = [z[1]]
#         else:
#             pUMI[z[0]].append(z[1])
#     for y in pUMI:
#         if len(pUMI[y]) < 2:
#             continue
#         for i in range(0, len(pUMI[y])):
#             for j in range(i+1, len(pUMI[y])):
#                 hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
#                 if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
#                     print(pUMI[y])
#                     print(pUMI[y][i], pUMI[y][j])

# %% [raw]
# _ = plt.hist(hdist, bins='auto', histtype='step')
#
# plt.ylabel("Counts")
# plt.show()

# %% [raw]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %% [raw]
# validshRNANameHash = {}
# for x in assignedCellshRNA:
#     validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %% [raw]
# len(assignedCellbarcode)

# %% [raw]
# import pandas as pd
# pUMI = {}
# for x in poorUMI2:
#     pUMI[x] = 1
# cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
# cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
# cellhashobj.to_pickle('pUMIcDNA.pickle')

# %% [raw]
# import pandas as pd
#
# cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
# cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
# cellhashobj.to_pickle('shRNAcDNA.pickle')
#
# cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
# cellhashobj.rename(columns={0: "barcode"}, inplace=True)
# cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
