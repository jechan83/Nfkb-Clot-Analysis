# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7114

# %%
afile = pysam.AlignmentFile("./final_0.8.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
_
# Out:
# (array([6.670944e+06, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 2.474625e+06, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.394398e+06, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 9.190150e+05,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 6.447060e+05, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 4.685580e+05,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         3.479830e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         2.660410e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 2.067480e+05,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.661680e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.342650e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.105680e+05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 9.348300e+04,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 8.014400e+04, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         6.951200e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 6.084600e+04, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 5.414100e+04,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         4.868400e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 4.323000e+04, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 3.934200e+04, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 3.589000e+04, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 3.307900e+04, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 3.006200e+04, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 2.795900e+04, 0.000000e+00,
#         0.000000e+00, 2.570900e+04, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 2.384100e+04, 0.000000e+00, 0.000000e+00,
#         2.201100e+04, 0.000000e+00, 0.000000e+00, 2.049900e+04,
#         0.000000e+00, 0.000000e+00, 1.894900e+04, 0.000000e+00,
#         0.000000e+00, 1.765500e+04, 0.000000e+00, 0.000000e+00,
#         1.657900e+04, 0.000000e+00, 0.000000e+00, 1.548600e+04,
#         0.000000e+00, 0.000000e+00, 1.461700e+04, 0.000000e+00,
#         0.000000e+00, 1.372000e+04, 0.000000e+00, 1.281900e+04,
#         14.05605117, 14.07230094, 14.08855071, 14.10480048, 14.12105025,
#         14.13730002, 14.15354979, 14.16979956, 14.18604933, 14.2022991 ,
#         14.21854887, 14.23479864, 14.25104841, 14.26729818, 14.28354795,
#         14.29979772, 14.31604749, 14.33229726, 14.34854703, 14.3647968 ,
#         14.38104657, 14.39729634, 14.41354611, 14.42979588, 14.44604565,
#         14.46229542, 14.47854519, 14.49479496, 14.51104473, 14.5272945 ,
#         14.54354427, 14.55979404, 14.57604381, 14.59229358, 14.60854335,
#         14.62479312, 14.64104289, 14.65729266, 14.67354243, 14.6897922 ,
#         14.70604197, 14.72229174, 14.73854151, 14.75479128, 14.77104105,
#         14.78729082, 14.80354059, 14.81979036, 14.83604013, 14.8522899 ,
#         14.86853967, 14.88478944, 14.90103921, 14.91728898, 14.93353875,
#         14.94978852, 14.96603829, 14.98228806, 14.99853783, 15.0147876 ,
#         15.03103737, 15.04728714, 15.06353691, 15.07978668, 15.09603645,
#         15.11228622, 15.12853599, 15.14478576, 15.16103553, 15.1772853 ,
#         15.19353507, 15.20978484, 15.22603462, 15.24228439, 15.25853416,
#         15.27478393, 15.2910337 , 15.30728347, 15.32353324, 15.33978301,
#         15.35603278, 15.37228255, 15.38853232, 15.40478209, 15.42103186,
#         15.43728163, 15.4535314 , 15.46978117, 15.48603094, 15.50228071,
#         15.51853048, 15.53478025, 15.55103002, 15.56727979, 15.58352956,
#         15.59977933, 15.6160291 , 15.63227887, 15.64852864, 15.66477841,
#         15.68102818, 15.69727795, 15.71352772, 15.72977749, 15.74602726,
#         15.76227703, 15.7785268 , 15.79477657, 15.81102634, 15.82727611,
#         15.84352588, 15.85977565, 15.87602542, 15.89227519, 15.90852496,
#         15.92477473, 15.9410245 , 15.95727427, 15.97352404, 15.98977381,
#         16.00602358, 16.02227335, 16.03852312, 16.05477289, 16.07102266,
#         16.08727243, 16.1035222 , 16.11977197]),
#  [<matplotlib.patches.Polygon at 0x3289d46d0>])

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 4:
        count = x
        break

# %%
count
# Out:
# 216

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 16

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
  
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
        else:
            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1 and list(UMIpairs.values())[0] >= 5:
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort()
    newUMI.reverse()
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if newUMI[0][0] < 5: continue
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# [(26, ('TTAATTAG', 'TTTTCAATGTTTTTATTTTAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(33, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (28, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(22, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTAAATTATTTTCTTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (25, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('GTACTTGC', 'GTGGGAATCGACTTCTCACAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(40, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(34, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('CGTTAGGG', 'GAAGGAATCAAATTTAACAAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA'))]
# [(21, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(29, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CGTTAGGG', 'GCGGCAAATGGATTTGCTAAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(35, ('CGTTCAAG', 'CCTGTAAGTCAATTCTTGCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')), (22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA'))]
# [(25, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(37, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(31, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(37, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('GGTAGGGA', 'GGCACAACTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCTAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGAAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (22, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(27, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(32, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('CCATTACT', 'CTCGCAATCGTCTTGCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(24, ('GGTAGGGA', 'GAGGAAATTTACTTAGTCTAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(30, ('CGGGAATG', 'GTATGAAAGCCTTTTTTGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGAAGTTGGGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')), (24, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (23, ('GCCAATCG', 'CACATAAGACCCTTCATTGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACACGTGA', 'GATTCAAGGTCCTTGAGACAA'))]
# [(17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CGTTCAAG', 'GATGTAAATTTCTTTGCTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(27, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(48, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(18, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('TTAATTAG', 'TTTTAAATATATTTCTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA'))]
# [(25, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTCGAA'))]
# [(20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA'))]
# [(20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(27, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (21, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))]
# [(29, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(36, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(30, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(22, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(27, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(20, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTTAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(42, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TTAATTAG', 'ATGATAATTTGTTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTGGAA')), (26, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TTAATTAG', 'TTTTTAATTATTTTATTTTAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTACCCCAA'))]
# [(22, ('GCCTACGT', 'GCGTCAATTTGCTTGATTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(19, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(29, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(18, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA'))]
# [(32, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGATTGGTTCAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CTGAATCT', 'CCTGCAACACCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(39, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (37, ('CGTTCAAG', 'GTACGAAGGCTTTTCGGGTAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(23, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA'))]
# [(20, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'AAAACAACGAAATTACAAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATATTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTCTTGGTAGAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTTGTATAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TTAATTAG', 'CTTTCAATCATTTTATTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(22, ('CGGGAATG', 'TTCTCAACGCCTTTTTCACAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTAATTGGTAGAA')), (24, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (23, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA'))]
# [(31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (25, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('ACAGAGCC', 'ACGATAATCAGTTTTACTAAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (18, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (27, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CATCGAAGGACCTTACGATAA'))]
# [(30, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')), (25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(30, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('ACACGTGA', 'CAAAAAAAAATCTTGTAAAAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(24, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(29, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(37, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(40, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(35, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('GCCTACGT', 'TTCTGAAGGCGTTTTTATTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TTCTGAAGGCGTTTTTTTTAA'))]
# [(28, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(40, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (40, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (39, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (36, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (34, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(24, ('ACAGAGCC', 'GGTCAAAAGTTGTTTACTTAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(39, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (37, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (36, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (33, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(39, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(41, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (41, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TTAATTAG', 'TGGTAAATTATTTTATTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('GGTAGGGA', 'TGTATAAGGTTATTACTAGAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA'))]
# [(38, ('TGTCTAGT', 'GGGGGAAATGATTTGGGAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CGGGAATG', 'CTCTTAACACCTTTATATCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA'))]
# [(19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(24, ('TTAATTAG', 'AAGAAAAACGAATTAAAGAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(29, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (25, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (23, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (26, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (33, ('TGTCTAGT', 'CCACCAACCCCCTTCCCCCAA')), (29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (26, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (32, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(27, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CGTTAGGG', 'GTAATAATGAGGTTATGCGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('ACACGTGA', 'GGGGTAAATGTTTTGGTTTAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CCATTACT', 'AATGAAAATAGGTTATAGTAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))]
# [(29, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CGGGAATG', 'TTTGCAAGCACTTTTGTGTAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTGATTGGTAGAA'))]
# [(21, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA'))]
# [(17, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(34, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATATTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('TTAATTAG', 'GTTTTAATTTTTTTTTTTAAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(18, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(49, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (35, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('ACACGTGA', 'GGGGGAAGGGGGTTGAGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA'))]
# [(22, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(39, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TCTGGGGC', 'TTTTGAATATTTTTTTTTTAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TTAATTAG', 'TTTGTAATTAATTTTTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))]
# [(25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CGTTTCCT', 'GGTCTAAGATAGTTGGGTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('CGTTTCCT', 'GGTCTAAGATAGTTGGGTTAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(30, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(25, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')), (23, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('GGTAGGGA', 'AAAACAAATCACTTCAGCGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# ...
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (18, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('CGGGAATG', 'TTTTGAATTTTTTTTTTTTAA'))]
# [(26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(37, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (34, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (33, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (28, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (25, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CGTTCAAG', 'TAAGAAATACAGTTACTGTAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (22, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(33, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(23, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(36, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (35, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGAAGTTGGGGGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (25, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (18, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(28, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (27, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('ACAGAGCC', 'GTACTAATTTTCTTCACCTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(31, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTCTTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (26, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (18, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(23, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (19, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(22, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (22, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))]
# is zero
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (34, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (33, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (27, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# is zero
# [(30, ('CGTTAGGG', 'CAGATAAGAGTGTTGTTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# is zero
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAAACCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCAATCG', 'CACTTAAGAACCTTCATTGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# is zero

# %%
print(sum(histogram_of_UMIs))
# Out:
# 68626

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# #plt.axvline()
# plt.show()

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# plt.axvline(x=cutoff2)
# plt.show()

# %% [raw]
# cutoff2 = 2**cutoff2
# print(cutoff2)

# %% [raw]
# ## counting total UMIs from dominant shRNA
# assignedCellshRNA = {}
# assignedCellbarcode = {}
# poorUMI = []
# poorUMI2 = []
# count = []
# threshold = cutoff
#
# for x in cellbyUMI:
#     ncellbyUMI = {}
#     for y in cellbyUMI[x]:
#         UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
#         UMIpairs.sort(reverse=True)
#         newUMI = []
#         while len(UMIpairs) != 0:
#             shRNAIDbarcodepair = UMIpairs.pop(0) #
#             toDelete = []
#             for z in range(0, len(UMIpairs)):
#                 if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
#                 if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
#                     toDelete.append(z)
#                     shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
#             newUMI.append(shRNAIDbarcodepair)
#             for z in sorted(toDelete, reverse = True):
#                 del UMIpairs[z]
#
#         if len(newUMI) == 1:
#         # uncomment here if we don't want to ignore single counts
#             if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
#             continue
#
#         # Shouldn't happen anymore with the cleaned up version
#         newUMI.sort(reverse=True)
#         if newUMI[0][0] < threshold: continue
#
#         totalUMI = sum([z[0] for z in newUMI])
#         if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
#             ncellbyUMI[y] = newUMI[0][1]
#         else:
#             print("multiple: %s" % str(newUMI))
#         #### end
#
#     UMIpairs = {}
#
#     if len(ncellbyUMI) == 0:
#         print("is zero")
#         continue
#
# #    if len(ncellbyUMI) == 1:
# #        continue
#         # uncomment here if we don't want to ignore UMIs assigned by single counts
#         #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
#         #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
#         #count.append(1)
#
#         #adding single UMIs to poorUMI list instead of assigning label
# #        poorUMI.append([(1,ncellbyUMI)])
# #        poorUMI2.append(x)
# #        continue
#
#     for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
#         if ncellbyUMI[y] in UMIpairs:
#             UMIpairs[ncellbyUMI[y]] += 1
#         else:
#             hamming=False
#             for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
#                 if z[0] != ncellbyUMI[y][0]: continue
#                 if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
#                     UMIpairs[z] += 1
#                     hamming=True
#                     break
#             if hamming: continue
#             UMIpairs[ncellbyUMI[y]] = 1
#
# #    if len(UMIpairs) == 0:
# #        print("UMIPairs")
# #        print(ncellbyUMI)
# #        print(cellbyUMI[x])
# #        print("error this shoudl not happen")
# #        continue
#
#     if len(UMIpairs) == 1:
#         if list(UMIpairs.values())[0] < cutoff2:
#             #print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
#             continue
#         assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
#         assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
#         count.append(list(UMIpairs.values())[0])
#         continue
#
#     newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
#     newUMI.sort(reverse=True)
#     if newUMI[0][0] < cutoff2: continue
#
#     totalUMI = sum([y[0] for y in newUMI])
#     count.extend([z[0] for z in newUMI])
#
#     if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
#         assignedCellshRNA[x] = newUMI[0][1][0]
#         assignedCellbarcode[x] = newUMI[0][1][1]
#         continue
#     else:
#         set_trace()
#     poorUMI.append(newUMI)
#     poorUMI2.append(x)

# %% [raw]
# import statistics
# sum(count)/len(count), min(count), max(count), statistics.median(count)

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(count), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# plt.show()

# %% [raw]
# len(assignedCellshRNA)

# %% [raw]
# len(whitelist)

# %% [raw]
# #count.sort()
# #count

# %% [raw]
# len(poorUMI)

# %% [raw]
# poorUMI

# %% [raw]
# #calculate average hammandDistance
# hdist = []
# for x in poorUMI:
#     if len(x) == 1:
# #        hdist.append(0)
#         continue
#     y = [(z[1][0], z[1][1]) for z in x]
#     pUMI = {}
#     for z in y:
#         if z[0] not in pUMI:
#             pUMI[z[0]] = [z[1]]
#         else:
#             pUMI[z[0]].append(z[1])
#     for y in pUMI:
#         if len(pUMI[y]) < 2:
#             continue
#         for i in range(0, len(pUMI[y])):
#             for j in range(i+1, len(pUMI[y])):
#                 hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
#                 if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
#                     print(pUMI[y])
#                     print(pUMI[y][i], pUMI[y][j])

# %% [raw]
# _ = plt.hist(hdist, bins='auto', histtype='step')
#
# plt.ylabel("Counts")
# plt.show()

# %% [raw]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %% [raw]
# validshRNANameHash = {}
# for x in assignedCellshRNA:
#     validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %% [raw]
# len(assignedCellbarcode)

# %% [raw]
# import pandas as pd
# pUMI = {}
# for x in poorUMI2:
#     pUMI[x] = 1
# cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
# cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
# cellhashobj.to_pickle('pUMIcDNA.pickle')

# %% [raw]
# import pandas as pd
#
# cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
# cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
# cellhashobj.to_pickle('shRNAcDNA.pickle')
#
# cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
# cellhashobj.rename(columns={0: "barcode"}, inplace=True)
# cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
