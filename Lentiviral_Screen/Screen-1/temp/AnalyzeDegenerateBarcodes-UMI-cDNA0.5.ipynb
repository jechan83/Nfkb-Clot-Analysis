# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7114

# %%
afile = pysam.AlignmentFile("./final_0.5.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
_
# Out:
# (array([5.873715e+06, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([0.00000000e+00, 1.38505801e-02, 2.77011603e-02, ...,
#         1.54156957e+01, 1.54295463e+01, 1.54433969e+01]),
#  [<matplotlib.patches.Polygon at 0x2f659cbe0>])

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 4:
        count = x
        break

# %%
count
# Out:
# 253

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 16

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
  
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
        else:
            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1 and list(UMIpairs.values())[0] >= 5:
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort()
    newUMI.reverse()
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if newUMI[0][0] < 5: continue
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# [(21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(31, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (31, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (30, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (23, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(26, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCTACGT', 'GGGGGAAGGCGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(36, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA'))]
# [(21, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(24, ('TGTCTAGT', 'GTGGGAATTTCTTTGGAGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('CCATTACT', 'ACGTTAATAGTATTACGTAAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA'))]
# [(26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('ACACGTGA', 'CAATCAAATGGATTGTCTGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA'))]
# [(18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(34, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(34, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(30, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (22, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(26, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(18, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))]
# [(22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (21, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TTAATTAG', 'TTTTTAATTATTTTATTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CTGAATCT', 'ACAAAAAAATAATTTAAAAAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(18, ('CTGAATCT', 'CCTGCAACACCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCACCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(27, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(29, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (26, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')), (17, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(35, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(34, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGCTCAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(27, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTTAA')), (34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CGTTCAAG', 'TTCCGAAAATATTTTTAAAAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGTTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(28, ('ACAGAGCC', 'ACTGGAAACCATTTGAATAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('ACAGAGCC', 'ACTGGAAACCATTTGAATAAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (20, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('GCCTACGT', 'AGGTGAACTGTGTTGGGAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (20, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(19, ('CGTTAGGG', 'GTAATAATGAGGTTATGCGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('ACAGAGCC', 'TCGTTAACATCGTTTTGCTAA')), (17, ('TGTCTAGT', 'CCCCTAACCCCCTTCCACCAA'))]
# [(23, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))]
# [(31, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(36, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (35, ('TTAATTAG', 'GTTTTAATTTTTTTTTTTAAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(31, ('ACAGAGCC', 'CTTTTAATCGGGTTTGTTCAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')), (19, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')), (27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(39, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('TTAATTAG', 'AAAAGAAGAACGTTGAAAAAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'CTTTCAATCATTTTATTTTAA'))]
# [(42, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA'))]
# [(21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('CAGTGCAT', 'GTGAAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('ACACGTGA', 'TGGTTAAGGATTTTGGTTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('TGTCTAGT', 'GGTGGAAGTGAGTTGGAGAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('GGTAGGGA', 'TGTCGAAAAGCCTTCGCTGAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('ACACGTGA', 'CCCCCAATGCCATTCCCCCAA'))]
# [(18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CCATTACT', 'CCCCCAACCACCTTCCGCCAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(34, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA'))]
# [(35, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (23, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(34, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGAAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))]
# [(29, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCACCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCATTCCACCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))]
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(36, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (32, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(17, ('TGTCTAGT', 'CGTATAATTTTTTTATGTGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(35, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(17, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA'))]
# [(26, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('ACAGAGCC', 'GGTGTAATTGTATTGCTACAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (17, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))]
# [(27, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))]
# [(29, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(22, ('ACAGAGCC', 'GAATAAAGATGCTTCGAAGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(23, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('ACAGAGCC', 'GGTGAAACACCGTTAGGTGAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('GGTAGGGA', 'CTGAAAAGATTGTTCTTTGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(28, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACAGAGCC', 'GCTTTAAATTTGTTATTAAAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(36, ('CGTTAGGG', 'GATGTAACTTTTTTAGTCCAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('TTAATTAG', 'GGCAGAAGATAGTTATAACAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(32, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(19, ('CGTTCAAG', 'TATCGAACTCTATTCAGGTAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('TTAATTAG', 'ATGATAATTTGTTTTTTGTAA'))]
# [(22, ('ACACGTGA', 'GGTGGAATGTGGTTGTGTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(37, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAATTATTTTGGTTGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(37, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('GGTAGGGA', 'AAAACAAATCACTTCAGCGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CGGGAATG', 'TTTTTAAGGGTTTTTGGTGAA')), (20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'ATGTTAATCATGTTTGCTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA')), (21, ('CAGTGCAT', 'GTGGAAATGTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(28, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('ACAGAGCC', 'GAATAAAGATGCTTCGAAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(33, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (22, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('ACACGTGA', 'CAAAAAAAAATCTTGTAAAAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CGTTAGGG', 'CATTTAATTTCGTTTTTGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CGTTAGGG', 'CATTTAATTTCGTTTTTGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'TATTTAATTTGTTTTGGTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TTAATTAG', 'GGATGAACAAGGTTAGACTAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (26, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (27, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACAAAAGAACCTTCAATGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# ...
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(31, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGTTTGGGGGAA'))]
# [(24, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (20, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(24, ('CGGGAATG', 'CCCCCAATGCCCTTTGCCAAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(25, ('CGTTCAAG', 'TGTTTAATGCATTTTCTTGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))]
# [(21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGTAAGGGGATTGGGGGAA'))]
# [(30, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAATTTGGTTGGTTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('ACAGAGCC', 'CGCACAATAGGATTCTGAAAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(31, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (22, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (18, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# is zero
# [(20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (30, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (30, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (29, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (28, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (27, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (25, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (23, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (20, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')), (20, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TTAATTAG', 'AACATAAACCCATTCCCAAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# is zero
# [(32, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(22, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# is zero
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (29, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(34, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (27, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'TATTTAATTTGTTTTGGTTAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# is zero
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# is zero
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# is zero
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGTTAGGG', 'CAGATAAGAGTGTTGTTTCAA'))]
# is zero
# [(24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# is zero
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# is zero

# %%
print(sum(histogram_of_UMIs))
# Out:
# 61671

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# #plt.axvline()
# plt.show()

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# plt.axvline(x=cutoff2)
# plt.show()

# %% [raw]
# cutoff2 = 2**cutoff2
# print(cutoff2)

# %% [raw]
# ## counting total UMIs from dominant shRNA
# assignedCellshRNA = {}
# assignedCellbarcode = {}
# poorUMI = []
# poorUMI2 = []
# count = []
# threshold = cutoff
#
# for x in cellbyUMI:
#     ncellbyUMI = {}
#     for y in cellbyUMI[x]:
#         UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
#         UMIpairs.sort(reverse=True)
#         newUMI = []
#         while len(UMIpairs) != 0:
#             shRNAIDbarcodepair = UMIpairs.pop(0) #
#             toDelete = []
#             for z in range(0, len(UMIpairs)):
#                 if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
#                 if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
#                     toDelete.append(z)
#                     shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
#             newUMI.append(shRNAIDbarcodepair)
#             for z in sorted(toDelete, reverse = True):
#                 del UMIpairs[z]
#
#         if len(newUMI) == 1:
#         # uncomment here if we don't want to ignore single counts
#             if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
#             continue
#
#         # Shouldn't happen anymore with the cleaned up version
#         newUMI.sort(reverse=True)
#         if newUMI[0][0] < threshold: continue
#
#         totalUMI = sum([z[0] for z in newUMI])
#         if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
#             ncellbyUMI[y] = newUMI[0][1]
#         else:
#             print("multiple: %s" % str(newUMI))
#         #### end
#
#     UMIpairs = {}
#
#     if len(ncellbyUMI) == 0:
#         print("is zero")
#         continue
#
# #    if len(ncellbyUMI) == 1:
# #        continue
#         # uncomment here if we don't want to ignore UMIs assigned by single counts
#         #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
#         #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
#         #count.append(1)
#
#         #adding single UMIs to poorUMI list instead of assigning label
# #        poorUMI.append([(1,ncellbyUMI)])
# #        poorUMI2.append(x)
# #        continue
#
#     for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
#         if ncellbyUMI[y] in UMIpairs:
#             UMIpairs[ncellbyUMI[y]] += 1
#         else:
#             hamming=False
#             for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
#                 if z[0] != ncellbyUMI[y][0]: continue
#                 if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
#                     UMIpairs[z] += 1
#                     hamming=True
#                     break
#             if hamming: continue
#             UMIpairs[ncellbyUMI[y]] = 1
#
# #    if len(UMIpairs) == 0:
# #        print("UMIPairs")
# #        print(ncellbyUMI)
# #        print(cellbyUMI[x])
# #        print("error this shoudl not happen")
# #        continue
#
#     if len(UMIpairs) == 1:
#         if list(UMIpairs.values())[0] < cutoff2:
#             #print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
#             continue
#         assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
#         assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
#         count.append(list(UMIpairs.values())[0])
#         continue
#
#     newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
#     newUMI.sort(reverse=True)
#     if newUMI[0][0] < cutoff2: continue
#
#     totalUMI = sum([y[0] for y in newUMI])
#     count.extend([z[0] for z in newUMI])
#
#     if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
#         assignedCellshRNA[x] = newUMI[0][1][0]
#         assignedCellbarcode[x] = newUMI[0][1][1]
#         continue
#     else:
#         set_trace()
#     poorUMI.append(newUMI)
#     poorUMI2.append(x)

# %% [raw]
# import statistics
# sum(count)/len(count), min(count), max(count), statistics.median(count)

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(count), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# plt.show()

# %% [raw]
# len(assignedCellshRNA)

# %% [raw]
# len(whitelist)

# %% [raw]
# #count.sort()
# #count

# %% [raw]
# len(poorUMI)

# %% [raw]
# poorUMI

# %% [raw]
# #calculate average hammandDistance
# hdist = []
# for x in poorUMI:
#     if len(x) == 1:
# #        hdist.append(0)
#         continue
#     y = [(z[1][0], z[1][1]) for z in x]
#     pUMI = {}
#     for z in y:
#         if z[0] not in pUMI:
#             pUMI[z[0]] = [z[1]]
#         else:
#             pUMI[z[0]].append(z[1])
#     for y in pUMI:
#         if len(pUMI[y]) < 2:
#             continue
#         for i in range(0, len(pUMI[y])):
#             for j in range(i+1, len(pUMI[y])):
#                 hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
#                 if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
#                     print(pUMI[y])
#                     print(pUMI[y][i], pUMI[y][j])

# %% [raw]
# _ = plt.hist(hdist, bins='auto', histtype='step')
#
# plt.ylabel("Counts")
# plt.show()

# %% [raw]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %% [raw]
# validshRNANameHash = {}
# for x in assignedCellshRNA:
#     validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %% [raw]
# len(assignedCellbarcode)

# %% [raw]
# import pandas as pd
# pUMI = {}
# for x in poorUMI2:
#     pUMI[x] = 1
# cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
# cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
# cellhashobj.to_pickle('pUMIcDNA.pickle')

# %% [raw]
# import pandas as pd
#
# cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
# cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
# cellhashobj.to_pickle('shRNAcDNA.pickle')
#
# cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
# cellhashobj.rename(columns={0: "barcode"}, inplace=True)
# cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
