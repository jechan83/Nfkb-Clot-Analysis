# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7114

# %% [raw]
# afile = pysam.AlignmentFile("./final.bam")
# hashcount = {}
# hashset = {}
# cellhash = {}
# taghash = {}
# readcount = {}
# barcodehash = {} # barcodes listing shRNAID
# barcodebycellUMI = {} # barcode listing cellUMI
# doublecounts = 0
# cellbyUMI = {}
# inwhitelist = set()
# inwhitelistcount = 0
# outwhitelist = set()
# outwhitelistcount = 0
# for seq_record in afile.fetch(until_eof=True):
#     cellUMI = None  # here this is the CellRanger cell UMI
#     UMI = None
#     if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
#     cellUMI = seq_record.get_tag("CB")
#     if cellUMI not in whitelist:
#         outwhitelistcount +=1
#         if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
#         continue
#     else:
#         inwhitelistcount += 1
#         if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
#     UMI = seq_record.get_tag("UB") # umi barcode
#
#     m = hashmatch.search(seq_record.query_sequence)
#     if m == None or (m.end() + 8) > len(seq_record.query_sequence):
#         #print("Error, match not found")
#         continue
#     shRNAID = seq_record.query_sequence[m.end():m.end()+8]
#     barcode = seq_record.query_sequence[m.end()-21:m.end()]
#     sbID = (shRNAID,barcode)
#     if shRNAID not in hashes: continue
#     if cellUMI not in cellbyUMI:
#         cellbyUMI[cellUMI] = {}
#     if UMI not in cellbyUMI[cellUMI]:
#         cellbyUMI[cellUMI][UMI] = {sbID: 1}
#         continue
#     if sbID in cellbyUMI[cellUMI][UMI]:
#         cellbyUMI[cellUMI][UMI][sbID] += 1
#     else:
#         hamming = False
#         for x in cellbyUMI[cellUMI][UMI]:
#             if hammingDistance(sbID[1],x[1]) <= 2:
#                 cellbyUMI[cellUMI][UMI][x] += 1
#                 hamming = True
#                 break
#         if hamming: continue
#         cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle
cellbyUMI = False
with open('cellbyUMI.pickle', 'rb') as f:
    cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 1:
        count = x
        break

# %%
count
# Out:
# 28

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 2

# %%
len(cellbyUMI)
# Out:
# 7113

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %%
len(cellbyUMI)
# Out:
# 6684

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] > threshold: 
                ncellbyUMI[y] = newUMI[0][1]
            else:
                print("Not past threshold: %s" % str(newUMI))
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
            
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
#        else:
#            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
            continue        
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)

    if newUMI[0][0] < cutoff2: 
        print("Not past UMI threshold: %s" % str(newUMI))
        continue
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    else:
        set_trace()
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis/lib/python3.8/site-packages/scipy/stats/_discrete_distns.py:75: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff2 = 2
plt.axvline(x=cutoff2)
plt.show()
# Out:
# By UMI/Cell

# %% [raw]
# _

# %%
cutoff2 = 2**cutoff2
print(cutoff2)
# Out:
# 4

# %%
## counting total UMIs from dominant shRNA
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
        if newUMI[0][0] < threshold: continue
    
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]
#        else:
#            print(newUMI)
        
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        poorUMI2.append(x)
        continue            
        
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1:
        if list(UMIpairs.values())[0] < cutoff2: 
            #print("Not past UMI Threshold: %s" % str(UMIpairs))
            poorUMI.append(UMIpairs)
            poorUMI2.append(x)
            continue
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort(reverse=True)
    if newUMI[0][0] < cutoff2: 
        #print("Not past second cutoff: %s" % str(UMIpairs))
        poorUMI.append(newUMI)
        poorUMI2.append(x)
        continue

    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI])

    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue

    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# /Users/chanj2/opt/miniconda3/envs/scanalysis/lib/python3.8/site-packages/scipy/stats/_discrete_distns.py:75: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero
# is zero

# %%
import statistics
sum(count)/len(count), min(count), max(count), statistics.median(count)
# Out:
# (13.150090780714141, 1, 2392, 1.0)

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(count), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
plt.show()
# Out:
# By UMI/Cell

# %%
len(assignedCellshRNA)
# Out:
# 1960

# %%
len(whitelist)
# Out:
# 7114

# %%
#count.sort()
#count

# %%
len(poorUMI)
# Out:
# 4605

# %%
poorUMI
# Out:
# [{('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA'): 1},
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TTAATTAG', 'TGTTGAATTATTTTGTTGTAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'GGATGAACAAGGTTAGACTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAATGGGTTTGTGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGGGAATG', 'TGGTGAATGTTGTTGAATGAA')),
#   (1, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('ACAGAGCC', 'GAATAAAGATGCTTCGAAGAA')),
#   (1, ('ACAGAGCC', 'ACTGGAAACCATTTGAATAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAATGCCATTCCCCCAA'))],
#  [(3, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')),
#   (1, ('TTAATTAG', 'GGCAGAAGATAGTTATAACAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))],
#  [(2, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('GGTAGGGA', 'TCAATAAACAGTTTTCTGAAA')),
#   (1, ('GGTAGGGA', 'GGCACAACTTTGTTATTAAAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))],
#  [(1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('CCATTACT', 'TGGTTAAAGAGTTTTGGTAAA')),
#   (1, ('CCATTACT', 'CTCGCAATCGTCTTGCCCCAA')),
#   (1, ('ACACGTGA', 'ATCTCAAGCCTCTTCTTGTAA'))],
#  [(3, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'CCACCAACCCCCTTGTCCCAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GTACTTGC', 'GTGGGAAGGCAGTTGGCTTAA')),
#   (1, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CTGAATCT', 'ACAAAAAAATAATTTAAAAAA')),
#   (1, ('CGTTAGGG', 'AATACAATAGTGTTTTGTTAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCATCCAA'))],
#  [(2, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')),
#   (1, ('GTACTTGC', 'GGTGGAAATATGTTCAATGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA'))],
#  [(1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGTTAATAGGGTTGGTCTAA')),
#   (1, ('TGTCTAGT', 'CATACAATCGTTTTATTTTAA')),
#   (1, ('GGTAGGGA', 'TGTCGAAAAGCCTTCGCTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'GATGTAAATTTCTTTGCTTAA')),
#   (1, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('ACAGAGCC', 'TGAATAAATATCTTAAAATAA')),
#   (1, ('ACAGAGCC', 'TCGTTAACATCGTTTTGCTAA')),
#   (1, ('ACAGAGCC', 'GGTGTAATTGTATTGCTACAA')),
#   (1, ('ACAGAGCC', 'GGTCAAAAGTTGTTTACTTAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  [(3, ('TTAATTAG', 'ATGATAATTTGTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA'))],
#  [(2, ('CTGAATCT', 'TTCTTAACTTCTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATGTTGCAAGAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGGTTAGGAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TCGTTAACCGTGTTTTAACAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))],
#  [(3, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GGTAGGGA', 'TGTATAAAGTTATTACTAGAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(3, ('GTACTTGC', 'GCTTTAAATACATTTGGATAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTCAATGTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GACAAAAAGAAGTTAAAGAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCGTTCCCCCAA')),
#   (1, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')),
#   (1, ('CGTTAGGG', 'GTAATAATGAGGTTATGCGAA')),
#   (1, ('CAGTGCAT', 'TCCAGAACTATTTTGATCTAA'))],
#  [(2, ('TGTCTAGT', 'GTAGGAATTTTTTTGGGGTAA')),
#   (2, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA')),
#   (1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')),
#   (1, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATAGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('CGGGAATG', 'AGATGAATACTGTTAAAGGAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA'))],
#  [(1, ('TTAATTAG', 'GGATGAACAAGGTTAGACTAA')),
#   (1, ('TTAATTAG', 'GACAAAAAGAAGTTAAAGAAA')),
#   (1, ('TGTCTAGT', 'GTGGGAAGGAGATTGTGGCAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CGTATAATTTTTTTATGTGAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CCATTACT', 'AAAAAAATCTAATTTAAAAAA'))],
#  [(1, ('TCTGGGGC', 'TTGTTAATTTTTTTTGGGTAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA'))],
#  [(1, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TGTATAAAGTTATTACTAGAA')),
#   (1, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')),
#   (1, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA'))],
#  [(2, ('TTAATTAG', 'TTTTAAATTTTTTTTCTATAA')),
#   (2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('GTACTTGC', 'TCGTTAAGAGGGTTCTCGCAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('CGGGAATG', 'GTATGAAAGCCTTTTTTGGAA')),
#   (1, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')),
#   (1, ('ACACGTGA', 'ATCTCAAGCCTCTTCTTGTAA'))],
#  [(2, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (2, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('TGTCTAGT', 'ACAACAACGACATTACAATAA')),
#   (1, ('GTACTTGC', 'TGGGTAAATTTGTTAATAGAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGTTCAAG', 'CCTGTAAGTCAATTCTTGCAA')),
#   (1, ('CGTTAGGG', 'CATTTAATTTCGTTTTTGGAA')),
#   (1, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTTAA')),
#   (1, ('CCATTACT', 'CTCGCAATCGTCTTGCCCCAA')),
#   (1, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA')),
#   (1, ('ACAGAGCC', 'CGCACAATAGGATTCAGAAAA'))],
#  [(3, ('GCCTACGT', 'AGGTGAACTGCATTGGGAAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTCAATGTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'CGGGCAACTTCATTGATGTAA')),
#   (1, ('TGTCTAGT', 'CATCGAAGGACCTTACGATAA')),
#   (1, ('GTACTTGC', 'TATGTAAGGAATTTGGTTAAA')),
#   (1, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'AAAAAAATCTAATTTAAAAAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  [(1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCAATGAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))],
#  [(1, ('TTAATTAG', 'GGGGAAAAGCGGTTGGGACAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GGTAGGGA', 'TAGGAAATCTGGTTCTATGAA')),
#   (1, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CGTTAGGG', 'AGTGCAAGTGTATTCCAAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))],
#  [(2, ('GGTAGGGA', 'ATAGCAAATGTTTTTCCAAAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')),
#   (1, ('TGTCTAGT', 'CCCCTAACCCCCTTCCACCAA')),
#   (1, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(2, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('GTACTTGC', 'TGCCCAATGACATTGATACAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))],
#  [(1, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('ACAGAGCC', 'CTTTTAATCGGGTTTGTTCAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))],
#  [(2, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'AAAACAACGAAATTACAAAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGTTAGGG', 'GAAGGAATCAAATTTAACAAA')),
#   (1, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GCTTTAAATTTGTTATTAAAA')),
#   (1, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))],
#  [(2, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GACAAAAAGAAGTTAAAGAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))],
#  [(2, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATGTTGCAAGAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGGGAATG', 'CTCTTAACACCTTTCTTTCAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))],
#  [(2, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')),
#   (1, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA')),
#   (1, ('CGGGAATG', 'GGGAGAAGGGTGTTGGGGGAA')),
#   (1, ('CGGGAATG', 'AATTGAATCATTTTTTTGAAA'))],
#  [(1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('CGGGAATG', 'TTTTGAATTGTTTTGGGTGAA')),
#   (1, ('CCATTACT', 'TGGTTAAAGAGTTTTGGTAAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA'))],
#  [(1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('ACAGAGCC', 'TATCCAAGTATCTTTGTTGAA'))],
#  [(1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))],
#  [(2, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTACCCCAA')),
#   (1, ('GGTAGGGA', 'GAGGAAATTTACTTAGTCTAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CCATTACT', 'TATTTAAACGTTTTGTGTAAA')),
#   (1, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA')),
#   (1, ('ACACGTGA', 'TGTTTAATTTTTTTTTCTGAA')),
#   (1, ('ACACGTGA', 'GATTCAAGGTACTTGAGACAA'))],
#  [(2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA'))],
#  [(1, ('TTAATTAG', 'TTATTAATTTTTTTTTTTCAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GGTAGGGA', 'TAGGAAACCTTATTTTGCAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))],
#  [(1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GTACTTGC', 'GTGGGAAGGCAGTTGGCTTAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))],
#  [(2, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (2, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')),
#   (1, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')),
#   (1, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTAGGG', 'TATTTAAAAGGATTTTGAGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA'))],
#  {('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'): 1},
#  {('CCATTACT', 'AGGGAAAAGGTGTTAAATTAA'): 2},
#  [(1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(2, ('TGTCTAGT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('CCATTACT', 'ACGTTAATAGTATTACGTAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TTAATTAG', 'CCGACAAAGTGATTGAAATAA')),
#   (1, ('TGTCTAGT', 'CGTATAATTTTTTTATGTGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGTGTTGAGGTAA')),
#   (1, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')),
#   (1, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGTGGTTTGGGGGAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA'))],
#  [(1, ('TTAATTAG', 'GGAGGAATGAGGTTAGGAAAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTTCCT', 'GGTCTAAGATAGTTGGGTTAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(2, ('CTGAATCT', 'AAAAAAAAAAAATTAAAAAAA')),
#   (1, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTCAATTTCCTTCCTCTAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GTACTTGC', 'GGTGGAAATATGTTCAATGAA')),
#   (1, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('ACACGTGA', 'CAAGAAACAAGATTGGTAAAA'))],
#  [(1, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('ACACGTGA', 'GGGGTAAATGTTTTGGTTTAA'))],
#  [(1, ('CTGAATCT', 'CCACCAACCCCCTTGTCCCAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA'))],
#  [(3, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (3, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')),
#   (3, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GTACTTGC', 'GTGGTAATCGACTTCTCACAA')),
#   (1, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')),
#   (1, ('GGTAGGGA', 'TACGAAACTGCGTTTGGATAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CTGAATCT', 'CCCACAACCCCCTTCACCCAA')),
#   (1, ('CGTTAGGG', 'TATTTAAAAGGATTTTGAGAA')),
#   (1, ('ACACGTGA', 'TGGTTAAGGATTTTGGTTGAA')),
#   (1, ('ACACGTGA', 'GATTCAAGGTACTTGAGACAA'))],
#  [(1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'GTGTTAATTAATTTGTCATAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATAACATTCTTGCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CGGGAATG', 'GTATGAAAGCCTTTTTTGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))],
#  [(1, ('TTAATTAG', 'TGGTAAATTATTTTATTTTAA')),
#   (1, ('TTAATTAG', 'ATGATAATTTGTTTTTTTTAA')),
#   (1, ('CGTTCAAG', 'TAATTAACAGCATTGAATTAA'))],
#  [(3, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (2, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')),
#   (1, ('TTAATTAG', 'CCGACAAAGTGATTGAAATAA')),
#   (1, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGAACGAA')),
#   (1, ('GTACTTGC', 'GTGGGAAGGCAGTTGGCTTAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GGTAGGGA', 'AAATCAAAGCAATTCCAATAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGTTAGGG', 'TATTTAAAAGGATTTTGAGAA')),
#   (1, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA'))],
#  [(1, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))],
#  [(1, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')),
#   (1, ('GGTAGGGA', 'GATTGAAAAGACTTCAGTTAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTTCCT', 'CCAGTAATTTAGTTTGTTTAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('ACAGAGCC', 'GGGCCAAGTGCTTTCACACAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))],
#  [(3, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'TCTTGAATTGTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'AGAGAAATAATTTTTCTCTAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'TTCAGAAAATATTTTTAAAAA')),
#   (1, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('ACACGTGA', 'GATTCAAGGTACTTGAGACAA'))],
#  [(2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'CATCGAAGGACCTTACGATAA')),
#   (1, ('TCTGGGGC', 'TTGTTAATTTTTTTTGGGTAA')),
#   (1, ('CGTTCAAG', 'TGTTTAATGCATTTTCTTGAA')),
#   (1, ('CGGGAATG', 'TGGTGAATGTTGTTGAATGAA')),
#   (1, ('CAGTGCAT', 'TCCAGAACTATTTTGATCTAA'))],
#  [(1, ('TTAATTAG', 'GACAAAAAGAAGTTAAAGAAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')),
#   (1, ('TCTGGGGC', 'TATTTAACCCAATTGGTTCAA')),
#   (1, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))],
#  [(3, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (3, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (2, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (2, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('ACAGAGCC', 'GAATAAAGATGCTTCGAAGAA'))],
#  [(2, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('GTACTTGC', 'GTGGTAATCGACTTCTCACAA')),
#   (1, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA'))],
#  [(1, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('CTGAATCT', 'TTACCAAACCCCTTGCCCTAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGTGGTTTGGGGGAA')),
#   (1, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))],
#  [(2, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'AAAACAACGAAATTACAAAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))],
#  [(2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGTTTTTTTGTTGAA')),
#   (1, ('GGTAGGGA', 'AAATTAAAGCAATTCCAATAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CTGAATCT', 'CCTGCAACACCCTTCCTCCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGGGAATG', 'CTCTTAACACCTTTCTTTCAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('ACAGAGCC', 'TCGTTAACATCGTTTTGCTAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))],
#  {('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'): 1},
#  [(2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'AATAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA'))],
#  [(1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GGTAGGGA', 'TAGGAAATCTGGTTCTATGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TTAATTAG', 'TGGTAAATTATTTTATTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(2, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAAAAACTAAATTAAAATAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGGTTAGGAAAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA'))],
#  [(1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')),
#   (1, ('CCATTACT', 'ACGTTAATAGTATTACGTAAA'))],
#  [(2, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TCCCTAAAATCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'GTTATAAAAACATTAGGTTAA')),
#   (1, ('GGTAGGGA', 'GAGGAAATTTACTTAGTCTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))],
#  [(3, ('CGGGAATG', 'TCCCCAAACCCCTTTTCCGAA')),
#   (1, ('TGTCTAGT', 'GCAATAAGGGCGTTTTGGGAA'))],
#  [(3, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')),
#   (1, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')),
#   (1, ('TTAATTAG', 'AACATAAACCCATTCCCAAAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAATGTGGTTTGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GCCTACGT', 'TTCTGAAGGCGTTTTTTTTAA')),
#   (1, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTAGGG', 'GATGTAACTTTTTTAGTCCAA')),
#   (1, ('CGTTAGGG', 'CATTTAATTTCGTTTTTGGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'ACTGGAAACCATTTGAATAAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(2, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (2, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'CTGAAAAGATTGTTCTTTGAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(3, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TAGGAAATCTGGTTCTATGAA')),
#   (1, ('CGTTAGGG', 'GAAGGAATCAAATTTAACAAA'))],
#  [(1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('CGTTAGGG', 'GCGGCAAATGGATTTGCTAAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('ACACGTGA', 'CAAAAAAAAATCTTGTAAAAA'))],
#  [(2, ('TGTCTAGT', 'GCGGGAAGGTCATTTGAGGAA')),
#   (2, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('GCCAATCG', 'ATATTAAATTTTTTGCTGCAA')),
#   (1, ('CGTTAGGG', 'CAGATAAGAGTGTTGTTTCAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA'))],
#  [(1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GGTGAAACACCGTTAGGTGAA'))],
#  [(1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('TGTCTAGT', 'CATACAATCGTTTTATTTTAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  {('TGTCTAGT', 'CCCCAAATCCTCTTCCTCCAA'): 1},
#  [(2, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'CGCTGAATTTGATTGATAGAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'TACACAAATTGGTTGTATGAA')),
#   (1, ('CGTTCAAG', 'TAAGAAATACAGTTACTGTAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'TGAGGAAACGTCTTACGCAAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(1, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')),
#   (1, ('TTAATTAG', 'AACATAAACCCATTCCCAAAA')),
#   (1, ('TCTGGGGC', 'CGACCAAACAACTTCAAAAAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  [(2, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')),
#   (2, ('CGGGAATG', 'TTTGTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TCCCTAAAATCCTTCCATCAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTAGGG', 'AGTGCAAGTGTATTCCAAGAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(3, ('TGTCTAGT', 'TTTTTAATCTTTTTTTTTTAA')),
#   (3, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (2, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (2, ('TGTCTAGT', 'ACAACAACGACATTACAATAA')),
#   (2, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCACCAACCCCATTCCTCTAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GTACTTGC', 'GTGTTAATTAATTTGTCATAA')),
#   (1, ('GGTAGGGA', 'TGTCGAAAAGCCTTCGCTGAA')),
#   (1, ('GGTAGGGA', 'TGTATAATGTGTTTATATCAA')),
#   (1, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')),
#   (1, ('GGTAGGGA', 'AGCCAAAATAACTTTTCGTAA')),
#   (1, ('CTGAATCT', 'TTTATAAATATTTTGTCGTAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CTGAATCT', 'ACAAAAAAATAATTTAAAAAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTCAAG', 'TAATTAACAGCATTGAATTAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGTTAAAGAGTTTTGGTAAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('CAGTGCAT', 'ATGTTAATCATGTTTGCTTAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')),
#   (1, ('ACACGTGA', 'TGGTTAATTTTTTTTTTTTAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))],
#  {('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'): 1},
#  [(1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('ACAGAGCC', 'AGGCAAACTGTATTGCCCTAA')),
#   (1, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))],
#  [(2, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')),
#   (1, ('CGGGAATG', 'CTCTTAACACCTTTCTTTCAA')),
#   (1, ('CCATTACT', 'AAAAAAATCTAATTTAAAAAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')),
#   (1, ('ACACGTGA', 'GGTGGAATGTGGTTGTGTGAA'))],
#  [(2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTCAAG', 'ATCTAAAAACGATTGTTTAAA')),
#   (1, ('CGTTCAAG', 'ATAACAACTGGGTTCCTTTAA')),
#   (1, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')),
#   (1, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA')),
#   (1, ('ACAGAGCC', 'AAATAAACTGGGTTAGTCGAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'GTGGGAAGGCAGTTGGCTTAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGTTAGGG', 'ACAAAAATGTACTTGTCCTAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA'))],
#  {('CTGAATCT', 'ACAAAAAAATAATTTAAAAAA'): 1},
#  [(2, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CTGAATCT', 'ACAAAAAAATAATTTAAAAAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CCATTACT', 'TGGTTAAAGAGTTTTGGTAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))],
#  {('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'): 1},
#  [(1, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'CCACCAACAAAATTACAAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGATTGAAAGAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACACGTGA', 'GGTGGAATGTGGTTGTGTGAA'))],
#  [(1, ('TTAATTAG', 'TGGGGAAGAGGGTTAGAGGAA')),
#   (1, ('TGTCTAGT', 'CGGGCAACTTCATTGATGTAA')),
#   (1, ('TGTCTAGT', 'ACAACAACGACATTACAATAA')),
#   (1, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(1, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'CGCACAATAGGATTCAGAAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA'))],
#  [(3, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA'))],
#  [(3, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'TTGTAAATGTTTTTCTTTGAA')),
#   (1, ('CGTTTCCT', 'CCAGTAATTTAGTTTGTTTAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGGGTTTTTGGTGAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(2, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')),
#   (1, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')),
#   (1, ('GGTAGGGA', 'ATAGCAAATGTTTTTCCAAAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGGGAATG', 'TTTTGAATTGTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'ATTAGAAGTACGTTTTTAAAA'))],
#  {('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'): 1},
#  [(1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GGTAGGGA', 'GGCACAACTTTGTTATTAAAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA'))],
#  [(1, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('GGTAGGGA', 'GAGGAAATTTACTTAGTCTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGTTAGGG', 'ACCAAAAGAGTGTTATGTTAA')),
#   (1, ('CGGGAATG', 'CCCCTAACCTCTTTCTCCAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('ACAGAGCC', 'GGGCCAAGTGCTTTCACACAA'))],
#  [(2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'CTGAAAAGATTGTTCTTTGAA')),
#   (1, ('CGTTCAAG', 'TTCAGAAAATATTTTTAAAAA')),
#   (1, ('CGTTCAAG', 'TTAAAAACGCCATTCACTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))],
#  [(3, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (2, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('TTAATTAG', 'TGATTAATATTTTTCGATCAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('TGTCTAGT', 'ACAACAACGACATTACAATAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA')),
#   (1, ('CGGGAATG', 'TTTTGAATTGTTTTGGGTGAA')),
#   (1, ('ACAGAGCC', 'TATCCAAGTATCTTTGTTGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))],
#  [(3, ('ACAGAGCC', 'TCGCGAATTTTTTTTAATGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAAACCCCTTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  [(3, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTTTTTTTCTATAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'GGATGAACAAGGTTAGACTAA')),
#   (1, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')),
#   (1, ('TTAATTAG', 'AACATAAACCCATTCCCAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('TCTGGGGC', 'TATTTAACCCAATTGGTTCAA')),
#   (1, ('GTACTTGC', 'TGGGTAAATTTGTTAATAGAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGGATAA')),
#   (1, ('CGTTAGGG', 'TATAGAAGGTGATTTCTAGAA')),
#   (1, ('CGTTAGGG', 'GAAGGAATCAAATTTAACAAA')),
#   (1, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('CAGTGCAT', 'ATGTTAATCATGTTTGCTTAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(2, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(5, ('GGTAGGGA', 'TAGGAAACCTTATTTTGCAAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (2, ('ACACGTGA', 'TGTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'ATGATAATTTGTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA'))],
#  [(2, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTATTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TGTTGAATTATTTTGTTGTAA')),
#   (1, ('TGTCTAGT', 'GTGGGAAGTTGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCACCAACAAAATTACAAAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(3, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (2, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (2, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (2, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACACCCTTCCTCCAA')),
#   (1, ('TGTCTAGT', 'CCACCAACAAAATTACAAAAA')),
#   (1, ('GTACTTGC', 'GTGTTAATTAATTTGTCATAA')),
#   (1, ('GTACTTGC', 'GTGGTAATCGACTTCTCACAA')),
#   (1, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')),
#   (1, ('CGTTCAAG', 'ATCCTAATCAGGTTTAATCAA')),
#   (1, ('CGGGAATG', 'CCCCCAAACCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CCATTACT', 'AAAAAAATCTAATTTAAAAAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')),
#   (1, ('ACAGAGCC', 'GGTGTAATTGTATTGCTACAA')),
#   (1, ('ACAGAGCC', 'GGTCAAAAGTTGTTTACTTAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('ACACGTGA', 'GGGGTAAATGTTTTGGTTTAA'))],
#  [(2, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TCCCTAAAATCCTTCCATCAA')),
#   (1, ('TTAATTAG', 'GGCGCAAGGTTGTTGGAGGAA')),
#   (1, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCTACGT', 'ATGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'TTCAGAAAATATTTTTAAAAA')),
#   (1, ('CGGGAATG', 'TTTTGAATTGTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')),
#   (1, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTACCCCAA'))],
#  [(3, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')),
#   (2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GGTAGGGA', 'TGTATAATGTGTTTATATCAA')),
#   (1, ('GGTAGGGA', 'TAGGAAATCTGGTTCTATGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'CCACCAACCCCCTTGTCCCAA')),
#   (1, ('CCATTACT', 'TATTTAAACGTTTTGTGTAAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CTCGCAATCGTCTTGCCCCAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')),
#   (1, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CGTATAATTTTTTTATGTGAA')),
#   (1, ('GGTAGGGA', 'TAGGAAATCTGGTTCTATGAA')),
#   (1, ('GGTAGGGA', 'AAAACAAATCACTTCAGCGAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CGTTCAAG', 'ATAACAACTGGGTTCCTTTAA')),
#   (1, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA'))],
#  [(1, ('TTAATTAG', 'GGCGGAATGATGTTGTGTTAA')),
#   (1, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')),
#   (1, ('TCTGGGGC', 'CGACCAAACAACTTCAAAAAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('CGTTTCCT', 'CCAGTAATTTAGTTTGTTTAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA'))],
#  [(1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  [(1, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')),
#   (1, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA'))],
#  [(3, ('TGTCTAGT', 'TCTTGAATTGTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'GGCGCAAGGTTGTTGGAGGAA')),
#   (1, ('CGTTAGGG', 'AGCAAAAACGTCTTAGGGCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGTTCAAG', 'AAAGCAACACCTTTCTGCGAA')),
#   (1, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA'))],
#  [(3, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCCCTTTTCCTTAA')),
#   (1, ('GTACTTGC', 'GTGGTAATCGACTTCTCACAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGGGAATG', 'GGAGAAATGATGTTAGGAGAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')),
#   (1, ('ACAGAGCC', 'ACTGGAAACCATTTGAATAAA')),
#   (1, ('ACACGTGA', 'CACCCAATTCTGTTCGCCCAA'))],
#  [(3, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))],
#  [(4, ('CGGGAATG', 'GTGGGAAGTGGTTTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TGTCGAAAAGCCTTCGCTGAA'))],
#  [(1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CGTTCAAG', 'TTCAGAAAATATTTTTAAAAA'))],
#  [(2, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGTTCAAG', 'TGTTTAATGCATTTTCTTGAA'))],
#  [(2, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('TTAATTAG', 'GGTGCAATGATGTTGCAAGAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACACAAACACCATTCTCCGAA')),
#   (1, ('CTGAATCT', 'AAAAAAAAAAGATTAATAGAA')),
#   (1, ('CGTTAGGG', 'AATACAATAGTGTTTTGTTAA')),
#   (1, ('CGGGAATG', 'TTTTGAATTGTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'TGGTTAAAGAGTTTTGGTAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACACGTGA', 'GGTGGAATGTGGTTGTGTGAA'))],
#  [(3, ('TGTCTAGT', 'GTTTTAATTTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))],
#  [(1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGTGGTTTGGGGGAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))],
#  [(2, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TGTCTAGT', 'GGGGTAATGTGGTTTGGGGAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGGGAATG', 'GGGAGAAGGGTGTTGGGGGAA')),
# ...
#   (1, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')),
#   (1, ('CGTTCAAG', 'TTCAGAAAATATTTTTAAAAA')),
#   (1, ('CGTTAGGG', 'GATGTAACTTTTTTAGTCCAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'CCGACAAAGTGATTGAAATAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('ACAGAGCC', 'AATGGAAGAAAGTTATAGTAA'))],
#  [(1, ('CCATTACT', 'AGGGAAAAGGAGTTAAAGAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')),
#   (1, ('GGTAGGGA', 'CAAATAACATACTTGGACAAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA'))],
#  [(1, ('TTAATTAG', 'CCGACAAAGTGATTGAAATAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))],
#  [(1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GGTAGGGA', 'TGTATAAAGTTATTACTAGAA')),
#   (1, ('GCCTACGT', 'TTCTGAAGGCGTTTTTTTTAA')),
#   (1, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')),
#   (1, ('CGTTCAAG', 'TAATTAACAGCATTGAATTAA')),
#   (1, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')),
#   (1, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('ACAGAGCC', 'ACTGGAAACCATTTGAATAAA'))],
#  [(1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGTTAGGG', 'AATACAATAGTGTTTTGTTAA')),
#   (1, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  {('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA'): 1},
#  [(3, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TGATTAATATTTTTCGATCAA')),
#   (1, ('TTAATTAG', 'GTTTTAATTTTTTTTTTTAAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CCATTACT', 'TATTTAAACGTTTTGTGTAAA')),
#   (1, ('ACAGAGCC', 'TATCCAAGTATCTTTGTTGAA'))],
#  [(2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))],
#  [(1, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'GATGTAAATTTCTTTGCTTAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA'))],
#  [(3, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TGGGGAAGAGGGTTAGAGGAA')),
#   (1, ('TGTCTAGT', 'GGTGGAAGGGAGTTGGAGAAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'GTGGTAATCGACTTCTCACAA')),
#   (1, ('GTACTTGC', 'GGTGGAAATATGTTCAATGAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')),
#   (1, ('CGTTAGGG', 'AGCAAAAACGTCTTAGGTCAA')),
#   (1, ('CGGGAATG', 'TTTTGAATTGTTTTGGGTGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('ACAGAGCC', 'CGCACAATAGGATTCAGAAAA')),
#   (1, ('ACACGTGA', 'GGTGGAATGTGGTTGTGTGAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTGTTAA')),
#   (1, ('TTAATTAG', 'TTTTAAATTATTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')),
#   (1, ('TTAATTAG', 'GGCGGAATGATGTTGTGTTAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))],
#  [(2, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('CGTTCAAG', 'TACACAAATTGGTTGTATGAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))],
#  [(2, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGTTAGGG', 'CATTTAATTTCGTTTTTGGAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACACGTGA', 'TTGTTAATTTTTTTGTTTGAA'))],
#  [(2, ('GGTAGGGA', 'AAATTAAAGCAATTCCAATAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CGTTAGGG', 'CATTTAATTTCGTTTTTGGAA')),
#   (1, ('CGGGAATG', 'AGATGAATACTGTTAAAGGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')),
#   (1, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')),
#   (1, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')),
#   (1, ('CGGGAATG', 'CTCTTAACACCTTTCTTTCAA'))],
#  [(3, ('TTAATTAG', 'AACAAAACCCAATTCCAACAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))],
#  [(2, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CGTTAGGG', 'GTAATAATGAGGTTATGCGAA')),
#   (1, ('CGGGAATG', 'TAATCAAGGAAGTTATAGAAA'))],
#  [(2, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')),
#   (1, ('CGGGAATG', 'CCCTCAATCGTTTTCTACCAA')),
#   (1, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('CCATTACT', 'ACGTTAATAGTATTACGTAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'TGAATAAATATCTTAAAATAA')),
#   (1, ('ACAGAGCC', 'GGGCCAAGTGCTTTCACACAA')),
#   (1, ('ACAGAGCC', 'ACTGGAAACCATTTGAATAAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGATTGGAGCAA'))],
#  [(1, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')),
#   (1, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))],
#  [(2, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGGGAATG', 'CTCTTAACACCTTTCTTTCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'GTGTTAATTAATTTGTCATAA')),
#   (1, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CCATTACT', 'TGGTTAAAGAGTTTTGGTAAA')),
#   (1, ('CCATTACT', 'TGGTGAAGGGAGTTGTGGTAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('CCATTACT', 'CCCCCAACCCGCTTTAACCAA')),
#   (1, ('CCATTACT', 'ACGTTAATAGTATTACGTAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(2, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')),
#   (1, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGGTTAGGAAAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GTACTTGC', 'GTGTTAATTAATTTGTCATAA')),
#   (1, ('GTACTTGC', 'GTGGTAATCGACTTCTCACAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('GCCAATCG', 'CACATAAGACCCTTCATTGAA')),
#   (1, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')),
#   (1, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')),
#   (1, ('CGTTCAAG', 'GAGGTAAACATGTTTTAGTAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGTGGTTTGGGGGAA')),
#   (1, ('CGGGAATG', 'GGGAGAAGGGTGTTGGGGGAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('CAGTGCAT', 'ATGTTAATCATGTTTGCTTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGATTGGAGCAA'))],
#  [(1, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGGGAATG', 'GTGGGAAGTGGTTTGGGGGAA')),
#   (1, ('CAGTGCAT', 'TCCAGAACTATTTTGATCTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TGTGGAATTTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TTAATTAG', 'CTTTAAATATTTTTCTTTCAA')),
#   (1, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')),
#   (1, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')),
#   (1, ('GGTAGGGA', 'TATAGAACAGGGTTAATGTAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGGGAATG', 'GGAGAAATGATGTTAGGAGAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))],
#  [(1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GTACTTGC', 'GTGTTAATTAATTTGTCATAA')),
#   (1, ('GGTAGGGA', 'CTGAAAAGATTGTTCTTTGAA')),
#   (1, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')),
#   (1, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTGTTAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TCTGGGGC', 'TTGTTAATTTTTTTTGGGTAA')),
#   (1, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(2, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TCTGGGGC', 'TTGTTAATTTTTTTTGGGTAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('CGGGAATG', 'CTCTTAACACCTTTCTTTCAA')),
#   (1, ('CCATTACT', 'AATGAAAAGAGGTTATAGTAA')),
#   (1, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')),
#   (1, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')),
#   (1, ('ACACGTGA', 'CACCCAATTCTGTTCGCCCAA'))],
#  [(2, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (2, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (2, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  [(1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')),
#   (1, ('GGTAGGGA', 'CCTACAAGTACATTTAGGTAA')),
#   (1, ('GGTAGGGA', 'AAAACAAATCACTTCAGCGAA')),
#   (1, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('ACAGAGCC', 'GAATAAAGATGCTTCGAAGAA')),
#   (1, ('ACAGAGCC', 'CTTTTAATCGGGTTTGTTCAA')),
#   (1, ('ACACGTGA', 'GGGGTAAATGTTTTGGTTTAA'))],
#  [(3, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('GTACTTGC', 'GCTTTAAATACATTTGGATAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))],
#  [(2, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'GCGGGAAGGGGGTTGGTGTAA')),
#   (1, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')),
#   (1, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')),
#   (1, ('CGTTAGGG', 'GATGTAACTTTTTTAGTCCAA'))],
#  [(1, ('TGTCTAGT', 'CGTATAATTTTTTTATGTGAA')),
#   (1, ('GTACTTGC', 'GTGTTAATTAATTTGTCATAA')),
#   (1, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))],
#  {('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'): 1},
#  [(1, ('GTACTTGC', 'GTGGGAAGGCAGTTGGATTAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGTTAGGG', 'GATGTAACTTTTTTAGTCCAA')),
#   (1, ('CGGGAATG', 'GGGAGAAGGGTGTTGGGGGAA')),
#   (1, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA'))],
#  [(1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TTAATTAG', 'GGGGAAAAGCGGTTGGGACAA')),
#   (1, ('TTAATTAG', 'GGCAGAAGATAGTTATAACAA')),
#   (1, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')),
#   (1, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('TTAATTAG', 'GGAGGAATGAGGTTAGGAAAA')),
#   (1, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')),
#   (1, ('TGTCTAGT', 'CATCGAAGGACCTTACGATAA')),
#   (1, ('GGTAGGGA', 'GGCACAACTTTGTTATTAAAA')),
#   (1, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')),
#   (1, ('CGTTAGGG', 'GATGTAACTTTTTTAGTCCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))],
#  [(1, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')),
#   (1, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')),
#   (1, ('CGGGAATG', 'TCTTTAATTATTTTTTGGGAA')),
#   (1, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA'))],
#  [(1, ('TGTCTAGT', 'ATTACAACTGGTTTGTTGTAA')),
#   (1, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGGGAATG', 'TTTTTAAGGGTTTTTGGTGAA')),
#   (1, ('CCATTACT', 'TGGTTAAAGAGTTTTGGTAAA')),
#   (1, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))],
#  {('ACACGTGA', 'TGGTTAAGGATTTTGGTTGAA'): 1},
#  [(1, ('TTAATTAG', 'TTTTCAATGTTTTTATTTTAA')),
#   (1, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')),
#   (1, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))],
#  [(1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')),
#   (1, ('CTGAATCT', 'CCACCAACCCCCTTGTCCCAA')),
#   (1, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')),
#   (1, ('CGGGAATG', 'CTCTTAACACCTTTCTTTCAA')),
#   (1, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('ACAGAGCC', 'GAATAAAGATGCTTCGAAGAA'))],
#  [(3, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (2, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')),
#   (1, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (1, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')),
#   (1, ('GGTAGGGA', 'GTGTAAATAAGATTTTAGGAA')),
#   (1, ('GCCAATCG', 'ATATTAAATTTTTTGCTGCAA')),
#   (1, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')),
#   (1, ('CGGGAATG', 'TTTTGAATTGTTTTGGGTGAA')),
#   (1, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA'))],
#  [(1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')),
#   (1, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')),
#   (1, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')),
#   (1, ('ACAGAGCC', 'TCGCGAATTTTTTTTAATGAA')),
#   (1, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))],
#  [(2, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')),
#   (2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TTAATTAG', 'TGGGGAAGAGGGTTAGAGGAA')),
#   (1, ('TTAATTAG', 'TGATTAATATTTTTCGATCAA')),
#   (1, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')),
#   (1, ('TGTCTAGT', 'GGGGTAATGTGGTTTGGGGAA')),
#   (1, ('GGTAGGGA', 'TGTATAAAGTTATTACTAGAA')),
#   (1, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')),
#   (1, ('CTGAATCT', 'TTGTAAATGTTTTTCTTTGAA')),
#   (1, ('CCATTACT', 'AAAAAAATCTAATTTAAAAAA'))],
#  [(2, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')),
#   (1, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')),
#   (1, ('CGTTTCCT', 'CCAGTAATTTAGTTTGTTTAA'))],
#  ...]

# %%
#calculate average hammandDistance
hdist = []
for x in poorUMI:
    if len(x) == 1:
#        hdist.append(0)
        continue
    y = [(z[1][0], z[1][1]) for z in x]
    pUMI = {}
    for z in y:
        if z[0] not in pUMI:
            pUMI[z[0]] = [z[1]]
        else:
            pUMI[z[0]].append(z[1])
    for y in pUMI:
        if len(pUMI[y]) < 2:
            continue
        for i in range(0, len(pUMI[y])):
            for j in range(i+1, len(pUMI[y])):
                hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
                if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
                    print(pUMI[y])
                    print(pUMI[y][i], pUMI[y][j])

# %%
_ = plt.hist(hdist, bins='auto', histtype='step')

plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %%
validshRNANameHash = {}
for x in assignedCellshRNA:
    validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %%
len(assignedCellbarcode)
# Out:
# 1960

# %%
import pandas as pd
pUMI = {}
for x in poorUMI2:
    pUMI[x] = 1
cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
cellhashobj.to_pickle('pUMIcDNA.pickle')

# %%
import pandas as pd
  
cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
cellhashobj.to_pickle('shRNAcDNA.pickle')

cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
cellhashobj.rename(columns={0: "barcode"}, inplace=True)
cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
