# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7114

# %%
afile = pysam.AlignmentFile("./final_0.9.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
_
# Out:
# (array([6.875608e+06, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([0.00000000e+00, 1.59574665e-02, 3.19149330e-02, ...,
#         1.62606583e+01, 1.62766158e+01, 1.62925733e+01]),
#  [<matplotlib.patches.Polygon at 0x3348986d0>])

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 4:
        count = x
        break

# %%
count
# Out:
# 220

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 16

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
  
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
        else:
            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1 and list(UMIpairs.values())[0] >= 5:
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort()
    newUMI.reverse()
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if newUMI[0][0] < 5: continue
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('TTAATTAG', 'TTTTCAATGTTTTTATTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (27, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (27, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (26, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (28, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (33, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (33, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (33, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(33, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTAAATTATTTTCTTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (27, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('GTACTTGC', 'GTGGGAATCGACTTCTCACAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(33, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('ACACGTGA', 'TTTTTAATTTTTTTTGTCGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(23, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(24, ('CGTTAGGG', 'GAAGGAATCAAATTTAACAAA')), (21, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACACCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(30, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CTGAATCT', 'CCACCAACCAACTTCGCCCAA'))]
# [(20, ('CGTTCAAG', 'TATCGAACTCTATTCAAGTAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(26, ('CTGAATCT', 'TTGCGAACGGGGTTGTGGTAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(47, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (37, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('CGTTAGGG', 'GCGGCAAATGGATTTGCTAAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'GTGGGAATTTCATTGGAGGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA'))]
# [(30, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(23, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TCTGGGGC', 'GCCCCAACCCCCTTCATCTAA'))]
# [(34, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('ACACGTGA', 'GGTGGAATGTGGTTGTGTGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TTAATTAG', 'GGATTAATTTTTTTTCTTTAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(37, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA')), (35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('GGTAGGGA', 'GGCACAACTTTGTTATTAAAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCTAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGAAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA'))]
# [(28, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(38, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CCATTACT', 'CTCGCAATCGTCTTGCCCCAA')), (28, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('GGTAGGGA', 'GAGGAAATTTACTTAGTCTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('GGTAGGGA', 'GAGGAAATTTACTTAGTCTAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(19, ('CGGGAATG', 'GTATGAAAGCCTTTTTTGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(23, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGAAGTTGGGGGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('GGTAGGGA', 'GTTATAAAAACATTAGGTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('ACACGTGA', 'GATTCAAGGTACTTGAGACAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('ACACGTGA', 'GATTCAAGGTCCTTGAGACAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CGTTCAAG', 'GATGTAAATTTCTTTGCTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(31, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTATAA'))]
# [(25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA'))]
# [(21, ('TTAATTAG', 'TTTTAAATATATTTCTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTCGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (27, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (23, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))]
# [(31, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATCTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTACCCCAA')), (18, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TTAATTAG', 'TTTTTAATTATTTTATTTTAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(17, ('GCCTACGT', 'GCGTCAATTTGCTTGATTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('GCCTACGT', 'GCGTCAATTTGCTTGATTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(19, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(37, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGATTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(42, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (40, ('CGTTCAAG', 'GTACGAAGGCTTTTCGGGTAA')), (31, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(36, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))]
# [(20, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'AAAACAACGAAATTACAAAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(36, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTCTTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAAACTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATATTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(36, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (33, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('GCCTACGT', 'GGGGGAAGGGGGTTGTGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTTGTATAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(33, ('TTAATTAG', 'TGGTAAATTATTTTATTTTAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(19, ('TTAATTAG', 'CTTTCAATCATTTTATTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('TTAATTAG', 'CTTTCAATCATTTTATTTTAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAATTGGTTTTGTTCAA'))]
# [(19, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CGGGAATG', 'TTCTCAACGCCTTTTTCACAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('ACACGTGA', 'CTTTTAATTTTTTTCTTCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TTAATTAG', 'TCCCTAAAATCCTTCCATCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (33, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (33, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (26, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (25, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('ACAGAGCC', 'ACGATAATCAGTTTTACTAAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(21, ('ACAGAGCC', 'ACGATAATGAGTTTTACTAAA')), (21, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (19, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GTGTTAACGGGTTTGGTGGAA'))]
# [(30, ('CGTTCAAG', 'GCAGCAATTTTCTTGAGAGAA')), (22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('ACACGTGA', 'CAAAAAAAAATCTTGTAAAAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('GGTAGGGA', 'GTTTGAATGATCTTAGGAGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('ACAGAGCC', 'GGTGAAACACCGTTAGGTGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('ACAGAGCC', 'GGTGAAACACCGTTAGGTGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(28, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA'))]
# [(32, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(42, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(39, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('GCCTACGT', 'TTCTGAAGGCGTTTTTATTAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCTACGT', 'TTCTGAAGGCGTTTTTTTTAA'))]
# [(20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCTACGT', 'TTCTGAAGGCGTTTTTTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('ACAGAGCC', 'GGTCAAAAGTTGTTTACTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(43, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (42, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(32, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTCATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'TTTTTAACTTTTTTTGTTTAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(21, ('ACACGTGA', 'TGGTTAATTTTTTTTTTTAAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACACGTGA', 'TGGTTAATTTTTTTTTTTTAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GGTAGGGA', 'TGTATAAGGTTATTACTAGAA')), (22, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GGTAGGGA', 'TGTATAAAGTTATTACTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CGGGAATG', 'CTCTTAACACCTTTATATCAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('ACAGAGCC', 'GCTTTAATGTTGTTATTAAAA')), (18, ('ACAGAGCC', 'GCTTGAATTTTGTTATGAAAA'))]
# [(24, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(26, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(33, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TTAATTAG', 'AAGAAAAACGAATTAAAGAAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(32, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (28, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(32, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# /Users/chanj2/opt/miniconda3/envs/scanalysis202208/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:86: RuntimeWarning: divide by zero encountered in _binom_sf
#   return _boost._binom_sf(k, n, p)
# [(21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA'))]
# [(29, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CGTTAGGG', 'GTAATAATGAGGTTATGCGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(31, ('ACACGTGA', 'GGGGTAAATGTTTTGGTTTAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CCATTACT', 'AATGAAAATAGGTTATAGTAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TTAATTAG', 'GTTTTAATTTTTTTTTTTAAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(23, ('CGGGAATG', 'CCCTCAATCGTTTTCTACCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))]
# [(17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'AGAAGAACTAGATTGCCACAA'))]
# [(30, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CGGGAATG', 'TTTGCAAGCACTTTTGTGTAA')), (26, ('CAGTGCAT', 'GTGGAAATTTGATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA'))]
# [(20, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CGTTTCCT', 'AGAGAAAATAAGTTGTTCGAA')), (23, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(39, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATATTATTGGTAGAA'))]
# [(28, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGTTAGGG', 'AATACAATAGTGTTTTGTTAA'))]
# [(21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CTGAATCT', 'TTTTTAATTGAGTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(24, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(18, ('TTAATTAG', 'GGGGAAAAGCGGTTGGGACAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(30, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TCTGGGGC', 'TTTTGAATTATTTTTTTGTAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TCTGGGGC', 'TTTTGAATATTTTTTTTTTAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (20, ('TTAATTAG', 'TTTGTAATTAATTTTTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# ...
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(31, ('CGGGAATG', 'GTCTGAAAGCCTTTTTTGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(25, ('TTAATTAG', 'AACAAAATACAATTCCAAAAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CGTTAGGG', 'TCAGCAATCATTTTCGCTCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('CGTTAGGG', 'TCAGCAATCATTTTCGCTCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(36, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'CGTATAATTTTGTTATGTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAATAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(33, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(33, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('ACAGAGCC', 'AATGGAAGAAAGTTATAGTAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CGTTCAAG', 'TAAGAAATACAGTTACTGTAA'))]
# [(19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGAAGTTGGGGGAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (26, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(35, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(18, ('TTAATTAG', 'AACATAAACCCATTCCCAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CCATTACT', 'CCCCCAACCACCTTCCGCCAA'))]
# [(32, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(34, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (30, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (27, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(25, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (20, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(25, ('TTAATTAG', 'TCCCTAATACTTTTCTCTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('ACAGAGCC', 'ATATAAAGGATATTAGTACAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# is zero
# [(32, ('CGTTAGGG', 'CAGATAAGAGTGTTGTTTCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# is zero
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# is zero
# [(25, ('TGTCTAGT', 'CCCCCAAACCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACTTAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# is zero

# %%
print(sum(histogram_of_UMIs))
# Out:
# 70807

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# #plt.axvline()
# plt.show()

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# plt.axvline(x=cutoff2)
# plt.show()

# %% [raw]
# cutoff2 = 2**cutoff2
# print(cutoff2)

# %% [raw]
# ## counting total UMIs from dominant shRNA
# assignedCellshRNA = {}
# assignedCellbarcode = {}
# poorUMI = []
# poorUMI2 = []
# count = []
# threshold = cutoff
#
# for x in cellbyUMI:
#     ncellbyUMI = {}
#     for y in cellbyUMI[x]:
#         UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
#         UMIpairs.sort(reverse=True)
#         newUMI = []
#         while len(UMIpairs) != 0:
#             shRNAIDbarcodepair = UMIpairs.pop(0) #
#             toDelete = []
#             for z in range(0, len(UMIpairs)):
#                 if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
#                 if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
#                     toDelete.append(z)
#                     shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
#             newUMI.append(shRNAIDbarcodepair)
#             for z in sorted(toDelete, reverse = True):
#                 del UMIpairs[z]
#
#         if len(newUMI) == 1:
#         # uncomment here if we don't want to ignore single counts
#             if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
#             continue
#
#         # Shouldn't happen anymore with the cleaned up version
#         newUMI.sort(reverse=True)
#         if newUMI[0][0] < threshold: continue
#
#         totalUMI = sum([z[0] for z in newUMI])
#         if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
#             ncellbyUMI[y] = newUMI[0][1]
#         else:
#             print("multiple: %s" % str(newUMI))
#         #### end
#
#     UMIpairs = {}
#
#     if len(ncellbyUMI) == 0:
#         print("is zero")
#         continue
#
# #    if len(ncellbyUMI) == 1:
# #        continue
#         # uncomment here if we don't want to ignore UMIs assigned by single counts
#         #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
#         #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
#         #count.append(1)
#
#         #adding single UMIs to poorUMI list instead of assigning label
# #        poorUMI.append([(1,ncellbyUMI)])
# #        poorUMI2.append(x)
# #        continue
#
#     for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
#         if ncellbyUMI[y] in UMIpairs:
#             UMIpairs[ncellbyUMI[y]] += 1
#         else:
#             hamming=False
#             for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
#                 if z[0] != ncellbyUMI[y][0]: continue
#                 if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
#                     UMIpairs[z] += 1
#                     hamming=True
#                     break
#             if hamming: continue
#             UMIpairs[ncellbyUMI[y]] = 1
#
# #    if len(UMIpairs) == 0:
# #        print("UMIPairs")
# #        print(ncellbyUMI)
# #        print(cellbyUMI[x])
# #        print("error this shoudl not happen")
# #        continue
#
#     if len(UMIpairs) == 1:
#         if list(UMIpairs.values())[0] < cutoff2:
#             #print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
#             continue
#         assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
#         assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
#         count.append(list(UMIpairs.values())[0])
#         continue
#
#     newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
#     newUMI.sort(reverse=True)
#     if newUMI[0][0] < cutoff2: continue
#
#     totalUMI = sum([y[0] for y in newUMI])
#     count.extend([z[0] for z in newUMI])
#
#     if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
#         assignedCellshRNA[x] = newUMI[0][1][0]
#         assignedCellbarcode[x] = newUMI[0][1][1]
#         continue
#     else:
#         set_trace()
#     poorUMI.append(newUMI)
#     poorUMI2.append(x)

# %% [raw]
# import statistics
# sum(count)/len(count), min(count), max(count), statistics.median(count)

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(count), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# plt.show()

# %% [raw]
# len(assignedCellshRNA)

# %% [raw]
# len(whitelist)

# %% [raw]
# #count.sort()
# #count

# %% [raw]
# len(poorUMI)

# %% [raw]
# poorUMI

# %% [raw]
# #calculate average hammandDistance
# hdist = []
# for x in poorUMI:
#     if len(x) == 1:
# #        hdist.append(0)
#         continue
#     y = [(z[1][0], z[1][1]) for z in x]
#     pUMI = {}
#     for z in y:
#         if z[0] not in pUMI:
#             pUMI[z[0]] = [z[1]]
#         else:
#             pUMI[z[0]].append(z[1])
#     for y in pUMI:
#         if len(pUMI[y]) < 2:
#             continue
#         for i in range(0, len(pUMI[y])):
#             for j in range(i+1, len(pUMI[y])):
#                 hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
#                 if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
#                     print(pUMI[y])
#                     print(pUMI[y][i], pUMI[y][j])

# %% [raw]
# _ = plt.hist(hdist, bins='auto', histtype='step')
#
# plt.ylabel("Counts")
# plt.show()

# %% [raw]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %% [raw]
# validshRNANameHash = {}
# for x in assignedCellshRNA:
#     validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %% [raw]
# len(assignedCellbarcode)

# %% [raw]
# import pandas as pd
# pUMI = {}
# for x in poorUMI2:
#     pUMI[x] = 1
# cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
# cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
# cellhashobj.to_pickle('pUMIcDNA.pickle')

# %% [raw]
# import pandas as pd
#
# cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
# cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
# cellhashobj.to_pickle('shRNAcDNA.pickle')
#
# cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
# cellhashobj.rename(columns={0: "barcode"}, inplace=True)
# cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
