# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7114

# %%
afile = pysam.AlignmentFile("./final_0.4.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
_
# Out:
# (array([5.496752e+06, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([0.00000000e+00, 1.43898357e-02, 2.87796713e-02, ...,
#         1.50949376e+01, 1.51093274e+01, 1.51237173e+01]),
#  [<matplotlib.patches.Polygon at 0x2e4c00880>])

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 4:
        count = x
        break

# %%
count
# Out:
# 244

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 16

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
  
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
        else:
            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1 and list(UMIpairs.values())[0] >= 5:
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort()
    newUMI.reverse()
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if newUMI[0][0] < 5: continue
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# [(19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(31, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(27, ('CGTTCAAG', 'CCTGTAAGTCAATTATTGCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('TGTCTAGT', 'GTGGGAATTTCTTTGGAGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CCATTACT', 'ACGTTAATAGTATTACGTAAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CGGGAATG', 'CACACAAGAAGATTAAAAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(24, ('TGTCTAGT', 'GTGTTAATTGTGTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGAAGAA')), (27, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (22, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(29, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(24, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(26, ('CGTTAGGG', 'AGACCAAAGCTTTTACGTCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('GCCTACGT', 'AGGCGAACTGCGTTGGGAAAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(20, ('CTGAATCT', 'ACAAAAAAATAATTTAAAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CTGAATCT', 'ACAAAAAAATAATTTAAAAAA'))]
# [(28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('ACAGAGCC', 'TACGCAATCGAGTTTACCTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('ACAGAGCC', 'ACGATAATGAGTTTTACGAAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (22, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CGTTCAAG', 'CTTCCAATCCTATTTTGTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTTAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(20, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'GTTGTAATGTTTTTGGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGTTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(21, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(22, ('GCCTACGT', 'AGGTGAACTGTGTTGGGAAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('GGTAGGGA', 'TGGGCAATATATTTGTCGTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(24, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TTAATTAG', 'GGAGCAATTATGTTGTGAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('ACAGAGCC', 'CTTTTAATCGGGTTTGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('ACAGAGCC', 'ATCAGAATAATTTTGCATAAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(34, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('ACAGAGCC', 'GTCTGAAATACGTTGCATGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('GGTAGGGA', 'TATTAAAATCACTTTTTTAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('GTACTTGC', 'GTGGGAAGGCAGTTGGCTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(26, ('CAGTGCAT', 'GTGAAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (35, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (31, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('GGTAGGGA', 'TGTCGAAAAGCCTTCGCTGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACACGTGA', 'CCCCCAATGCCATTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(53, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (40, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TTAATTAG', 'GACGGAAGAGGGTTAAAATAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CGGGAATG', 'AAGGAAAGAAAATTAGGCAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(34, ('TGTCTAGT', 'GAAGGAAGAGAGTTAGAAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(22, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('TGTCTAGT', 'CCACCAACCCCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('GGTAGGGA', 'AGAGAAAAGTGTTTGCTTAAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(31, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(33, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('ACAGAGCC', 'GGTGTAATTGTATTGCTACAA')), (22, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(39, ('TTAATTAG', 'TGAGGAAACCAATTAAAACAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CGGGAATG', 'TTCTCAATTCTTTTCTTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'TAACAAAAACAATTAATAAAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(32, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGAAGTTGGGGGAA'))]
# [(24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CGTTAGGG', 'GATGTAACTTTTTTAGTCCAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CGTTCAAG', 'TTCCGAAAATATTTTTAAAAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(25, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('TTAATTAG', 'GGCAGAAGATCGTTATAACAA')), (17, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TTAATTAG', 'ATGATAATTTGTTTTTTGTAA'))]
# [(31, ('GGTAGGGA', 'ACAGTAAACTACTTGTGAAAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(30, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TTAATTAG', 'GGTTTAATGATGTTTTGATAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('ACACGTGA', 'GGGGGAAAGGGATTGTGTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA'))]
# [(22, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACACGTGA', 'CAAAAAAAAATCTTGTAAAAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CGTTAGGG', 'CATTTAATTTCGTTTTTGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TCTGGGGC', 'TTTTGAATTTTTTTTTTGTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'GGATGAACAAGGTTAGACTAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('TGTCTAGT', 'CACCCAACTCCATTTCATCAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('ACAGAGCC', 'TTAAAAACGTCATTTTTGAAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TTAATTAG', 'TGGTAAATTATTTTATTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (33, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(19, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(34, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('CGGGAATG', 'CCCCCAAACCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(28, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (24, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (22, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(37, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(30, ('GGTAGGGA', 'CTGAAAAGATTGTTCTTTGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CTCCCAACCCCCTTCCTCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('TGTCTAGT', 'TATTTAATATCTTTTGTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('GGTAGGGA', 'CTGAAAAGATTGTTCTTTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('CGGGAATG', 'TTTTTAAGGGTTTTTGGTGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CGGGAATG', 'TTTTTAAGGGTTTTTGGTGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(28, ('ACAGAGCC', 'TGAATAAATATCTTAAAATAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (22, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(32, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACAAAAGAACCTTCAATGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCCTTTGTTTAA')), (19, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(33, ('CGTTTCCT', 'CCAGTAATTTAGTTTGTTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CTGAATCT', 'TTTCAAATTTTGTTTTTTGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# ...
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CGGGAATG', 'CCCCCAATGCCCTTTGCCAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGTTCAAG', 'TGTTTAATGCATTTTCTTGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('ACAGAGCC', 'CGCACAATAGGATTCTGAAAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(34, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (24, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (36, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTTAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGATTGGAGCAA')), (18, ('CGTTCAAG', 'TATTCAAATATCTTGGTATAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(23, ('ACACGTGA', 'CCCCCAACCCCATTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTACCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (29, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (18, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# is zero
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (18, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (25, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (22, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (21, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('GTACTTGC', 'ATCTAAACGTGCTTTAATGAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(22, ('TTAATTAG', 'AACATAAACCCATTCCCAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(29, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (22, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# is zero
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# is zero
# [(25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# is zero
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# is zero
# [(22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# is zero
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(17, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# is zero
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGTTAGGG', 'CAGATAAGAGTGTTGTTTCAA'))]
# is zero
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# is zero
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGATAGAA')), (25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CCATTACT', 'CCTGCAAATAGTTTATGTTAA'))]
# [(30, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(32, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# is zero
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# is zero
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# is zero

# %%
print(sum(histogram_of_UMIs))
# Out:
# 59021

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# #plt.axvline()
# plt.show()

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# plt.axvline(x=cutoff2)
# plt.show()

# %% [raw]
# cutoff2 = 2**cutoff2
# print(cutoff2)

# %% [raw]
# ## counting total UMIs from dominant shRNA
# assignedCellshRNA = {}
# assignedCellbarcode = {}
# poorUMI = []
# poorUMI2 = []
# count = []
# threshold = cutoff
#
# for x in cellbyUMI:
#     ncellbyUMI = {}
#     for y in cellbyUMI[x]:
#         UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
#         UMIpairs.sort(reverse=True)
#         newUMI = []
#         while len(UMIpairs) != 0:
#             shRNAIDbarcodepair = UMIpairs.pop(0) #
#             toDelete = []
#             for z in range(0, len(UMIpairs)):
#                 if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
#                 if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
#                     toDelete.append(z)
#                     shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
#             newUMI.append(shRNAIDbarcodepair)
#             for z in sorted(toDelete, reverse = True):
#                 del UMIpairs[z]
#
#         if len(newUMI) == 1:
#         # uncomment here if we don't want to ignore single counts
#             if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
#             continue
#
#         # Shouldn't happen anymore with the cleaned up version
#         newUMI.sort(reverse=True)
#         if newUMI[0][0] < threshold: continue
#
#         totalUMI = sum([z[0] for z in newUMI])
#         if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
#             ncellbyUMI[y] = newUMI[0][1]
#         else:
#             print("multiple: %s" % str(newUMI))
#         #### end
#
#     UMIpairs = {}
#
#     if len(ncellbyUMI) == 0:
#         print("is zero")
#         continue
#
# #    if len(ncellbyUMI) == 1:
# #        continue
#         # uncomment here if we don't want to ignore UMIs assigned by single counts
#         #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
#         #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
#         #count.append(1)
#
#         #adding single UMIs to poorUMI list instead of assigning label
# #        poorUMI.append([(1,ncellbyUMI)])
# #        poorUMI2.append(x)
# #        continue
#
#     for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
#         if ncellbyUMI[y] in UMIpairs:
#             UMIpairs[ncellbyUMI[y]] += 1
#         else:
#             hamming=False
#             for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
#                 if z[0] != ncellbyUMI[y][0]: continue
#                 if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
#                     UMIpairs[z] += 1
#                     hamming=True
#                     break
#             if hamming: continue
#             UMIpairs[ncellbyUMI[y]] = 1
#
# #    if len(UMIpairs) == 0:
# #        print("UMIPairs")
# #        print(ncellbyUMI)
# #        print(cellbyUMI[x])
# #        print("error this shoudl not happen")
# #        continue
#
#     if len(UMIpairs) == 1:
#         if list(UMIpairs.values())[0] < cutoff2:
#             #print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
#             continue
#         assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
#         assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
#         count.append(list(UMIpairs.values())[0])
#         continue
#
#     newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
#     newUMI.sort(reverse=True)
#     if newUMI[0][0] < cutoff2: continue
#
#     totalUMI = sum([y[0] for y in newUMI])
#     count.extend([z[0] for z in newUMI])
#
#     if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
#         assignedCellshRNA[x] = newUMI[0][1][0]
#         assignedCellbarcode[x] = newUMI[0][1][1]
#         continue
#     else:
#         set_trace()
#     poorUMI.append(newUMI)
#     poorUMI2.append(x)

# %% [raw]
# import statistics
# sum(count)/len(count), min(count), max(count), statistics.median(count)

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(count), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# plt.show()

# %% [raw]
# len(assignedCellshRNA)

# %% [raw]
# len(whitelist)

# %% [raw]
# #count.sort()
# #count

# %% [raw]
# len(poorUMI)

# %% [raw]
# poorUMI

# %% [raw]
# #calculate average hammandDistance
# hdist = []
# for x in poorUMI:
#     if len(x) == 1:
# #        hdist.append(0)
#         continue
#     y = [(z[1][0], z[1][1]) for z in x]
#     pUMI = {}
#     for z in y:
#         if z[0] not in pUMI:
#             pUMI[z[0]] = [z[1]]
#         else:
#             pUMI[z[0]].append(z[1])
#     for y in pUMI:
#         if len(pUMI[y]) < 2:
#             continue
#         for i in range(0, len(pUMI[y])):
#             for j in range(i+1, len(pUMI[y])):
#                 hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
#                 if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
#                     print(pUMI[y])
#                     print(pUMI[y][i], pUMI[y][j])

# %% [raw]
# _ = plt.hist(hdist, bins='auto', histtype='step')
#
# plt.ylabel("Counts")
# plt.show()

# %% [raw]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %% [raw]
# validshRNANameHash = {}
# for x in assignedCellshRNA:
#     validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %% [raw]
# len(assignedCellbarcode)

# %% [raw]
# import pandas as pd
# pUMI = {}
# for x in poorUMI2:
#     pUMI[x] = 1
# cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
# cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
# cellhashobj.to_pickle('pUMIcDNA.pickle')

# %% [raw]
# import pandas as pd
#
# cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
# cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
# cellhashobj.to_pickle('shRNAcDNA.pickle')
#
# cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
# cellhashobj.rename(columns={0: "barcode"}, inplace=True)
# cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
