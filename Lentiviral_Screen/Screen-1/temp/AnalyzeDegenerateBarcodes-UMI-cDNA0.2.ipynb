# %% [markdown]
# ## Analyze degenerate barcodes
# 20221006 - Meant to be run after processing of unmapped reads (generated by CellRanger) using Picard / Samtools

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pysam
import scipy.stats

from Bio import SeqIO

np.random.seed(5)

# %%
hashes = {}
import csv
with open('barcodes.csv') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    #first column forward, second column reverse complement
    for row in csvreader:
        if row[0].startswith("#"): continue
        hashes[row[0]] = row[2]

# %%
hashes
# Out:
# {'TGTCTAGT': 'shRenilla-1',
#  'CTGAATCT': 'Myc (63)',
#  'TTAATTAG': 'Onecut2 (76)',
#  'CGGGAATG': 'Fosl2 (60)',
#  'GCCTACGT': 'Fhl2 (61)',
#  'GCCAATCG': 'Itga2 (1811)',
#  'CGTTTCCT': 'Cldn4 (1999)',
#  'ACACGTGA': 'Lif (2114)',
#  'CAGTGCAT': 'Nfkb1 (2118)',
#  'CGTTAGGG': 'Yap1 (65)',
#  'CGTTCAAG': 'Nfkb2 (71)',
#  'GGTAGGGA': 'Fosl1 (2115)',
#  'ACAGAGCC': 'Relb (73) ',
#  'GTACTTGC': 'patch4.4-1',
#  'CCATTACT': 'patch4.4-2',
#  'CATAGTCA': 'shRenilla-2',
#  'TCTGGGGC': 'Atf4 (67)'}

# %%
#hashes = {"TGTCTAGT": "shRenilla", "CTGAATCT": "shMyc(63)", "TTAATTAG": "shOnecut2(76)"}
hashmatch = re.compile('GT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AA') #forward
#hashmatch = re.compile('TT[ATCG]{5}AA[ATCG]{5}TT[ATCG]{5}AC') #reverse complement

# %%
def hammingDistance(a, b):
    return sum(str1 != str2 for str1, str2 in zip(a, b))

# %%
#Changed this to actual experimental whitelist
import pickle
whitelist = set()
#open whitelist
with open('../write/cellwhitelist0.pickle', 'rb') as f:
    whitelist = pickle.load(f)

# %%
print(len(whitelist))
# Out:
# 7114

# %%
afile = pysam.AlignmentFile("./final_0.2.bam")
hashcount = {}
hashset = {}
cellhash = {}
taghash = {}
readcount = {}
barcodehash = {} # barcodes listing shRNAID
barcodebycellUMI = {} # barcode listing cellUMI
doublecounts = 0
cellbyUMI = {}
inwhitelist = set()
inwhitelistcount = 0
outwhitelist = set()
outwhitelistcount = 0
for seq_record in afile.fetch(until_eof=True):
    cellUMI = None  # here this is the CellRanger cell UMI
    UMI = None
    if not seq_record.has_tag("CB") or not seq_record.has_tag("UB"): continue
    cellUMI = seq_record.get_tag("CB")
    if cellUMI not in whitelist: 
        outwhitelistcount +=1
        if cellUMI not in outwhitelist: outwhitelist.add(cellUMI)
        continue
    else:
        inwhitelistcount += 1
        if cellUMI not in inwhitelist: inwhitelist.add(cellUMI)
    UMI = seq_record.get_tag("UB") # umi barcode
    
    m = hashmatch.search(seq_record.query_sequence)
    if m == None or (m.end() + 8) > len(seq_record.query_sequence):
        #print("Error, match not found")
        continue
    shRNAID = seq_record.query_sequence[m.end():m.end()+8]
    barcode = seq_record.query_sequence[m.end()-21:m.end()]
    sbID = (shRNAID,barcode)
    if shRNAID not in hashes: continue
    if cellUMI not in cellbyUMI:
        cellbyUMI[cellUMI] = {}
    if UMI not in cellbyUMI[cellUMI]:
        cellbyUMI[cellUMI][UMI] = {sbID: 1}
        continue
    if sbID in cellbyUMI[cellUMI][UMI]:
        cellbyUMI[cellUMI][UMI][sbID] += 1
    else:
        hamming = False
        for x in cellbyUMI[cellUMI][UMI]:
            if hammingDistance(sbID[1],x[1]) <= 2:
                cellbyUMI[cellUMI][UMI][x] += 1
                hamming = True
                break
        if hamming: continue
        cellbyUMI[cellUMI][UMI][sbID] = 1

# %% [raw]
# totalUMI = 0
# for cellUMI in cellbyUMI:
#     totalUMI += len(cellbyUMI[cellUMI])
# print(totalUMI)

# %% [raw]
# print("In Whitelist UMI: %d\nOut Whitelist UMI: %d" % (len(inwhitelist), len(outwhitelist)))
# print("In Whitelist Reads: %d\nOut Whitelist Reads: %d" % (inwhitelistcount, outwhitelistcount))

# %% [raw]
# import pickle
# with open('cellbyUMI.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(cellbyUMI, f, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# import pickle
# cellbyUMI = False
# with open('cellbyUMI.pickle', 'rb') as f:
#     cellbyUMI = pickle.load(f)

# %% [markdown]
# ## IGNORE THIS

# %% [raw]
# counts = []
# for x in cellbyUMI:
#     for y in cellbyUMI[x]:
#         counts.append(len(set(cellbyUMI[x][y]['barcode'])))
# #        if len(set(cellbyUMI[x][y]['shRNA'])) != 1:
# #            print("%s, %s, %s\n" % (x,y,cellbyUMI[x][y]['shRNA']))

# %% [raw]
# print("Single %f, Double %f, Triple %f" % (len([x for x in counts if x == 1])/len(counts), len([x for x in counts if x == 2])/len(counts), len([x for x in counts if x == 3])/len(counts)))

# %% [raw]
# # should only be shRNA per UMI
# print("By Barcode/UMI Pair")
# _ = plt.hist(counts, bins='auto')
# plt.ylabel("Count")
# plt.title("# Barcode / UMI Cell Pair")
# plt.show()

# %% [markdown]
# ## END IGNORE

# %%
from IPython.core.debugger import set_trace

# %%
# first pass generate histogram of counts
histogram_of_counts = []
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
#cutoff = _[1][1]
#plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
_
# Out:
# (array([4.304507e+06, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([0.00000000e+00, 1.03149224e-02, 2.06298448e-02, ...,
#         1.41004989e+01, 1.41108138e+01, 1.41211288e+01]),
#  [<matplotlib.patches.Polygon at 0x2af2605e0>])

# %%
count = 0
for x in range(0,len(_[1])):
    if x == 0: continue
    if round(_[1][x]) >= 4:
        count = x
        break

# %%
count
# Out:
# 340

# %%
# should only be shRNA per UMI
print("By UMI/Cell")
_ = plt.hist(np.log2(histogram_of_counts), bins='auto', histtype='step')
plt.ylabel("Count")
plt.title("# Reads for each UMIs")
cutoff = round(_[1][count])
plt.axvline(x=cutoff)
plt.show()
# Out:
# By UMI/Cell

# %%
cutoff = 2**(round(cutoff))
print(cutoff)
# Out:
# 16

# %%
# Cleanup, prune any reads that don't pass the cutoff
for UMI in cellbyUMI:
    for y in cellbyUMI[UMI]:
        toRemove = []
        for z in cellbyUMI[UMI][y]:
            if cellbyUMI[UMI][y][z] <= cutoff: toRemove.append(z)
        for z in toRemove:
            del cellbyUMI[UMI][y][z]
    toRemove = []
    for y in cellbyUMI[UMI]:
        if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
    for y in toRemove:
        del cellbyUMI[UMI][y]
toRemove = []
for UMI in cellbyUMI:
    if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
for UMI in toRemove:
    del cellbyUMI[UMI]

# %% [markdown]
# ## second pass onwards

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# count = 0
# for x in range(0,len(_[0])):
#     if x == 0: continue
#     if _[0][x] != 0:
#         count = x
#         break

# %% [raw]
# count

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff = _[1][count]
# plt.axvline(x=cutoff)
# plt.show()

# %% [raw]
# print(cutoff)

# %% [raw]
# # Cleanup, prune any reads that don't pass the cutoff
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         toRemove = []
#         for z in cellbyUMI[UMI][y]:
#             if cellbyUMI[UMI][y][z] < cutoff: toRemove.append(z)
#         for z in toRemove:
#             del cellbyUMI[UMI][y][z]
#     toRemove = []
#     for y in cellbyUMI[UMI]:
#         if len(cellbyUMI[UMI][y]) == 0: toRemove.append(y)
#     for y in toRemove:
#         del cellbyUMI[UMI][y]
# toRemove = []
# for UMI in cellbyUMI:
#     if len(cellbyUMI[UMI]) == 0: toRemove.append(UMI)
# for UMI in toRemove:
#     del cellbyUMI[UMI]

# %% [raw]
# # second pass generate histogram of counts (ignore 1)
# histogram_of_counts = []
# for UMI in cellbyUMI:
#     for y in cellbyUMI[UMI]:
#         histogram_of_counts.extend(cellbyUMI[UMI][y].values())

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_counts, bins='doane', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# #cutoff = _[1][1]
# #plt.axvline(x=cutoff)
# plt.show()

# %% [markdown]
# ## end pass

# %%
## counting total UMIs from dominant shRNA
histogram_of_UMIs = []
assignedCellshRNA = {}
assignedCellbarcode = {}
poorUMI = []
poorUMI2 = []
count = []
threshold = cutoff

for x in cellbyUMI:
    ncellbyUMI = {}
    for y in cellbyUMI[x]:
        UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
        UMIpairs.sort(reverse=True)
        newUMI = []
        while len(UMIpairs) != 0:
            shRNAIDbarcodepair = UMIpairs.pop(0) #
            toDelete = []
            for z in range(0, len(UMIpairs)):
                if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
                if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
                    toDelete.append(z)
                    shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
            newUMI.append(shRNAIDbarcodepair)
            for z in sorted(toDelete, reverse = True):
                del UMIpairs[z]

        if len(newUMI) == 1:
        # uncomment here if we don't want to ignore single counts
            if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
            continue

        # Shouldn't happen anymore with the cleaned up version
        newUMI.sort(reverse=True)
  
        totalUMI = sum([z[0] for z in newUMI])
        if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
            ncellbyUMI[y] = newUMI[0][1]       
        else:
            print(newUMI)
        #### end
        
    UMIpairs = {}

    if len(ncellbyUMI) == 0: 
        print("is zero")
        continue            
            
#    if len(ncellbyUMI) == 1:
#        continue
        # uncomment here if we don't want to ignore UMIs assigned by single counts
        #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
        #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
        #count.append(1)

        #adding single UMIs to poorUMI list instead of assigning label
#        poorUMI.append([(1,ncellbyUMI)])
#        poorUMI2.append(x)
#        continue

    for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
        if ncellbyUMI[y] in UMIpairs:
            UMIpairs[ncellbyUMI[y]] += 1
        else:
            hamming=False
            for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
                if z[0] != ncellbyUMI[y][0]: continue
                if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
                    UMIpairs[z] += 1
                    hamming=True
                    break
            if hamming: continue
            UMIpairs[ncellbyUMI[y]] = 1
    histogram_of_UMIs.extend(UMIpairs.values())
    continue
    
    
    
#    if len(UMIpairs) == 0: 
#        print("UMIPairs")
#        print(ncellbyUMI)
#        print(cellbyUMI[x])
#        print("error this shoudl not happen")
#        continue

    if len(UMIpairs) == 1 and list(UMIpairs.values())[0] >= 5:
        assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
        assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
        count.append(list(UMIpairs.values())[0])
        continue        
    
    newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
    newUMI.sort()
    newUMI.reverse()
    totalUMI = sum([y[0] for y in newUMI])
    count.extend([z[0] for z in newUMI if z[0] >= 5])

#    set_trace()
    if newUMI[0][0] < 5: continue
    if len(newUMI) == 2: # newUMI = [(count, (shRNAID, barcode)), ...]
        if newUMI[0][0] - newUMI[1][0] >= 3 and newUMI[1][0] <= 3:
            assignedCellshRNA[x] = newUMI[0][1][0]
            assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.15:
        assignedCellshRNA[x] = newUMI[0][1][0]
        assignedCellbarcode[x] = newUMI[0][1][1]
        continue
    poorUMI.append(newUMI)
    poorUMI2.append(x)
# Out:
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(35, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(20, ('CAGTGCAT', 'GGGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('ACACGTGA', 'TTTTTAATTTTTTTTTTCGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# is zero
# [(18, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTCTTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('TCTGGGGC', 'TTGTTAATTTTTTTTGGGTAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('CAGTGCAT', 'GTGGAAATGATATTGGTAGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(32, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(28, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(33, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(21, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (32, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(37, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (32, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTCGAA')), (20, ('CCATTACT', 'CCCCCAACCACCTTCCGCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(34, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (32, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (29, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(33, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(25, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TCTGGGGC', 'TTGTTAATTTTTTTTGGGTAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AATAGAAGAAAGTTGAAAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(19, ('TTAATTAG', 'TCCTAAAATCCTTTCTATCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(32, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (19, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTACCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (23, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'CCCCCAAACCCCTTCCCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTGTATTGGTAGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCTAACCCCCTTCCACCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(28, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (22, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(25, ('TGTCTAGT', 'TTTTTAAGCTTTTTTGTTGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTGTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTGTTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(33, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'GTTTTAATTTTTTTTTTTAAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(30, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (24, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# [(27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CGGGAATG', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(31, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTGTTGAA')), (19, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'GGGGGAAGTGGGTTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCACCAA')), (18, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(35, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTACTCCAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (17, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA'))]
# [(18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('TGTCTAGT', 'GGGGTAAGGAGGTTGGGGGAA')), (18, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (18, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(31, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (26, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (24, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('GCCTACGT', 'TCTTTAAGTGGTTTGGTTCAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(20, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GTACTTGC', 'GTTAAAAGGAAATTGTACGAA'))]
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (19, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(27, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA'))]
# [(25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(22, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TTAATTAG', 'AAAAGAAGTAAGTTGAAAAAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# ...
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCTACGT', 'TCCTTAAGGGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (26, ('TGTCTAGT', 'GGGGGAATGGGGTTGGGGGAA')), (26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('TTAATTAG', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (25, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(24, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(21, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(20, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(36, ('TCTGGGGC', 'TTATGAATTTTTTTTTTGTAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'CCCCCAACCCCCTTACCCCAA'))]
# [(23, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA'))]
# is zero
# [(23, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('TGTCTAGT', 'TTTTTAATTTCTTTTTTTTAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('CTGAATCT', 'CCCCCAACCCCGTTCCCCCAA'))]
# [(24, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA'))]
# [(23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(33, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (25, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (24, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (24, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (20, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA')), (17, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA'))]
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(34, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('GCCTACGT', 'GGGGGAAGGGGGTTGGGGGAA')), (22, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA'))]
# [(20, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(24, ('CGGGAATG', 'TTTTGAATTTTTTTTTTTTAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# is zero
# [(32, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (28, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# is zero
# [(22, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (17, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (22, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(26, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (21, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA')), (19, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (18, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(20, ('CTGAATCT', 'CCCCCAAACCCATTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(25, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'CCCTCAACCGCCTTCCCCCAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (18, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (20, ('TTAATTAG', 'TTTTTAATATTTTTCTTTTAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(27, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(25, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(30, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (29, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('ACACGTGA', 'TTTAAAATTTTTTTGGATGAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# is zero
# [(31, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (22, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTCGAA')), (17, ('CTGAATCT', 'ACAACAAAAACCTTTAAACAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(30, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (27, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# [(18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# [(24, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (19, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# [(19, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# is zero
# [(25, ('CAGTGCAT', 'GTGGAAATTTTATTGTTAGAA')), (21, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA')), (19, ('CGGGAATG', 'AGCCCAACCCCCTTCCCCCAA')), (18, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(21, ('ACACGTGA', 'TGTTTAAGTTTTTTTTTTGAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA'))]
# is zero
# [(23, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# [(20, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# is zero
# [(36, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (30, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# [(34, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA'))]
# is zero
# [(29, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (27, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (26, ('GCCTACGT', 'GGGGGAAGGGGGTTAGGGGAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# is zero
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (18, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (17, ('GCCTACGT', 'AGGTGAACTGCGTTGGGAAAA')), (17, ('CGGGAATG', 'TTCTCAACGCCTTTTTCCCAA'))]
# [(31, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (29, ('CGGGAATG', 'CCCCCAACCTCCTTCCCCCAA')), (28, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (27, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (20, ('ACACGTGA', 'TTTTTAATTTTTTTTTTTTAA')), (19, ('TTAATTAG', 'AAAAGAAGAAAGTTGAAAAAA')), (18, ('TGTCTAGT', 'TATTTAATTTCTTTTGTTTAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# is zero
# [(22, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA')), (21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (20, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('TTAATTAG', 'TTTTAAATATTTTTCTTTTAA'))]
# [(24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CTGAATCT', 'CCCCCAACCCCTTTCCCCCAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# [(21, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('CGGGAATG', 'CCCCCAACCCCCTTCCGTCAA'))]
# [(23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGGGAAGGGGATTGGGGGAA'))]
# [(28, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (24, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA')), (21, ('TGTCTAGT', 'CCCCCAACCCCCTTCCTCCAA'))]
# is zero
# [(28, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('CGGGAATG', 'TTTTTAATTTTTTTTGTTTAA'))]
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (19, ('TGTCTAGT', 'GGGCGAAGGGGGTTGGGGGAA')), (17, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA'))]
# is zero
# [(26, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero
# [(21, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA')), (17, ('ACAGAGCC', 'GCTTTAATTTTGTTATTAAAA'))]
# is zero
# [(25, ('CGGGAATG', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('ACACGTGA', 'GGGGGAAGGGGGTTGTGGGAA'))]
# is zero
# [(20, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (19, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (18, ('TGTCTAGT', 'GGGGGAAGGGGGTTGGGGGAA'))]
# is zero
# [(27, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (18, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (17, ('GCCAATCG', 'CACATAAGAACCTTCATTGAA'))]
# is zero
# [(26, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (23, ('GCCTACGT', 'TCCTTAAGTGGTTTGGTTCAA')), (22, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA')), (21, ('TGTCTAGT', 'TTTTTAATTTCTTTGGTTTAA')), (21, ('CGTTCAAG', 'CTAATAACAACATTCTACAAA')), (17, ('TTAATTAG', 'TTTTTAATTTTTTTCTTTTAA'))]
# is zero
# [(32, ('TGTCTAGT', 'CCCCCAACCCCCTTCCCCCAA')), (24, ('CAGTGCAT', 'GTGGAAATTTTATTGGTAGAA'))]
# is zero

# %%
print(sum(histogram_of_UMIs))
# Out:
# 52006

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(histogram_of_UMIs, bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# #plt.axvline()
# plt.show()

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(histogram_of_UMIs), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# cutoff2 = 3
# plt.axvline(x=cutoff2)
# plt.show()

# %% [raw]
# cutoff2 = 2**cutoff2
# print(cutoff2)

# %% [raw]
# ## counting total UMIs from dominant shRNA
# assignedCellshRNA = {}
# assignedCellbarcode = {}
# poorUMI = []
# poorUMI2 = []
# count = []
# threshold = cutoff
#
# for x in cellbyUMI:
#     ncellbyUMI = {}
#     for y in cellbyUMI[x]:
#         UMIpairs = [(cellbyUMI[x][y][z],z) for z in cellbyUMI[x][y]] # stored as (count, (shRNAID,barcode))
#         UMIpairs.sort(reverse=True)
#         newUMI = []
#         while len(UMIpairs) != 0:
#             shRNAIDbarcodepair = UMIpairs.pop(0) #
#             toDelete = []
#             for z in range(0, len(UMIpairs)):
#                 if shRNAIDbarcodepair[1][0] != UMIpairs[z][1][0]: continue
#                 if hammingDistance(shRNAIDbarcodepair[1][1],UMIpairs[z][1][1]) <= 2:
#                     toDelete.append(z)
#                     shRNAIDbarcodepair = (shRNAIDbarcodepair[0]+UMIpairs[z][0],shRNAIDbarcodepair[1])
#             newUMI.append(shRNAIDbarcodepair)
#             for z in sorted(toDelete, reverse = True):
#                 del UMIpairs[z]
#
#         if len(newUMI) == 1:
#         # uncomment here if we don't want to ignore single counts
#             if newUMI[0][0] >= threshold: ncellbyUMI[y] = newUMI[0][1]
#             continue
#
#         # Shouldn't happen anymore with the cleaned up version
#         newUMI.sort(reverse=True)
#         if newUMI[0][0] < threshold: continue
#
#         totalUMI = sum([z[0] for z in newUMI])
#         if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.05:
#             ncellbyUMI[y] = newUMI[0][1]
#         else:
#             print("multiple: %s" % str(newUMI))
#         #### end
#
#     UMIpairs = {}
#
#     if len(ncellbyUMI) == 0:
#         print("is zero")
#         continue
#
# #    if len(ncellbyUMI) == 1:
# #        continue
#         # uncomment here if we don't want to ignore UMIs assigned by single counts
#         #assignedCellshRNA[x] = list(ncellbyUMI.values())[0][0]
#         #assignedCellbarcode[x] = list(ncellbyUMI.values())[0][1]
#         #count.append(1)
#
#         #adding single UMIs to poorUMI list instead of assigning label
# #        poorUMI.append([(1,ncellbyUMI)])
# #        poorUMI2.append(x)
# #        continue
#
#     for y in ncellbyUMI:   #ncellbyUMI[UMI] = (shRNAID, barcode)
#         if ncellbyUMI[y] in UMIpairs:
#             UMIpairs[ncellbyUMI[y]] += 1
#         else:
#             hamming=False
#             for z in UMIpairs:  #instead of assigning this randomly I could order it by number of highest read counts
#                 if z[0] != ncellbyUMI[y][0]: continue
#                 if hammingDistance(ncellbyUMI[y][1], z[1]) <= 2:
#                     UMIpairs[z] += 1
#                     hamming=True
#                     break
#             if hamming: continue
#             UMIpairs[ncellbyUMI[y]] = 1
#
# #    if len(UMIpairs) == 0:
# #        print("UMIPairs")
# #        print(ncellbyUMI)
# #        print(cellbyUMI[x])
# #        print("error this shoudl not happen")
# #        continue
#
#     if len(UMIpairs) == 1:
#         if list(UMIpairs.values())[0] < cutoff2:
#             #print("Didn't pass cutoff2: %d, %s" % (cutoff2, str(UMIpairs)))
#             continue
#         assignedCellshRNA[x] = list(UMIpairs.keys())[0][0]
#         assignedCellbarcode[x] = list(UMIpairs.keys())[0][1]
#         count.append(list(UMIpairs.values())[0])
#         continue
#
#     newUMI = [(UMIpairs[y], y) for y in UMIpairs]  # UMIpairs[(shRNAID, barcode)] = count
#     newUMI.sort(reverse=True)
#     if newUMI[0][0] < cutoff2: continue
#
#     totalUMI = sum([y[0] for y in newUMI])
#     count.extend([z[0] for z in newUMI])
#
#     if scipy.stats.binom_test(newUMI[0][0], totalUMI, 1/len(newUMI), alternative='greater') <= 0.10:
#         assignedCellshRNA[x] = newUMI[0][1][0]
#         assignedCellbarcode[x] = newUMI[0][1][1]
#         continue
#     else:
#         set_trace()
#     poorUMI.append(newUMI)
#     poorUMI2.append(x)

# %% [raw]
# import statistics
# sum(count)/len(count), min(count), max(count), statistics.median(count)

# %% [raw]
# # should only be shRNA per UMI
# print("By UMI/Cell")
# _ = plt.hist(np.log2(count), bins='auto', histtype='step')
# plt.ylabel("Count")
# plt.title("# Reads for each UMIs")
# plt.show()

# %% [raw]
# len(assignedCellshRNA)

# %% [raw]
# len(whitelist)

# %% [raw]
# #count.sort()
# #count

# %% [raw]
# len(poorUMI)

# %% [raw]
# poorUMI

# %% [raw]
# #calculate average hammandDistance
# hdist = []
# for x in poorUMI:
#     if len(x) == 1:
# #        hdist.append(0)
#         continue
#     y = [(z[1][0], z[1][1]) for z in x]
#     pUMI = {}
#     for z in y:
#         if z[0] not in pUMI:
#             pUMI[z[0]] = [z[1]]
#         else:
#             pUMI[z[0]].append(z[1])
#     for y in pUMI:
#         if len(pUMI[y]) < 2:
#             continue
#         for i in range(0, len(pUMI[y])):
#             for j in range(i+1, len(pUMI[y])):
#                 hdist.append(hammingDistance(pUMI[y][i], pUMI[y][j]))
#                 if hammingDistance(pUMI[y][i], pUMI[y][j]) == 2:
#                     print(pUMI[y])
#                     print(pUMI[y][i], pUMI[y][j])

# %% [raw]
# _ = plt.hist(hdist, bins='auto', histtype='step')
#
# plt.ylabel("Counts")
# plt.show()

# %% [raw]
# #assign shRNA to barcodes with same shRNA virus
# for x in range(len(poorUMI)):
#     y = [z[1][0] for z in poorUMI[x]]
#     if len(set(y)) == 1:
#         assignedCellshRNA[poorUMI2[x]] = y[0]
#         assignedCellbarcode[poorUMI2[x]] = "NA"

# %% [raw]
# validshRNANameHash = {}
# for x in assignedCellshRNA:
#     validshRNANameHash[x] = hashes[assignedCellshRNA[x]]

# %% [raw]
# len(assignedCellbarcode)

# %% [raw]
# import pandas as pd
# pUMI = {}
# for x in poorUMI2:
#     pUMI[x] = 1
# cellhashobj = pd.DataFrame.from_dict(pUMI, orient='index')
# cellhashobj.rename(columns={0: "pUMI"}, inplace=True)
# cellhashobj.to_pickle('pUMIcDNA.pickle')

# %% [raw]
# import pandas as pd
#
# cellhashobj = pd.DataFrame.from_dict(validshRNANameHash, orient='index')
# cellhashobj.rename(columns={0: "shRNA"}, inplace=True)
# cellhashobj.to_pickle('shRNAcDNA.pickle')
#
# cellhashobj = pd.DataFrame.from_dict(assignedCellbarcode, orient='index')
# cellhashobj.rename(columns={0: "barcode"}, inplace=True)
# cellhashobj.to_pickle('barcodecDNA.pickle')

# %% [markdown]
# ## END CODE HERE FOR NOW
